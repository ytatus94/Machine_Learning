# %% [markdown]
# # Yu-Ting Shen
#
# # RiskGenius Challenge Project
#
#
# https://www.irmi.com/glossary
#
# https://scrapy.org/
#
# The IRMI link points to a site with definitions of insurance terms.
# The Scrapy link is to a library which can extract data from websites.
#
# The idea of this project is in 3 parts:
#
# 1. Scrape and store the IRMI glossary into some data format (maybe SQLite, or .json or something).  Be sure to have at least the definition label and definition text.  Other data might be unnecessary.
#
# 2. Build a classifier (you can choose the model) and optimize hyperparameters to predict the definition label from the definition text.
#
# 3. Predict the word that will be in the definition label, instead of the label itself.  Possibly predict the count vector of the definition label in this case.
#
# This could have a real application in RiskGenius, as a step toward automatically generating definition labels by predicting the words that would be used in definition labels.  You are likely to find in many cases, words in the definition label cannot be found in the definition text, so keep that in mind.
#
# ***
# ***
# ***

# %% [markdown]
# # Load Data

# %%
import pandas as pd

df_insurance_terms = pd.read_csv('terms.csv')
# df_insurance_terms.head()
df = df_insurance_terms[['term', 'text']]
df.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...

# %% [markdown]
# # Normalize

# %%
df_cnt = df.copy()

from nltk.stem import WordNetLemmatizer
stemmer = WordNetLemmatizer()

import re

def normalize_string(string):
    '''
    normalize original string:
    1. remove punctuation
    2. use lower case
    3. lemmatize
    '''
    # Remove punctuation
    string = re.sub('[<(!?).,*->]', ' ', string)
    # Convert to lower case
    string = string.lower()
    # Lemmatization
    string = [stemmer.lemmatize(word) for word in string.split()]
    # joint list
    return ' '.join(string)

df_cnt['norm_term'] = df_cnt['term'].apply(lambda x: normalize_string(x))
df_cnt['norm_text'] = df_cnt['text'].apply(lambda x: normalize_string(x))

df_cnt.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text  \
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...
#
#                               norm_term  \
# 0                automatic premium loan
# 1  household good transportation act of
# 2                           hydrocarbon
# 3         hydraulic fracturing fracking
# 4                           hybrid plan
#
#                                            norm_text
# 0  an optional provision in life insurance that a...
# 1  provided a nonjudicial dispute settlement prog...
# 2  a class of organic compound composed only of c...
# 3  a process in which fracture in hard to reach s...
# 4  risk financing technique that are a combinatio...

# %% [markdown]
# # CountVectorize

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

cnt_vect_text = CountVectorizer(stop_words=stopwords.words('english'))
cnt_vect_term = CountVectorizer(stop_words=stopwords.words('english'))

X = cnt_vect_text.fit_transform(df_cnt['norm_text'])
y = cnt_vect_term.fit_transform(df_cnt['norm_term'])

# %%
X_dense = X.todense()
y_dense = y.todense()

X_arr = X.toarray()
y_arr = y.toarray()

# %%
print(X_dense.shape, y_dense.shape, X_arr.shape, y_arr.shape)
# Out:
# (3261, 7400) (3261, 2716) (3261, 7400) (3261, 2716)

# %%
text_features = cnt_vect_text.get_feature_names()
term_features = cnt_vect_term.get_feature_names()

print('text features: \n', text_features)
print('term features: \n', term_features)
# Out:
# text features:
#  ['aais', 'ab', 'abandoned', 'abandoning', 'abatement', 'abbreviated', 'abbreviation', 'abc', 'abide', 'ability', 'able', 'abnormal', 'aboard', 'abolished', 'abolishment', 'abrading', 'abridge', 'abroad', 'absconding', 'absence', 'absent', 'absolute', 'absolutely', 'absolve', 'absolved', 'absorb', 'absorbed', 'absorber', 'absorption', 'abstention', 'abuse', 'aca', 'acc', 'acca', 'accelerated', 'acceleration', 'accept', 'acceptability', 'acceptable', 'acceptance', 'accepted', 'accepting', 'accepts', 'access', 'accessible', 'accessing', 'accessory', 'accident', 'accidental', 'accidentally', 'accommodate', 'accommodation', 'accompanied', 'accompanying', 'accomplish', 'accomplished', 'accord', 'accordance', 'according', 'accordingly', 'account', 'accountability', 'accountable', 'accountant', 'accounted', 'accounting', 'accreditation', 'accredited', 'accredits', 'accrual', 'accrue', 'accrued', 'accrues', 'accruing', 'accumulate', 'accumulated', 'accumulates', 'accumulation', 'accuracy', 'accurate', 'accurately', 'accusation', 'accused', 'ace', 'achievable', 'achieve', 'achieved', 'achievement', 'achieves', 'achieving', 'acid', 'acii', 'acknowledge', 'acknowledges', 'aclu', 'acm', 'acquire', 'acquired', 'acquires', 'acquiring', 'acquisition', 'acre', 'acronym', 'across', 'acsc', 'act', 'acted', 'acting', 'actinolite', 'action', 'activate', 'activated', 'activates', 'activating', 'active', 'actively', 'activist', 'activity', 'actual', 'actually', 'actuarial', 'actuarially', 'actuary', 'acute', 'acutely', 'acv', 'ada', 'adapted', 'add', 'added', 'addendum', 'addiction', 'addictive', 'adding', 'addition', 'additional', 'additionally', 'address', 'addressed', 'addressing', 'adea', 'adept', 'adequacy', 'adequate', 'adequately', 'adhere', 'adhered', 'adhering', 'adhesion', 'adhesive', 'adjacent', 'adjoining', 'adjudicate', 'adjudicated', 'adjudicating', 'adjudication', 'adjunct', 'adjust', 'adjustable', 'adjusted', 'adjuster', 'adjusting', 'adjustment', 'adjusts', 'administer', 'administered', 'administering', 'administers', 'administration', 'administrative', 'administrator', 'admissibility', 'admission', 'admit', 'admits', 'admitted', 'admittedly', 'admitting', 'adopt', 'adopted', 'adoption', 'adr', 'adult', 'advance', 'advanced', 'advancement', 'advancing', 'advantage', 'advantageous', 'advent', 'adversarial', 'adverse', 'adversely', 'advertisement', 'advertising', 'advice', 'advise', 'adviser', 'advises', 'advising', 'advisor', 'advisory', 'advocate', 'aei', 'aeration', 'aerial', 'affair', 'affect', 'affected', 'affecting', 'affiant', 'affidavit', 'affiliate', 'affiliated', 'affiliation', 'affirmation', 'affirmative', 'affirmatively', 'affixed', 'afford', 'affordable', 'affordably', 'afforded', 'affording', 'affords', 'afis', 'aforementioned', 'aftermarket', 'agc', 'age', 'aged', 'agency', 'agent', 'aggravation', 'aggregate', 'aggregated', 'aggregation', 'aggressive', 'aggrieved', 'ago', 'agree', 'agreed', 'agreeing', 'agreement', 'agrees', 'agribusiness', 'agricultural', 'agriculture', 'ai', 'aia', 'aicpa', 'aicpcu', 'aid', 'aiding', 'aig', 'aim', 'aimed', 'aiming', 'aimu', 'air', 'airborne', 'aircraft', 'airline', 'airplane', 'airport', 'airspace', 'airstream', 'aisg', 'ala', 'alaes', 'alarm', 'alaska', 'alaskan', 'albeit', 'alcohol', 'alcoholic', 'ale', 'aleatory', 'alert', 'alerted', 'alien', 'alienated', 'aligning', 'alignment', 'alive', 'alkali', 'allegation', 'allege', 'alleged', 'allegedly', 'alleges', 'alleging', 'alleviates', 'alleviating', 'allied', 'allocable', 'allocate', 'allocated', 'allocating', 'allocation', 'allow', 'allowable', 'allowance', 'allowed', 'allowing', 'allows', 'ally', 'almost', 'alone', 'along', 'alongside', 'alop', 'alphabetic', 'already', 'also', 'alter', 'alteration', 'altered', 'altering', 'alternate', 'alternative', 'alternatively', 'alters', 'although', 'altogether', 'always', 'ambient', 'ambiguity', 'ambiguous', 'ambulance', 'ambulatory', 'amenable', 'amend', 'amendatory', 'amended', 'amending',  ...
# term features:
#  ['aai', 'aais', 'aam', 'ab', 'abandonment', 'abatement', 'ability', 'absolute', 'absorbed', 'abuse', 'acc', 'acceleration', 'accept', 'acceptance', 'accepted', 'access', 'accident', 'accidental', 'accommodation', 'accordance', 'account', 'accountability', 'accountant', 'accounting', 'accreditation', 'accredited', 'accumulation', 'achievable', 'acii', 'acla', 'acls', 'acm', 'acquired', 'acquisition', 'act', 'action', 'activity', 'actual', 'actuarial', 'actuary', 'acute', 'acv', 'ad', 'ada', 'adaaa', 'add', 'added', 'addition', 'additional', 'adea', 'adequacy', 'adhesion', 'adjustable', 'adjusted', 'adjuster', 'adjustment', 'administration', 'administrative', 'administrator', 'admiralty', 'admitted', 'adr', 'advance', 'advanced', 'advancement', 'adverse', 'advertisement', 'advertising', 'advice', 'advised', 'adviser', 'advisory', 'aerobic', 'affiant', 'affidavit', 'affiliated', 'affinity', 'affirmative', 'affordable', 'afis', 'afsb', 'afterburner', 'aftermarket', 'agc', 'age', 'agency', 'agent', 'aggravation', 'aggregate', 'agreed', 'agreement', 'agribusiness', 'agricultural', 'ai', 'aia', 'aiaf', 'aic', 'aicpa', 'aicpcu', 'aim', 'air', 'airborne', 'aircraft', 'airport', 'ait', 'ala', 'alcm', 'ale', 'aleatory', 'alien', 'alienated', 'allegation', 'allied', 'allocated', 'allocation', 'allowance', 'alone', 'along', 'alongside', 'alteration', 'alternate', 'alternative', 'amendment', 'amerco', 'america', 'american', 'amim', 'amortization', 'amount', 'analysis', 'analytic', 'analytics', 'animal', 'anniversary', 'annual', 'annuitant', 'annuity', 'answer', 'anti', 'antitheft', 'antitrust', 'antwerp', 'apa', 'api', 'apparent', 'appeal', 'appear', 'appetite', 'application', 'apportionment', 'appraisal', 'appraiser', 'approach', 'appropriation', 'approval', 'appurtenant', 'ar', 'arbitration', 'architect', 'area', 'arm', 'around', 'arp', 'arrest', 'art', 'article', 'asbestos', 'aside', 'asli', 'aso', 'assault', 'assessment', 'asset', 'assigned', 'assignee', 'assignment', 'assistance', 'associate', 'associated', 'associateship', 'association', 'associational', 'assume', 'assumed', 'assumption', 'assurance', 'ata', 'atima', 'atla', 'attachment', 'attack', 'attained', 'attorney', 'attractive', 'attribution', 'au', 'auction', 'audit', 'auditing', 'authentication', 'authority', 'authorized', 'auto', 'automatic', 'automation', 'automobile', 'autonomous', 'available', 'average', 'aviation', 'avoidance', 'aww', 'back', 'backdated', 'backdating', 'backed', 'bacm', 'bad', 'bailee', 'balance', 'ban', 'bancassurance', 'bank', 'banker', 'banking', 'bankruptcy', 'bap', 'bare', 'bareboat', 'barratry', 'base', 'based', 'basel', 'basic', 'basis', 'basket', 'batch', 'bcar', 'bcegs', 'bcm', 'bcp', 'bdat', 'beauty', 'ben', 'bench', 'benchmarking', 'beneficiary', 'benefit', 'berp', 'best', 'beta', 'betterment', 'bfcgl', 'bfpd', 'bi', 'bias', 'bid', 'bidding', 'bifurcation', 'bilateral', 'bill', 'billing', 'bim', 'binder', 'binding', 'bingo', 'biological', 'biomechanical', 'bioremediation', 'bipartisan', 'bite', 'black', 'blackout', 'blank', 'blanket', 'blended', 'bliley', 'block', 'blockchain', 'blowout', 'blue', 'board', 'boatowners', 'bobtail', 'bodily', 'boiler', 'boilerplate', 'bomb', 'bond', 'bonding', 'book', 'boom', 'bop', 'bordereau', 'borderline', 'bornhuetter', 'borrowed', 'boutique', 'box', 'bpl', 'bpli', 'branch', 'brand', 'breach', 'break', 'breakdown', 'brigade', 'broad', 'broadcaster', 'broker', 'brokerage', 'brother', 'brownfield', 'brownian', 'browse', 'btr', 'budget', 'buffer', 'bug', 'build', 'builder', 'building', 'bulk', 'bullying', 'bumbershoot', 'burden', 'bureau', 'burglary', 'burning', 'business', 'businessowners', 'buy', 'buyback', 'buyer', 'buyout', 'bystander', 'caa', 'cable', 'cac', 'calendar', 'call', 'called', 'camera', 'campaign', 'cancel', 'cancelable', 'cancellation', 'candidate', 'canine', 'cap', 'capacity', 'capital', 'capitated', 'capm', 'captain', 'captive', 'capture', 'caput', 'car', 'card', 'care', 'career', 'carfra', ' ...

# %% [markdown]
# # Try Neural Network model

# %%
from sklearn.neural_network import MLPRegressor

nn = MLPRegressor()
nn.fit(X_arr, y_arr)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
# from nltk import sent_tokenize

# data = 'The history of natural language processing generally started in the 1950s, although work can be found from earlier periods. In 1950, Alan Turing published an article titled "Intelligence" which proposed what is now called the Turing test as a criterion of intelligence. The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem.[2] However, real progress was much slower, and after the ALPAC report in 1966, which found that ten-year-long research had failed to fulfill the expectations, funding for machine translation was dramatically reduced. Little further research in machine translation was conducted until the late 1980s, when the first statistical machine translation systems were developed. Some notably successful natural language processing systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapist, written by Joseph Weizenbaum between 1964 and 1966. Using almost no information about human thought or emotion, ELIZA sometimes provided a startlingly human-like interaction. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?". During the 1970s, many programmers began to write "conceptual ontologies", which structured real-world information into computer-understandable data. Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981). During this time, many chatterbots were written including PARRY, Racter, and Jabberwacky.'
# sentences = sent_tokenize(data)
# print(sentences)
# print(len(sentences))

# %%
# pred = nn.predict(cnt_vect_text.transform(['This is a book', 'This is a pencil', 'I am an idiot']))

# pred

# %%
def words_in_label(input_string, threshold=0.05,
                   regressor=nn,
                   def_vectorizer=cnt_vect_text,
                   label_vectorizer=cnt_vect_term):
    
    vector = def_vectorizer.transform([input_string])
    preds = regressor.predict(vector)
    
    probabilities = [preds[0, n] for n in range(preds.shape[1])]
    labels = label_vectorizer.get_feature_names()
    
    labels_with_probabilities = zip(labels, probabilities)
    
    possible_labels = {}
    for label, prob in labels_with_probabilities:
        if prob > threshold:
            print('{0}: \t {1:.4f}'.format(label, prob))
            possible_labels[label]=prob
    return possible_labels

# %% [markdown]
# Use the following to test:
# * term = automatic premium loan
# * text = An optional provision in life insurance that authorizes the insurer to pay from the cash value any premium due at the end of the grace period  This provision is useful in preventing inadvertent lapse of the policy

# %%
data = 'An optional provision in life insurance that authorizes the insurer to pay from the cash value any premium due at the end of the grace period  This provision is useful in preventing inadvertent lapse of the policy'

possible_labels = words_in_label(data, 0.05)
print(possible_labels)

print(sorted(possible_labels, key=lambda x: x[1], reverse=True))
highest_probability_term = sorted(possible_labels, key=lambda x: x[1], reverse=True)[0]
print(highest_probability_term)
# Out:
# coverage: 	 0.0509
# insurance: 	 0.0562
# premium: 	 0.0639
# provision: 	 0.0520
# {'coverage': 0.05094763504555058, 'insurance': 0.05620772550689963, 'premium': 0.06385063337150998, 'provision': 0.05199933267837055}
# ['premium', 'provision', 'coverage', 'insurance']
# premium

# %% [markdown]
# **Why insurance is the last one after sorting?**

# %%
all_terms = [term for term in df['term']]
print(all_terms)
# Out:
# ['automatic premium loan', 'Household Goods Transportation Act of 1980', 'hydrocarbons', 'hydraulic fracturing (fracking)', 'hybrid plans', 'hybrid captive', 'hurdle rate', 'hybrid', 'job safety analysis (JSA)', 'improvements and betterments', 'implied warranty', 'implied authority', 'implead', 'impairment capital', 'incorporation doctrine', 'incontestable clause', 'incident reporting provision', 'management advisory services', 'managed care organization (MCO)', 'manufacturers penalty insurance', 'managed care liability insurance', 'managed care coverage endorsement', 'managed care', 'malware', 'manufacturers output policy (MOP)', 'market value clause', 'matching deductible', 'master service agreement (MSA)', 'master policy', 'masonry noncombustible construction (ISO)', 'medical malpractice insurance', 'market value', 'maximum possible loss (MPL)', 'medical malpractice  caps ', 'Migrant and Seasonal Agricultural Worker Protection Act (MSAWPA) of 1983', 'Medical Injury Compensation Reform Act (MICRA) of 1975', 'medical fee schedule', 'Medicaid', 'insurance requirements', 'Insurance Regulatory Information System (IRIS)', 'insurance policy', 'mill construction', 'model', 'mixed-motive evidentiary standard (in employment discrimination cases)', 'misstatement of age provision', 'mobile home policy', 'mobile equipment', 'mix of services', 'misrepresentation', 'multi-period excess earnings (MPEE) method', 'mutual additional insured status', 'mutual company', 'mutual benefit association', 'multiple trigger insurance contracts', 'moonlighting coverage', 'multiple protection insurance', 'expropriation', 'multiplied damages', 'extra premium', 'extra percentage tables', 'extracontractual obligations (ECO)', 'extracontractual damages', 'extremely hazardous substances', 'extraterritorial coverage', ' extrinsic facts  test', 'probable maximum loss (PML)', 'probability of ruin', 'probability analysis', 'privileged communication', 'probability', 'profit sharing plan', 'privity of contract', 'contract repudiation indemnity', 'products tampering insurance', 'profit commission', 'property transfer liability insurance', 'property insurance', 'property damage (PD)', 'Property Claim Law Specialist (PCLS)', 'pro rata', 'proportional reinsurance', 'proportional liability', 'proration', 'prospective rating', 'prospective aggregates', 'provisional notice of cancellation (PNOC)', 'protective safeguards endorsement', 'protective professional indemnity insurance', 'Public Company Accounting Oversight Board (PCAOB)', 'purchasing group', 'punitive damages', 'cyberspace liability', 'putting in expenses', 'public officials bond', 'public officials liability', 'pure captive', 'public officials liability insurance', 'publicly held corporation', 'putative class action', 'cut through endorsement', 'cyber and privacy insurance', 'cyberextortion', 'cyberextortion coverage', 'custom bond', 'cut through clause', 'customer s auto', 'cutoff', 'pure endowment', 'current disbursement', 'current service benefit', 'Cumis counsel', 'purpose not designated exclusion  aircraft', 'cumulative injury', 'cumulative collusive excess cover', 'pure loss cost', 'pure risk', 'pure claims-made policy', 'public policy exception', 'cross purchase', 'cross-liability endorsement', 'cross-defendant', 'cross-liability coverage', 'cross-indemnity agreement', 'public private partnership', 'Public Risk Management Association (PRIMA)', 'publishers liability', 'crowdfunding', 'public or livery conveyance use', 'cross-complaint', 'crop-hail insurance', 'cross-complainant', 'critical recommendation', 'public liability insurance', 'Public Law 15 (McCarran Act)', 'criticism', 'public employee dishonesty coverage', 'crisis management plan', 'public easement', 'criteria pollutant', 'crisis', 'crisis management coverage', 'crisis management approach', 'public adjuster', 'credit wrap', 'proximate cause', 'credit risk', 'credit report', 'credit life insurance', 'credit insurance', 'credit for reinsurance', ...

# %%
for term in all_terms:
    tokens = term.split()
    for token in tokens:
        if token in highest_probability_term:
            print(term)
# Out:
# automatic premium loan
# extra premium
# premium tax
# premium reserve
# premium prepayment
# premium payment plan
# premium notice
# premium discount
# premium loan
# premium capacity
# premium audit
# premium  advance
# premium
# exportability of premium risk
# excess loss premium (ELP) factor
# modified premium
# minimum premium
# fractional premium
# nonsubject premium
# estimated premium
# direct written premium
# original gross premium (OGP)
# maximum premium
# net level premium
# net written premium
# in rem endorsement
# initial premium
# guaranteed cost premium
# deposit premium
# gross written premium (GWP)
# gross premium
# manual premium
# earned reinsurance premium
# basic premium
# earned premium
# basic premium factor
# base premium
# standard premium
# written premium
# return premium
# return of premium (or cash value)
# single premium insurance
# waiver of premium
# unearned premium reserve (UPR)
# unearned reinsurance premium
# reinsurance premium
# vanishing premium
# reinstatement premium
