# %% [markdown]
# # Yu-Ting Shen
#
# # RiskGenius Challenge Project
#
#
# https://www.irmi.com/glossary
#
# https://scrapy.org/
#
# The IRMI link points to a site with definitions of insurance terms.
# The Scrapy link is to a library which can extract data from websites.
#
# The idea of this project is in 3 parts:
#
# 1. Scrape and store the IRMI glossary into some data format (maybe SQLite, or .json or something).  Be sure to have at least the definition label and definition text.  Other data might be unnecessary.
#
# 2. Build a classifier (you can choose the model) and optimize hyperparameters to predict the definition label from the definition text.
#
# 3. Predict the word that will be in the definition label, instead of the label itself.  Possibly predict the count vector of the definition label in this case.
#
# This could have a real application in RiskGenius, as a step toward automatically generating definition labels by predicting the words that would be used in definition labels.  You are likely to find in many cases, words in the definition label cannot be found in the definition text, so keep that in mind.
#
# ***
# ***
# ***

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df_insurance_terms = pd.read_csv('terms.csv')
df_insurance_terms.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text synonym
# 0  An optional provision in life insurance that a...     NaN
# 1  Provided a nonjudicial dispute settlement prog...     NaN
# 2  A class of organic compounds composed only of ...     NaN
# 3  A process in which fractures in hard-to-reach ...     NaN
# 4  Risk financing techniques that are a combinati...     NaN

# %%
df_insurance_terms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3261 entries, 0 to 3260
# Data columns (total 3 columns):
# term       3261 non-null object
# text       3261 non-null object
# synonym    18 non-null object
# dtypes: object(3)
# memory usage: 76.5+ KB

# %% [markdown]
# Most of the **synonym** are **NaN**, but there are 18 recorders not NaN.
#
# List these 18 recorders.

# %%
df_insurance_terms[df_insurance_terms['synonym'].notnull()]
# Out:
#                                           term  \
# 215                   cost of hire endorsement
# 273                      product disparagement
# 314                            primary insurer
# 323                   preservation of property
# 578           excess of loss ratio reinsurance
# 584                            fronted captive
# 593                             policy reserve
# 769             interrelated claims provisions
# 796                             buyers  market
# 866                   inter-insurance exchange
# 963                loan participation coverage
# 1206                                 line slip
# 1348                         passive retention
# 1616  manufacturer s selling price endorsement
# 1714               off-premises power coverage
# 1732         chronological stabilization plans
# 2101                              base premium
# 2337        asbestos-containing material (ACM)
#
#                                                    text  \
# 215   A contractors equipment coverage endorsement t...
# 273   A standard peril covered under a media profess...
# 314   A transaction in which one party  the  reinsur...
# 323   An ocean and inland marine insurance provision...
# 578   A form of reinsurance also known as  aggregate...
# 584   A special-purpose insurer that operates only o...
# 593   That portion of the policy premium that has no...
# 769   Provisions within professional liability insur...
# 796   One side of the market cycle that is character...
# 866   An unincorporated group of individuals or orga...
# 963   A provision of the SAA Financial Institution B...
# 1206  The piece of paper containing all the pertinen...
# 1348  A risk financing term referring to retention o...
# 1616  A property insurance provision or endorsement ...
# 1714  Coverage for loss due to lack of incoming elec...
# 1732  Financing risk in such a way that the financia...
# 2101  In conjunction with retrospective rating  the ...
# 2337  Friable asbestos material or nonfriable asbest...
#
#                                      synonym
# 215    Rental cost reimbursement endorsement
# 273                              Trade libel
# 314                              Reinsurance
# 323                     Sue and labor clause
# 578                                Stop loss
# 584                      Reinsurance captive
# 593                         Unearned premium
# 769                Related claims provisions
# 796                              Soft market
# 866                       Reciprocal company
# 963            Securities insuring agreement
# 1206                                    Slip
# 1348                     Unplanned retention
# 1616     Selling price clause or endorsement
# 1714   Utility service interruption coverage
# 1732                          Risk smoothing
# 2101                         Subject premium
# 2337  Regulated asbestos-containing material

# %% [markdown]
# ## Convert into SQL
#
# * Using SQLite

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///insurance_terms.sqlite', echo=False)
df_insurance_terms.to_sql('insurance_terms', con=engine)

# %% [markdown]
# * Load the SQL file to check

# %%
engine2 = create_engine('sqlite:///insurance_terms.sqlite')
table_names = engine2.table_names()
print(table_names)

sql_command = 'SELECT * FROM ' + table_names[0]
print(sql_command)

con = engine2.connect()
rs = con.execute(sql_command)
df_test_sql = pd.DataFrame(rs.fetchall())
df_test_sql.head()
# Out:
# ['insurance_terms']
# SELECT * FROM insurance_terms
#    0                                           1  \
# 0  0                      automatic premium loan
# 1  1  Household Goods Transportation Act of 1980
# 2  2                                hydrocarbons
# 3  3             hydraulic fracturing (fracking)
# 4  4                                hybrid plans
#
#                                                    2     3
# 0  An optional provision in life insurance that a...  None
# 1  Provided a nonjudicial dispute settlement prog...  None
# 2  A class of organic compounds composed only of ...  None
# 3  A process in which fractures in hard-to-reach ...  None
# 4  Risk financing techniques that are a combinati...  None

# %%
df_test_sql.columns=['index', 'term', 'text', 'synonym']
df_test_sql_2 = df_test_sql.drop(['index'], axis=1)
df_test_sql_2.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text synonym
# 0  An optional provision in life insurance that a...    None
# 1  Provided a nonjudicial dispute settlement prog...    None
# 2  A class of organic compounds composed only of ...    None
# 3  A process in which fractures in hard-to-reach ...    None
# 4  Risk financing techniques that are a combinati...    None

# %%
# df_test_sql.drop(['index'], axis=1).equals(df_insurance_terms)
df_test_sql_2.equals(df_insurance_terms)
# Out:
# True

# %% [markdown]
# ## Convert into JSON format
#
# * From CSV to JSON

# %%
import json
import numpy as np

fout = open('insurance_terms.json', 'w')

with open('terms.csv', 'r') as fin:
    for line in fin:
        split_line = line.rstrip().split(',')
        if len(split_line) == 3:
#             term = split_line[0]
#             text = split_line[1]
#             synonym = split_line[2]
       
#             print(term)
#             print(text)
#             print(synonym)
#             print('\n')
            
            d = {}
            d['term'] = split_line[0]
            d['text'] = split_line[1]
            d['synonym'] = split_line[2]
            
            if d['term'] == 'term':
                    continue
                    
#             if d['synonym'] == '':
#                 print(d['synonym'])
#                 d['synonym'] = np.nan
            
#             print(json_dict)
            json_dict = json.dumps(d)
            fout.write(json_dict)
            fout.write('\n')
    
fout.close()

# %% [markdown]
# * Load JSON to check

# %%
df_test_json = pd.read_json('insurance_terms.json', orient='columns', lines=True)
df_test_json.head()
# Out:
#   synonym                                        term  \
# 0                              automatic premium loan
# 1          Household Goods Transportation Act of 1980
# 2                                        hydrocarbons
# 3                     hydraulic fracturing (fracking)
# 4                                        hybrid plans
#
#                                                 text
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...

# %%
len(df_test_json)
# Out:
# 3261

# %%
cols = ['term', 'text', 'synonym']
df_test_json2 = df_test_json[cols].reset_index(drop=True)
df_test_json2.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text synonym
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...

# %%
len(df_test_json2)
# Out:
# 3261

# %%
df_test_json2.equals(df_insurance_terms)
# Out:
# False

# %% [markdown]
# Above is False because synonym is None in `df_insurance_terms` and is empty in `df_test_json2`. Let's compare term and text columns only.

# %%
df_test_json2.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text synonym
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...

# %%
df_insurance_terms.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text synonym
# 0  An optional provision in life insurance that a...     NaN
# 1  Provided a nonjudicial dispute settlement prog...     NaN
# 2  A class of organic compounds composed only of ...     NaN
# 3  A process in which fractures in hard-to-reach ...     NaN
# 4  Risk financing techniques that are a combinati...     NaN

# %%
df_test_json3 = df_test_json2[['term', 'text']]
df_test_json3.equals(df_insurance_terms[['term', 'text']])
# Out:
# True

# %%
df_test_json3.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...

# %%
len(df_test_json3), len(df_insurance_terms)
# Out:
# (3261, 3261)

# %% [markdown]
# * From pandas dataframe to JSON

# %%
df_insurance_terms.to_json(path_or_buf='insurance_terms_2.json', orient='index')

# %%
df_test_json4 = pd.read_json('insurance_terms_2.json', orient='index')
df_test_json4.head()
# Out:
#   synonym                                        term  \
# 0    None                      automatic premium loan
# 1    None  Household Goods Transportation Act of 1980
# 2    None                                hydrocarbons
# 3    None             hydraulic fracturing (fracking)
# 4    None                                hybrid plans
#
#                                                 text
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...

# %%
df_test_json4 = df_test_json4[cols]
df_test_json4.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text synonym
# 0  An optional provision in life insurance that a...    None
# 1  Provided a nonjudicial dispute settlement prog...    None
# 2  A class of organic compounds composed only of ...    None
# 3  A process in which fractures in hard-to-reach ...    None
# 4  Risk financing techniques that are a combinati...    None

# %%
df_test_json4.equals(df_insurance_terms)
# Out:
# True

# %% [markdown]
# ## Only keep term and text for the analysis

# %%
df_insurance_terms_2 = df_insurance_terms[['term', 'text']]
df_insurance_terms_2.head()
# Out:
#                                          term  \
# 0                      automatic premium loan
# 1  Household Goods Transportation Act of 1980
# 2                                hydrocarbons
# 3             hydraulic fracturing (fracking)
# 4                                hybrid plans
#
#                                                 text
# 0  An optional provision in life insurance that a...
# 1  Provided a nonjudicial dispute settlement prog...
# 2  A class of organic compounds composed only of ...
# 3  A process in which fractures in hard-to-reach ...
# 4  Risk financing techniques that are a combinati...

# %%
def dataframe_to_sql(df, table_name):
    from sqlalchemy import create_engine

    sqlite = 'sqlite:///' + table_name + '.sqlite'
    engine = create_engine(sqlite, echo=False)
    df.to_sql(table_name, con=engine)

# %%
dataframe_to_sql(df_insurance_terms_2, 'insurance_terms_2')

# %%
def csv_to_json(csv_file, json_file):
    import json
    import numpy as np

    fout = open(json_file, 'w')

    with open(csv_file, 'r') as fin:
        for line in fin:
            split_line = line.rstrip().split(',')
            if len(split_line) == 3:
                d = {}
                d['term'] = split_line[0]
                d['text'] = split_line[1]
#                 d['synonym'] = split_line[2]
                json_dict = json.dumps(d)
                if d['term'] == 'term':
                    continue
                fout.write(json_dict)
                fout.write('\n')
    
    fout.close()

# %%
csv_to_json('terms.csv', 'insurance_terms_3.json')

# %%
def dataframe_to_json(df, json_file):
    df.to_json(path_or_buf=json_file, orient='index')

# %%
dataframe_to_json(df_insurance_terms_2, 'insurance_terms_4.json')

# %% [markdown]
# ***
# ***
# ***

# %% [markdown]
# ### This part is just for test

# %%
# divide terms by the starting character
df_term_a = df_insurance_terms_2[df_insurance_terms_2['term'].str.startswith('a')]

# %%
df_term_a.head()
# Out:
#                              term  \
# 0          automatic premium loan
# 2249                    avoidance
# 2250    average weekly wage (AWW)
# 2251              aviation hazard
# 2252  aviation accident insurance
#
#                                                    text
# 0     An optional provision in life insurance that a...
# 2249  A risk management technique whereby risk of lo...
# 2250  An employee s pre-injury earning capacity  bas...
# 2251  A hazard associated with the peril of death or...
# 2252  Protects employees of a company or other insur...

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

def normalize_string(string):
    string = string.lower()
    tokenized_words = word_tokenize(string)
    stopwords_removed = [word for word in tokenized_words if word not in stop_words]
    alphabet_string = [word for word in stopwords_removed if word.isalpha()]
    return alphabet_string

# %%
df_term_a.loc[:, 'term'] = df_term_a.apply(lambda row: normalize_string(row['term']), axis=1)
df_term_a.loc[:, 'text'] = df_term_a.apply(lambda row: normalize_string(row['text']), axis=1)

df_term_a.head()
# Out:
#                                  term  \
# 0          [automatic, premium, loan]
# 2249                      [avoidance]
# 2250     [average, weekly, wage, aww]
# 2251               [aviation, hazard]
# 2252  [aviation, accident, insurance]
#
#                                                    text
# 0     [optional, provision, life, insurance, authori...
# 2249  [risk, management, technique, whereby, risk, l...
# 2250  [employee, earning, capacity, based, earnings,...
# 2251  [hazard, associated, peril, death, disability,...
# 2252  [protects, employees, company, insured, person...

# %%
# lower case
# df_term_a['term'] = df_term_a['term'].str.lower()
# df_term_a['text'] = df_term_a['text'].str.lower()
df_term_a.loc[:,'term'] = df_term_a['term'].str.lower()
df_term_a.loc[:,'text'] = df_term_a['text'].str.lower()

# %%
df_term_a.head()
# Out:
#                              term  \
# 0          automatic premium loan
# 2249                    avoidance
# 2250    average weekly wage (aww)
# 2251              aviation hazard
# 2252  aviation accident insurance
#
#                                                    text
# 0     an optional provision in life insurance that a...
# 2249  a risk management technique whereby risk of lo...
# 2250  an employee s pre-injury earning capacity  bas...
# 2251  a hazard associated with the peril of death or...
# 2252  protects employees of a company or other insur...

# %%
# Tokenize
from nltk import word_tokenize
# df_term_a['term_tokenized'] = df_term_a.apply(lambda row: word_tokenize(row['term']), axis=1)
# df_term_a['text_tokenized'] = df_term_a.apply(lambda row: word_tokenize(row['text']), axis=1)
df_term_a.loc[:, 'term_tokenized'] = df_term_a['term'].apply(word_tokenize)
df_term_a.loc[:, 'text_tokenized'] = df_term_a['text'].apply(word_tokenize)

# %%
df_term_a.head()
# Out:
#                              term  \
# 0          automatic premium loan
# 2249                    avoidance
# 2250    average weekly wage (aww)
# 2251              aviation hazard
# 2252  aviation accident insurance
#
#                                                    text  \
# 0     an optional provision in life insurance that a...
# 2249  a risk management technique whereby risk of lo...
# 2250  an employee s pre-injury earning capacity  bas...
# 2251  a hazard associated with the peril of death or...
# 2252  protects employees of a company or other insur...
#
#                           term_tokenized  \
# 0             [automatic, premium, loan]
# 2249                         [avoidance]
# 2250  [average, weekly, wage, (, aww, )]
# 2251                  [aviation, hazard]
# 2252     [aviation, accident, insurance]
#
#                                          text_tokenized
# 0     [an, optional, provision, in, life, insurance,...
# 2249  [a, risk, management, technique, whereby, risk...
# 2250  [an, employee, s, pre-injury, earning, capacit...
# 2251  [a, hazard, associated, with, the, peril, of, ...
# 2252  [protects, employees, of, a, company, or, othe...

# %%
before_remove_stopwords = df_term_a.loc[0, 'text_tokenized']

# %%
# Remove stop words
from nltk.corpus import stopwords
stop = stopwords.words('english')

# df_term_a['term_tokenized'] = df_term_a['term_tokenized'].apply(lambda x: [item for item in x if item not in stop])
# df_term_a['text_tokenized'] = df_term_a['text_tokenized'].apply(lambda x: [item for item in x if item not in stop])
df_term_a.loc[:,'term_tokenized'] = df_term_a['term_tokenized'].apply(lambda x: [item for item in x if item not in stop])
df_term_a.loc[:,'text_tokenized'] = df_term_a['text_tokenized'].apply(lambda x: [item for item in x if item not in stop])

# %%
df_term_a.head()
# Out:
#                              term  \
# 0          automatic premium loan
# 2249                    avoidance
# 2250    average weekly wage (aww)
# 2251              aviation hazard
# 2252  aviation accident insurance
#
#                                                    text  \
# 0     an optional provision in life insurance that a...
# 2249  a risk management technique whereby risk of lo...
# 2250  an employee s pre-injury earning capacity  bas...
# 2251  a hazard associated with the peril of death or...
# 2252  protects employees of a company or other insur...
#
#                           term_tokenized  \
# 0             [automatic, premium, loan]
# 2249                         [avoidance]
# 2250  [average, weekly, wage, (, aww, )]
# 2251                  [aviation, hazard]
# 2252     [aviation, accident, insurance]
#
#                                          text_tokenized
# 0     [optional, provision, life, insurance, authori...
# 2249  [risk, management, technique, whereby, risk, l...
# 2250  [employee, pre-injury, earning, capacity, base...
# 2251  [hazard, associated, peril, death, disability,...
# 2252  [protects, employees, company, insured, person...

# %%
after_remove_stopwords = df_term_a.loc[0, 'text_tokenized']

# %%
before_remove_stopwords
# Out:
# ['an',
#  'optional',
#  'provision',
#  'in',
#  'life',
#  'insurance',
#  'that',
#  'authorizes',
#  'the',
#  'insurer',
#  'to',
#  'pay',
#  'from',
#  'the',
#  'cash',
#  'value',
#  'any',
#  'premium',
#  'due',
#  'at',
#  'the',
#  'end',
#  'of',
#  'the',
#  'grace',
#  'period',
#  'this',
#  'provision',
#  'is',
#  'useful',
#  'in',
#  'preventing',
#  'inadvertent',
#  'lapse',
#  'of',
#  'the',
#  'policy']

# %%
after_remove_stopwords
# Out:
# ['optional',
#  'provision',
#  'life',
#  'insurance',
#  'authorizes',
#  'insurer',
#  'pay',
#  'cash',
#  'value',
#  'premium',
#  'due',
#  'end',
#  'grace',
#  'period',
#  'provision',
#  'useful',
#  'preventing',
#  'inadvertent',
#  'lapse',
#  'policy']

# %%
for item in before_remove_stopwords:
    if item not in after_remove_stopwords:
        print(item)
# Out:
# an
# in
# that
# the
# to
# from
# the
# any
# at
# the
# of
# the
# this
# is
# in
# of
# the

# %%
# keep only alphabet
# df_term_a['term_tokenized'] = df_term_a['term_tokenized'].apply(lambda x: [item for item in x if item.isalpha()])
# df_term_a['text_tokenized'] = df_term_a['text_tokenized'].apply(lambda x: [item for item in x if item.isalpha()])
df_term_a.loc[:,'term_tokenized'] = df_term_a['term_tokenized'].apply(lambda x: [item for item in x if item.isalpha()])
df_term_a.loc[:,'text_tokenized'] = df_term_a['text_tokenized'].apply(lambda x: [item for item in x if item.isalpha()])

# %%
df_term_a.head()
# Out:
#                              term  \
# 0          automatic premium loan
# 2249                    avoidance
# 2250    average weekly wage (aww)
# 2251              aviation hazard
# 2252  aviation accident insurance
#
#                                                    text  \
# 0     an optional provision in life insurance that a...
# 2249  a risk management technique whereby risk of lo...
# 2250  an employee s pre-injury earning capacity  bas...
# 2251  a hazard associated with the peril of death or...
# 2252  protects employees of a company or other insur...
#
#                        term_tokenized  \
# 0          [automatic, premium, loan]
# 2249                      [avoidance]
# 2250     [average, weekly, wage, aww]
# 2251               [aviation, hazard]
# 2252  [aviation, accident, insurance]
#
#                                          text_tokenized
# 0     [optional, provision, life, insurance, authori...
# 2249  [risk, management, technique, whereby, risk, l...
# 2250  [employee, earning, capacity, based, earnings,...
# 2251  [hazard, associated, peril, death, disability,...
# 2252  [protects, employees, company, insured, person...

# %%
X = documents.values
y = labels.values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)

vec_trained = vectorizer.fit_transform(X_train)

vec_trained = vec_trained.toarray()

words = vectorizer.get_feature_names()

vec_test = vectorizer.transform(X_test)

vec_test = vec_test.toarray()

# %%
vec_trained.shape
# Out:
# (2282, 5000)

# %%
words
# Out:
# ['00',
#  '000',
#  '01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '06',
#  '08',
#  '10',
#  '100',
#  '11',
#  '110',
#  '113',
#  '114',
#  '12',
#  '125',
#  '13',
#  '15',
#  '159',
#  '17',
#  '18',
#  '1913',
#  '1950s',
#  '1964',
#  '1970',
#  '1973',
#  '1974',
#  '1980s',
#  '1981',
#  '1986',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1995',
#  '1998',
#  '1999',
#  '20',
#  '2000',
#  '2000s',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2020',
#  '21',
#  '23',
#  '24',
#  '25',
#  '250',
#  '26',
#  '28',
#  '30',
#  '300',
#  '31',
#  '32',
#  '35',
#  '40',
#  '401',
#  '41',
#  '45',
#  '48',
#  '50',
#  '500',
#  '501',
#  '510',
#  '53',
#  '54',
#  '55',
#  '60',
#  '63',
#  '65',
#  '70',
#  '72',
#  '73',
#  '831',
#  '90',
#  '96',
#  '99',
#  'a201',
#  'aais',
#  'abandoned',
#  'abatement',
#  'abbreviated',
#  'abc',
#  'abilities',
#  'ability',
#  'able',
#  'absence',
#  'absent',
#  'absolute',
#  'absolve',
#  'abuse',
#  'abuses',
#  'acc',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'accepts',
#  'access',
#  'accessible',
#  'accessing',
#  'accident',
#  'accidental',
#  'accidents',
#  'accommodate',
#  'accommodation',
#  'accommodations',
#  'accompanying',
#  'accomplished',
#  'accordance',
#  'according',
#  'accordingly',
#  'account',
#  'accountability',
#  'accountant',
#  'accountants',
#  'accounting',
#  'accounts',
#  'accrue',
#  'accrued',
#  'accruing',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accused',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'acid',
#  'acids',
#  'acii',
#  'acquire',
#  'acquired',
#  'acquiring',
#  'acquisition',
#  'acronym',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'activating',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'acts',
#  'actual',
#  'actually',
#  'actuarial',
#  'actuaries',
#  'actuary',
#  'acute',
#  'acv',
#  'ada',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'address',
#  'addressed',
#  'addresses',
#  'adds',
#  'adequacy',
#  'adequate',
#  'adequately',
#  'adhesion',
#  'adhesive',
#  'adjacent',
#  'adjudicated',
#  'adjust',
#  'adjusted',
#  'adjuster',
#  'adjusters',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'administer',
#  'administered',
#  'administering',
#  'administers',
#  'administration',
#  'administrative',
#  'administrator',
#  'administrators',
#  'admissibility',
#  'admitted',
#  'adopted',
#  'adoption',
#  'adr',
#  'advance',
#  'advanced',
#  'advancement',
#  'advances',
#  'advancing',
#  'advantage',
#  'advantageous',
#  'advantages',
#  'advent',
#  'adverse',
#  'adversely',
#  'advertisements',
#  'advertising',
#  'advice',
#  'advisers',
#  'advisory',
#  'aei',
#  'affairs',
#  'affect',
#  'affected',
#  'affecting',
#  'affiliated',
#  'affiliates',
#  'affiliation',
#  'affirmatively',
#  'affixed',
#  'afford',
#  'afforded',
#  'affords',
#  'afis',
#  'aftermarket',
#  'age',
#  'agencies',
#  'agency',
#  'agent',
#  'agents',
#  'aggregate',
#  'aggregation',
#  'agree',
#  'agreed',
#  'agreement',
#  'agreements',
#  'agrees',
#  'agribusiness',
#  'agricultural',
#  'agriculture',
#  'aia',
#  'aicpa',
#  'aid',
#  'aids',
#  'aimed',
#  'air',
#  'airborne',
#  'aircraft',
#  'airlines',
#  'airplane',
#  'airport',
#  'alae',
#  'alaes',
#  'alcoholic',
#  'ale',
#  'alert',
#  'alien',
#  'alive',
#  'alkalis',
#  'allegations',
#  'allege',
#  'alleged',
#  'allegedly',
#  'alleges',
#  'alleging',
#  'allocable',
#  'allocated',
#  'allocating',
#  'allocation',
#  'allow',
#  'allowable',
#  'allowance',
#  'allowed',
#  'allowing',
#  'allows',
#  'alongside',
#  'alteration',
#  'altering',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'alters',
#  'ambient',
#  'ambiguities',
#  'ambiguity',
#  'amend',
#  'amended',
#  'amendment',
#  'amendments',
#  'amends',
#  'america',
#  'american',
#  'americans',
#  'amortization',
#  'amounting',
#  'amounts',
#  'analogous',
#  'analyses',
#  'analysis',
#  'analytical',
#  'analyzed',
#  'analyzing',
#  'anesthesia',
#  'anesthesiologist',
#  'anesthetic',
#  'animal',
#  'animals',
#  'anniversary',
#  'annual',
#  'annually',
#  'annuitant',
#  'annuity',
#  'answer',
#  'answers',
#  'anti',
#  'anticipated',
#  'anticipates',
#  'antitrust',
#  'apparatus',
#  'appeal',
#  'appear',
#  'appearance',
#  'appears',
#  'appliances',
#  'applicability',
#  'applicable',
#  'applicant',
#  'applicants',
#  'application',
#  'applications',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appoint',
#  'appointed',
#  'appointment',
#  'apportioned',
#  'apportioning',
#  'appraisal',
#  'appraiser',
#  'approach',
#  'approaches',
#  'appropriate',
#  'appropriately',
#  'approval',
#  'approve',
#  'approved',
#  'approximate',
#  'approximated',
#  'arbitration',
#  'arbitrator',
#  'arbitrators',
#  'architect',
#  'architects',
#  'area',
#  'areas',
#  'arena',
#  'argument',
#  'arise',
#  'arisen',
#  'arises',
#  'arising',
#  'arm',
#  'arose',
#  'arranged',
#  'arrangement',
#  'arrangements',
#  'arranges',
#  'arranging',
#  'arrest',
#  'arriving',
#  'ars',
#  'arss',
#  'artificial',
#  'arts',
#  'asbestos',
#  'ascertain',
#  'aside',
#  'ask',
#  'aspect',
#  'aspects',
#  'assent',
#  'assert',
#  'asserted',
#  'asserting',
#  'assertion',
#  'asserts',
#  'assess',
#  'assessed',
#  'assessing',
#  'assessment',
#  'assessments',
#  'asset',
#  'assets',
#  'assigned',
#  'assignment',
#  'assigns',
#  'assist',
#  'assistance',
#  'assisting',
#  'associate',
#  'associated',
#  'associateship',
#  'association',
#  'associations',
#  'assume',
#  'assumed',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'assurance',
#  'assuring',
#  'atima',
#  'attached',
#  'attaching',
#  'attachment',
#  'attack',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attention',
#  'attorney',
#  'attorneys',
#  'attract',
#  'attributable',
#  'attributed',
#  'auction',
#  'audit',
#  'audited',
#  'auditors',
#  'audits',
#  'authorities',
#  'authority',
#  'authorized',
#  'authorizes',
#  'authorizing',
#  'auto',
#  'automated',
#  'automatic',
#  'automatically',
#  'automobile',
#  'automobiles',
#  'autos',
#  'availability',
#  'available',
#  'average',
#  'aviation',
#  'avoid',
#  'avoidance',
#  'avoiding',
#  'avoids',
#  'awaiting',
#  'award',
#  'awarded',
#  'awards',
#  'aware',
#  'awareness',
#  'away',
#  'backdating',
#  'backed',
#  'backup',
#  'bad',
#  'baggage',
#  'bailee',
#  'bailees',
#  'balance',
#  'balances',
#  'bands',
#  'bank',
#  'bankers',
#  'banking',
#  'bankruptcy',
#  'banks',
#  'banned',
#  'bap',
#  'bar',
#  'barbados',
#  'bare',
#  'bargaining',
#  'barge',
#  'barring',
#  'bars',
#  'base',
#  'based',
#  'basel',
#  'basic',
#  'basis',
#  'basket',
#  'beams',
#  'bear',
#  'bearing',
#  'bears',
#  'began',
#  'begin',
#  'beginning',
#  'begins',
#  'begun',
#  'behalf',
#  'believe',
#  'believed',
#  'belonging',
#  'bench',
#  'benchmark',
#  'beneath',
#  'beneficial',
#  'beneficiaries',
#  'beneficiary',
#  'benefit',
#  'benefits',
#  'bermuda',
#  'berps',
#  'berth',
#  'best',
#  'better',
#  'betterments',
#  'beverages',
#  'bi',
#  'bias',
#  'bicycles',
#  'bielby',
#  'bikini',
#  'billing',
#  'billion',
#  'bills',
#  'bind',
#  'binder',
#  'bingo',
#  'biological',
#  'biomechanics',
#  'blackmail',
#  'blackout',
#  'blanket',
#  'blue',
#  'bm',
#  'board',
#  'bodies',
#  'bodily',
#  'body',
#  'boiler',
#  'boilerplate',
#  'bomb',
#  'bond',
#  'bondholders',
#  'bonding',
#  'bonds',
#  'book',
#  'booked',
#  'books',
#  'bop',
#  'border',
#  'borne',
#  'borrowed',
#  'borrower',
#  'borrowers',
#  'borrowing',
#  'borrows',
#  'bought',
#  'bound',
#  'box',
#  'branches',
#  'brand',
#  'breach',
#  'breached',
#  'breaches',
#  'break',
#  'breakage',
#  'breakdown',
#  'bridge',
#  'bridges',
#  'brief',
#  'brigade',
#  'bring',
#  'bringing',
#  'brings',
#  'british',
#  'broad',
#  'broadcasters',
#  'broaden',
#  'broadened',
#  'broadens',
#  'broader',
#  'broadly',
#  'broker',
#  'brokers',
#  'brought',
#  'browser',
#  'brush',
#  'budget',
#  'buffer',
#  'build',
#  'builder',
#  'builders',
#  'building',
#  'buildings',
#  'buildup',
#  'built',
#  'bullying',
#  'burden',
#  'bureau',
#  'bureaus',
#  'burglary',
#  'burning',
#  'business',
#  'businesses',
#  'buy',
#  'buyer',
#  'buyers',
#  'buying',
#  'buyout',
#  'bylaws',
#  'ca',
#  'cable',
#  'calculate',
#  'calculated',
#  'calculating',
#  'calculation',
#  'calendar',
#  'california',
#  'called',
#  'calling',
#  'calls',
#  'cameras',
#  'canada',
#  'canadian',
#  'cancel',
#  'canceled',
#  'canceling',
#  'cancellation',
#  'cancels',
#  'cancer',
#  'candidate',
#  'candidates',
#  'cap',
#  'capability',
#  'capable',
#  'capacity',
#  'capita',
#  'capital',
#  'capitalization',
#  'capped',
#  'caps',
#  'captive',
#  'captives',
#  'car',
#  'carbon',
#  'card',
#  'cards',
#  'care',
#  'career',
#  'carefully',
#  'cargo',
#  'carolina',
#  'carried',
#  'carrier',
#  'carriers',
#  'carries',
#  'carry',
#  'carryback',
#  'carryforward',
#  'cars',
#  'cart',
#  'case',
#  'cases',
#  'cash',
#  'casualty',
#  'cat',
#  'catastrophe',
#  'catastrophic',
#  'categories',
#  'categorized',
#  'category',
#  'caucasian',
#  'causation',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'caveat',
#  'cbot',
#  'ccc',
#  'ce',
#  'cease',
#  'ceases',
#  'cede',
#  'ceded',
#  'cedent',
#  'cedes',
#  'ceding',
#  'ceiling',
#  'celebrity',
#  'cell',
#  'cells',
#  'center',
#  'centers',
#  'central',
#  'centralized',
#  'ceo',
#  'cercla',
#  'certain',
#  'certainty',
#  'certificate',
#  'certification',
#  'certified',
#  'certify',
#  'cessions',
#  'cg',
#  'cgl',
#  'chain',
#  'challenged',
#  'challenges',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'characteristics',
#  'characterized',
#  'charge',
#  'charged',
#  'charges',
#  'charging',
#  'charitable',
#  'chartered',
#  'charterer',
#  'chemical',
#  'chemicals',
#  'chicago',
#  'chief',
#  'child',
#  'children',
#  'choice',
#  'choose',
#  'chooses',
#  'chosen',
#  'chronic',
#  'church',
#  'cica',
#  'cip',
#  'circles',
#  'circumstance',
#  'circumstances',
#  'cities',
#  'citizen',
#  'city',
#  'civil',
#  'civilian',
#  'claim',
#  'claimant',
#  'claimants',
#  'claimed',
#  'claiming',
#  'claims',
#  'clarify',
#  'clarifying',
#  'class',
#  'classes',
#  'classic',
#  'classification',
#  'classifications',
#  'classified',
#  'classifying',
#  'clause',
#  'clauses',
#  'clayton',
#  'clean',
#  'cleanup',
#  'clear',
#  'clearly',
#  'click',
#  'client',
#  'clients',
#  'climate',
#  'clinical',
#  'close',
#  'closed',
#  'closely',
#  'cm',
#  'cms',
#  'coal',
#  'coalition',
#  'coast',
#  'coat',
#  'cobra',
#  'code',
#  'codes',
#  'coemployers',
#  'coerce',
#  'coincidental',
#  'coined',
#  'coinsurance',
#  'collaboration',
#  'collapse',
#  'collateral',
#  'collateralization',
#  'collateralize',
#  'collateralized',
#  'collect',
#  'collected',
#  'collecting',
#  'collection',
#  'collections',
#  'collectively',
#  'collects',
#  'collision',
#  'collusion',
#  'columbia',
#  'columns',
#  'combat',
#  'combination',
#  'combinations',
#  'combine',
#  'combined',
#  'combines',
#  'combining',
#  'come',
#  'comes',
#  'comfortable',
#  'coming',
#  'commerce',
#  'commercial',
#  'commercially',
#  'commission',
#  'commissioner',
#  'commissioners',
#  'commissions',
#  'commit',
#  'commitment',
#  'committed',
#  'committee',
#  'committees',
#  'committing',
#  'commodities',
#  'commodity',
#  'common',
#  'commonly',
#  'commotion',
#  'communication',
#  'communications',
#  'communities',
#  'community',
#  'companies',
#  'companionship',
#  'company',
#  'comparable',
#  'compare',
#  'compared',
#  'comparing',
#  'comparisons',
#  'compelled',
#  'compels',
#  'compendium',
#  'compensable',
#  'compensate',
#  'compensated',
#  'compensating',
#  'compensation',
#  'compensatory',
#  'competing',
#  'competition',
#  'competitive',
#  'competitor',
#  'complaint',
#  'complete',
#  'completed',
#  'completely',
#  'completes',
#  'completing',
#  'completion',
#  'complex',
#  'complexity',
#  'compliance',
#  'complicated',
#  'complied',
#  'comply',
#  'component',
#  'components',
#  'composed',
#  'compounds',
#  'comprehensive',
#  'comprise',
#  'compulsory',
#  'computer',
#  'computerized',
#  'computers',
#  'computes',
#  'computing',
#  'concealed',
#  'concealment',
#  'concentration',
#  'concept',
#  'concepts',
#  'concern',
#  'concerned',
#  'concerning',
#  'concerns',
#  'conclusion',
#  'conclusive',
#  'concrete',
#  'concurrent',
#  'concurrently',
#  'condition',
#  'conditioning',
#  'conditions',
#  'condominium',
#  'conduct',
#  'conducted',
#  'conducting',
#  'conducts',
#  'conference',
#  'conferences',
#  'confers',
#  'confidence',
#  'confiscation',
#  'conflict',
#  'conflicts',
#  'confronted',
#  'congress',
#  'congressional',
#  'conjunction',
#  'connect',
#  'connected',
#  'connection',
#  'conscious',
#  'consecutive',
#  'consent',
#  'consequence',
#  'consequences',
#  'consequential',
#  'consequently',
#  'conservation',
#  'consider',
#  'considerable',
#  'consideration',
#  'considerations',
#  'considered',
#  'considering',
#  'consist',
#  'consistent',
#  'consisting',
#  'consists',
#  'consolidated',
#  'consolidates',
#  'consortium',
#  'constitute',
#  'constraint',
#  'construct',
#  'constructed',
#  'construction',
#  'constructive',
#  'consultants',
#  'consulting',
#  'consumer',
#  'consumers',
#  'consuming',
#  'consumption',
#  'contact',
#  'contain',
#  'contained',
#  'containing',
#  'contains',
#  'contaminant',
#  'contaminants',
#  'contaminated',
#  'contamination',
#  'contemporary',
#  'contents',
#  'context',
#  'contingencies',
#  'contingency',
#  'contingent',
#  'continue',
#  'continues',
#  'continuing',
#  'continuity',
#  'continuous',
#  'continuously',
#  'contract',
#  'contracted',
#  'contracting',
#  'contractor',
#  ...]

# %%
vec_test = vectorizer.transform(X_test)

# %% [markdown]
# Because there 3261 terms corresponding to 3261 labels. First I categorize the label into different clusters. And I want to know how many unique words in documents and labels? So I can decide the size of vocabulary.

# %%
docs = []
for index, text in documents.iteritems():
#     print(text)
    docs.append(text)

# %%
docs
# Out:
# ['An optional provision in life insurance that authorizes the insurer to pay from the cash value any premium due at the end of the grace period  This provision is useful in preventing inadvertent lapse of the policy ',
#  'Provided a nonjudicial dispute settlement program for the carriage of household goods ',
#  'A class of organic compounds composed only of carbon and hydrogen  Common hydrocarbons include natural gas  crude oil  and coal  Hydrocarbons are the primary source of the world s electric energy and heat sources due to the power created when they are burned ',
#  'A process in which fractures in hard-to-reach shale rock formations below the earth s surface are opened and widened by injecting water  chemicals  and sand under high pressure to extract natural gas and oil trapped in the shale rocks  It enables wells that would flow only at very low rates to produce oil and gas in commercially viable volumes ',
#  'Risk financing techniques that are a combination of retention and transfer  Hybrid plans are designed to transfer only part of the risk of loss to an insurer while the organization retains the balance of the exposure  Also called blended plans or alternative market plans ',
#  'The combination of a standard group captive and structured reinsurance  It is designed to create significant limits of insurance for risks that  for one reason or another  cannot be covered in the commercial insurance markets  The major difference between the hybrid captive and a standard group captive is how limits of liability are structured ',
#  'The internal rate of return established in an organization as necessary to justify investment in an operation  based usually on the short-term cost of borrowing  Often used as the discount rate in a net present value cost analysis ',
#  'A type of risk financing plan that makes use of both internal and external funds to pay losses  It thus falls between a pure transfer approach and a pure retention approach to risk  The costs of hybrid techniques tend to be less experience-responsive as compared to pure retention but more experience-responsive as compared to pure transfer techniques  Examples of hybrid techniques include pooling arrangements  high-deductible plans  multiple-parent captives  and retrospectively rated insurance policies ',
#  'Involves a detailed analysis of all the steps integral to a particular task  This process includes listing and categorizing all the hazards to persons and property that might impact each step and detailing all reasonable mechanical  procedural  and managerial safeguards against each hazard  The main goal is to make each task and the overall process subject to appropriate risk control techniques  leading to greater workplace safety ',
#  'Permanent additions or changes made to a building by a lessee at his or her own expense that may not legally be removed  Property policies vary as to whether tenants  improvements and betterments are covered under the building category or under the contents category  so care must be taken to assign these values to the proper category of covered property ',
#  'As a point of law  the understanding that a particular product is safe and suitable for a particular use  when the vendor knows at the time of sale the use for which the product is intended ',
#  'Actions of an agent that may extend beyond the rights and powers explicitly provided in the agency contract  If these actions result in no response from the insurer  authority is extended as if these fall within the agency contract ',
#  'To sue  to prosecute  To bring a new party into an action ',
#  'The situation in which the surplus account of a stock insurer is threatened by exhaustion and the insurer invades its capital account to meet liabilities  Some jurisdictions allow this  but most do not ',
#  'A legal principle that holds that the incorporation of a defective product into real property constitutes  property damage  (PD) as defined in the commercial general liability (CGL) policy  This doctrine has been argued  mostly unsuccessfully  in pursuit of liability coverage for construction defects that have not produced actual physical damage ',
#  'A clause in a life or health insurance policy that stipulates a given length of time (usually 2 years) during which the insurer may contest claims  After expiration of this time  claims cannot be contested for any reason other than nonpayment of premium ',
#  'A provision in a liability insurance policy that requires or allows the insured to report incidents  accidents  or occurrences that may lead to claims  Also called an  awareness provision  or a  notice of potential claim provision  ',
#  'Consulting services provided by accounting firms  the bulk of which involve computer software and hardware  Other areas falling under the heading of management advisory services include  business or asset valuation  mergers and acquisitions  investments  capital budgeting  business strategy and marketing  organizational structure  business operations  real estate  and litigation support  This is one of the more severe exposures covered by accountants professional liability policies ',
#  'A healthcare provider whose goal it is to provide appropriate  cost-effective medical treatment  Two types of these providers are the health maintenance organization (HMO) and the preferred provider organization (PPO) ',
#  'Coverage in the event of late delivery of a product for an agreed amount based on the contract between the insured manufacturer and a purchaser  Designed for manufacturers that are compelled to enter into contracts under which they assume responsibility for delay in completion of a product  The policy generally covers 90 percent of the penalty loss sustained but does not extend to strikes or labor disputes ',
#  'A form of liability coverage written to cover organizations engaged in delivering medical services on a managed-care basis  such as health maintenance organizations (HMOs)  Representative types of claims covered by the policies include allegations of negligent provider selection  direct professional liability  and wrongful denial of treatment ',
#  'An endorsement to a fiduciary liability policy providing coverage for bodily injury (BI)  property damage (PD)  and personal injury (PI) when they result from administering managed care health plans  This endorsement is necessary because fiduciary liability policies usually exclude coverage for these perils  However  because managed care plans are subject to Employee Retirement Income Security Act (ERISA)  such coverage is necessary  The two most common claims involving managed care plans allege (1) that the employer-sponsor of a managed healthcare plan negligently selected the managed healthcare plan provider  and (2) that the employer-sponsor of a managed healthcare plan wrongly denied or delayed medical benefits provided by the plan ',
#  'A process by which the delivery of health care is structured and monitored with the goal of providing medical services that are both appropriate and economically reasonable ',
#  'Software that is designed to infiltrate and damage a computer system without the computer owner s knowledge or consent  The term is a shortened combination of the words  malicious  and  software  and is a generic term used to refer to a variety of forms of hostile or intrusive software  such as computer viruses  worms  Trojan horses  and spyware  See also',
#  'A broad all risks policy that provides a combination of commercial property and commercial inland marine coverages manufacturers and many other businesses need  MOPs were developed in the mid-1950s as a method of insuring in a single policy stock both during the manufacturing process and in transit  Because the MOP s combination of commercial property and commercial marine coverages met the needs of many different types of organizations  MOP eligibility also expanded over time to include many industrial  processing  and commercial operations  In recent years  the term  commercial output policy  and the  COP  acronym have begun to replace the term  manufacturers output policy  and the  MOP  acronym in the commercial insurance arena since they more accurately reflect the wide range of organizations that can be insured under this type of policy  The American Association of Insurance Services (AAIS) offers standard COP forms and rules for use by its member insurers  In addition  many insurers have developed their own COP forms and rules  COP premiums are typically developed using a distinctive rating system (referred to as a  deficiency point rating system )  which allows many insurers to be more competitive using a COP than they could be using a standard commercial property policy ',
#  'A property insurance endorsement or provision establishing market value (rather than actual cash value (ACV) or replacement cost (RC) value) as the valuation basis for covered property  Usually used in connection with agricultural products and other commodities whose value fluctuates in accordance with a commodities exchange  Also occasionally used as the valuation basis for a building ',
#  'Refers to a deductible arrangement under which the policy deductible equals the policy limit ',
#  'A contract used by oil and gas companies to enter into an agreement in advance with their contractors that specifies the terms and conditions that will govern the contractors  work  The agreement is typically used for on-site services performed by oilfield service contractors on a repetitive basis  such as equipment maintenance  well services  and cementing services  Its goal is to speed up and simplify future contracts for long-term client vendor relationships ',
#  'In property and liability coverage  the combining of several locations or operations under a single policy for the same insured or insureds  The term may also be used in the case of construction wrap-ups  In either case  underlying policies or certificates of insurance are issued to insureds under the policy as evidence of coverage under the master policy ',
#  'One of six building construction categories established by Insurance Services Office  Inc  (ISO)  in its',
#  'Coverage for the acts  errors  and omissions of physicians and surgeons  encompassing physicians professional liability insurance  hospital professional liability (HPL) insurance  and allied healthcare (e g   nurses) professional liability insurance  Although the majority of policies are written with a claims-made coverage trigger  such coverage is sometimes available on an occurrence basis  Typical exclusions are for  intentional criminal acts  punitive damages  sexual misconduct  and specialized procedures (e g   radial keratotomy) for which coverage may be  bought back  in return for additional premium  In addition to commercial insurers  medical malpractice coverage is also available in most states through physician-owned insurance companies known as  bedpan mutuals  ',
#  'The price that would have to be paid to purchase an asset in its particular market ',
#  'The worst loss that could possibly occur because of a single event  See also',
#  'Statutory limitations  currently on the books in a number of states (and being considered in others  as well as on the federal level)  limiting the dollar amount of non-economic damages recoverable in a claim alleging medical malpractice  Such legislation is most prevalent in states where high medical liability claim levels have made it difficult or even impossible for substantial numbers of doctors to obtain professional liability coverage   Caps  place a limit on damages for items such as pain and suffering  loss of companionship  and permanent disfigurement  generally in the amount of either  250 000 or  500 000 per claimant  However   caps  are inapplicable to economic losses  such as medical expenses and lost wages that result from medical negligence ',
#  'Federal act that establishes a private right of action for actual or statutory damages (as well as criminal and administrative sanctions) against employers and contractors of migrant or seasonal agricultural workers who violate the Act s housing and motor vehicle safety requirements  motor vehicle liability insurance requirements  and job information disclosure requirements ',
#  'A California tort reform act  passed in 1975  that may be replicated in other states  It has shown success in limiting the increases of medical malpractice costs  Several of MICRA s important features include  (1) non-economic damages that are capped for medical negligence at  250 000  (2) economic damages that are not capped  (3) damage limitations that are provided through the collateral source rule  (4) a sliding scale for lawyers  contingency fees  (5) a 90-day advance notice for filing a claim  and (6) a statute of limitations that requires notification within 1 year from discovery and within 3 years of the date of injury ',
#  'A provision of most state workers compensation laws that establishes the maximum amount a healthcare provider may collect for injuries treatable under the act ',
#  'The U S  government welfare system administered by the states and subsidized by the federal government covering various medical expenses for those of low income  below limits set by state laws ',
#  'The part of a commercial contract in which the types and minimum amounts of insurance the parties agree to provide in connection with their performance of the contract are specified ',
#  'The mechanism developed by the National Association of Insurance Commissioners (NAIC) to assist states in overseeing the financial condition of insurance companies  The IRIS ratios are a set of ratios designed to measure solvency and liquidity  They are calculated from insurers  annual statements that are filed with the NAIC  and insurers that fail one or more tests can be placed under the supervision of their domicile regulator ',
#  'In broad terms  the entire printed insurance contract  Generally  an insurance policy is assembled with a combination of various standard forms  including a declarations page  coverage form  and endorsements  Sometimes a causes of loss form is also required  Together these forms delineate the coverage term  the insurance policy limits  the grant of coverage  exclusions and other limitations of coverage  and the duties and responsibilities of the insured in the event of a loss  See also',
#  'A strong  durable  slow-burning type of joisted masonry construction  also called  heavy timber construction   characterized by heavy floors and thick wooden columns or beams  The walls of such a building generally are assigned a fire-resistive rating of at least 2 hours  The lack of floor joists in this form of construction contributes to its fire-resistance since the corresponding air pockets are eliminated ',
#  'A standardized  formulaic method of predicting future events using historical information  Catastrophe models  which are usually computerized  can be used to predict losses based upon anticipated future atmospheric weather patterns in various geographic regions ',
#  'An evidentiary standard that applies in certain employment discrimination cases  (Whether or not the mixed-motive evidentiary standard applies depends upon (1) the particular jurisdiction in which a case is filed and (2) the exact type of discrimination alleged ) Under this standard  employee-plaintiffs must prove that the employer s discriminatory act for which a claim is being brought (e g   termination  reassignment  demotion) was merely',
#  'A provision in a life insurance policy that adjusts the amount of insurance when the insured s age was misstated on the application to the amount that the premium would have purchased at the correct age based on the insurer s rates at the date of policy issuance ',
#  'Specialized form designed to meet the unique needs of mobile home or manufactured housing owners  It provides coverage comparable to the homeowners policy  including property  loss of use  and premises and personal liability  In some cases  coverage is granted via a mobile home endorsement to the standard homeowners policy  In other cases  a stand-alone mobile home policy is used to provide coverage ',
#  'A term that is defined in both the commercial general liability (CGL) and commercial auto policies  It refers to equipment such as earthmovers  tractors  diggers  farm machinery  forklifts  etc   that  even when self-propelled  are not considered automobiles for insurance purposes (unless they are subject to a compulsory or financial responsibility law or other motor vehicle insurance law)  Liability arising from mobile equipment is covered in the general liability policy  Physical damage coverage is usually provided by an  equipment floater   See also',
#  'A term used in conjunction with underwriting several types of professional liability insurance  notably accountants  lawyers  architects and engineers  and insurance agents  It refers to the respective proportions of specific services provided by a given professional firm  a factor that influences the expected frequency and severity of losses and therefore the premium and scope of coverage afforded  For example  assume that plaintiff personal injury (PI) cases (a high exposure area) comprise the majority of Law Firm A s work  In contrast  most of Law Firm B s work is in the area of trusts and estates  a relatively low exposure activity  All other things being equal  given its mix of services  Law Firm A will probably pay a higher premium and may be offered more restrictive coverage  compared to Law Firm B ',
#  'A false or misleading statement that  if intentional and material  can allow the insurer to void the insurance contract  Some insurance policies and state laws that govern insurance contract provisions vary on the exact details of the conditions under which coverage may be voided  these variations are usually denoted in state amendatory endorsements  See also',
#  'A financial valuation model often used in valuing customer-related intangible assets that estimates revenues and cash flows derived from the intangible asset and then deducts portions of the cash flow that can be attributed to supporting assets  such as a brand name or fixed assets  that contributed to the generation of the cash flows  These deductions are sometimes referred to as  supporting asset charges   The resulting cash flow  which is attributable solely to the subject intangible asset  is then discounted at a rate of return commensurate with the risk of the asset to calculate a present value ',
#  'A situation that arises when parties with relatively equal bargaining power agree to name each other as additional insureds on their respective insurance policies  generally with the intent that each party (the named insured) provide primary coverage to the other (as an additional insured) for damages arising out of the named insured s negligence ',
#  'A corporation owned and operated by and for its insureds  Every owner of the company is an insured  every insured is an owner ',
#  'An organization offering benefits to members for no fixed premiums  but assessments are levied to meet specific losses as they occur ',
#  'Traditional insurance contracts have one trigger  a physical event or occurrence that activates coverage  Multiple trigger contracts are designed to respond to both physical hazard-type events and resultant financial movements  These financial movements can be any benchmark against which the firm measures its financial viabilities  such as its stock price  quarterly earnings  internal rate of return  etc  For example  a multiple trigger (also known as a dual trigger) program could cover property loss due to fire  windstorm  etc   and a reduction in quarterly earnings that results from the physical event ',
#  'An endorsement available under professional liability policies  nearly always in police professional law enforcement policies  Moonlighting endorsements cover insureds for their liability in connection with off-duty law enforcement activities  Coverage is available in recognition of the fact that it is not uncommon for law enforcement officers to hold second jobs ',
#  'A combination of whole life and term insurance paying some multiple of the amount of protection ',
#  'Nationalization or confiscation by a host country government of a multinational s investment (e g   plant  inventory  equipment)  If compensation is offered at all  it is usually far below fair market value ',
#  'Damages awarded based upon a statutory directive  For example  the Clayton Act (a law that prohibits agreements between companies to fix or control prices for the purpose of lessening competition) provides for treble damages in the event of an antitrust violation  Therefore  if a jury awarded  1 million in compensatory damages for violating the Clayton Act  the multiplied damages would be an additional  2 million  resulting in a total award of  3 million  Multiplied damages  although similar in nature and intent to punitive damages  are not always treated in the same manner when determining coverage within a liability policy  See also',
#  'A premium charge added to the premium for a class rate because of extra hazardous exposures ',
#  'A form of substandard rating using mortality or morbidity tables for certain impaired health conditions ',
#  'The requirement under a policy that the insurer pay certain losses or expenses not arising from the insuring agreement but from externally imposed obligations for example  fines from a court or regulatory body  If ECOs are covered under a reinsurance agreement  the reinsurer pays punitive damages imposed on the insurer ',
#  'Damages that are in addition to or outside of a contract of insurance  Extracontractual damages are awarded in  bad faith  claims against insurance companies  They are a form of punitive damages  intended to punish extreme insurer conduct  Extracontractual damage awards most frequently arise from unfair claims handling practices (e g   unjust denial of coverage  failure to settle a claim within policy limits)  See also',
#  'Any of 406 chemicals identified by the Environmental Protection Agency (EPA) as toxic and listed under Superfund Amendments and Reauthorization Act (SARA) of 1986 Title III ',
#  'The extension of state workers compensation law to provide benefits for workers hired in the state  but injured while working in another state  There is usually a maximum placed on the amount of time an employee can spend outside the state of hire and still file a claim in that state  This term is also used in international insurance to denote coverage for work-related injuries occurring outside the boundaries of the country of hire ',
#  'The legal principle that an insurer owes a duty of defense to its insured when the actual facts of a claim or loss match the provisions of the insurance policy  regardless of the language in which the claim is asserted against the insured  See also',
#  'A property loss control term referring to the maximum loss expected at a given location in the event of a fire at that location  expressed in dollars or as a percentage of total values  See also',
#  'The percentile of the probability distribution corresponding to the point at which capital is exhausted  Typically  a minimum acceptable probability of ruin is specified  and economic capital is derived therefrom ',
#  'A technique used by risk managers for forecasting future events  such as accidental and business losses  This process involves a review of historical loss data to calculate a probability distribution that can be used to predict future losses  The probability analyst views past losses as a range of outcomes of what might be expected for the future and assumes that the environment will remain fairly stable  This technique is particularly effective for companies that have a large amount of data on past losses and that have experienced stable operations  This type of analysis is contrasted to trend analysis ',
#  'Communication during  special  relationships that is protected from disclosure to third parties  The most common protected relationships are those of attorney client  cleric penitents  and husband wife ',
#  'A numerical measure of the chance or likelihood that a particular event will occur  Probabilities are generally assigned on a scale from 0 to 1  A probability near 0 indicates an outcome that is unlikely to occur  while a probability near 1 indicates an outcome that is almost certain to occur ',
#  'A defined contribution benefit plan that does not promise a set amount at retirement  Up to 15 percent of employee compensation can be contributed on behalf of any employee annually ',
#  'The relationship that exists between two parties by virtue of their having entered into a contract  This concept incorporates the legal principle that a contract may not impose duties on a noncontracting party  nor may a noncontracting party claim any right or benefit as being guaranteed by the contract ',
#  'Provides coverage for economic losses arising out of the unilateral cancellation of a contract as a result of direct or indirect actions of a foreign government or its agents under circumstances in which the insured is not in breach of contract  The coverage is usually purchased by importers  exporters  and contractors ',
#  'Insurance to indemnify the insured for loss of net profit  chemical analysis  recall  examination  transportation  destruction  and extra expenses incurred to regain market share following a malicious product tampering incident ',
#  'A provision found in some reinsurance agreements that provides for profit sharing  Parties agree to a formula for calculating profit  an allowance for the reinsurer s expenses  and the cedent s share of such profit after expenses ',
#  'Property transfer liability insurance covers the buyer of a property for third-party bodily injury (BI) and property damage (PD) claims and cleanup costs arising out of the property  but only for contamination that had not yet been detected as of the policy s inception date  Failure to disclose known contamination voids coverage with respect to that particular pollution incident ',
#  'First-party insurance that indemnifies the owner or user of property for its loss  or the loss of its income-producing ability  when the loss or damage is caused by a covered peril  such as fire or explosion  In this sense  property insurance encompasses inland marine  boiler and machinery (BM)  and crime insurance  as well as what was once known as fire insurance  now simply called property insurance  insurance on buildings and their contents ',
#  'As defined in the general liability policy  physical injury to tangible property including resulting loss of use and loss of use of tangible property that has not been physically injured  Also addressed in the homeowners and personal auto policies ',
#  'Claims law specialist designation offered by the American Educational Institute (AEI)  It requires successful completion of the AEI property self-study program ',
#  'Proportionately ',
#  'The premium and losses are calculated on a pro rata basis  The reinsurer has a fixed percentage of premium and the same percentage of losses ',
#  'Refers to an arrangement for the assignment of liability in which each member of a group is held responsible for the financial results of the group in proportion to its participation  Compare to',
#  'The adjustment of policy benefits due to a change of exposure or existence of  other insurance  ',
#  'A method used in arriving at an insurance or reinsurance rate and premium for a policy period based on the loss experience of a prior period  Schedule credits  experience modification  and individual risk rating modifications are factors used in prospective rating  whereas losses incurred during the policy period have no effect on final premium  Guaranteed cost plans  with or without a dividend  are examples of prospectively rated insurance plans ',
#  'Spread loss program giving accident year reinsurance for long tail risks with premiums paid annually over the expected life of the policy  (Any adjustments in pricing resulting from adverse loss development occur prospectively )',
#  'Notice is given to allow the option of withdrawing from the reinsurance treaty if renewal terms are unacceptable  Issued with continuous contracts ',
#  'A property insurance endorsement that makes it a condition of coverage that the protective safeguards cited in the endorsement (such as an automatic sprinkler system or night watch guard) be in operation at all times except when the insurer has been notified of the impairment in protection  Failure to maintain the protective safeguards in good working order or failure to notify the insurer of even a temporary impairment in protection suspends coverage until the protection is restored ',
#  'Provides supplemental coverage for professional errors and omissions (E O) claims by the insured against its own design professionals  The policy sits atop all of the insured s design professionals  practice policies as a form of excess coverage in the event the design professional s policy limit has been exhausted or is not sufficient to pay the claim  The insured (e g   project owner or design-build contractor) must prove a legal claim for professional negligence against the design professional to collect under the policy ',
#  'A private-sector  non-profit corporation created as part of the Sarbanes-Oxley Act (SOx)  The PCAOB developed in response to the auditing failures that were associated with several high-profile corporate bankruptcies in the early 2000s  Its purpose is to oversee the accounting firms that audit public corporations  in an effort to protect the interests of the investing public  The PCAOB consists of five members  including its chairman  each of whom the Securities and Exchange Commission (SEC) appoints  It conducts inspections of public accounting firms  develops auditing quality control standards  and conducts investigations and disciplinary proceedings ',
#  'Authorized by the Liability Risk Retention Act of 1986  a group formed to obtain liability coverage for its members  all of which must have similar or related exposures  The Act requires a purchasing group to be domiciled in a specific state  In contrast to risk retention groups (RRGs)  purchasing groups are not risk-bearing entities ',
#  'Damages in excess of those required to compensate the plaintiff for the wrong done  which are imposed in order to punish the defendant because of the particularly wanton or willful nature of his or her wrongdoing  Also called  exemplary damages   Although the standard commercial general liability (CGL) policy and business auto policy (BAP) contain no punitive damage exclusion  many umbrella and excess liability policies contain such an exclusion ',
#  'A term used to describe the liability exposures encountered when communicating or conducting business online  Potential liabilities include the Internet and e-mail  Online communication tools could result in claims alleging breaches of privacy rights  infringement or misappropriation of intellectual property  employment discrimination  violations of obscenity laws  the spreading of computer viruses  and defamation  Media liability policies are available to cover these exposures ',
#  'A coverage extension found in a protection and indemnity policy that pays for port charges incurred as well as the net loss to the policyholder when the vessel must deviate from its specified route to put ashore a sick or injured passenger or crew member ',
#  'A bond under which the surety guarantees that the specified public official will faithfully perform his or her official duties  including accounting for all funds entrusted to his or her care ',
#  'The liability exposure faced by a public official from  wrongful acts   usually defined under public officials liability insurance policies as actual or alleged errors  omissions  misstatements  negligence  or breach of duty in his or her capacity as a public official or employee of the public entity ',
#  'A captive insurance company with one corporate owner  insuring only the risks of the parent organization or its subsidiaries  Also called a single-parent captive ',
#  'Provides liability coverage for the errors and omissions of public officials  In effect  such policies serve the same function for elected appointed officials of state and local government as directors and officers (D O) insurance serves for the directors and officers of corporations  However  one major difference is that under public officials liability forms  employees and the public entity itself are insureds  whereas this is not the case with D O policies  Exclusions under this policy include losses due to fraud or dishonesty  bodily injury (BI) or property damage (PD)  false arrest  assault and battery  defamation  and fiduciary liability ',
#  'A corporation whose shares of stock are held by and are available for purchase by members of the public  The shares of public corporations can be bought or sold on one of the major stock exchanges  such as the New York Stock Exchange (NYSE) or the National Association of Securities Dealers Automated Quotations (NASDAQ)  See also',
#  'A lawsuit brought by one or more named plaintiffs on behalf of a potential group of similarly situated individuals (known as a class) who allegedly suffered a common claim  Lawsuits do not become class actions until an actual class has been certified by the court  Therefore  a putative class action means the class has not yet been certified by the court  If the court certifies the class  the lawsuit becomes a class action  See also',
#  'A reinsurance contract endorsement providing that  in the event of the cedent s insolvency  the reinsurer will pay any loss covered by the reinsurance contract directly to the insured  Also called an  assumption endorsement  ',
#  'A type of insurance designed to cover consumers of technology services or products  More specifically  the policies are intended to cover a variety of both liability and property losses that may result when a business engages in various electronic activities  such as selling on the Internet or collecting data within its internal electronic network ',
#  'A type of online crime in which a criminal threatens to damage or shut down a company s website  e-mail server  or computer system or threatens to expose electronic data or information belonging to the company unless the company pays the criminal a specific ransom amount ',
#  'An insuring agreement contained within some policies written to cover claims associated with data breaches  Such policies are most often termed  cyber and privacy insurance    information security and privacy insurance   and  cybersecurity insurance  ',
#  'Bond required by the U S  Customs Service that guarantees the payment of duties or taxes due by law on all goods directly or indirectly imported or exported to or from the United States as well as the reporting of statistical data relating to the shipments involved  The bond may be issued on either a single or a continuous form ',
#  'Used with retrocessions  The primary insurer has the ability to receive reinsurance payments directly from the retrocessionaire if unable to recover from the reinsurer ',
#  'A policy term that is defined in the Insurance Services Office  Inc  (ISO)  garage policy  The term is defined to include autos of employees and members of their households while they are left with the insured garage for service  repair  storage  or safekeeping when these individuals pay for services performed ',
#  'A termination provision in a reinsurance contract under which the reinsurer is not liable for losses taking place after the date of termination  See also',
#  'An endowment payable at the end of the policy period if the insured is alive  If the insured has died  there is nothing paid in the form of benefits ',
#  'The pay-as-you-go technique to funding a pension plan  It is used today in Social Security and is known as the most costly method of pension funding ',
#  'The portion of an insured s pension benefit that has accrued due to credited service in a given time period ',
#  'The 1984 California Court of Appeals decision in',
#  'A unique feature of aircraft insurance policies is that they commonly specify in the declarations the intended use of the aircraft (e g   business and pleasure  industrial aid  or crop dusting)  This exclusion may invalidate coverage if the aircraft is used for a purpose other than the one stated in the policy  For the exclusion to apply  the aircraft typically must be used for an unauthorized purpose with the knowledge and consent of the named insured  an executive officer  or partner ',
#  'A type of workers injury that arises from the repetition of mentally or physically traumatic job tasks over an extended length of time  Examples are carpal tunnel syndrome and hearing loss ',
#  'A reinsurance contract under which the ceding company further reduces its net exposure that has been reinsured under a share agreement ',
#  'Under a reinsurance agreement  the ratio of reinsured losses to the ceding company s earned  subject premium for that agreement  less expense loading  Also known as  burning cost  ',
#  'The risk involved in situations that present the opportunity for loss but no opportunity for gain  Pure risks are generally insurable  whereas speculative risks (which also present the opportunity for gain) generally are not  See also',
#  'A type of claims-made policy requiring that a claim must be made against the insured during the policy period for coverage to apply  Unlike claims-made and reported forms  pure claims-made policies do not specify that the claim must also be reported to the insurer during the policy period  Instead  they indicate only that the claim must be reported to the insurer  immediately  or  as soon as practicable   For insureds  pure claims-made policies are preferable to claims-made and reported policies because it is sometimes difficult to report a claim to an insurer when it is made late in a policy period ',
#  'A common law remedy to the employment-at-will doctrine that has been created by the judicial system  Courts in various jurisdictions have recognized that an employee should not be terminated for exercising rights under other laws that were enacted to protect the employee  An example of a wrongful termination suit that has been allowed involved the firing of an employee for missing a week of work to serve on jury duty ',
#  'A form of business life insurance in which each member of a group purchases insurance on the other members of the group to ensure continuance of the business in the event one of the principals becomes disabled or dies ',
#  'An endorsement that alters or clarifies the application of a liability policy to cross-liability claims  Most commonly intended to mean an endorsement that provides cross-liability coverage  However  the term should be used with caution as the original cross-liability endorsements were exclusions that deleted this coverage ',
#  'The party named as a defendant in the cross-complaint ',
#  'Coverage in connection with a suit brought against an insured by another party that has insured status under the same policy  Cross-liability coverage is provided as an intrinsic feature of the standard commercial general liability (CGL) policy  by means of the  separation of insureds  condition  Some umbrella and professional liability policies contain insured-versus-insured exclusions that eliminate cross-liability coverage ',
#  'A form of indemnity that is often used in energy industry and chemical industry contracts  Under cross-indemnity agreements  the indemnification obligation is reciprocal in nature  regardless of fault  Therefore  each party obligates itself to indemnify the other for liabilities arising out of each other s acts or omissions  See also',
#  'An arrangement between a governmental entity and a private entity to finance a public project with private funds  The most common use of this arrangement in the United States is for highways  but it can be utilized on a variety of other infrastructure projects  such as airport  telecommunication  or power projects  In exchange for providing the financing  the private entity receives a share of the revenue generated by the project  such as tolls or fees  for a specified time period ',
#  'An association of governmental risk managers that publishes a monthly magazine  sponsors seminars and an annual conference  and provides other services to its members ',
#  'Liability of a book  periodical  or other type of publisher arising from acts such as plagiarism  libel  or copyright infringement  Publishers of medical  engineering  and technical works may also face an errors and omissions (E O) exposure from damage or injury arising from incorrect information that they provide  Coverage for these exposures is available in specialized policies  known as media liability insurance ',
#  'A process that uses the Internet and related social media to offer a company s stock to investors  This approach represents a dramatic departure from traditional methods of funding business startups (such as having an investment bank offer shares of the company to investors) ',
#  'The transporting of people and or goods for hire  such as by a taxi service  motor carrier  or a delivery service  This coverage is excluded under the personal auto policy (PAP)  Incidental use in an insured s sideline business can be an exception to this exclusion  A taxi service and a delivery service would need a business auto policy (BAP)  and a motor carrier would need a motor carrier or truckers policy ',
#  'An action brought by the defendant against the plaintiff ',
#  'An insurance policy  marketed and underwritten by private insurers  that covers hail damage to insured crops  Farmers often purchase this coverage in areas of the country susceptible to hail  particularly for high-yielding crops  Unlike federal crop insurance  the federal government does not subsidize crop-hail insurance  Licensed insurance agents sell it and the premiums depend  for a large part  on past loss experience  The coverage is township or county rated  in other words  the rate is determined by the historical hail loss experience of that particular township or county  The perils of fire and wind can be added to this coverage  although the availability of these extensions varies by state and by type of crop  See also',
#  'The  plaintiff  named in the cross-complaint ',
#  'Loss prevention suggestions made to an insured that are considered essential to avoid imminent loss of property or injury  These recommendations are normally based on accepted and published safety and loss prevention standards and or governmental regulations and typically have to be fulfilled by the insured for the policy to be written ',
#  'Insurance covering an insured s liability to third parties for causing bodily injury (BI) or property damage (PD) ',
#  'A congressional act of 1945 exempting insurance from federal antitrust laws to the extent that the individual states regulate the industry  The legislation was made necessary by the U S  Supreme Court decision in',
#  'A correction suggested by a rating bureau  which  if not complied with  can result in a fine ',
#  'Insurance for governmental entities (e g   cities  towns  counties  etc ) covering loss resulting from employee dishonesty  Limits can be written to apply per loss (Insurance Services Office  Inc  (ISO)  coverage form O  CR 00 16) or per employee (coverage form P  CR 00 17) ',
#  'A plan for actions to be taken immediately before  during and after a catastrophic event that preserve lives  safeguard property  and reduce the loss of resources essential to the organization s recovery  A crisis management plan is part of a broader business continuity management plan  See also',
#  'An easement that is granted to the public in general or to an entire community  An example of this type of easement is one permitting people to walk across a home owner s land to get to a public beach ',
#  'The 1970 amendments to the Clean Air Act required the Environmental Protection Agency (EPA) to set National Ambient Air Quality Standards (NAAQS) for certain pollutants known to be hazardous to human health  The EPA has identified and set standards to protect human health and welfare for six pollutants  ozone  carbon monoxide  total suspended particulates  sulfur dioxide  lead  and nitrogen oxide  The term  criteria pollutants  derives from the requirement that the EPA must describe the characteristics and potential health and welfare effects of these pollutants  It is on the basis of these criteria that standards are set or revised  See also',
#  'In risk management  any unplanned event or series of events that can cause death or injury to employees or the public or that can disrupt operations  cause physical or environmental damage  shut down the organization  or threaten the organization s financial standing or public image ',
#  'An insuring agreement found within technology errors and omissions and Internet online property and liability insurance policies  Subject to a sublimit (e g    25 000  50 000)  crisis management coverage generally reimburses expenses incurred to restore confidence in the security of the insured s computer system  For example  a crisis management firm might be hired to develop a program for reassuring the customers of an online retailer that  following a breach of the retailer s security system  the system has been reconfigured to prevent future breaches ',
#  'A theory of accident causation and control where any major incidents or accidents that can lead to a crisis are identified and extensive plans to mitigate the effects of such incidents are developed  Crisis management involves effective planning  organizing  leading  and controlling activities and assets in the critical time immediately before  during  and after a major incident  A risk manager should be actively involved in the crisis management process ',
#  'A claims adjuster who represents the interests of an insured in a property loss  Public adjusters negotiate settlement of such claims with the insurer s claim representative  Public adjusters are compensated with a percentage of the payable loss that they are able to secure for their clients (2 to 15 percent  depending upon the size and complexity of the claim)  They are frequently retained in situations involving business interruption (BI) claims  which involve special expertise in the areas of accounting and insurance coverage analysis ',
#  'A form of financial guarantee insurance  covering not all debts of the borrower  but a specific loan  debt issuance  or other financial transaction ',
#  'The cause having the most significant impact in bringing about the loss under a first-party property insurance policy  when two or more independent perils operate at the same time (i e   concurrently) to produce a loss  Courts employ a set of proximate cause rules to resolve causation disputes when a property policy states that it covers or excludes losses  caused by  a peril and there is more than one peril at work in a fact pattern  Under common law  whether the policy provides coverage depends on which peril is chosen as the proximate cause  If the peril selected as the proximate cause is covered  courts consider the loss to have been caused by the covered peril and will hold that the loss is covered  If the peril selected as the proximate cause is uncovered or excluded  courts consider the loss to have been caused by the uncovered or excluded peril and will hold that the loss is not covered ',
# ...
#  'Involves the study of physical forces that impact people who perform particular tasks in a set environment  By designing the work environment with the tasks and people in mind  ergonomics will assist in the process of developing and implementing safe and productive work settings  This process is frequently used to establish well-designed computer workstations and to improve factory and material-handling tasks ',
#  'Written in connection with construction projects outside the United States  EAR policies are designed to cover the risk of loss arising out of the erection and installation of machinery  plant and steel structures  including physical damage to the contract works  equipment and machinery  and liability for third-party bodily injury (BI) or property damage (PD) arising out of these operations  Coverage for delay in start-up (DSU) costs is typically an optional coverage  Covered parties include the general contractor  subcontractors  and in some cases suppliers and manufacturers of equipment  Examples of the types of projects for which EAR coverage is typically purchased include power plants  manufacturing and fabrication facilities  water and wastewater treatment facilities  and telecommunications centers (particularly where the erection of signal towers is involved)  Some insurers combine EAR and contractors all risks (CAR) coverages into one form  Although these terms are sometimes used interchangeably  there are some substantive differences ',
#  'A type of home equity loan in which a disproportionate percentage of minority and elderly home owners were saddled with loans requiring high fees and high interest rates  Such loans  which were common from 2003 to 2008  effectively reduced borrowers  home equity positions to zero and were clearly unaffordable  given these borrowers  relatively limited incomes  In response to the widespread use of such loans  a number of consumer organizations  in conjunction with various state attorneys general  brought lawsuits against the major banks and their directors and officers who had perpetrated equity stripping  The suits were based on the theory that banks  along with their directors and officers  encouraged and assisted lenders in what amounted to predatory lending schemes  knowing they could package and sell these loans in the form of mortgage-backed bonds and  at the same time  remove such loans from their own financial statements  A number of these suits have been settled  with payments made to affected home owners  Other suits are ongoing  See also',
#  'Coverage for loss caused by enforcement of ordinances or laws regulating construction and repair of damaged buildings  Older structures that are damaged may need upgraded electrical  heating  ventilating  and air-conditioning (HVAC)  roofing materials  fences  and plumbing units based on city codes  Many communities have a building ordinance(s) requiring that a building that has been damaged to a specified extent (typically 50 percent) must be demolished and rebuilt in accordance with current building codes rather than simply repaired  Unendorsed  standard commercial property insurance forms do not cover the loss of the undamaged portion of the building  the cost of demolishing that undamaged portion of the building  or the increased cost of rebuilding the entire structure in accordance with current building codes  However  coverage for these loss exposures is widely available by endorsement  Standard homeowners policies include a provision granting a limited amount (e g   10 percent of the dwelling limit) of building ordinance coverage  this amount can be increased by endorsement  See also',
#  'The right of subrogation granted under common law when one party has made a payment on behalf of another and becomes entitled to whatever recovery rights the other party has against a responsible third party  See also',
#  'A judicial doctrine by which a litigant may be prevented  or  stopped   from raising an argument or a legal defense in a lawsuit  Generally  the elements of equitable estoppel are an act or omission on the part of the party to be estopped  reliance on that act or omission by the other party  and circumstances that would make it unfair if the party to be estopped is allowed to raise the argument or legal defense  For example  equitable estoppel may be applied to an insurer that stalls the investigation of a claim  indicates to the insured that the claim will be paid  convinces the insured not to sue the insurer  and then denies the claim based on a 1-year time-to-sue limitation in the policy  Since the insurer in this example persuaded the insured not to file suit in a timely manner  and the insured relied on the insurer s overtures  it would be unfair to allow the insurer to raise the 1-year time-to-sue limitation in the policy  Out of fairness  the insurer may be equitably estopped from raising its time-to-sue limitation as a defense to the claim ',
#  'Environmental monitoring data collected under the auspices of the EMAP  All EMAP data share the common attribute of being of known quality  having been collected in the context of explicit data quality objectives (DQOs) and a consistent quality assurance program ',
#  'Reduces the risk of pollution cleanup cost overruns by providing insurance coverage for excess cleanup costs when the actual cost exceeds the original estimate by more than some established percentage  such as 130 percent  That part of the percentage that exceeds 100 percent represents a built-in  buffer  before coverage is triggered under the policy  The size of the buffer will depend on the underwriter s confidence in the estimate ',
#  'Any layer of insurance (or risk retention) that resides between the primary (burning) layer and the excess layers  For example  if the primary layer is  100 000 and the excess layer attachment point is  500 000  a buffer layer of  400 000 is required ',
#  'For purposes of motor carrier liability limits requirements  motor carriers in foreign commerce are subject to the same requirements as carriers in interstate commerce  As defined in the Motor Carrier Act (MCA) of 1980  the term means commerce between any place in a foreign country  or between the United States and a territory or possession of the United States  insofar as such transportation takes place within the United States  It also includes commerce between places in a foreign country or countries (e g   trade between Canada and Mexico)  insofar as such transportation takes place within the United States ',
#  'A law imposing criminal liability on corporate directors and officers for illegal payments made to foreign officials  For example  the minister of trade in Country A may demand an annual  50 000 payment from Corporation X in return for allowing the corporation to ship its products into Country A  Corporation X s payment of such monies would constitute a violation of FCPA and could subject Corporation X and its directors and officers to liability in the United States ',
#  'Establishes rules for the reporting of foreign financial assets held by U S  taxpayers in a foreign financial institution (FFI) or a nonfinancial foreign entity (NFFE)  FATCA imposes a 30 percent FATCA withholding tax on withholdable payments made to an FFI or an NFFE unless the FFI or the NFFE meets certain stipulated conditions ',
#  'A federal law prohibiting pay discrimination against employees because of their gender  The Act compels businesses to pay equal wages to employees performing substantially equal work  regardless of the sex of the individual employees  Pay differentials may be based on merit  seniority  or any lawful factor other than sex  The Equal Pay Act applies to all businesses regardless of the number of employees  Inequalities in pay between men and women for performance of  substantially equal jobs  are prohibited  unless the differences are due to a factor other than sex  such as a seniority system or merit system  Claims alleging violation of the Equal Pay Act are covered by employment practices liability insurance (EPLI) policies ',
#  'Coverage for loss due to mechanical or electrical breakdown of nearly any type of equipment  including photocopiers and computers  Coverage applies to the cost to repair or replace the equipment and any other property damaged by the equipment breakdown  Resulting business income and extra expense loss is often covered as well  Equipment breakdown insurance is increasingly replacing traditional boiler and machinery (BM) insurance  in part simply because the title is more descriptive of the coverage provided  Also  today s equipment breakdown policies typically provide slightly broader coverage than traditional BM policies  and they usually do not use the specialized terminology found in traditional BM policies ',
#  'Insurance that must be purchased to comply with terms of a contract for example  a mortgagee can purchase insurance on a mortgaged property and charge the premium to the mortgagor ',
#  'A lawsuit brought by foreign investors who bought their shares in foreign-domiciled companies on foreign exchanges for violations of American securities laws with respect to those securities ',
#  'Provides coverage for financial losses arising out of the inability to bring a project to completion  The coverage encompasses delays as well as total termination of the contract resulting from events totally outside the control of the contractor (i e   fire  earthquake  war  revolution  flood  and epidemics)  Types of losses covered by the policy include continued debt servicing  loss of income  ongoing fixed costs  spoilage  and related contingencies  The coverage has a very limited domestic market but is commonly placed as a political risk coverage for contractors working in foreign countries ',
#  'Property insurance covering equipment that is often moved from place to place  A form of inland marine insurance ',
#  'French  a superior force  An unexpected or uncontrollable event that upsets one s plans or releases one from obligation ',
#  'Enforces the principal federal statutes prohibiting employment discrimination  including Title VII of the Civil Rights Act of 1964  the Age Discrimination in Employment Act of 1967  the Equal Pay Act of 1963  Title I of the Americans with Disabilities Act (ADA) of 1990  the Civil Rights Act of 1991  and Section 501 of the Rehabilitation Act of 1973  The EEOC was established by Title VII of the Civil Rights Act of 1964 and began operating July 2  1965  Individuals who believe they have been discriminated against in employment can file administrative charges  which the EEOC investigates and then attempts to reach a voluntary resolution between the charging party and the respondent if it finds that discrimination has occurred  If unable to do so  the EEOC may sue in federal court  The commission also issues regulatory and other forms of guidance interpreting the laws it enforces ',
#  'The clause in a reinsurance contract stating that it is the reinsurer s duty to  follow the fortunes  of the insured as if the reinsurer were a party to the original insurance ',
#  'Also known as specific  working layer  or underlying excess of loss reinsurance  A method by which an insurer may recover losses on an individual risk in excess of a specific per risk retention  Has both property and casualty applications ',
#  'The official flood insurance map of a community on which the Federal Emergency Management Agency (FEMA) has indicated both the special flood hazard areas and the risk premium zones for the designated community  It is the most common map that FEMA produces  used by a variety of parties  Insurance agents and insurers use the FIRM to determine the extent of the flood risk faced by properties and buildings  Community officials use the FIRM to administer floodplain management regulations and to mitigate the loss exposure to floods  Lending institutions and federal government entities use the FIRM to locate properties and buildings in relation to mapped flood hazards and to ascertain whether flood insurance is required when making loans or providing grants to rebuild structures following a disaster  See also',
#  'When an umbrella policy provision follows the underlying policy as to how the provision applies  Follow form also identifies an  excess  liability policy that follows the underlying policies for most policy provisions  The policy may stand alone for certain exclusions  conditions  etc   while relating back to the underlying coverage for most provisions  This type of policy form is typically used excess of scheduled underlying insurance and usually contains a requirement that the insured maintain scheduled underlying insurance  See also',
#  'In liability insurance  the maximum amount the insurer will pay for one person s injuries  If two people are injured in an auto accident and the at-fault driver s policy has a  50 000 per person limit  the insurer will pay no more than  50 000 to each person for his or her injuries  If one person s injuries are worth  25 000 and the other person s are worth  75 000  the first claimant will receive  25 000 and the second will receive the per person maximum of  50 000 from the insurer  See also',
#  'A provision found in nearly all property insurance policies (even in all risks policies) eliminating coverage for damage by flood  May also eliminate coverage for other types of water damage  such as seepage and sewer backup  Flood coverage can sometimes be provided by endorsement  If not  a separate flood insurance policy may be available from the National Flood Insurance Program (NFIP) ',
#  'A nonstandard commercial property insurance provision that essentially converts blanket limits to specific  per location limits  This provision establishes that the most the insured can collect for a commercial property loss at a given location is the amount reported for that location on the insured s statement of values  It is sometimes used in combination with another nonstandard commercial property insurance provision  a margin clause  A margin clause softens the negative impact of the per occurrence limitation of liability provision by stipulating that the most the insured can collect for a loss at a given location is a specified percentage greater than 100 percent (such as 110 or 125 percent) of the values reported for that location ',
#  'In liability insurance  the maximum amount the insurer will pay for all claims resulting from a single occurrence  no matter how many people are injured  how much property is damaged  or how many different claimants may make claims  See also',
#  'Life insurance that has no expiration date and that provides for the payment of the face value upon death of the insured  regardless of when it may occur  This contrasts with term insurance  which pays benefits only if death takes place during the limited term (e g   1  3  5  or 10 years) of the policy  Under permanent life insurance policies  the insured pays a level premium rate all of his or her life  This approach results in an overpayment of premiums in the early years of the policy and an underpayment in the latter years which is intended to average out over the life of the insured  Most types of permanent life insurance (e g   whole life  universal life  and variable life insurance) accumulate a cash value that the insured may borrow or otherwise use ',
#  'A class of workers compensation disability in which the injured employee is incapable of ever working again at any employment  Under most statutes  the employee will receive weekly wages for life ',
#  'A workers compensation disability level in which the injured employee is still able to work but not with the skill and efficiency demonstrated prior to the injury  As a result  the earning capability of the worker is affected  Most workers compensation statutes provide for scheduled benefits based on the percentage of disability ',
#  ...]

# %%
from nltk.tokenize import word_tokenize

tokenized = [word_tokenize(text.lower()) for text in docs]
tokenized
# Out:
# [['an',
#   'optional',
#   'provision',
#   'in',
#   'life',
#   'insurance',
#   'that',
#   'authorizes',
#   'the',
#   'insurer',
#   'to',
#   'pay',
#   'from',
#   'the',
#   'cash',
#   'value',
#   'any',
#   'premium',
#   'due',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'grace',
#   'period',
#   'this',
#   'provision',
#   'is',
#   'useful',
#   'in',
#   'preventing',
#   'inadvertent',
#   'lapse',
#   'of',
#   'the',
#   'policy'],
#  ['provided',
#   'a',
#   'nonjudicial',
#   'dispute',
#   'settlement',
#   'program',
#   'for',
#   'the',
#   'carriage',
#   'of',
#   'household',
#   'goods'],
#  ['a',
#   'class',
#   'of',
#   'organic',
#   'compounds',
#   'composed',
#   'only',
#   'of',
#   'carbon',
#   'and',
#   'hydrogen',
#   'common',
#   'hydrocarbons',
#   'include',
#   'natural',
#   'gas',
#   'crude',
#   'oil',
#   'and',
#   'coal',
#   'hydrocarbons',
#   'are',
#   'the',
#   'primary',
#   'source',
#   'of',
#   'the',
#   'world',
#   's',
#   'electric',
#   'energy',
#   'and',
#   'heat',
#   'sources',
#   'due',
#   'to',
#   'the',
#   'power',
#   'created',
#   'when',
#   'they',
#   'are',
#   'burned'],
#  ['a',
#   'process',
#   'in',
#   'which',
#   'fractures',
#   'in',
#   'hard-to-reach',
#   'shale',
#   'rock',
#   'formations',
#   'below',
#   'the',
#   'earth',
#   's',
#   'surface',
#   'are',
#   'opened',
#   'and',
#   'widened',
#   'by',
#   'injecting',
#   'water',
#   'chemicals',
#   'and',
#   'sand',
#   'under',
#   'high',
#   'pressure',
#   'to',
#   'extract',
#   'natural',
#   'gas',
#   'and',
#   'oil',
#   'trapped',
#   'in',
#   'the',
#   'shale',
#   'rocks',
#   'it',
#   'enables',
#   'wells',
#   'that',
#   'would',
#   'flow',
#   'only',
#   'at',
#   'very',
#   'low',
#   'rates',
#   'to',
#   'produce',
#   'oil',
#   'and',
#   'gas',
#   'in',
#   'commercially',
#   'viable',
#   'volumes'],
#  ['risk',
#   'financing',
#   'techniques',
#   'that',
#   'are',
#   'a',
#   'combination',
#   'of',
#   'retention',
#   'and',
#   'transfer',
#   'hybrid',
#   'plans',
#   'are',
#   'designed',
#   'to',
#   'transfer',
#   'only',
#   'part',
#   'of',
#   'the',
#   'risk',
#   'of',
#   'loss',
#   'to',
#   'an',
#   'insurer',
#   'while',
#   'the',
#   'organization',
#   'retains',
#   'the',
#   'balance',
#   'of',
#   'the',
#   'exposure',
#   'also',
#   'called',
#   'blended',
#   'plans',
#   'or',
#   'alternative',
#   'market',
#   'plans'],
#  ['the',
#   'combination',
#   'of',
#   'a',
#   'standard',
#   'group',
#   'captive',
#   'and',
#   'structured',
#   'reinsurance',
#   'it',
#   'is',
#   'designed',
#   'to',
#   'create',
#   'significant',
#   'limits',
#   'of',
#   'insurance',
#   'for',
#   'risks',
#   'that',
#   'for',
#   'one',
#   'reason',
#   'or',
#   'another',
#   'can',
#   'not',
#   'be',
#   'covered',
#   'in',
#   'the',
#   'commercial',
#   'insurance',
#   'markets',
#   'the',
#   'major',
#   'difference',
#   'between',
#   'the',
#   'hybrid',
#   'captive',
#   'and',
#   'a',
#   'standard',
#   'group',
#   'captive',
#   'is',
#   'how',
#   'limits',
#   'of',
#   'liability',
#   'are',
#   'structured'],
#  ['the',
#   'internal',
#   'rate',
#   'of',
#   'return',
#   'established',
#   'in',
#   'an',
#   'organization',
#   'as',
#   'necessary',
#   'to',
#   'justify',
#   'investment',
#   'in',
#   'an',
#   'operation',
#   'based',
#   'usually',
#   'on',
#   'the',
#   'short-term',
#   'cost',
#   'of',
#   'borrowing',
#   'often',
#   'used',
#   'as',
#   'the',
#   'discount',
#   'rate',
#   'in',
#   'a',
#   'net',
#   'present',
#   'value',
#   'cost',
#   'analysis'],
#  ['a',
#   'type',
#   'of',
#   'risk',
#   'financing',
#   'plan',
#   'that',
#   'makes',
#   'use',
#   'of',
#   'both',
#   'internal',
#   'and',
#   'external',
#   'funds',
#   'to',
#   'pay',
#   'losses',
#   'it',
#   'thus',
#   'falls',
#   'between',
#   'a',
#   'pure',
#   'transfer',
#   'approach',
#   'and',
#   'a',
#   'pure',
#   'retention',
#   'approach',
#   'to',
#   'risk',
#   'the',
#   'costs',
#   'of',
#   'hybrid',
#   'techniques',
#   'tend',
#   'to',
#   'be',
#   'less',
#   'experience-responsive',
#   'as',
#   'compared',
#   'to',
#   'pure',
#   'retention',
#   'but',
#   'more',
#   'experience-responsive',
#   'as',
#   'compared',
#   'to',
#   'pure',
#   'transfer',
#   'techniques',
#   'examples',
#   'of',
#   'hybrid',
#   'techniques',
#   'include',
#   'pooling',
#   'arrangements',
#   'high-deductible',
#   'plans',
#   'multiple-parent',
#   'captives',
#   'and',
#   'retrospectively',
#   'rated',
#   'insurance',
#   'policies'],
#  ['involves',
#   'a',
#   'detailed',
#   'analysis',
#   'of',
#   'all',
#   'the',
#   'steps',
#   'integral',
#   'to',
#   'a',
#   'particular',
#   'task',
#   'this',
#   'process',
#   'includes',
#   'listing',
#   'and',
#   'categorizing',
#   'all',
#   'the',
#   'hazards',
#   'to',
#   'persons',
#   'and',
#   'property',
#   'that',
#   'might',
#   'impact',
#   'each',
#   'step',
#   'and',
#   'detailing',
#   'all',
#   'reasonable',
#   'mechanical',
#   'procedural',
#   'and',
#   'managerial',
#   'safeguards',
#   'against',
#   'each',
#   'hazard',
#   'the',
#   'main',
#   'goal',
#   'is',
#   'to',
#   'make',
#   'each',
#   'task',
#   'and',
#   'the',
#   'overall',
#   'process',
#   'subject',
#   'to',
#   'appropriate',
#   'risk',
#   'control',
#   'techniques',
#   'leading',
#   'to',
#   'greater',
#   'workplace',
#   'safety'],
#  ['permanent',
#   'additions',
#   'or',
#   'changes',
#   'made',
#   'to',
#   'a',
#   'building',
#   'by',
#   'a',
#   'lessee',
#   'at',
#   'his',
#   'or',
#   'her',
#   'own',
#   'expense',
#   'that',
#   'may',
#   'not',
#   'legally',
#   'be',
#   'removed',
#   'property',
#   'policies',
#   'vary',
#   'as',
#   'to',
#   'whether',
#   'tenants',
#   'improvements',
#   'and',
#   'betterments',
#   'are',
#   'covered',
#   'under',
#   'the',
#   'building',
#   'category',
#   'or',
#   'under',
#   'the',
#   'contents',
#   'category',
#   'so',
#   'care',
#   'must',
#   'be',
#   'taken',
#   'to',
#   'assign',
#   'these',
#   'values',
#   'to',
#   'the',
#   'proper',
#   'category',
#   'of',
#   'covered',
#   'property'],
#  ['as',
#   'a',
#   'point',
#   'of',
#   'law',
#   'the',
#   'understanding',
#   'that',
#   'a',
#   'particular',
#   'product',
#   'is',
#   'safe',
#   'and',
#   'suitable',
#   'for',
#   'a',
#   'particular',
#   'use',
#   'when',
#   'the',
#   'vendor',
#   'knows',
#   'at',
#   'the',
#   'time',
#   'of',
#   'sale',
#   'the',
#   'use',
#   'for',
#   'which',
#   'the',
#   'product',
#   'is',
#   'intended'],
#  ['actions',
#   'of',
#   'an',
#   'agent',
#   'that',
#   'may',
#   'extend',
#   'beyond',
#   'the',
#   'rights',
#   'and',
#   'powers',
#   'explicitly',
#   'provided',
#   'in',
#   'the',
#   'agency',
#   'contract',
#   'if',
#   'these',
#   'actions',
#   'result',
#   'in',
#   'no',
#   'response',
#   'from',
#   'the',
#   'insurer',
#   'authority',
#   'is',
#   'extended',
#   'as',
#   'if',
#   'these',
#   'fall',
#   'within',
#   'the',
#   'agency',
#   'contract'],
#  ['to',
#   'sue',
#   'to',
#   'prosecute',
#   'to',
#   'bring',
#   'a',
#   'new',
#   'party',
#   'into',
#   'an',
#   'action'],
#  ['the',
#   'situation',
#   'in',
#   'which',
#   'the',
#   'surplus',
#   'account',
#   'of',
#   'a',
#   'stock',
#   'insurer',
#   'is',
#   'threatened',
#   'by',
#   'exhaustion',
#   'and',
#   'the',
#   'insurer',
#   'invades',
#   'its',
#   'capital',
#   'account',
#   'to',
#   'meet',
#   'liabilities',
#   'some',
#   'jurisdictions',
#   'allow',
#   'this',
#   'but',
#   'most',
#   'do',
#   'not'],
#  ['a',
#   'legal',
#   'principle',
#   'that',
#   'holds',
#   'that',
#   'the',
#   'incorporation',
#   'of',
#   'a',
#   'defective',
#   'product',
#   'into',
#   'real',
#   'property',
#   'constitutes',
#   'property',
#   'damage',
#   '(',
#   'pd',
#   ')',
#   'as',
#   'defined',
#   'in',
#   'the',
#   'commercial',
#   'general',
#   'liability',
#   '(',
#   'cgl',
#   ')',
#   'policy',
#   'this',
#   'doctrine',
#   'has',
#   'been',
#   'argued',
#   'mostly',
#   'unsuccessfully',
#   'in',
#   'pursuit',
#   'of',
#   'liability',
#   'coverage',
#   'for',
#   'construction',
#   'defects',
#   'that',
#   'have',
#   'not',
#   'produced',
#   'actual',
#   'physical',
#   'damage'],
#  ['a',
#   'clause',
#   'in',
#   'a',
#   'life',
#   'or',
#   'health',
#   'insurance',
#   'policy',
#   'that',
#   'stipulates',
#   'a',
#   'given',
#   'length',
#   'of',
#   'time',
#   '(',
#   'usually',
#   '2',
#   'years',
#   ')',
#   'during',
#   'which',
#   'the',
#   'insurer',
#   'may',
#   'contest',
#   'claims',
#   'after',
#   'expiration',
#   'of',
#   'this',
#   'time',
#   'claims',
#   'can',
#   'not',
#   'be',
#   'contested',
#   'for',
#   'any',
#   'reason',
#   'other',
#   'than',
#   'nonpayment',
#   'of',
#   'premium'],
#  ['a',
#   'provision',
#   'in',
#   'a',
#   'liability',
#   'insurance',
#   'policy',
#   'that',
#   'requires',
#   'or',
#   'allows',
#   'the',
#   'insured',
#   'to',
#   'report',
#   'incidents',
#   'accidents',
#   'or',
#   'occurrences',
#   'that',
#   'may',
#   'lead',
#   'to',
#   'claims',
#   'also',
#   'called',
#   'an',
#   'awareness',
#   'provision',
#   'or',
#   'a',
#   'notice',
#   'of',
#   'potential',
#   'claim',
#   'provision'],
#  ['consulting',
#   'services',
#   'provided',
#   'by',
#   'accounting',
#   'firms',
#   'the',
#   'bulk',
#   'of',
#   'which',
#   'involve',
#   'computer',
#   'software',
#   'and',
#   'hardware',
#   'other',
#   'areas',
#   'falling',
#   'under',
#   'the',
#   'heading',
#   'of',
#   'management',
#   'advisory',
#   'services',
#   'include',
#   'business',
#   'or',
#   'asset',
#   'valuation',
#   'mergers',
#   'and',
#   'acquisitions',
#   'investments',
#   'capital',
#   'budgeting',
#   'business',
#   'strategy',
#   'and',
#   'marketing',
#   'organizational',
#   'structure',
#   'business',
#   'operations',
#   'real',
#   'estate',
#   'and',
#   'litigation',
#   'support',
#   'this',
#   'is',
#   'one',
#   'of',
#   'the',
#   'more',
#   'severe',
#   'exposures',
#   'covered',
#   'by',
#   'accountants',
#   'professional',
#   'liability',
#   'policies'],
#  ['a',
#   'healthcare',
#   'provider',
#   'whose',
#   'goal',
#   'it',
#   'is',
#   'to',
#   'provide',
#   'appropriate',
#   'cost-effective',
#   'medical',
#   'treatment',
#   'two',
#   'types',
#   'of',
#   'these',
#   'providers',
#   'are',
#   'the',
#   'health',
#   'maintenance',
#   'organization',
#   '(',
#   'hmo',
#   ')',
#   'and',
#   'the',
#   'preferred',
#   'provider',
#   'organization',
#   '(',
#   'ppo',
#   ')'],
#  ['coverage',
#   'in',
#   'the',
#   'event',
#   'of',
#   'late',
#   'delivery',
#   'of',
#   'a',
#   'product',
#   'for',
#   'an',
#   'agreed',
#   'amount',
#   'based',
#   'on',
#   'the',
#   'contract',
#   'between',
#   'the',
#   'insured',
#   'manufacturer',
#   'and',
#   'a',
#   'purchaser',
#   'designed',
#   'for',
#   'manufacturers',
#   'that',
#   'are',
#   'compelled',
#   'to',
#   'enter',
#   'into',
#   'contracts',
#   'under',
#   'which',
#   'they',
#   'assume',
#   'responsibility',
#   'for',
#   'delay',
#   'in',
#   'completion',
#   'of',
#   'a',
#   'product',
#   'the',
#   'policy',
#   'generally',
#   'covers',
#   '90',
#   'percent',
#   'of',
#   'the',
#   'penalty',
#   'loss',
#   'sustained',
#   'but',
#   'does',
#   'not',
#   'extend',
#   'to',
#   'strikes',
#   'or',
#   'labor',
#   'disputes'],
#  ['a',
#   'form',
#   'of',
#   'liability',
#   'coverage',
#   'written',
#   'to',
#   'cover',
#   'organizations',
#   'engaged',
#   'in',
#   'delivering',
#   'medical',
#   'services',
#   'on',
#   'a',
#   'managed-care',
#   'basis',
#   'such',
#   'as',
#   'health',
#   'maintenance',
#   'organizations',
#   '(',
#   'hmos',
#   ')',
#   'representative',
#   'types',
#   'of',
#   'claims',
#   'covered',
#   'by',
#   'the',
#   'policies',
#   'include',
#   'allegations',
#   'of',
#   'negligent',
#   'provider',
#   'selection',
#   'direct',
#   'professional',
#   'liability',
#   'and',
#   'wrongful',
#   'denial',
#   'of',
#   'treatment'],
#  ['an',
#   'endorsement',
#   'to',
#   'a',
#   'fiduciary',
#   'liability',
#   'policy',
#   'providing',
#   'coverage',
#   'for',
#   'bodily',
#   'injury',
#   '(',
#   'bi',
#   ')',
#   'property',
#   'damage',
#   '(',
#   'pd',
#   ')',
#   'and',
#   'personal',
#   'injury',
#   '(',
#   'pi',
#   ')',
#   'when',
#   'they',
#   'result',
#   'from',
#   'administering',
#   'managed',
#   'care',
#   'health',
#   'plans',
#   'this',
#   'endorsement',
#   'is',
#   'necessary',
#   'because',
#   'fiduciary',
#   'liability',
#   'policies',
#   'usually',
#   'exclude',
#   'coverage',
#   'for',
#   'these',
#   'perils',
#   'however',
#   'because',
#   'managed',
#   'care',
#   'plans',
#   'are',
#   'subject',
#   'to',
#   'employee',
#   'retirement',
#   'income',
#   'security',
#   'act',
#   '(',
#   'erisa',
#   ')',
#   'such',
#   'coverage',
#   'is',
#   'necessary',
#   'the',
#   'two',
#   'most',
#   'common',
#   'claims',
#   'involving',
#   'managed',
#   'care',
#   'plans',
#   'allege',
#   '(',
#   '1',
#   ')',
#   'that',
#   'the',
#   'employer-sponsor',
#   'of',
#   'a',
#   'managed',
#   'healthcare',
#   'plan',
#   'negligently',
#   'selected',
#   'the',
#   'managed',
#   'healthcare',
#   'plan',
#   'provider',
#   'and',
#   '(',
#   '2',
#   ')',
#   'that',
#   'the',
#   'employer-sponsor',
#   'of',
#   'a',
#   'managed',
#   'healthcare',
#   'plan',
#   'wrongly',
#   'denied',
#   'or',
#   'delayed',
#   'medical',
#   'benefits',
#   'provided',
#   'by',
#   'the',
#   'plan'],
#  ['a',
#   'process',
#   'by',
#   'which',
#   'the',
#   'delivery',
#   'of',
#   'health',
#   'care',
#   'is',
#   'structured',
#   'and',
#   'monitored',
#   'with',
#   'the',
#   'goal',
#   'of',
#   'providing',
#   'medical',
#   'services',
#   'that',
#   'are',
#   'both',
#   'appropriate',
#   'and',
#   'economically',
#   'reasonable'],
#  ['software',
#   'that',
#   'is',
#   'designed',
#   'to',
#   'infiltrate',
#   'and',
#   'damage',
#   'a',
#   'computer',
#   'system',
#   'without',
#   'the',
#   'computer',
#   'owner',
#   's',
#   'knowledge',
#   'or',
#   'consent',
#   'the',
#   'term',
#   'is',
#   'a',
#   'shortened',
#   'combination',
#   'of',
#   'the',
#   'words',
#   'malicious',
#   'and',
#   'software',
#   'and',
#   'is',
#   'a',
#   'generic',
#   'term',
#   'used',
#   'to',
#   'refer',
#   'to',
#   'a',
#   'variety',
#   'of',
#   'forms',
#   'of',
#   'hostile',
#   'or',
#   'intrusive',
#   'software',
#   'such',
#   'as',
#   'computer',
#   'viruses',
#   'worms',
#   'trojan',
#   'horses',
#   'and',
#   'spyware',
#   'see',
#   'also'],
#  ['a',
#   'broad',
#   'all',
#   'risks',
#   'policy',
#   'that',
#   'provides',
#   'a',
#   'combination',
#   'of',
#   'commercial',
#   'property',
#   'and',
#   'commercial',
#   'inland',
#   'marine',
#   'coverages',
#   'manufacturers',
#   'and',
#   'many',
#   'other',
#   'businesses',
#   'need',
#   'mops',
#   'were',
#   'developed',
#   'in',
#   'the',
#   'mid-1950s',
#   'as',
#   'a',
#   'method',
#   'of',
#   'insuring',
#   'in',
#   'a',
#   'single',
#   'policy',
#   'stock',
#   'both',
#   'during',
#   'the',
#   'manufacturing',
#   'process',
#   'and',
#   'in',
#   'transit',
#   'because',
#   'the',
#   'mop',
#   's',
#   'combination',
#   'of',
#   'commercial',
#   'property',
#   'and',
#   'commercial',
#   'marine',
#   'coverages',
#   'met',
#   'the',
#   'needs',
#   'of',
#   'many',
#   'different',
#   'types',
#   'of',
#   'organizations',
#   'mop',
#   'eligibility',
#   'also',
#   'expanded',
#   'over',
#   'time',
#   'to',
#   'include',
#   'many',
#   'industrial',
#   'processing',
#   'and',
#   'commercial',
#   'operations',
#   'in',
#   'recent',
#   'years',
#   'the',
#   'term',
#   'commercial',
#   'output',
#   'policy',
#   'and',
#   'the',
#   'cop',
#   'acronym',
#   'have',
#   'begun',
#   'to',
#   'replace',
#   'the',
#   'term',
#   'manufacturers',
#   'output',
#   'policy',
#   'and',
#   'the',
#   'mop',
#   'acronym',
#   'in',
#   'the',
#   'commercial',
#   'insurance',
#   'arena',
#   'since',
#   'they',
#   'more',
#   'accurately',
#   'reflect',
#   'the',
#   'wide',
#   'range',
#   'of',
#   'organizations',
#   'that',
#   'can',
#   'be',
#   'insured',
#   'under',
#   'this',
#   'type',
#   'of',
#   'policy',
#   'the',
#   'american',
#   'association',
#   'of',
#   'insurance',
#   'services',
#   '(',
#   'aais',
#   ')',
#   'offers',
#   'standard',
#   'cop',
#   'forms',
#   'and',
#   'rules',
#   'for',
#   'use',
#   'by',
#   'its',
#   'member',
#   'insurers',
#   'in',
#   'addition',
#   'many',
#   'insurers',
#   'have',
#   'developed',
#   'their',
#   'own',
#   'cop',
#   'forms',
#   'and',
#   'rules',
#   'cop',
#   'premiums',
#   'are',
#   'typically',
#   'developed',
#   'using',
#   'a',
#   'distinctive',
#   'rating',
#   'system',
#   '(',
#   'referred',
#   'to',
#   'as',
#   'a',
#   'deficiency',
#   'point',
#   'rating',
#   'system',
#   ')',
#   'which',
#   'allows',
#   'many',
#   'insurers',
#   'to',
#   'be',
#   'more',
#   'competitive',
#   'using',
#   'a',
#   'cop',
#   'than',
#   'they',
#   'could',
#   'be',
#   'using',
#   'a',
#   'standard',
#   'commercial',
#   'property',
#   'policy'],
#  ['a',
#   'property',
#   'insurance',
#   'endorsement',
#   'or',
#   'provision',
#   'establishing',
#   'market',
#   'value',
#   '(',
#   'rather',
#   'than',
#   'actual',
#   'cash',
#   'value',
#   '(',
#   'acv',
#   ')',
#   'or',
#   'replacement',
#   'cost',
#   '(',
#   'rc',
#   ')',
#   'value',
#   ')',
#   'as',
#   'the',
#   'valuation',
#   'basis',
#   'for',
#   'covered',
#   'property',
#   'usually',
#   'used',
#   'in',
#   'connection',
#   'with',
#   'agricultural',
#   'products',
#   'and',
#   'other',
#   'commodities',
#   'whose',
#   'value',
#   'fluctuates',
#   'in',
#   'accordance',
#   'with',
#   'a',
#   'commodities',
#   'exchange',
#   'also',
#   'occasionally',
#   'used',
#   'as',
#   'the',
#   'valuation',
#   'basis',
#   'for',
#   'a',
#   'building'],
#  ['refers',
#   'to',
#   'a',
#   'deductible',
#   'arrangement',
#   'under',
#   'which',
#   'the',
#   'policy',
#   'deductible',
#   'equals',
#   'the',
#   'policy',
#   'limit'],
#  ['a',
#   'contract',
#   'used',
#   'by',
#   'oil',
#   'and',
#   'gas',
#   'companies',
#   'to',
#   'enter',
#   'into',
#   'an',
#   'agreement',
#   'in',
#   'advance',
#   'with',
#   'their',
#   'contractors',
#   'that',
#   'specifies',
#   'the',
#   'terms',
#   'and',
#   'conditions',
#   'that',
#   'will',
#   'govern',
#   'the',
#   'contractors',
#   'work',
#   'the',
#   'agreement',
#   'is',
#   'typically',
#   'used',
#   'for',
#   'on-site',
#   'services',
#   'performed',
#   'by',
#   'oilfield',
#   'service',
#   'contractors',
#   'on',
#   'a',
#   'repetitive',
#   'basis',
#   'such',
#   'as',
#   'equipment',
#   'maintenance',
#   'well',
#   'services',
#   'and',
#   'cementing',
#   'services',
#   'its',
#   'goal',
#   'is',
#   'to',
#   'speed',
#   'up',
#   'and',
#   'simplify',
#   'future',
#   'contracts',
#   'for',
#   'long-term',
#   'client',
#   'vendor',
#   'relationships'],
#  ['in',
#   'property',
#   'and',
#   'liability',
#   'coverage',
#   'the',
#   'combining',
#   'of',
#   'several',
#   'locations',
#   'or',
#   'operations',
#   'under',
#   'a',
#   'single',
#   'policy',
#   'for',
#   'the',
#   'same',
#   'insured',
#   'or',
#   'insureds',
#   'the',
#   'term',
#   'may',
#   'also',
#   'be',
#   'used',
#   'in',
#   'the',
#   'case',
#   'of',
#   'construction',
#   'wrap-ups',
#   'in',
#   'either',
#   'case',
#   'underlying',
#   'policies',
#   'or',
#   'certificates',
#   'of',
#   'insurance',
#   'are',
#   'issued',
#   'to',
#   'insureds',
#   'under',
#   'the',
#   'policy',
#   'as',
#   'evidence',
#   'of',
#   'coverage',
#   'under',
#   'the',
#   'master',
#   'policy'],
#  ['one',
#   'of',
#   'six',
#   'building',
#   'construction',
#   'categories',
#   'established',
#   'by',
#   'insurance',
#   'services',
#   'office',
#   'inc',
#   '(',
#   'iso',
#   ')',
#   'in',
#   'its'],
#  ['coverage',
#   'for',
#   'the',
#   'acts',
#   'errors',
#   'and',
#   'omissions',
#   'of',
#   'physicians',
#   'and',
#   'surgeons',
#   'encompassing',
#   'physicians',
#   'professional',
#   'liability',
#   'insurance',
#   'hospital',
#   'professional',
#   'liability',
#   '(',
#   'hpl',
#   ')',
#   'insurance',
#   'and',
#   'allied',
#   'healthcare',
#   '(',
#   'e',
#   'g',
#   'nurses',
#   ')',
#   'professional',
#   'liability',
#   'insurance',
#   'although',
#   'the',
#   'majority',
#   'of',
#   'policies',
#   'are',
#   'written',
#   'with',
#   'a',
#   'claims-made',
#   'coverage',
#   'trigger',
#   'such',
#   'coverage',
#   'is',
#   'sometimes',
#   'available',
#   'on',
#   'an',
#   'occurrence',
#   'basis',
#   'typical',
#   'exclusions',
#   'are',
#   'for',
#   'intentional',
#   'criminal',
#   'acts',
#   'punitive',
#   'damages',
#   'sexual',
#   'misconduct',
#   'and',
#   'specialized',
#   'procedures',
#   '(',
#   'e',
#   'g',
#   'radial',
#   'keratotomy',
#   ')',
#   'for',
#   'which',
#   'coverage',
#   'may',
#   'be',
#   'bought',
#   'back',
#   'in',
#   'return',
#   'for',
#   'additional',
#   'premium',
#   'in',
#   'addition',
#   'to',
#   'commercial',
#   'insurers',
#   'medical',
#   'malpractice',
#   'coverage',
#   'is',
#   'also',
#   'available',
#   'in',
#   'most',
#   'states',
#   'through',
#   'physician-owned',
#   'insurance',
#   'companies',
#   'known',
#   'as',
#   'bedpan',
#   'mutuals'],
#  ['the',
#   'price',
#   'that',
#   'would',
#   'have',
#   'to',
#   'be',
#   'paid',
#   'to',
#   'purchase',
#   'an',
#   'asset',
#   'in',
#   'its',
#   'particular',
#   'market'],
#  ['the',
#   'worst',
#   'loss',
#   'that',
#   'could',
#   'possibly',
#   'occur',
#   'because',
#   'of',
#   'a',
#   'single',
#   'event',
#   'see',
#   'also'],
#  ['statutory',
#   'limitations',
#   'currently',
#   'on',
#   'the',
#   'books',
#   'in',
#   'a',
#   'number',
#   'of',
#   'states',
#   '(',
#   'and',
#   'being',
#   'considered',
#   'in',
#   'others',
#   'as',
#   'well',
#   'as',
#   'on',
#   'the',
#   'federal',
#   'level',
#   ')',
#   'limiting',
#   'the',
#   'dollar',
#   'amount',
#   'of',
#   'non-economic',
#   'damages',
#   'recoverable',
#   'in',
#   'a',
#   'claim',
#   'alleging',
#   'medical',
#   'malpractice',
#   'such',
#   'legislation',
#   'is',
#   'most',
#   'prevalent',
#   'in',
#   'states',
#   'where',
#   'high',
#   'medical',
#   'liability',
#   'claim',
#   'levels',
#   'have',
#   'made',
#   'it',
#   'difficult',
#   'or',
#   'even',
#   'impossible',
#   'for',
#   'substantial',
#   'numbers',
#   'of',
#   'doctors',
#   'to',
#   'obtain',
#   'professional',
#   'liability',
#   'coverage',
#   'caps',
#   'place',
#   'a',
#   'limit',
#   'on',
#   'damages',
#   'for',
#   'items',
#   'such',
#   'as',
#   'pain',
#   'and',
#   'suffering',
#   'loss',
#   'of',
#   'companionship',
#   'and',
#   'permanent',
#   'disfigurement',
#   'generally',
#   'in',
#   'the',
#   'amount',
#   'of',
#   'either',
#   '250',
#   '000',
#   'or',
#   '500',
#   '000',
#   'per',
#   'claimant',
#   'however',
#   'caps',
#   'are',
#   'inapplicable',
#   'to',
#   'economic',
#   'losses',
#   'such',
#   'as',
#   'medical',
#   'expenses',
#   'and',
#   'lost',
#   'wages',
#   'that',
#   'result',
#   'from',
#   'medical',
#   'negligence'],
#  ['federal',
#   'act',
#   'that',
#   'establishes',
#   'a',
#   'private',
#   'right',
#   'of',
#   'action',
#   'for',
#   'actual',
#   'or',
#   'statutory',
#   'damages',
#   '(',
#   'as',
#   'well',
#   'as',
#   'criminal',
#   'and',
#   'administrative',
#   'sanctions',
#   ')',
#   'against',
#   'employers',
#   'and',
#   'contractors',
#   'of',
#   'migrant',
#   'or',
#   'seasonal',
#   'agricultural',
#   'workers',
#   'who',
#   'violate',
#   'the',
#   'act',
#   's',
#   'housing',
#   'and',
#   'motor',
#   'vehicle',
#   'safety',
#   'requirements',
#   'motor',
#   'vehicle',
#   'liability',
#   'insurance',
#   'requirements',
#   'and',
#   'job',
#   'information',
#   'disclosure',
#   'requirements'],
#  ['a',
#   'california',
#   'tort',
#   'reform',
#   'act',
#   'passed',
#   'in',
#   '1975',
#   'that',
#   'may',
#   'be',
#   'replicated',
#   'in',
#   'other',
#   'states',
#   'it',
#   'has',
#   'shown',
#   'success',
#   'in',
#   'limiting',
#   'the',
#   'increases',
#   'of',
#   'medical',
#   'malpractice',
#   'costs',
#   'several',
#   'of',
#   'micra',
#   's',
#   'important',
#   'features',
#   'include',
#   '(',
#   '1',
#   ')',
#   'non-economic',
#   'damages',
#   'that',
#   'are',
#   'capped',
#   'for',
#   'medical',
#   'negligence',
#   'at',
#   '250',
#   '000',
#   '(',
#   '2',
#   ')',
#   'economic',
#   'damages',
#   'that',
#   'are',
#   'not',
#   'capped',
#   '(',
#   '3',
#   ')',
#   'damage',
#   'limitations',
#   'that',
#   'are',
#   'provided',
#   'through',
#   'the',
#   'collateral',
#   'source',
#   'rule',
#   '(',
#   '4',
#   ')',
#   'a',
#   'sliding',
#   'scale',
#   'for',
#   'lawyers',
#   'contingency',
#   'fees',
#   '(',
#   '5',
#   ')',
#   'a',
#   '90-day',
#   'advance',
#   'notice',
#   'for',
#   'filing',
#   'a',
#   'claim',
#   'and',
#   '(',
#   '6',
#   ')',
#   'a',
#   'statute',
#   'of',
#   'limitations',
#   'that',
#   'requires',
#   'notification',
#   'within',
#   '1',
#   'year',
#   'from',
#   'discovery',
#   'and',
#   'within',
#   '3',
#   'years',
#   'of',
#   'the',
#   'date',
#   'of',
#   'injury'],
#  ['a',
#   'provision',
#   'of',
#   'most',
#   'state',
#   'workers',
#   'compensation',
#   'laws',
#   'that',
#   'establishes',
#   'the',
#   'maximum',
#   'amount',
#   'a',
#   'healthcare',
#   'provider',
#   'may',
#   'collect',
#   'for',
#   'injuries',
#   'treatable',
#   'under',
#   'the',
#   'act'],
#  ['the',
#   'u',
#   's',
#   'government',
#   'welfare',
#   'system',
#   'administered',
#   'by',
#   'the',
#   'states',
#   'and',
#   'subsidized',
#   'by',
#   'the',
#   'federal',
#   'government',
#   'covering',
#   'various',
#   'medical',
#   'expenses',
#   'for',
#   'those',
#   'of',
#   'low',
#   'income',
#   'below',
#   'limits',
#   'set',
#   'by',
#   'state',
#   'laws'],
#  ['the',
#   'part',
#   'of',
#   'a',
#   'commercial',
#   'contract',
#   'in',
#   'which',
#   'the',
#   'types',
#   'and',
#   'minimum',
#   'amounts',
#   'of',
#   'insurance',
#   'the',
#   'parties',
#   'agree',
#   'to',
#   'provide',
#   'in',
#   'connection',
#   'with',
#   'their',
#   'performance',
#   'of',
#   'the',
#   'contract',
#   'are',
#   'specified'],
#  ['the',
#   'mechanism',
#   'developed',
#   'by',
#   'the',
#   'national',
#   'association',
#   'of',
#   'insurance',
#   'commissioners',
#   '(',
#   'naic',
#   ')',
#   'to',
#   'assist',
#   'states',
#   'in',
#   'overseeing',
#   'the',
#   'financial',
#   'condition',
#   'of',
#   'insurance',
#   'companies',
#   'the',
#   'iris',
#   'ratios',
#   'are',
#   'a',
#   'set',
#   'of',
#   'ratios',
#   'designed',
#   'to',
#   'measure',
#   'solvency',
#   'and',
#   'liquidity',
#   'they',
#   'are',
#   'calculated',
#   'from',
#   'insurers',
#   'annual',
#   'statements',
#   'that',
#   'are',
#   'filed',
#   'with',
#   'the',
#   'naic',
#   'and',
#   'insurers',
#   'that',
#   'fail',
#   'one',
#   'or',
#   'more',
#   'tests',
#   'can',
#   'be',
#   'placed',
#   'under',
#   'the',
#   'supervision',
#   'of',
#   'their',
#   'domicile',
#   'regulator'],
#  ['in',
#   'broad',
#   'terms',
#   'the',
#   'entire',
#   'printed',
#   'insurance',
#   'contract',
#   'generally',
#   'an',
#   'insurance',
#   'policy',
#   'is',
#   'assembled',
#   'with',
#   'a',
#   'combination',
#   'of',
#   'various',
#   'standard',
#   'forms',
#   'including',
#   'a',
#   'declarations',
#   'page',
#   'coverage',
#   'form',
#   'and',
#   'endorsements',
#   'sometimes',
#   'a',
#   'causes',
#   'of',
#   'loss',
#   'form',
#   'is',
#   'also',
#   'required',
#   'together',
#   'these',
#   'forms',
#   'delineate',
#   'the',
#   'coverage',
#   'term',
#   'the',
#   'insurance',
#   'policy',
#   'limits',
#   'the',
#   'grant',
#   'of',
#   'coverage',
#   'exclusions',
#   'and',
#   'other',
#   'limitations',
#   'of',
#   'coverage',
#   'and',
#   'the',
#   'duties',
#   'and',
#   'responsibilities',
#   'of',
#   'the',
#   'insured',
#   'in',
#   'the',
#   'event',
#   'of',
#   'a',
#   'loss',
#   'see',
#   'also'],
#  ['a',
#   'strong',
#   'durable',
#   'slow-burning',
#   'type',
#   'of',
#   'joisted',
#   'masonry',
#   'construction',
#   'also',
#   'called',
#   'heavy',
#   'timber',
#   'construction',
#   'characterized',
#   'by',
#   'heavy',
#   'floors',
#   'and',
#   'thick',
#   'wooden',
#   'columns',
#   'or',
#   'beams',
#   'the',
#   'walls',
#   'of',
#   'such',
#   'a',
#   'building',
#   'generally',
#   'are',
#   'assigned',
#   'a',
#   'fire-resistive',
#   'rating',
#   'of',
#   'at',
#   'least',
#   '2',
#   'hours',
#   'the',
#   'lack',
#   'of',
#   'floor',
#   'joists',
#   'in',
#   'this',
#   'form',
#   'of',
#   'construction',
#   'contributes',
#   'to',
#   'its',
#   'fire-resistance',
#   'since',
#   'the',
#   'corresponding',
#   'air',
#   'pockets',
#   'are',
#   'eliminated'],
#  ['a',
#   'standardized',
#   'formulaic',
#   'method',
#   'of',
#   'predicting',
#   'future',
#   'events',
#   'using',
#   'historical',
#   'information',
#   'catastrophe',
#   'models',
#   'which',
#   'are',
#   'usually',
#   'computerized',
#   'can',
#   'be',
#   'used',
#   'to',
#   'predict',
#   'losses',
#   'based',
#   'upon',
#   'anticipated',
#   'future',
#   'atmospheric',
#   'weather',
#   'patterns',
#   'in',
#   'various',
#   'geographic',
#   'regions'],
#  ['an',
#   'evidentiary',
#   'standard',
#   'that',
#   'applies',
#   'in',
#   'certain',
#   'employment',
#   'discrimination',
#   'cases',
#   '(',
#   'whether',
#   'or',
#   'not',
#   'the',
#   'mixed-motive',
#   'evidentiary',
#   'standard',
#   'applies',
#   'depends',
#   'upon',
#   '(',
#   '1',
#   ')',
#   'the',
#   'particular',
#   'jurisdiction',
#   'in',
#   'which',
#   'a',
#   'case',
#   'is',
#   'filed',
#   'and',
#   '(',
#   '2',
#   ')',
#   'the',
#   'exact',
#   'type',
#   'of',
#   'discrimination',
#   'alleged',
#   ')',
#   'under',
#   'this',
#   'standard',
#   'employee-plaintiffs',
#   'must',
#   'prove',
#   'that',
#   'the',
#   'employer',
#   's',
#   'discriminatory',
#   'act',
#   'for',
#   'which',
#   'a',
#   'claim',
#   'is',
#   'being',
#   'brought',
#   '(',
#   'e',
#   'g',
#   'termination',
#   'reassignment',
#   'demotion',
#   ')',
#   'was',
#   'merely'],
#  ['a',
#   'provision',
#   'in',
#   'a',
#   'life',
#   'insurance',
#   'policy',
#   'that',
#   'adjusts',
#   'the',
#   'amount',
#   'of',
#   'insurance',
#   'when',
#   'the',
#   'insured',
#   's',
#   'age',
#   'was',
#   'misstated',
#   'on',
#   'the',
#   'application',
#   'to',
#   'the',
#   'amount',
#   'that',
#   'the',
#   'premium',
#   'would',
#   'have',
#   'purchased',
#   'at',
#   'the',
#   'correct',
#   'age',
#   'based',
#   'on',
#   'the',
#   'insurer',
#   's',
#   'rates',
#   'at',
#   'the',
#   'date',
#   'of',
#   'policy',
#   'issuance'],
#  ['specialized',
#   'form',
#   'designed',
#   'to',
#   'meet',
#   'the',
#   'unique',
#   'needs',
#   'of',
#   'mobile',
#   'home',
#   'or',
#   'manufactured',
#   'housing',
#   'owners',
#   'it',
#   'provides',
#   'coverage',
#   'comparable',
#   'to',
#   'the',
#   'homeowners',
#   'policy',
#   'including',
#   'property',
#   'loss',
#   'of',
#   'use',
#   'and',
#   'premises',
#   'and',
#   'personal',
#   'liability',
#   'in',
#   'some',
#   'cases',
#   'coverage',
#   'is',
#   'granted',
#   'via',
#   'a',
#   'mobile',
#   'home',
#   'endorsement',
#   'to',
#   'the',
#   'standard',
#   'homeowners',
#   'policy',
#   'in',
#   'other',
#   'cases',
#   'a',
#   'stand-alone',
#   'mobile',
#   'home',
#   'policy',
#   'is',
#   'used',
#   'to',
#   'provide',
#   'coverage'],
#  ['a',
#   'term',
#   'that',
#   'is',
#   'defined',
#   'in',
#   'both',
#   'the',
#   'commercial',
#   'general',
#   'liability',
#   '(',
#   'cgl',
#   ')',
#   'and',
#   'commercial',
#   'auto',
#   'policies',
#   'it',
#   'refers',
#   'to',
#   'equipment',
#   'such',
#   'as',
#   'earthmovers',
#   'tractors',
#   'diggers',
#   'farm',
#   'machinery',
#   'forklifts',
#   'etc',
#   'that',
#   'even',
#   'when',
#   'self-propelled',
#   'are',
#   'not',
#   'considered',
#   'automobiles',
#   'for',
#   'insurance',
#   'purposes',
#   '(',
#   'unless',
#   'they',
#   'are',
#   'subject',
#   'to',
#   'a',
#   'compulsory',
#   'or',
#   'financial',
#   'responsibility',
#   'law',
#   'or',
#   'other',
#   'motor',
#   'vehicle',
#   'insurance',
#   'law',
#   ')',
#   'liability',
#   'arising',
#   'from',
#   'mobile',
#   'equipment',
#   'is',
#   'covered',
#   'in',
#   'the',
#   'general',
#   'liability',
#   'policy',
#   'physical',
#   'damage',
#   'coverage',
#   'is',
#   'usually',
#   'provided',
#   'by',
#   'an',
#   'equipment',
#   'floater',
#   'see',
#   'also'],
#  ['a',
#   'term',
#   'used',
#   'in',
#   'conjunction',
#   'with',
#   'underwriting',
#   'several',
#   'types',
#   'of',
#   'professional',
#   'liability',
#   'insurance',
#   'notably',
#   'accountants',
#   'lawyers',
#   'architects',
#   'and',
#   'engineers',
#   'and',
#   'insurance',
#   'agents',
#   'it',
#   'refers',
#   'to',
#   'the',
#   'respective',
#   'proportions',
#   'of',
#   'specific',
#   'services',
#   'provided',
#   'by',
#   'a',
#   'given',
#   'professional',
#   'firm',
#   'a',
#   'factor',
#   'that',
#   'influences',
#   'the',
#   'expected',
#   'frequency',
#   'and',
#   'severity',
#   'of',
#   'losses',
#   'and',
#   'therefore',
#   'the',
#   'premium',
#   'and',
#   'scope',
#   'of',
#   'coverage',
#   'afforded',
#   'for',
#   'example',
#   'assume',
#   'that',
#   'plaintiff',
#   'personal',
#   'injury',
#   '(',
#   'pi',
#   ')',
#   'cases',
#   '(',
#   'a',
#   'high',
#   'exposure',
#   'area',
#   ')',
#   'comprise',
#   'the',
#   'majority',
#   'of',
#   'law',
#   'firm',
#   'a',
#   's',
#   'work',
#   'in',
#   'contrast',
#   'most',
#   'of',
#   'law',
#   'firm',
#   'b',
#   's',
#   'work',
#   'is',
#   'in',
#   'the',
#   'area',
#   'of',
#   'trusts',
#   'and',
#   'estates',
#   'a',
#   'relatively',
#   'low',
#   'exposure',
#   'activity',
#   'all',
#   'other',
#   'things',
#   'being',
#   'equal',
#   'given',
#   'its',
#   'mix',
#   'of',
#   'services',
#   'law',
#   'firm',
#   'a',
#   'will',
#   'probably',
#   'pay',
#   'a',
#   'higher',
#   'premium',
#   'and',
#   'may',
#   'be',
#   'offered',
#   'more',
#   'restrictive',
#   'coverage',
#   'compared',
#   'to',
#   'law',
#   'firm',
#   'b'],
#  ['a',
#   'false',
#   'or',
#   'misleading',
#   'statement',
#   'that',
#   'if',
#   'intentional',
#   'and',
#   'material',
#   'can',
#   'allow',
#   'the',
#   'insurer',
#   'to',
#   'void',
#   'the',
#   'insurance',
#   'contract',
#   'some',
#   'insurance',
#   'policies',
#   'and',
#   'state',
#   'laws',
#   'that',
#   'govern',
#   'insurance',
#   'contract',
#   'provisions',
#   'vary',
#   'on',
#   'the',
#   'exact',
#   'details',
#   'of',
#   'the',
#   'conditions',
#   'under',
#   'which',
#   'coverage',
#   'may',
#   'be',
#   'voided',
#   'these',
#   'variations',
#   'are',
#   'usually',
#   'denoted',
#   'in',
#   'state',
#   'amendatory',
#   'endorsements',
#   'see',
#   'also'],
#  ['a',
#   'financial',
#   'valuation',
#   'model',
#   'often',
#   'used',
#   'in',
#   'valuing',
#   'customer-related',
#   'intangible',
#   'assets',
#   'that',
#   'estimates',
#   'revenues',
#   'and',
#   'cash',
#   'flows',
#   'derived',
#   'from',
#   'the',
#   'intangible',
#   'asset',
#   'and',
#   'then',
#   'deducts',
#   'portions',
#   'of',
#   'the',
#   'cash',
#   'flow',
#   'that',
#   'can',
#   'be',
#   'attributed',
#   'to',
#   'supporting',
#   'assets',
#   'such',
#   'as',
#   'a',
#   'brand',
#   'name',
#   'or',
#   'fixed',
#   'assets',
#   'that',
#   'contributed',
#   'to',
#   'the',
#   'generation',
#   'of',
#   'the',
#   'cash',
#   'flows',
#   'these',
#   'deductions',
#   'are',
#   'sometimes',
#   'referred',
#   'to',
#   'as',
#   'supporting',
#   'asset',
#   'charges',
#   'the',
#   'resulting',
#   'cash',
#   'flow',
#   'which',
#   'is',
#   'attributable',
#   'solely',
#   'to',
#   'the',
#   'subject',
#   'intangible',
#   'asset',
#   'is',
#   'then',
#   'discounted',
#   'at',
#   'a',
#   'rate',
#   'of',
#   'return',
#   'commensurate',
#   'with',
#   'the',
#   'risk',
#   'of',
#   'the',
#   'asset',
#   'to',
#   'calculate',
#   'a',
#   'present',
#   'value'],
#  ['a',
#   'situation',
#   'that',
#   'arises',
#   'when',
#   'parties',
#   'with',
#   'relatively',
#   'equal',
#   'bargaining',
#   'power',
#   'agree',
#   'to',
#   'name',
#   'each',
#   'other',
#   'as',
#   'additional',
#   'insureds',
#   'on',
#   'their',
#   'respective',
#   'insurance',
#   'policies',
#   'generally',
#   'with',
#   'the',
#   'intent',
#   'that',
#   'each',
#   'party',
#   '(',
#   'the',
#   'named',
#   'insured',
#   ')',
#   'provide',
#   'primary',
#   'coverage',
#   'to',
#   'the',
#   'other',
#   '(',
#   'as',
#   'an',
#   'additional',
#   'insured',
#   ')',
#   'for',
#   'damages',
#   'arising',
#   'out',
#   'of',
#   'the',
#   'named',
#   'insured',
#   's',
#   'negligence'],
#  ['a',
#   'corporation',
#   'owned',
#   'and',
#   'operated',
#   'by',
#   'and',
#   'for',
#   'its',
#   'insureds',
#   'every',
#   'owner',
#   'of',
#   'the',
#   'company',
#   'is',
#   'an',
#   'insured',
#   'every',
#   'insured',
#   'is',
#   'an',
#   'owner'],
#  ['an',
#   'organization',
#   'offering',
#   'benefits',
#   'to',
#   'members',
#   'for',
#   'no',
#   'fixed',
#   'premiums',
#   'but',
#   'assessments',
#   'are',
#   'levied',
#   'to',
#   'meet',
#   'specific',
#   'losses',
#   'as',
#   'they',
#   'occur'],
#  ['traditional',
#   'insurance',
#   'contracts',
#   'have',
#   'one',
#   'trigger',
#   'a',
#   'physical',
#   'event',
#   'or',
#   'occurrence',
#   'that',
#   'activates',
#   'coverage',
#   'multiple',
#   'trigger',
#   'contracts',
#   'are',
#   'designed',
#   'to',
#   'respond',
#   'to',
#   'both',
#   'physical',
#   'hazard-type',
#   'events',
#   'and',
#   'resultant',
#   'financial',
#   'movements',
#   'these',
#   'financial',
#   'movements',
#   'can',
#   'be',
#   'any',
#   'benchmark',
#   'against',
#   'which',
#   'the',
#   'firm',
#   'measures',
#   'its',
#   'financial',
#   'viabilities',
#   'such',
#   'as',
#   'its',
#   'stock',
#   'price',
#   'quarterly',
#   'earnings',
#   'internal',
#   'rate',
#   'of',
#   'return',
#   'etc',
#   'for',
#   'example',
#   'a',
#   'multiple',
#   'trigger',
#   '(',
#   'also',
#   'known',
#   'as',
#   'a',
#   'dual',
#   'trigger',
#   ')',
#   'program',
#   'could',
#   'cover',
#   'property',
#   'loss',
#   'due',
#   'to',
#   'fire',
#   'windstorm',
#   'etc',
#   'and',
#   'a',
#   'reduction',
#   'in',
#   'quarterly',
#   'earnings',
#   'that',
#   'results',
#   'from',
#   'the',
#   'physical',
#   'event'],
#  ['an',
#   'endorsement',
#   'available',
#   'under',
#   'professional',
#   'liability',
#   'policies',
#   'nearly',
#   'always',
#   'in',
#   'police',
#   'professional',
#   'law',
#   'enforcement',
#   'policies',
#   'moonlighting',
#   'endorsements',
#   'cover',
#   'insureds',
#   'for',
#   'their',
#   'liability',
#   'in',
#   'connection',
#   'with',
#   'off-duty',
#   'law',
#   'enforcement',
#   'activities',
#   'coverage',
#   'is',
#   'available',
#   'in',
#   'recognition',
#   'of',
#   'the',
#   'fact',
#   'that',
#   'it',
#   'is',
#   'not',
#   'uncommon',
#   'for',
#   'law',
#   'enforcement',
#   'officers',
#   'to',
#   'hold',
#   'second',
#   'jobs'],
#  ['a',
#   'combination',
#   'of',
#   'whole',
#   'life',
#   'and',
#   'term',
#   'insurance',
#   'paying',
#   'some',
#   'multiple',
#   'of',
#   'the',
#   'amount',
#   'of',
#   'protection'],
#  ['nationalization',
#   'or',
#   'confiscation',
#   'by',
#   'a',
#   'host',
#   'country',
#   'government',
#   'of',
#   'a',
#   'multinational',
#   's',
#   'investment',
#   '(',
#   'e',
#   'g',
#   'plant',
#   'inventory',
#   'equipment',
#   ')',
#   'if',
#   'compensation',
#   'is',
#   'offered',
#   'at',
#   'all',
#   'it',
#   'is',
#   'usually',
#   'far',
#   'below',
#   'fair',
#   'market',
#   'value'],
#  ['damages',
#   'awarded',
#   'based',
#   'upon',
#   'a',
#   'statutory',
#   'directive',
#   'for',
#   'example',
#   'the',
#   'clayton',
#   'act',
#   '(',
#   'a',
#   'law',
#   'that',
#   'prohibits',
#   'agreements',
#   'between',
#   'companies',
#   'to',
#   'fix',
#   'or',
#   'control',
#   'prices',
#   'for',
#   'the',
#   'purpose',
#   'of',
#   'lessening',
#   'competition',
#   ')',
#   'provides',
#   'for',
#   'treble',
#   'damages',
#   'in',
#   'the',
#   'event',
#   'of',
#   'an',
#   'antitrust',
#   'violation',
#   'therefore',
#   'if',
#   'a',
#   'jury',
#   'awarded',
#   '1',
#   'million',
#   'in',
#   'compensatory',
#   'damages',
#   'for',
#   'violating',
#   'the',
#   'clayton',
#   'act',
#   'the',
#   'multiplied',
#   'damages',
#   'would',
#   'be',
#   'an',
#   'additional',
#   '2',
#   'million',
#   'resulting',
#   'in',
#   'a',
#   'total',
#   'award',
#   'of',
#   '3',
#   'million',
#   'multiplied',
#   'damages',
#   'although',
#   'similar',
#   'in',
#   'nature',
#   'and',
#   'intent',
#   'to',
#   'punitive',
#   'damages',
#   'are',
#   'not',
#   'always',
#   'treated',
#   'in',
#   'the',
#   'same',
#   'manner',
#   'when',
#   'determining',
#   'coverage',
#   'within',
#   'a',
#   'liability',
#   'policy',
#   'see',
#   'also'],
#  ['a',
#   'premium',
#   'charge',
#   'added',
#   'to',
#   'the',
#   'premium',
#   'for',
#   'a',
#   'class',
#   'rate',
#   'because',
#   'of',
#   'extra',
#   'hazardous',
#   'exposures'],
#  ['a',
#   'form',
#   'of',
#   'substandard',
#   'rating',
#   'using',
#   'mortality',
#   'or',
#   'morbidity',
#   'tables',
#   'for',
#   'certain',
#   'impaired',
#   'health',
#   'conditions'],
#  ['the',
#   'requirement',
#   'under',
#   'a',
#   'policy',
#   'that',
#   'the',
#   'insurer',
#   'pay',
#   'certain',
#   'losses',
#   'or',
#   'expenses',
#   'not',
#   'arising',
#   'from',
#   'the',
#   'insuring',
#   'agreement',
#   'but',
#   'from',
#   'externally',
#   'imposed',
#   'obligations',
#   'for',
#   'example',
#   'fines',
#   'from',
#   'a',
#   'court',
#   'or',
#   'regulatory',
#   'body',
#   'if',
#   'ecos',
#   'are',
#   'covered',
#   'under',
#   'a',
#   'reinsurance',
#   'agreement',
#   'the',
#   'reinsurer',
#   'pays',
#   'punitive',
#   'damages',
#   'imposed',
#   'on',
#   'the',
#   'insurer'],
#  ['damages',
#   'that',
#   'are',
#   'in',
#   'addition',
#   'to',
#   'or',
#   'outside',
#   'of',
#   'a',
#   'contract',
#   'of',
#   'insurance',
#   'extracontractual',
#   'damages',
#   'are',
#   'awarded',
#   'in',
#   'bad',
#   'faith',
#   'claims',
#   'against',
#   'insurance',
#   'companies',
#   'they',
#   'are',
#   'a',
#   'form',
#   'of',
#   'punitive',
#   'damages',
#   'intended',
#   'to',
#   'punish',
#   'extreme',
#   'insurer',
#   'conduct',
#   'extracontractual',
#   'damage',
#   'awards',
#   'most',
#   'frequently',
#   'arise',
#   'from',
#   'unfair',
#   'claims',
#   'handling',
#   'practices',
#   '(',
#   'e',
#   'g',
#   'unjust',
#   'denial',
#   'of',
#   'coverage',
#   'failure',
#   'to',
#   'settle',
#   'a',
#   'claim',
#   'within',
#   'policy',
#   'limits',
#   ')',
#   'see',
#   'also'],
#  ['any',
#   'of',
#   '406',
#   'chemicals',
#   'identified',
#   'by',
#   'the',
#   'environmental',
#   'protection',
#   'agency',
#   '(',
#   'epa',
#   ')',
#   'as',
#   'toxic',
#   'and',
#   'listed',
#   'under',
#   'superfund',
#   'amendments',
#   'and',
#   'reauthorization',
#   'act',
#   '(',
#   'sara',
#   ')',
#   'of',
#   '1986',
#   'title',
#   'iii'],
#  ['the',
#   'extension',
#   'of',
#   'state',
#   'workers',
#   'compensation',
#   'law',
#   'to',
#   'provide',
#   'benefits',
#   'for',
#   'workers',
#   'hired',
#   'in',
#   'the',
#   'state',
#   'but',
#   'injured',
#   'while',
#   'working',
#   'in',
#   'another',
#   'state',
#   'there',
#   'is',
#   'usually',
#   'a',
#   'maximum',
#   'placed',
#   'on',
#   'the',
#   'amount',
#   'of',
#   'time',
#   'an',
#   'employee',
#   'can',
#   'spend',
#   'outside',
#   'the',
#   'state',
#   'of',
#   'hire',
#   'and',
#   'still',
#   'file',
#   'a',
#   'claim',
#   'in',
#   'that',
#   'state',
#   'this',
#   'term',
#   'is',
#   'also',
#   'used',
#   'in',
#   'international',
#   'insurance',
#   'to',
#   'denote',
#   'coverage',
#   'for',
#   'work-related',
#   'injuries',
#   'occurring',
#   'outside',
#   'the',
#   'boundaries',
#   'of',
#   'the',
#   'country',
#   'of',
#   'hire'],
#  ['the',
#   'legal',
#   'principle',
#   'that',
#   'an',
#   'insurer',
#   'owes',
#   'a',
#   'duty',
#   'of',
#   'defense',
#   'to',
#   'its',
#   'insured',
#   'when',
#   'the',
#   'actual',
#   'facts',
#   'of',
#   'a',
#   'claim',
#   'or',
#   'loss',
#   'match',
#   'the',
#   'provisions',
#   'of',
#   'the',
#   'insurance',
#   'policy',
#   'regardless',
#   'of',
#   'the',
#   'language',
#   'in',
#   'which',
#   'the',
#   'claim',
#   'is',
#   'asserted',
#   'against',
#   'the',
#   'insured',
#   'see',
#   'also'],
#  ['a',
#   'property',
#   'loss',
#   'control',
#   'term',
#   'referring',
#   'to',
#   'the',
#   'maximum',
#   'loss',
#   'expected',
#   'at',
#   'a',
#   'given',
#   'location',
#   'in',
#   'the',
#   'event',
#   'of',
#   'a',
#   'fire',
#   'at',
#   'that',
#   'location',
#   'expressed',
#   'in',
#   'dollars',
#   'or',
#   'as',
#   'a',
#   'percentage',
#   'of',
#   'total',
#   'values',
#   'see',
#   'also'],
#  ['the',
#   'percentile',
#   'of',
#   'the',
#   'probability',
#   'distribution',
#   'corresponding',
#   'to',
#   'the',
#   'point',
#   'at',
#   'which',
#   'capital',
#   'is',
#   'exhausted',
#   'typically',
#   'a',
#   'minimum',
#   'acceptable',
#   'probability',
#   'of',
#   'ruin',
#   'is',
#   'specified',
#   'and',
#   'economic',
#   'capital',
#   'is',
#   'derived',
#   'therefrom'],
#  ['a',
#   'technique',
#   'used',
#   'by',
#   'risk',
#   'managers',
#   'for',
#   'forecasting',
#   'future',
#   'events',
#   'such',
#   'as',
#   'accidental',
#   'and',
#   'business',
#   'losses',
#   'this',
#   'process',
#   'involves',
#   'a',
#   'review',
#   'of',
#   'historical',
#   'loss',
#   'data',
#   'to',
#   'calculate',
#   'a',
#   'probability',
#   'distribution',
#   'that',
#   'can',
#   'be',
#   'used',
#   'to',
#   'predict',
#   'future',
#   'losses',
#   'the',
#   'probability',
#   'analyst',
#   'views',
#   'past',
#   'losses',
#   'as',
#   'a',
#   'range',
#   'of',
#   'outcomes',
#   'of',
#   'what',
#   'might',
#   'be',
#   'expected',
#   'for',
#   'the',
#   'future',
#   'and',
#   'assumes',
#   'that',
#   'the',
#   'environment',
#   'will',
#   'remain',
#   'fairly',
#   'stable',
#   'this',
#   'technique',
#   'is',
#   'particularly',
#   'effective',
#   'for',
#   'companies',
#   'that',
#   'have',
#   'a',
#   'large',
#   'amount',
#   'of',
#   'data',
#   'on',
#   'past',
#   'losses',
#   'and',
#   'that',
#   'have',
#   'experienced',
#   'stable',
#   'operations',
#   'this',
#   'type',
#   'of',
#   'analysis',
#   'is',
#   'contrasted',
#   'to',
#   'trend',
#   'analysis'],
#  ['communication',
#   'during',
#   'special',
#   'relationships',
#   'that',
#   'is',
#   'protected',
#   'from',
#   'disclosure',
#   'to',
#   'third',
#   'parties',
#   'the',
#   'most',
#   'common',
#   'protected',
#   'relationships',
#   'are',
#   'those',
#   'of',
#   'attorney',
#   'client',
#   'cleric',
#   'penitents',
#   'and',
#   'husband',
#   'wife'],
#  ['a',
#   'numerical',
#   'measure',
#   'of',
#   'the',
#   'chance',
#   'or',
#   'likelihood',
#   'that',
#   'a',
#   'particular',
#   'event',
#   'will',
#   'occur',
#   'probabilities',
#   'are',
#   'generally',
#   'assigned',
#   'on',
#   'a',
#   'scale',
#   'from',
#   '0',
#   'to',
#   '1',
#   'a',
#   'probability',
#   'near',
#   '0',
#   'indicates',
#   'an',
#   'outcome',
#   'that',
#   'is',
#   'unlikely',
#   'to',
#   'occur',
#   'while',
#   'a',
#   'probability',
#   'near',
#   '1',
#   'indicates',
#   'an',
#   'outcome',
#   'that',
#   'is',
#   'almost',
#   'certain',
#   'to',
#   'occur'],
#  ['a',
#   'defined',
#   'contribution',
#   'benefit',
#   'plan',
#   'that',
#   'does',
#   'not',
#   'promise',
#   'a',
#   'set',
#   'amount',
#   'at',
#   'retirement',
#   'up',
#   'to',
#   '15',
#   'percent',
#   'of',
#   'employee',
#   'compensation',
#   'can',
#   'be',
#   'contributed',
#   'on',
#   'behalf',
#   'of',
#   'any',
#   'employee',
#   'annually'],
#  ['the',
#   'relationship',
#   'that',
#   'exists',
#   'between',
#   'two',
#   'parties',
#   'by',
#   'virtue',
#   'of',
#   'their',
#   'having',
#   'entered',
#   'into',
#   'a',
#   'contract',
#   'this',
#   'concept',
#   'incorporates',
#   'the',
#   'legal',
#   'principle',
#   'that',
#   'a',
#   'contract',
#   'may',
#   'not',
#   'impose',
#   'duties',
#   'on',
#   'a',
#   'noncontracting',
#   'party',
#   'nor',
#   'may',
#   'a',
#   'noncontracting',
#   'party',
#   'claim',
#   'any',
#   'right',
#   'or',
#   'benefit',
#   'as',
#   'being',
#   'guaranteed',
#   'by',
#   'the',
#   'contract'],
#  ['provides',
#   'coverage',
#   'for',
#   'economic',
#   'losses',
#   'arising',
#   'out',
#   'of',
#   'the',
#   'unilateral',
#   'cancellation',
#   'of',
#   'a',
#   'contract',
#   'as',
#   'a',
#   'result',
#   'of',
#   'direct',
#   'or',
#   'indirect',
#   'actions',
#   'of',
#   'a',
#   'foreign',
#   'government',
#   'or',
#   'its',
#   'agents',
#   'under',
#   'circumstances',
#   'in',
#   'which',
#   'the',
#   'insured',
#   'is',
#   'not',
#   'in',
#   'breach',
#   'of',
#   'contract',
#   'the',
#   'coverage',
#   'is',
#   'usually',
#   'purchased',
#   'by',
#   'importers',
#   'exporters',
#   'and',
#   'contractors'],
#  ['insurance',
#   'to',
#   'indemnify',
#   'the',
#   'insured',
#   'for',
#   'loss',
#   'of',
#   'net',
#   'profit',
#   'chemical',
#   'analysis',
#   'recall',
#   'examination',
#   'transportation',
#   'destruction',
#   'and',
#   'extra',
#   'expenses',
#   'incurred',
#   'to',
#   'regain',
#   'market',
#   'share',
#   'following',
#   'a',
#   'malicious',
#   'product',
#   'tampering',
#   'incident'],
#  ['a',
#   'provision',
#   'found',
#   'in',
#   'some',
#   'reinsurance',
#   'agreements',
#   'that',
#   'provides',
#   'for',
#   'profit',
#   'sharing',
#   'parties',
#   'agree',
#   'to',
#   'a',
#   'formula',
#   'for',
#   'calculating',
#   'profit',
#   'an',
#   'allowance',
#   'for',
#   'the',
#   'reinsurer',
#   's',
#   'expenses',
#   'and',
#   'the',
#   'cedent',
#   's',
#   'share',
#   'of',
#   'such',
#   'profit',
#   'after',
#   'expenses'],
#  ['property',
#   'transfer',
#   'liability',
#   'insurance',
#   'covers',
#   'the',
#   'buyer',
#   'of',
#   'a',
#   'property',
#   'for',
#   'third-party',
#   'bodily',
#   'injury',
#   '(',
#   'bi',
#   ')',
#   'and',
#   'property',
#   'damage',
#   '(',
#   'pd',
#   ')',
#   'claims',
#   'and',
#   'cleanup',
#   'costs',
#   'arising',
#   'out',
#   'of',
#   'the',
#   'property',
#   'but',
#   'only',
#   'for',
#   'contamination',
#   'that',
#   'had',
#   'not',
#   'yet',
#   'been',
#   'detected',
#   'as',
#   'of',
#   'the',
#   'policy',
#   's',
#   'inception',
#   'date',
#   'failure',
#   'to',
#   'disclose',
#   'known',
#   'contamination',
#   'voids',
#   'coverage',
#   'with',
#   'respect',
#   'to',
#   'that',
#   'particular',
#   'pollution',
#   'incident'],
#  ['first-party',
#   'insurance',
#   'that',
#   'indemnifies',
#   'the',
#   'owner',
#   'or',
#   'user',
#   'of',
#   'property',
#   'for',
#   'its',
#   'loss',
#   'or',
#   'the',
#   'loss',
#   'of',
#   'its',
#   'income-producing',
#   'ability',
#   'when',
#   'the',
#   'loss',
#   'or',
#   'damage',
#   'is',
#   'caused',
#   'by',
#   'a',
#   'covered',
#   'peril',
#   'such',
#   'as',
#   'fire',
#   'or',
#   'explosion',
#   'in',
#   'this',
#   'sense',
#   'property',
#   'insurance',
#   'encompasses',
#   'inland',
#   'marine',
#   'boiler',
#   'and',
#   'machinery',
#   '(',
#   'bm',
#   ')',
#   'and',
#   'crime',
#   'insurance',
#   'as',
#   'well',
#   'as',
#   'what',
#   'was',
#   'once',
#   'known',
#   'as',
#   'fire',
#   'insurance',
#   'now',
#   'simply',
#   'called',
#   'property',
#   'insurance',
#   'insurance',
#   'on',
#   'buildings',
#   'and',
#   'their',
#   'contents'],
#  ['as',
#   'defined',
#   'in',
#   'the',
#   'general',
#   'liability',
#   'policy',
#   'physical',
#   'injury',
#   'to',
#   'tangible',
#   'property',
#   'including',
#   'resulting',
#   'loss',
#   'of',
#   'use',
#   'and',
#   'loss',
#   'of',
#   'use',
#   'of',
#   'tangible',
#   'property',
#   'that',
#   'has',
#   'not',
#   'been',
#   'physically',
#   'injured',
#   'also',
#   'addressed',
#   'in',
#   'the',
#   'homeowners',
#   'and',
#   'personal',
#   'auto',
#   'policies'],
#  ['claims',
#   'law',
#   'specialist',
#   'designation',
#   'offered',
#   'by',
#   'the',
#   'american',
#   'educational',
#   'institute',
#   '(',
#   'aei',
#   ')',
#   'it',
#   'requires',
#   'successful',
#   'completion',
#   'of',
#   'the',
#   'aei',
#   'property',
#   'self-study',
#   'program'],
#  ['proportionately'],
#  ['the',
#   'premium',
#   'and',
#   'losses',
#   'are',
#   'calculated',
#   'on',
#   'a',
#   'pro',
#   'rata',
#   'basis',
#   'the',
#   'reinsurer',
#   'has',
#   'a',
#   'fixed',
#   'percentage',
#   'of',
#   'premium',
#   'and',
#   'the',
#   'same',
#   'percentage',
#   'of',
#   'losses'],
#  ['refers',
#   'to',
#   'an',
#   'arrangement',
#   'for',
#   'the',
#   'assignment',
#   'of',
# ...
#   'liability',
#   'in',
#   'the',
#   'united',
#   'states'],
#  ['establishes',
#   'rules',
#   'for',
#   'the',
#   'reporting',
#   'of',
#   'foreign',
#   'financial',
#   'assets',
#   'held',
#   'by',
#   'u',
#   's',
#   'taxpayers',
#   'in',
#   'a',
#   'foreign',
#   'financial',
#   'institution',
#   '(',
#   'ffi',
#   ')',
#   'or',
#   'a',
#   'nonfinancial',
#   'foreign',
#   'entity',
#   '(',
#   'nffe',
#   ')',
#   'fatca',
#   'imposes',
#   'a',
#   '30',
#   'percent',
#   'fatca',
#   'withholding',
#   'tax',
#   'on',
#   'withholdable',
#   'payments',
#   'made',
#   'to',
#   'an',
#   'ffi',
#   'or',
#   'an',
#   'nffe',
#   'unless',
#   'the',
#   'ffi',
#   'or',
#   'the',
#   'nffe',
#   'meets',
#   'certain',
#   'stipulated',
#   'conditions'],
#  ['a',
#   'federal',
#   'law',
#   'prohibiting',
#   'pay',
#   'discrimination',
#   'against',
#   'employees',
#   'because',
#   'of',
#   'their',
#   'gender',
#   'the',
#   'act',
#   'compels',
#   'businesses',
#   'to',
#   'pay',
#   'equal',
#   'wages',
#   'to',
#   'employees',
#   'performing',
#   'substantially',
#   'equal',
#   'work',
#   'regardless',
#   'of',
#   'the',
#   'sex',
#   'of',
#   'the',
#   'individual',
#   'employees',
#   'pay',
#   'differentials',
#   'may',
#   'be',
#   'based',
#   'on',
#   'merit',
#   'seniority',
#   'or',
#   'any',
#   'lawful',
#   'factor',
#   'other',
#   'than',
#   'sex',
#   'the',
#   'equal',
#   'pay',
#   'act',
#   'applies',
#   'to',
#   'all',
#   'businesses',
#   'regardless',
#   'of',
#   'the',
#   'number',
#   'of',
#   'employees',
#   'inequalities',
#   'in',
#   'pay',
#   'between',
#   'men',
#   'and',
#   'women',
#   'for',
#   'performance',
#   'of',
#   'substantially',
#   'equal',
#   'jobs',
#   'are',
#   'prohibited',
#   'unless',
#   'the',
#   'differences',
#   'are',
#   'due',
#   'to',
#   'a',
#   'factor',
#   'other',
#   'than',
#   'sex',
#   'such',
#   'as',
#   'a',
#   'seniority',
#   'system',
#   'or',
#   'merit',
#   'system',
#   'claims',
#   'alleging',
#   'violation',
#   'of',
#   'the',
#   'equal',
#   'pay',
#   'act',
#   'are',
#   'covered',
#   'by',
#   'employment',
#   'practices',
#   'liability',
#   'insurance',
#   '(',
#   'epli',
#   ')',
#   'policies'],
#  ['coverage',
#   'for',
#   'loss',
#   'due',
#   'to',
#   'mechanical',
#   'or',
#   'electrical',
#   'breakdown',
#   'of',
#   'nearly',
#   'any',
#   'type',
#   'of',
#   'equipment',
#   'including',
#   'photocopiers',
#   'and',
#   'computers',
#   'coverage',
#   'applies',
#   'to',
#   'the',
#   'cost',
#   'to',
#   'repair',
#   'or',
#   'replace',
#   'the',
#   'equipment',
#   'and',
#   'any',
#   'other',
#   'property',
#   'damaged',
#   'by',
#   'the',
#   'equipment',
#   'breakdown',
#   'resulting',
#   'business',
#   'income',
#   'and',
#   'extra',
#   'expense',
#   'loss',
#   'is',
#   'often',
#   'covered',
#   'as',
#   'well',
#   'equipment',
#   'breakdown',
#   'insurance',
#   'is',
#   'increasingly',
#   'replacing',
#   'traditional',
#   'boiler',
#   'and',
#   'machinery',
#   '(',
#   'bm',
#   ')',
#   'insurance',
#   'in',
#   'part',
#   'simply',
#   'because',
#   'the',
#   'title',
#   'is',
#   'more',
#   'descriptive',
#   'of',
#   'the',
#   'coverage',
#   'provided',
#   'also',
#   'today',
#   's',
#   'equipment',
#   'breakdown',
#   'policies',
#   'typically',
#   'provide',
#   'slightly',
#   'broader',
#   'coverage',
#   'than',
#   'traditional',
#   'bm',
#   'policies',
#   'and',
#   'they',
#   'usually',
#   'do',
#   'not',
#   'use',
#   'the',
#   'specialized',
#   'terminology',
#   'found',
#   'in',
#   'traditional',
#   'bm',
#   'policies'],
#  ['insurance',
#   'that',
#   'must',
#   'be',
#   'purchased',
#   'to',
#   'comply',
#   'with',
#   'terms',
#   'of',
#   'a',
#   'contract',
#   'for',
#   'example',
#   'a',
#   'mortgagee',
#   'can',
#   'purchase',
#   'insurance',
#   'on',
#   'a',
#   'mortgaged',
#   'property',
#   'and',
#   'charge',
#   'the',
#   'premium',
#   'to',
#   'the',
#   'mortgagor'],
#  ['a',
#   'lawsuit',
#   'brought',
#   'by',
#   'foreign',
#   'investors',
#   'who',
#   'bought',
#   'their',
#   'shares',
#   'in',
#   'foreign-domiciled',
#   'companies',
#   'on',
#   'foreign',
#   'exchanges',
#   'for',
#   'violations',
#   'of',
#   'american',
#   'securities',
#   'laws',
#   'with',
#   'respect',
#   'to',
#   'those',
#   'securities'],
#  ['provides',
#   'coverage',
#   'for',
#   'financial',
#   'losses',
#   'arising',
#   'out',
#   'of',
#   'the',
#   'inability',
#   'to',
#   'bring',
#   'a',
#   'project',
#   'to',
#   'completion',
#   'the',
#   'coverage',
#   'encompasses',
#   'delays',
#   'as',
#   'well',
#   'as',
#   'total',
#   'termination',
#   'of',
#   'the',
#   'contract',
#   'resulting',
#   'from',
#   'events',
#   'totally',
#   'outside',
#   'the',
#   'control',
#   'of',
#   'the',
#   'contractor',
#   '(',
#   'i',
#   'e',
#   'fire',
#   'earthquake',
#   'war',
#   'revolution',
#   'flood',
#   'and',
#   'epidemics',
#   ')',
#   'types',
#   'of',
#   'losses',
#   'covered',
#   'by',
#   'the',
#   'policy',
#   'include',
#   'continued',
#   'debt',
#   'servicing',
#   'loss',
#   'of',
#   'income',
#   'ongoing',
#   'fixed',
#   'costs',
#   'spoilage',
#   'and',
#   'related',
#   'contingencies',
#   'the',
#   'coverage',
#   'has',
#   'a',
#   'very',
#   'limited',
#   'domestic',
#   'market',
#   'but',
#   'is',
#   'commonly',
#   'placed',
#   'as',
#   'a',
#   'political',
#   'risk',
#   'coverage',
#   'for',
#   'contractors',
#   'working',
#   'in',
#   'foreign',
#   'countries'],
#  ['property',
#   'insurance',
#   'covering',
#   'equipment',
#   'that',
#   'is',
#   'often',
#   'moved',
#   'from',
#   'place',
#   'to',
#   'place',
#   'a',
#   'form',
#   'of',
#   'inland',
#   'marine',
#   'insurance'],
#  ['french',
#   'a',
#   'superior',
#   'force',
#   'an',
#   'unexpected',
#   'or',
#   'uncontrollable',
#   'event',
#   'that',
#   'upsets',
#   'one',
#   's',
#   'plans',
#   'or',
#   'releases',
#   'one',
#   'from',
#   'obligation'],
#  ['enforces',
#   'the',
#   'principal',
#   'federal',
#   'statutes',
#   'prohibiting',
#   'employment',
#   'discrimination',
#   'including',
#   'title',
#   'vii',
#   'of',
#   'the',
#   'civil',
#   'rights',
#   'act',
#   'of',
#   '1964',
#   'the',
#   'age',
#   'discrimination',
#   'in',
#   'employment',
#   'act',
#   'of',
#   '1967',
#   'the',
#   'equal',
#   'pay',
#   'act',
#   'of',
#   '1963',
#   'title',
#   'i',
#   'of',
#   'the',
#   'americans',
#   'with',
#   'disabilities',
#   'act',
#   '(',
#   'ada',
#   ')',
#   'of',
#   '1990',
#   'the',
#   'civil',
#   'rights',
#   'act',
#   'of',
#   '1991',
#   'and',
#   'section',
#   '501',
#   'of',
#   'the',
#   'rehabilitation',
#   'act',
#   'of',
#   '1973',
#   'the',
#   'eeoc',
#   'was',
#   'established',
#   'by',
#   'title',
#   'vii',
#   'of',
#   'the',
#   'civil',
#   'rights',
#   'act',
#   'of',
#   '1964',
#   'and',
#   'began',
#   'operating',
#   'july',
#   '2',
#   '1965',
#   'individuals',
#   'who',
#   'believe',
#   'they',
#   'have',
#   'been',
#   'discriminated',
#   'against',
#   'in',
#   'employment',
#   'can',
#   'file',
#   'administrative',
#   'charges',
#   'which',
#   'the',
#   'eeoc',
#   'investigates',
#   'and',
#   'then',
#   'attempts',
#   'to',
#   'reach',
#   'a',
#   'voluntary',
#   'resolution',
#   'between',
#   'the',
#   'charging',
#   'party',
#   'and',
#   'the',
#   'respondent',
#   'if',
#   'it',
#   'finds',
#   'that',
#   'discrimination',
#   'has',
#   'occurred',
#   'if',
#   'unable',
#   'to',
#   'do',
#   'so',
#   'the',
#   'eeoc',
#   'may',
#   'sue',
#   'in',
#   'federal',
#   'court',
#   'the',
#   'commission',
#   'also',
#   'issues',
#   'regulatory',
#   'and',
#   'other',
#   'forms',
#   'of',
#   'guidance',
#   'interpreting',
#   'the',
#   'laws',
#   'it',
#   'enforces'],
#  ['the',
#   'clause',
#   'in',
#   'a',
#   'reinsurance',
#   'contract',
#   'stating',
#   'that',
#   'it',
#   'is',
#   'the',
#   'reinsurer',
#   's',
#   'duty',
#   'to',
#   'follow',
#   'the',
#   'fortunes',
#   'of',
#   'the',
#   'insured',
#   'as',
#   'if',
#   'the',
#   'reinsurer',
#   'were',
#   'a',
#   'party',
#   'to',
#   'the',
#   'original',
#   'insurance'],
#  ['also',
#   'known',
#   'as',
#   'specific',
#   'working',
#   'layer',
#   'or',
#   'underlying',
#   'excess',
#   'of',
#   'loss',
#   'reinsurance',
#   'a',
#   'method',
#   'by',
#   'which',
#   'an',
#   'insurer',
#   'may',
#   'recover',
#   'losses',
#   'on',
#   'an',
#   'individual',
#   'risk',
#   'in',
#   'excess',
#   'of',
#   'a',
#   'specific',
#   'per',
#   'risk',
#   'retention',
#   'has',
#   'both',
#   'property',
#   'and',
#   'casualty',
#   'applications'],
#  ['the',
#   'official',
#   'flood',
#   'insurance',
#   'map',
#   'of',
#   'a',
#   'community',
#   'on',
#   'which',
#   'the',
#   'federal',
#   'emergency',
#   'management',
#   'agency',
#   '(',
#   'fema',
#   ')',
#   'has',
#   'indicated',
#   'both',
#   'the',
#   'special',
#   'flood',
#   'hazard',
#   'areas',
#   'and',
#   'the',
#   'risk',
#   'premium',
#   'zones',
#   'for',
#   'the',
#   'designated',
#   'community',
#   'it',
#   'is',
#   'the',
#   'most',
#   'common',
#   'map',
#   'that',
#   'fema',
#   'produces',
#   'used',
#   'by',
#   'a',
#   'variety',
#   'of',
#   'parties',
#   'insurance',
#   'agents',
#   'and',
#   'insurers',
#   'use',
#   'the',
#   'firm',
#   'to',
#   'determine',
#   'the',
#   'extent',
#   'of',
#   'the',
#   'flood',
#   'risk',
#   'faced',
#   'by',
#   'properties',
#   'and',
#   'buildings',
#   'community',
#   'officials',
#   'use',
#   'the',
#   'firm',
#   'to',
#   'administer',
#   'floodplain',
#   'management',
#   'regulations',
#   'and',
#   'to',
#   'mitigate',
#   'the',
#   'loss',
#   'exposure',
#   'to',
#   'floods',
#   'lending',
#   'institutions',
#   'and',
#   'federal',
#   'government',
#   'entities',
#   'use',
#   'the',
#   'firm',
#   'to',
#   'locate',
#   'properties',
#   'and',
#   'buildings',
#   'in',
#   'relation',
#   'to',
#   'mapped',
#   'flood',
#   'hazards',
#   'and',
#   'to',
#   'ascertain',
#   'whether',
#   'flood',
#   'insurance',
#   'is',
#   'required',
#   'when',
#   'making',
#   'loans',
#   'or',
#   'providing',
#   'grants',
#   'to',
#   'rebuild',
#   'structures',
#   'following',
#   'a',
#   'disaster',
#   'see',
#   'also'],
#  ['when',
#   'an',
#   'umbrella',
#   'policy',
#   'provision',
#   'follows',
#   'the',
#   'underlying',
#   'policy',
#   'as',
#   'to',
#   'how',
#   'the',
#   'provision',
#   'applies',
#   'follow',
#   'form',
#   'also',
#   'identifies',
#   'an',
#   'excess',
#   'liability',
#   'policy',
#   'that',
#   'follows',
#   'the',
#   'underlying',
#   'policies',
#   'for',
#   'most',
#   'policy',
#   'provisions',
#   'the',
#   'policy',
#   'may',
#   'stand',
#   'alone',
#   'for',
#   'certain',
#   'exclusions',
#   'conditions',
#   'etc',
#   'while',
#   'relating',
#   'back',
#   'to',
#   'the',
#   'underlying',
#   'coverage',
#   'for',
#   'most',
#   'provisions',
#   'this',
#   'type',
#   'of',
#   'policy',
#   'form',
#   'is',
#   'typically',
#   'used',
#   'excess',
#   'of',
#   'scheduled',
#   'underlying',
#   'insurance',
#   'and',
#   'usually',
#   'contains',
#   'a',
#   'requirement',
#   'that',
#   'the',
#   'insured',
#   'maintain',
#   'scheduled',
#   'underlying',
#   'insurance',
#   'see',
#   'also'],
#  ['in',
#   'liability',
#   'insurance',
#   'the',
#   'maximum',
#   'amount',
#   'the',
#   'insurer',
#   'will',
#   'pay',
#   'for',
#   'one',
#   'person',
#   's',
#   'injuries',
#   'if',
#   'two',
#   'people',
#   'are',
#   'injured',
#   'in',
#   'an',
#   'auto',
#   'accident',
#   'and',
#   'the',
#   'at-fault',
#   'driver',
#   's',
#   'policy',
#   'has',
#   'a',
#   '50',
#   '000',
#   'per',
#   'person',
#   'limit',
#   'the',
#   'insurer',
#   'will',
#   'pay',
#   'no',
#   'more',
#   'than',
#   '50',
#   '000',
#   'to',
#   'each',
#   'person',
#   'for',
#   'his',
#   'or',
#   'her',
#   'injuries',
#   'if',
#   'one',
#   'person',
#   's',
#   'injuries',
#   'are',
#   'worth',
#   '25',
#   '000',
#   'and',
#   'the',
#   'other',
#   'person',
#   's',
#   'are',
#   'worth',
#   '75',
#   '000',
#   'the',
#   'first',
#   'claimant',
#   'will',
#   'receive',
#   '25',
#   '000',
#   'and',
#   'the',
#   'second',
#   'will',
#   'receive',
#   'the',
#   'per',
#   'person',
#   'maximum',
#   'of',
#   '50',
#   '000',
#   'from',
#   'the',
#   'insurer',
#   'see',
#   'also'],
#  ['a',
#   'provision',
#   'found',
#   'in',
#   'nearly',
#   'all',
#   'property',
#   'insurance',
#   'policies',
#   '(',
#   'even',
#   'in',
#   'all',
#   'risks',
#   'policies',
#   ')',
#   'eliminating',
#   'coverage',
#   'for',
#   'damage',
#   'by',
#   'flood',
#   'may',
#   'also',
#   'eliminate',
#   'coverage',
#   'for',
#   'other',
#   'types',
#   'of',
#   'water',
#   'damage',
#   'such',
#   'as',
#   'seepage',
#   'and',
#   'sewer',
#   'backup',
#   'flood',
#   'coverage',
#   'can',
#   'sometimes',
#   'be',
#   'provided',
#   'by',
#   'endorsement',
#   'if',
#   'not',
#   'a',
#   'separate',
#   'flood',
#   'insurance',
#   'policy',
#   'may',
#   'be',
#   'available',
#   'from',
#   'the',
#   'national',
#   'flood',
#   'insurance',
#   'program',
#   '(',
#   'nfip',
#   ')'],
#  ['a',
#   'nonstandard',
#   'commercial',
#   'property',
#   'insurance',
#   'provision',
#   'that',
#   'essentially',
#   'converts',
#   'blanket',
#   'limits',
#   'to',
#   'specific',
#   'per',
#   'location',
#   'limits',
#   'this',
#   'provision',
#   'establishes',
#   'that',
#   'the',
#   'most',
#   'the',
#   'insured',
#   'can',
#   'collect',
#   'for',
#   'a',
#   'commercial',
#   'property',
#   'loss',
#   'at',
#   'a',
#   'given',
#   'location',
#   'is',
#   'the',
#   'amount',
#   'reported',
#   'for',
#   'that',
#   'location',
#   'on',
#   'the',
#   'insured',
#   's',
#   'statement',
#   'of',
#   'values',
#   'it',
#   'is',
#   'sometimes',
#   'used',
#   'in',
#   'combination',
#   'with',
#   'another',
#   'nonstandard',
#   'commercial',
#   'property',
#   'insurance',
#   'provision',
#   'a',
#   'margin',
#   'clause',
#   'a',
#   'margin',
#   'clause',
#   'softens',
#   'the',
#   'negative',
#   'impact',
#   'of',
#   'the',
#   'per',
#   'occurrence',
#   'limitation',
#   'of',
#   'liability',
#   'provision',
#   'by',
#   'stipulating',
#   'that',
#   'the',
#   'most',
#   'the',
#   'insured',
#   'can',
#   'collect',
#   'for',
#   'a',
#   'loss',
#   'at',
#   'a',
#   'given',
#   'location',
#   'is',
#   'a',
#   'specified',
#   'percentage',
#   'greater',
#   'than',
#   '100',
#   'percent',
#   '(',
#   'such',
#   'as',
#   '110',
#   'or',
#   '125',
#   'percent',
#   ')',
#   'of',
#   'the',
#   'values',
#   'reported',
#   'for',
#   'that',
#   'location'],
#  ['in',
#   'liability',
#   'insurance',
#   'the',
#   'maximum',
#   'amount',
#   'the',
#   'insurer',
#   'will',
#   'pay',
#   'for',
#   'all',
#   'claims',
#   'resulting',
#   'from',
#   'a',
#   'single',
#   'occurrence',
#   'no',
#   'matter',
#   'how',
#   'many',
#   'people',
#   'are',
#   'injured',
#   'how',
#   'much',
#   'property',
#   'is',
#   'damaged',
#   'or',
#   'how',
#   'many',
#   'different',
#   'claimants',
#   'may',
#   'make',
#   'claims',
#   'see',
#   'also'],
#  ['life',
#   'insurance',
#   'that',
#   'has',
#   'no',
#   'expiration',
#   'date',
#   'and',
#   'that',
#   'provides',
#   'for',
#   'the',
#   'payment',
#   'of',
#   'the',
#   'face',
#   'value',
#   'upon',
#   'death',
#   'of',
#   'the',
#   'insured',
#   'regardless',
#   'of',
#   'when',
#   'it',
#   'may',
#   'occur',
#   'this',
#   'contrasts',
#   'with',
#   'term',
#   'insurance',
#   'which',
#   'pays',
#   'benefits',
#   'only',
#   'if',
#   'death',
#   'takes',
#   'place',
#   'during',
#   'the',
#   'limited',
#   'term',
#   '(',
#   'e',
#   'g',
#   '1',
#   '3',
#   '5',
#   'or',
#   '10',
#   'years',
#   ')',
#   'of',
#   'the',
#   'policy',
#   'under',
#   'permanent',
#   'life',
#   'insurance',
#   'policies',
#   'the',
#   'insured',
#   'pays',
#   'a',
#   'level',
#   'premium',
#   'rate',
#   'all',
#   'of',
#   'his',
#   'or',
#   'her',
#   'life',
#   'this',
#   'approach',
#   'results',
#   'in',
#   'an',
#   'overpayment',
#   'of',
#   'premiums',
#   'in',
#   'the',
#   'early',
#   'years',
#   'of',
#   'the',
#   'policy',
#   'and',
#   'an',
#   'underpayment',
#   'in',
#   'the',
#   'latter',
#   'years',
#   'which',
#   'is',
#   'intended',
#   'to',
#   'average',
#   'out',
#   'over',
#   'the',
#   'life',
#   'of',
#   'the',
#   'insured',
#   'most',
#   'types',
#   'of',
#   'permanent',
#   'life',
#   'insurance',
#   '(',
#   'e',
#   'g',
#   'whole',
#   'life',
#   'universal',
#   'life',
#   'and',
#   'variable',
#   'life',
#   'insurance',
#   ')',
#   'accumulate',
#   'a',
#   'cash',
#   'value',
#   'that',
#   'the',
#   'insured',
#   'may',
#   'borrow',
#   'or',
#   'otherwise',
#   'use'],
#  ['a',
#   'class',
#   'of',
#   'workers',
#   'compensation',
#   'disability',
#   'in',
#   'which',
#   'the',
#   'injured',
#   'employee',
#   'is',
#   'incapable',
#   'of',
#   'ever',
#   'working',
#   'again',
#   'at',
#   'any',
#   'employment',
#   'under',
#   'most',
#   'statutes',
#   'the',
#   'employee',
#   'will',
#   'receive',
#   'weekly',
#   'wages',
#   'for',
#   'life'],
#  ['a',
#   'workers',
#   'compensation',
#   'disability',
#   'level',
#   'in',
#   'which',
#   'the',
#   'injured',
#   'employee',
#   'is',
#   'still',
#   'able',
#   'to',
#   'work',
#   'but',
#   'not',
#   'with',
#   'the',
#   'skill',
#   'and',
#   'efficiency',
#   'demonstrated',
#   'prior',
#   'to',
#   'the',
#   'injury',
#   'as',
#   'a',
#   'result',
#   'the',
#   'earning',
#   'capability',
#   'of',
#   'the',
#   'worker',
#   'is',
#   'affected',
#   'most',
#   'workers',
#   'compensation',
#   'statutes',
#   'provide',
#   'for',
#   'scheduled',
#   'benefits',
#   'based',
#   'on',
#   'the',
#   'percentage',
#   'of',
#   'disability'],
#  ...]

# %%
from nltk.corpus import stopwords

stop = set(stopwords.words('english'))

docs = [[word for word in words if  word not in stop] for words in tokenized] # words 是一個列 word 是該列的一個單字
docs
# Out:
# [['optional',
#   'provision',
#   'life',
#   'insurance',
#   'authorizes',
#   'insurer',
#   'pay',
#   'cash',
#   'value',
#   'premium',
#   'due',
#   'end',
#   'grace',
#   'period',
#   'provision',
#   'useful',
#   'preventing',
#   'inadvertent',
#   'lapse',
#   'policy'],
#  ['provided',
#   'nonjudicial',
#   'dispute',
#   'settlement',
#   'program',
#   'carriage',
#   'household',
#   'goods'],
#  ['class',
#   'organic',
#   'compounds',
#   'composed',
#   'carbon',
#   'hydrogen',
#   'common',
#   'hydrocarbons',
#   'include',
#   'natural',
#   'gas',
#   'crude',
#   'oil',
#   'coal',
#   'hydrocarbons',
#   'primary',
#   'source',
#   'world',
#   'electric',
#   'energy',
#   'heat',
#   'sources',
#   'due',
#   'power',
#   'created',
#   'burned'],
#  ['process',
#   'fractures',
#   'hard-to-reach',
#   'shale',
#   'rock',
#   'formations',
#   'earth',
#   'surface',
#   'opened',
#   'widened',
#   'injecting',
#   'water',
#   'chemicals',
#   'sand',
#   'high',
#   'pressure',
#   'extract',
#   'natural',
#   'gas',
#   'oil',
#   'trapped',
#   'shale',
#   'rocks',
#   'enables',
#   'wells',
#   'would',
#   'flow',
#   'low',
#   'rates',
#   'produce',
#   'oil',
#   'gas',
#   'commercially',
#   'viable',
#   'volumes'],
#  ['risk',
#   'financing',
#   'techniques',
#   'combination',
#   'retention',
#   'transfer',
#   'hybrid',
#   'plans',
#   'designed',
#   'transfer',
#   'part',
#   'risk',
#   'loss',
#   'insurer',
#   'organization',
#   'retains',
#   'balance',
#   'exposure',
#   'also',
#   'called',
#   'blended',
#   'plans',
#   'alternative',
#   'market',
#   'plans'],
#  ['combination',
#   'standard',
#   'group',
#   'captive',
#   'structured',
#   'reinsurance',
#   'designed',
#   'create',
#   'significant',
#   'limits',
#   'insurance',
#   'risks',
#   'one',
#   'reason',
#   'another',
#   'covered',
#   'commercial',
#   'insurance',
#   'markets',
#   'major',
#   'difference',
#   'hybrid',
#   'captive',
#   'standard',
#   'group',
#   'captive',
#   'limits',
#   'liability',
#   'structured'],
#  ['internal',
#   'rate',
#   'return',
#   'established',
#   'organization',
#   'necessary',
#   'justify',
#   'investment',
#   'operation',
#   'based',
#   'usually',
#   'short-term',
#   'cost',
#   'borrowing',
#   'often',
#   'used',
#   'discount',
#   'rate',
#   'net',
#   'present',
#   'value',
#   'cost',
#   'analysis'],
#  ['type',
#   'risk',
#   'financing',
#   'plan',
#   'makes',
#   'use',
#   'internal',
#   'external',
#   'funds',
#   'pay',
#   'losses',
#   'thus',
#   'falls',
#   'pure',
#   'transfer',
#   'approach',
#   'pure',
#   'retention',
#   'approach',
#   'risk',
#   'costs',
#   'hybrid',
#   'techniques',
#   'tend',
#   'less',
#   'experience-responsive',
#   'compared',
#   'pure',
#   'retention',
#   'experience-responsive',
#   'compared',
#   'pure',
#   'transfer',
#   'techniques',
#   'examples',
#   'hybrid',
#   'techniques',
#   'include',
#   'pooling',
#   'arrangements',
#   'high-deductible',
#   'plans',
#   'multiple-parent',
#   'captives',
#   'retrospectively',
#   'rated',
#   'insurance',
#   'policies'],
#  ['involves',
#   'detailed',
#   'analysis',
#   'steps',
#   'integral',
#   'particular',
#   'task',
#   'process',
#   'includes',
#   'listing',
#   'categorizing',
#   'hazards',
#   'persons',
#   'property',
#   'might',
#   'impact',
#   'step',
#   'detailing',
#   'reasonable',
#   'mechanical',
#   'procedural',
#   'managerial',
#   'safeguards',
#   'hazard',
#   'main',
#   'goal',
#   'make',
#   'task',
#   'overall',
#   'process',
#   'subject',
#   'appropriate',
#   'risk',
#   'control',
#   'techniques',
#   'leading',
#   'greater',
#   'workplace',
#   'safety'],
#  ['permanent',
#   'additions',
#   'changes',
#   'made',
#   'building',
#   'lessee',
#   'expense',
#   'may',
#   'legally',
#   'removed',
#   'property',
#   'policies',
#   'vary',
#   'whether',
#   'tenants',
#   'improvements',
#   'betterments',
#   'covered',
#   'building',
#   'category',
#   'contents',
#   'category',
#   'care',
#   'must',
#   'taken',
#   'assign',
#   'values',
#   'proper',
#   'category',
#   'covered',
#   'property'],
#  ['point',
#   'law',
#   'understanding',
#   'particular',
#   'product',
#   'safe',
#   'suitable',
#   'particular',
#   'use',
#   'vendor',
#   'knows',
#   'time',
#   'sale',
#   'use',
#   'product',
#   'intended'],
#  ['actions',
#   'agent',
#   'may',
#   'extend',
#   'beyond',
#   'rights',
#   'powers',
#   'explicitly',
#   'provided',
#   'agency',
#   'contract',
#   'actions',
#   'result',
#   'response',
#   'insurer',
#   'authority',
#   'extended',
#   'fall',
#   'within',
#   'agency',
#   'contract'],
#  ['sue', 'prosecute', 'bring', 'new', 'party', 'action'],
#  ['situation',
#   'surplus',
#   'account',
#   'stock',
#   'insurer',
#   'threatened',
#   'exhaustion',
#   'insurer',
#   'invades',
#   'capital',
#   'account',
#   'meet',
#   'liabilities',
#   'jurisdictions',
#   'allow'],
#  ['legal',
#   'principle',
#   'holds',
#   'incorporation',
#   'defective',
#   'product',
#   'real',
#   'property',
#   'constitutes',
#   'property',
#   'damage',
#   '(',
#   'pd',
#   ')',
#   'defined',
#   'commercial',
#   'general',
#   'liability',
#   '(',
#   'cgl',
#   ')',
#   'policy',
#   'doctrine',
#   'argued',
#   'mostly',
#   'unsuccessfully',
#   'pursuit',
#   'liability',
#   'coverage',
#   'construction',
#   'defects',
#   'produced',
#   'actual',
#   'physical',
#   'damage'],
#  ['clause',
#   'life',
#   'health',
#   'insurance',
#   'policy',
#   'stipulates',
#   'given',
#   'length',
#   'time',
#   '(',
#   'usually',
#   '2',
#   'years',
#   ')',
#   'insurer',
#   'may',
#   'contest',
#   'claims',
#   'expiration',
#   'time',
#   'claims',
#   'contested',
#   'reason',
#   'nonpayment',
#   'premium'],
#  ['provision',
#   'liability',
#   'insurance',
#   'policy',
#   'requires',
#   'allows',
#   'insured',
#   'report',
#   'incidents',
#   'accidents',
#   'occurrences',
#   'may',
#   'lead',
#   'claims',
#   'also',
#   'called',
#   'awareness',
#   'provision',
#   'notice',
#   'potential',
#   'claim',
#   'provision'],
#  ['consulting',
#   'services',
#   'provided',
#   'accounting',
#   'firms',
#   'bulk',
#   'involve',
#   'computer',
#   'software',
#   'hardware',
#   'areas',
#   'falling',
#   'heading',
#   'management',
#   'advisory',
#   'services',
#   'include',
#   'business',
#   'asset',
#   'valuation',
#   'mergers',
#   'acquisitions',
#   'investments',
#   'capital',
#   'budgeting',
#   'business',
#   'strategy',
#   'marketing',
#   'organizational',
#   'structure',
#   'business',
#   'operations',
#   'real',
#   'estate',
#   'litigation',
#   'support',
#   'one',
#   'severe',
#   'exposures',
#   'covered',
#   'accountants',
#   'professional',
#   'liability',
#   'policies'],
#  ['healthcare',
#   'provider',
#   'whose',
#   'goal',
#   'provide',
#   'appropriate',
#   'cost-effective',
#   'medical',
#   'treatment',
#   'two',
#   'types',
#   'providers',
#   'health',
#   'maintenance',
#   'organization',
#   '(',
#   'hmo',
#   ')',
#   'preferred',
#   'provider',
#   'organization',
#   '(',
#   'ppo',
#   ')'],
#  ['coverage',
#   'event',
#   'late',
#   'delivery',
#   'product',
#   'agreed',
#   'amount',
#   'based',
#   'contract',
#   'insured',
#   'manufacturer',
#   'purchaser',
#   'designed',
#   'manufacturers',
#   'compelled',
#   'enter',
#   'contracts',
#   'assume',
#   'responsibility',
#   'delay',
#   'completion',
#   'product',
#   'policy',
#   'generally',
#   'covers',
#   '90',
#   'percent',
#   'penalty',
#   'loss',
#   'sustained',
#   'extend',
#   'strikes',
#   'labor',
#   'disputes'],
#  ['form',
#   'liability',
#   'coverage',
#   'written',
#   'cover',
#   'organizations',
#   'engaged',
#   'delivering',
#   'medical',
#   'services',
#   'managed-care',
#   'basis',
#   'health',
#   'maintenance',
#   'organizations',
#   '(',
#   'hmos',
#   ')',
#   'representative',
#   'types',
#   'claims',
#   'covered',
#   'policies',
#   'include',
#   'allegations',
#   'negligent',
#   'provider',
#   'selection',
#   'direct',
#   'professional',
#   'liability',
#   'wrongful',
#   'denial',
#   'treatment'],
#  ['endorsement',
#   'fiduciary',
#   'liability',
#   'policy',
#   'providing',
#   'coverage',
#   'bodily',
#   'injury',
#   '(',
#   'bi',
#   ')',
#   'property',
#   'damage',
#   '(',
#   'pd',
#   ')',
#   'personal',
#   'injury',
#   '(',
#   'pi',
#   ')',
#   'result',
#   'administering',
#   'managed',
#   'care',
#   'health',
#   'plans',
#   'endorsement',
#   'necessary',
#   'fiduciary',
#   'liability',
#   'policies',
#   'usually',
#   'exclude',
#   'coverage',
#   'perils',
#   'however',
#   'managed',
#   'care',
#   'plans',
#   'subject',
#   'employee',
#   'retirement',
#   'income',
#   'security',
#   'act',
#   '(',
#   'erisa',
#   ')',
#   'coverage',
#   'necessary',
#   'two',
#   'common',
#   'claims',
#   'involving',
#   'managed',
#   'care',
#   'plans',
#   'allege',
#   '(',
#   '1',
#   ')',
#   'employer-sponsor',
#   'managed',
#   'healthcare',
#   'plan',
#   'negligently',
#   'selected',
#   'managed',
#   'healthcare',
#   'plan',
#   'provider',
#   '(',
#   '2',
#   ')',
#   'employer-sponsor',
#   'managed',
#   'healthcare',
#   'plan',
#   'wrongly',
#   'denied',
#   'delayed',
#   'medical',
#   'benefits',
#   'provided',
#   'plan'],
#  ['process',
#   'delivery',
#   'health',
#   'care',
#   'structured',
#   'monitored',
#   'goal',
#   'providing',
#   'medical',
#   'services',
#   'appropriate',
#   'economically',
#   'reasonable'],
#  ['software',
#   'designed',
#   'infiltrate',
#   'damage',
#   'computer',
#   'system',
#   'without',
#   'computer',
#   'owner',
#   'knowledge',
#   'consent',
#   'term',
#   'shortened',
#   'combination',
#   'words',
#   'malicious',
#   'software',
#   'generic',
#   'term',
#   'used',
#   'refer',
#   'variety',
#   'forms',
#   'hostile',
#   'intrusive',
#   'software',
#   'computer',
#   'viruses',
#   'worms',
#   'trojan',
#   'horses',
#   'spyware',
#   'see',
#   'also'],
#  ['broad',
#   'risks',
#   'policy',
#   'provides',
#   'combination',
#   'commercial',
#   'property',
#   'commercial',
#   'inland',
#   'marine',
#   'coverages',
#   'manufacturers',
#   'many',
#   'businesses',
#   'need',
#   'mops',
#   'developed',
#   'mid-1950s',
#   'method',
#   'insuring',
#   'single',
#   'policy',
#   'stock',
#   'manufacturing',
#   'process',
#   'transit',
#   'mop',
#   'combination',
#   'commercial',
#   'property',
#   'commercial',
#   'marine',
#   'coverages',
#   'met',
#   'needs',
#   'many',
#   'different',
#   'types',
#   'organizations',
#   'mop',
#   'eligibility',
#   'also',
#   'expanded',
#   'time',
#   'include',
#   'many',
#   'industrial',
#   'processing',
#   'commercial',
#   'operations',
#   'recent',
#   'years',
#   'term',
#   'commercial',
#   'output',
#   'policy',
#   'cop',
#   'acronym',
#   'begun',
#   'replace',
#   'term',
#   'manufacturers',
#   'output',
#   'policy',
#   'mop',
#   'acronym',
#   'commercial',
#   'insurance',
#   'arena',
#   'since',
#   'accurately',
#   'reflect',
#   'wide',
#   'range',
#   'organizations',
#   'insured',
#   'type',
#   'policy',
#   'american',
#   'association',
#   'insurance',
#   'services',
#   '(',
#   'aais',
#   ')',
#   'offers',
#   'standard',
#   'cop',
#   'forms',
#   'rules',
#   'use',
#   'member',
#   'insurers',
#   'addition',
#   'many',
#   'insurers',
#   'developed',
#   'cop',
#   'forms',
#   'rules',
#   'cop',
#   'premiums',
#   'typically',
#   'developed',
#   'using',
#   'distinctive',
#   'rating',
#   'system',
#   '(',
#   'referred',
#   'deficiency',
#   'point',
#   'rating',
#   'system',
#   ')',
#   'allows',
#   'many',
#   'insurers',
#   'competitive',
#   'using',
#   'cop',
#   'could',
#   'using',
#   'standard',
#   'commercial',
#   'property',
#   'policy'],
#  ['property',
#   'insurance',
#   'endorsement',
#   'provision',
#   'establishing',
#   'market',
#   'value',
#   '(',
#   'rather',
#   'actual',
#   'cash',
#   'value',
#   '(',
#   'acv',
#   ')',
#   'replacement',
#   'cost',
#   '(',
#   'rc',
#   ')',
#   'value',
#   ')',
#   'valuation',
#   'basis',
#   'covered',
#   'property',
#   'usually',
#   'used',
#   'connection',
#   'agricultural',
#   'products',
#   'commodities',
#   'whose',
#   'value',
#   'fluctuates',
#   'accordance',
#   'commodities',
#   'exchange',
#   'also',
#   'occasionally',
#   'used',
#   'valuation',
#   'basis',
#   'building'],
#  ['refers',
#   'deductible',
#   'arrangement',
#   'policy',
#   'deductible',
#   'equals',
#   'policy',
#   'limit'],
#  ['contract',
#   'used',
#   'oil',
#   'gas',
#   'companies',
#   'enter',
#   'agreement',
#   'advance',
#   'contractors',
#   'specifies',
#   'terms',
#   'conditions',
#   'govern',
#   'contractors',
#   'work',
#   'agreement',
#   'typically',
#   'used',
#   'on-site',
#   'services',
#   'performed',
#   'oilfield',
#   'service',
#   'contractors',
#   'repetitive',
#   'basis',
#   'equipment',
#   'maintenance',
#   'well',
#   'services',
#   'cementing',
#   'services',
#   'goal',
#   'speed',
#   'simplify',
#   'future',
#   'contracts',
#   'long-term',
#   'client',
#   'vendor',
#   'relationships'],
#  ['property',
#   'liability',
#   'coverage',
#   'combining',
#   'several',
#   'locations',
#   'operations',
#   'single',
#   'policy',
#   'insured',
#   'insureds',
#   'term',
#   'may',
#   'also',
#   'used',
#   'case',
#   'construction',
#   'wrap-ups',
#   'either',
#   'case',
#   'underlying',
#   'policies',
#   'certificates',
#   'insurance',
#   'issued',
#   'insureds',
#   'policy',
#   'evidence',
#   'coverage',
#   'master',
#   'policy'],
#  ['one',
#   'six',
#   'building',
#   'construction',
#   'categories',
#   'established',
#   'insurance',
#   'services',
#   'office',
#   'inc',
#   '(',
#   'iso',
#   ')'],
#  ['coverage',
#   'acts',
#   'errors',
#   'omissions',
#   'physicians',
#   'surgeons',
#   'encompassing',
#   'physicians',
#   'professional',
#   'liability',
#   'insurance',
#   'hospital',
#   'professional',
#   'liability',
#   '(',
#   'hpl',
#   ')',
#   'insurance',
#   'allied',
#   'healthcare',
#   '(',
#   'e',
#   'g',
#   'nurses',
#   ')',
#   'professional',
#   'liability',
#   'insurance',
#   'although',
#   'majority',
#   'policies',
#   'written',
#   'claims-made',
#   'coverage',
#   'trigger',
#   'coverage',
#   'sometimes',
#   'available',
#   'occurrence',
#   'basis',
#   'typical',
#   'exclusions',
#   'intentional',
#   'criminal',
#   'acts',
#   'punitive',
#   'damages',
#   'sexual',
#   'misconduct',
#   'specialized',
#   'procedures',
#   '(',
#   'e',
#   'g',
#   'radial',
#   'keratotomy',
#   ')',
#   'coverage',
#   'may',
#   'bought',
#   'back',
#   'return',
#   'additional',
#   'premium',
#   'addition',
#   'commercial',
#   'insurers',
#   'medical',
#   'malpractice',
#   'coverage',
#   'also',
#   'available',
#   'states',
#   'physician-owned',
#   'insurance',
#   'companies',
#   'known',
#   'bedpan',
#   'mutuals'],
#  ['price', 'would', 'paid', 'purchase', 'asset', 'particular', 'market'],
#  ['worst',
#   'loss',
#   'could',
#   'possibly',
#   'occur',
#   'single',
#   'event',
#   'see',
#   'also'],
#  ['statutory',
#   'limitations',
#   'currently',
#   'books',
#   'number',
#   'states',
#   '(',
#   'considered',
#   'others',
#   'well',
#   'federal',
#   'level',
#   ')',
#   'limiting',
#   'dollar',
#   'amount',
#   'non-economic',
#   'damages',
#   'recoverable',
#   'claim',
#   'alleging',
#   'medical',
#   'malpractice',
#   'legislation',
#   'prevalent',
#   'states',
#   'high',
#   'medical',
#   'liability',
#   'claim',
#   'levels',
#   'made',
#   'difficult',
#   'even',
#   'impossible',
#   'substantial',
#   'numbers',
#   'doctors',
#   'obtain',
#   'professional',
#   'liability',
#   'coverage',
#   'caps',
#   'place',
#   'limit',
#   'damages',
#   'items',
#   'pain',
#   'suffering',
#   'loss',
#   'companionship',
#   'permanent',
#   'disfigurement',
#   'generally',
#   'amount',
#   'either',
#   '250',
#   '000',
#   '500',
#   '000',
#   'per',
#   'claimant',
#   'however',
#   'caps',
#   'inapplicable',
#   'economic',
#   'losses',
#   'medical',
#   'expenses',
#   'lost',
#   'wages',
#   'result',
#   'medical',
#   'negligence'],
#  ['federal',
#   'act',
#   'establishes',
#   'private',
#   'right',
#   'action',
#   'actual',
#   'statutory',
#   'damages',
#   '(',
#   'well',
#   'criminal',
#   'administrative',
#   'sanctions',
#   ')',
#   'employers',
#   'contractors',
#   'migrant',
#   'seasonal',
#   'agricultural',
#   'workers',
#   'violate',
#   'act',
#   'housing',
#   'motor',
#   'vehicle',
#   'safety',
#   'requirements',
#   'motor',
#   'vehicle',
#   'liability',
#   'insurance',
#   'requirements',
#   'job',
#   'information',
#   'disclosure',
#   'requirements'],
#  ['california',
#   'tort',
#   'reform',
#   'act',
#   'passed',
#   '1975',
#   'may',
#   'replicated',
#   'states',
#   'shown',
#   'success',
#   'limiting',
#   'increases',
#   'medical',
#   'malpractice',
#   'costs',
#   'several',
#   'micra',
#   'important',
#   'features',
#   'include',
#   '(',
#   '1',
#   ')',
#   'non-economic',
#   'damages',
#   'capped',
#   'medical',
#   'negligence',
#   '250',
#   '000',
#   '(',
#   '2',
#   ')',
#   'economic',
#   'damages',
#   'capped',
#   '(',
#   '3',
#   ')',
#   'damage',
#   'limitations',
#   'provided',
#   'collateral',
#   'source',
#   'rule',
#   '(',
#   '4',
#   ')',
#   'sliding',
#   'scale',
#   'lawyers',
#   'contingency',
#   'fees',
#   '(',
#   '5',
#   ')',
#   '90-day',
#   'advance',
#   'notice',
#   'filing',
#   'claim',
#   '(',
#   '6',
#   ')',
#   'statute',
#   'limitations',
#   'requires',
#   'notification',
#   'within',
#   '1',
#   'year',
#   'discovery',
#   'within',
#   '3',
#   'years',
#   'date',
#   'injury'],
#  ['provision',
#   'state',
#   'workers',
#   'compensation',
#   'laws',
#   'establishes',
#   'maximum',
#   'amount',
#   'healthcare',
#   'provider',
#   'may',
#   'collect',
#   'injuries',
#   'treatable',
#   'act'],
#  ['u',
#   'government',
#   'welfare',
#   'system',
#   'administered',
#   'states',
#   'subsidized',
#   'federal',
#   'government',
#   'covering',
#   'various',
#   'medical',
#   'expenses',
#   'low',
#   'income',
#   'limits',
#   'set',
#   'state',
#   'laws'],
#  ['part',
#   'commercial',
#   'contract',
#   'types',
#   'minimum',
#   'amounts',
#   'insurance',
#   'parties',
#   'agree',
#   'provide',
#   'connection',
#   'performance',
#   'contract',
#   'specified'],
#  ['mechanism',
#   'developed',
#   'national',
#   'association',
#   'insurance',
#   'commissioners',
#   '(',
#   'naic',
#   ')',
#   'assist',
#   'states',
#   'overseeing',
#   'financial',
#   'condition',
#   'insurance',
#   'companies',
#   'iris',
#   'ratios',
#   'set',
#   'ratios',
#   'designed',
#   'measure',
#   'solvency',
#   'liquidity',
#   'calculated',
#   'insurers',
#   'annual',
#   'statements',
#   'filed',
#   'naic',
#   'insurers',
#   'fail',
#   'one',
#   'tests',
#   'placed',
#   'supervision',
#   'domicile',
#   'regulator'],
#  ['broad',
#   'terms',
#   'entire',
#   'printed',
#   'insurance',
#   'contract',
#   'generally',
#   'insurance',
#   'policy',
#   'assembled',
#   'combination',
#   'various',
#   'standard',
#   'forms',
#   'including',
#   'declarations',
#   'page',
#   'coverage',
#   'form',
#   'endorsements',
#   'sometimes',
#   'causes',
#   'loss',
#   'form',
#   'also',
#   'required',
#   'together',
#   'forms',
#   'delineate',
#   'coverage',
#   'term',
#   'insurance',
#   'policy',
#   'limits',
#   'grant',
#   'coverage',
#   'exclusions',
#   'limitations',
#   'coverage',
#   'duties',
#   'responsibilities',
#   'insured',
#   'event',
#   'loss',
#   'see',
#   'also'],
#  ['strong',
#   'durable',
#   'slow-burning',
#   'type',
#   'joisted',
#   'masonry',
#   'construction',
#   'also',
#   'called',
#   'heavy',
#   'timber',
#   'construction',
#   'characterized',
#   'heavy',
#   'floors',
#   'thick',
#   'wooden',
#   'columns',
#   'beams',
#   'walls',
#   'building',
#   'generally',
#   'assigned',
#   'fire-resistive',
#   'rating',
#   'least',
#   '2',
#   'hours',
#   'lack',
#   'floor',
#   'joists',
#   'form',
#   'construction',
#   'contributes',
#   'fire-resistance',
#   'since',
#   'corresponding',
#   'air',
#   'pockets',
#   'eliminated'],
#  ['standardized',
#   'formulaic',
#   'method',
#   'predicting',
#   'future',
#   'events',
#   'using',
#   'historical',
#   'information',
#   'catastrophe',
#   'models',
#   'usually',
#   'computerized',
#   'used',
#   'predict',
#   'losses',
#   'based',
#   'upon',
#   'anticipated',
#   'future',
#   'atmospheric',
#   'weather',
#   'patterns',
#   'various',
#   'geographic',
#   'regions'],
#  ['evidentiary',
#   'standard',
#   'applies',
#   'certain',
#   'employment',
#   'discrimination',
#   'cases',
#   '(',
#   'whether',
#   'mixed-motive',
#   'evidentiary',
#   'standard',
#   'applies',
#   'depends',
#   'upon',
#   '(',
#   '1',
#   ')',
#   'particular',
#   'jurisdiction',
#   'case',
#   'filed',
#   '(',
#   '2',
#   ')',
#   'exact',
#   'type',
#   'discrimination',
#   'alleged',
#   ')',
#   'standard',
#   'employee-plaintiffs',
#   'must',
#   'prove',
#   'employer',
#   'discriminatory',
#   'act',
#   'claim',
#   'brought',
#   '(',
#   'e',
#   'g',
#   'termination',
#   'reassignment',
#   'demotion',
#   ')',
#   'merely'],
#  ['provision',
#   'life',
#   'insurance',
#   'policy',
#   'adjusts',
#   'amount',
#   'insurance',
#   'insured',
#   'age',
#   'misstated',
#   'application',
#   'amount',
#   'premium',
#   'would',
#   'purchased',
#   'correct',
#   'age',
#   'based',
#   'insurer',
#   'rates',
#   'date',
#   'policy',
#   'issuance'],
#  ['specialized',
#   'form',
#   'designed',
#   'meet',
#   'unique',
#   'needs',
#   'mobile',
#   'home',
#   'manufactured',
#   'housing',
#   'owners',
#   'provides',
#   'coverage',
#   'comparable',
#   'homeowners',
#   'policy',
#   'including',
#   'property',
#   'loss',
#   'use',
#   'premises',
#   'personal',
#   'liability',
#   'cases',
#   'coverage',
#   'granted',
#   'via',
#   'mobile',
#   'home',
#   'endorsement',
#   'standard',
#   'homeowners',
#   'policy',
#   'cases',
#   'stand-alone',
#   'mobile',
#   'home',
#   'policy',
#   'used',
#   'provide',
#   'coverage'],
#  ['term',
#   'defined',
#   'commercial',
#   'general',
#   'liability',
#   '(',
#   'cgl',
#   ')',
#   'commercial',
#   'auto',
#   'policies',
#   'refers',
#   'equipment',
#   'earthmovers',
#   'tractors',
#   'diggers',
#   'farm',
#   'machinery',
#   'forklifts',
#   'etc',
#   'even',
#   'self-propelled',
#   'considered',
#   'automobiles',
#   'insurance',
#   'purposes',
#   '(',
#   'unless',
#   'subject',
#   'compulsory',
#   'financial',
#   'responsibility',
#   'law',
#   'motor',
#   'vehicle',
#   'insurance',
#   'law',
#   ')',
#   'liability',
#   'arising',
#   'mobile',
#   'equipment',
#   'covered',
#   'general',
#   'liability',
#   'policy',
#   'physical',
#   'damage',
#   'coverage',
#   'usually',
#   'provided',
#   'equipment',
#   'floater',
#   'see',
#   'also'],
#  ['term',
#   'used',
#   'conjunction',
#   'underwriting',
#   'several',
#   'types',
#   'professional',
#   'liability',
#   'insurance',
#   'notably',
#   'accountants',
#   'lawyers',
#   'architects',
#   'engineers',
#   'insurance',
#   'agents',
#   'refers',
#   'respective',
#   'proportions',
#   'specific',
#   'services',
#   'provided',
#   'given',
#   'professional',
#   'firm',
#   'factor',
#   'influences',
#   'expected',
#   'frequency',
#   'severity',
#   'losses',
#   'therefore',
#   'premium',
#   'scope',
#   'coverage',
#   'afforded',
#   'example',
#   'assume',
#   'plaintiff',
#   'personal',
#   'injury',
#   '(',
#   'pi',
#   ')',
#   'cases',
#   '(',
#   'high',
#   'exposure',
#   'area',
#   ')',
#   'comprise',
#   'majority',
#   'law',
#   'firm',
#   'work',
#   'contrast',
#   'law',
#   'firm',
#   'b',
#   'work',
#   'area',
#   'trusts',
#   'estates',
#   'relatively',
#   'low',
#   'exposure',
#   'activity',
#   'things',
#   'equal',
#   'given',
#   'mix',
#   'services',
#   'law',
#   'firm',
#   'probably',
#   'pay',
#   'higher',
#   'premium',
#   'may',
#   'offered',
#   'restrictive',
#   'coverage',
#   'compared',
#   'law',
#   'firm',
#   'b'],
#  ['false',
#   'misleading',
#   'statement',
#   'intentional',
#   'material',
#   'allow',
#   'insurer',
#   'void',
#   'insurance',
#   'contract',
#   'insurance',
#   'policies',
#   'state',
#   'laws',
#   'govern',
#   'insurance',
#   'contract',
#   'provisions',
#   'vary',
#   'exact',
#   'details',
#   'conditions',
#   'coverage',
#   'may',
#   'voided',
#   'variations',
#   'usually',
#   'denoted',
#   'state',
#   'amendatory',
#   'endorsements',
#   'see',
#   'also'],
#  ['financial',
#   'valuation',
#   'model',
#   'often',
#   'used',
#   'valuing',
#   'customer-related',
#   'intangible',
#   'assets',
#   'estimates',
#   'revenues',
#   'cash',
#   'flows',
#   'derived',
#   'intangible',
#   'asset',
#   'deducts',
#   'portions',
#   'cash',
#   'flow',
#   'attributed',
#   'supporting',
#   'assets',
#   'brand',
#   'name',
#   'fixed',
#   'assets',
#   'contributed',
#   'generation',
#   'cash',
#   'flows',
#   'deductions',
#   'sometimes',
#   'referred',
#   'supporting',
#   'asset',
#   'charges',
#   'resulting',
#   'cash',
#   'flow',
#   'attributable',
#   'solely',
#   'subject',
#   'intangible',
#   'asset',
#   'discounted',
#   'rate',
#   'return',
#   'commensurate',
#   'risk',
#   'asset',
#   'calculate',
#   'present',
#   'value'],
#  ['situation',
#   'arises',
#   'parties',
#   'relatively',
#   'equal',
#   'bargaining',
#   'power',
#   'agree',
#   'name',
#   'additional',
#   'insureds',
#   'respective',
#   'insurance',
#   'policies',
#   'generally',
#   'intent',
#   'party',
#   '(',
#   'named',
#   'insured',
#   ')',
#   'provide',
#   'primary',
#   'coverage',
#   '(',
#   'additional',
#   'insured',
#   ')',
#   'damages',
#   'arising',
#   'named',
#   'insured',
#   'negligence'],
#  ['corporation',
#   'owned',
#   'operated',
#   'insureds',
#   'every',
#   'owner',
#   'company',
#   'insured',
#   'every',
#   'insured',
#   'owner'],
#  ['organization',
#   'offering',
#   'benefits',
#   'members',
#   'fixed',
#   'premiums',
#   'assessments',
#   'levied',
#   'meet',
#   'specific',
#   'losses',
#   'occur'],
#  ['traditional',
#   'insurance',
#   'contracts',
#   'one',
#   'trigger',
#   'physical',
#   'event',
#   'occurrence',
#   'activates',
#   'coverage',
#   'multiple',
#   'trigger',
#   'contracts',
#   'designed',
#   'respond',
#   'physical',
#   'hazard-type',
#   'events',
#   'resultant',
#   'financial',
#   'movements',
#   'financial',
#   'movements',
#   'benchmark',
#   'firm',
#   'measures',
#   'financial',
#   'viabilities',
#   'stock',
#   'price',
#   'quarterly',
#   'earnings',
#   'internal',
#   'rate',
#   'return',
#   'etc',
#   'example',
#   'multiple',
#   'trigger',
#   '(',
#   'also',
#   'known',
#   'dual',
#   'trigger',
#   ')',
#   'program',
#   'could',
#   'cover',
#   'property',
#   'loss',
#   'due',
#   'fire',
#   'windstorm',
#   'etc',
#   'reduction',
#   'quarterly',
#   'earnings',
#   'results',
#   'physical',
#   'event'],
#  ['endorsement',
#   'available',
#   'professional',
#   'liability',
#   'policies',
#   'nearly',
#   'always',
#   'police',
#   'professional',
#   'law',
#   'enforcement',
#   'policies',
#   'moonlighting',
#   'endorsements',
#   'cover',
#   'insureds',
#   'liability',
#   'connection',
#   'off-duty',
#   'law',
#   'enforcement',
#   'activities',
#   'coverage',
#   'available',
#   'recognition',
#   'fact',
#   'uncommon',
#   'law',
#   'enforcement',
#   'officers',
#   'hold',
#   'second',
#   'jobs'],
#  ['combination',
#   'whole',
#   'life',
#   'term',
#   'insurance',
#   'paying',
#   'multiple',
#   'amount',
#   'protection'],
#  ['nationalization',
#   'confiscation',
#   'host',
#   'country',
#   'government',
#   'multinational',
#   'investment',
#   '(',
#   'e',
#   'g',
#   'plant',
#   'inventory',
#   'equipment',
#   ')',
#   'compensation',
#   'offered',
#   'usually',
#   'far',
#   'fair',
#   'market',
#   'value'],
#  ['damages',
#   'awarded',
#   'based',
#   'upon',
#   'statutory',
#   'directive',
#   'example',
#   'clayton',
#   'act',
#   '(',
#   'law',
#   'prohibits',
#   'agreements',
#   'companies',
#   'fix',
#   'control',
#   'prices',
#   'purpose',
#   'lessening',
#   'competition',
#   ')',
#   'provides',
#   'treble',
#   'damages',
#   'event',
#   'antitrust',
#   'violation',
#   'therefore',
#   'jury',
#   'awarded',
#   '1',
#   'million',
#   'compensatory',
#   'damages',
#   'violating',
#   'clayton',
#   'act',
#   'multiplied',
#   'damages',
#   'would',
#   'additional',
#   '2',
#   'million',
#   'resulting',
#   'total',
#   'award',
#   '3',
#   'million',
#   'multiplied',
#   'damages',
#   'although',
#   'similar',
#   'nature',
#   'intent',
#   'punitive',
#   'damages',
#   'always',
#   'treated',
#   'manner',
#   'determining',
#   'coverage',
#   'within',
#   'liability',
#   'policy',
#   'see',
#   'also'],
#  ['premium',
#   'charge',
#   'added',
#   'premium',
#   'class',
#   'rate',
#   'extra',
#   'hazardous',
#   'exposures'],
#  ['form',
#   'substandard',
#   'rating',
#   'using',
#   'mortality',
#   'morbidity',
#   'tables',
#   'certain',
#   'impaired',
#   'health',
#   'conditions'],
#  ['requirement',
#   'policy',
#   'insurer',
#   'pay',
#   'certain',
#   'losses',
#   'expenses',
#   'arising',
#   'insuring',
#   'agreement',
#   'externally',
#   'imposed',
#   'obligations',
#   'example',
#   'fines',
#   'court',
#   'regulatory',
#   'body',
#   'ecos',
#   'covered',
#   'reinsurance',
#   'agreement',
#   'reinsurer',
#   'pays',
#   'punitive',
#   'damages',
#   'imposed',
#   'insurer'],
#  ['damages',
#   'addition',
#   'outside',
#   'contract',
#   'insurance',
#   'extracontractual',
#   'damages',
#   'awarded',
#   'bad',
#   'faith',
#   'claims',
#   'insurance',
#   'companies',
#   'form',
#   'punitive',
#   'damages',
#   'intended',
#   'punish',
#   'extreme',
#   'insurer',
#   'conduct',
#   'extracontractual',
#   'damage',
#   'awards',
#   'frequently',
#   'arise',
#   'unfair',
#   'claims',
#   'handling',
#   'practices',
#   '(',
#   'e',
#   'g',
#   'unjust',
#   'denial',
#   'coverage',
#   'failure',
#   'settle',
#   'claim',
#   'within',
#   'policy',
#   'limits',
#   ')',
#   'see',
#   'also'],
#  ['406',
#   'chemicals',
#   'identified',
#   'environmental',
#   'protection',
#   'agency',
#   '(',
#   'epa',
#   ')',
#   'toxic',
#   'listed',
#   'superfund',
#   'amendments',
#   'reauthorization',
#   'act',
#   '(',
#   'sara',
#   ')',
#   '1986',
#   'title',
#   'iii'],
#  ['extension',
#   'state',
#   'workers',
#   'compensation',
#   'law',
#   'provide',
#   'benefits',
#   'workers',
#   'hired',
#   'state',
#   'injured',
#   'working',
#   'another',
#   'state',
#   'usually',
#   'maximum',
#   'placed',
#   'amount',
#   'time',
#   'employee',
#   'spend',
#   'outside',
#   'state',
#   'hire',
#   'still',
#   'file',
#   'claim',
#   'state',
#   'term',
#   'also',
#   'used',
#   'international',
#   'insurance',
#   'denote',
#   'coverage',
#   'work-related',
#   'injuries',
#   'occurring',
#   'outside',
#   'boundaries',
#   'country',
#   'hire'],
#  ['legal',
#   'principle',
#   'insurer',
#   'owes',
#   'duty',
#   'defense',
#   'insured',
#   'actual',
#   'facts',
#   'claim',
#   'loss',
#   'match',
#   'provisions',
#   'insurance',
#   'policy',
#   'regardless',
#   'language',
#   'claim',
#   'asserted',
#   'insured',
#   'see',
#   'also'],
#  ['property',
#   'loss',
#   'control',
#   'term',
#   'referring',
#   'maximum',
#   'loss',
#   'expected',
#   'given',
#   'location',
#   'event',
#   'fire',
#   'location',
#   'expressed',
#   'dollars',
#   'percentage',
#   'total',
#   'values',
#   'see',
#   'also'],
#  ['percentile',
#   'probability',
#   'distribution',
#   'corresponding',
#   'point',
#   'capital',
#   'exhausted',
#   'typically',
#   'minimum',
#   'acceptable',
#   'probability',
#   'ruin',
#   'specified',
#   'economic',
#   'capital',
#   'derived',
#   'therefrom'],
#  ['technique',
#   'used',
#   'risk',
#   'managers',
#   'forecasting',
#   'future',
#   'events',
#   'accidental',
#   'business',
#   'losses',
#   'process',
#   'involves',
#   'review',
#   'historical',
#   'loss',
#   'data',
#   'calculate',
#   'probability',
#   'distribution',
#   'used',
#   'predict',
#   'future',
#   'losses',
#   'probability',
#   'analyst',
#   'views',
#   'past',
#   'losses',
#   'range',
#   'outcomes',
#   'might',
#   'expected',
#   'future',
#   'assumes',
#   'environment',
#   'remain',
#   'fairly',
#   'stable',
#   'technique',
#   'particularly',
#   'effective',
#   'companies',
#   'large',
#   'amount',
#   'data',
#   'past',
#   'losses',
#   'experienced',
#   'stable',
#   'operations',
#   'type',
#   'analysis',
#   'contrasted',
#   'trend',
#   'analysis'],
#  ['communication',
#   'special',
#   'relationships',
#   'protected',
#   'disclosure',
#   'third',
#   'parties',
#   'common',
#   'protected',
#   'relationships',
#   'attorney',
#   'client',
#   'cleric',
#   'penitents',
#   'husband',
#   'wife'],
#  ['numerical',
#   'measure',
#   'chance',
#   'likelihood',
#   'particular',
#   'event',
#   'occur',
#   'probabilities',
#   'generally',
#   'assigned',
#   'scale',
#   '0',
#   '1',
#   'probability',
#   'near',
#   '0',
#   'indicates',
#   'outcome',
#   'unlikely',
#   'occur',
#   'probability',
#   'near',
#   '1',
#   'indicates',
#   'outcome',
#   'almost',
#   'certain',
#   'occur'],
#  ['defined',
#   'contribution',
#   'benefit',
#   'plan',
#   'promise',
#   'set',
#   'amount',
#   'retirement',
#   '15',
#   'percent',
#   'employee',
#   'compensation',
#   'contributed',
#   'behalf',
#   'employee',
#   'annually'],
#  ['relationship',
#   'exists',
#   'two',
#   'parties',
#   'virtue',
#   'entered',
#   'contract',
#   'concept',
#   'incorporates',
#   'legal',
#   'principle',
#   'contract',
#   'may',
#   'impose',
#   'duties',
#   'noncontracting',
#   'party',
#   'may',
#   'noncontracting',
#   'party',
#   'claim',
#   'right',
#   'benefit',
#   'guaranteed',
#   'contract'],
#  ['provides',
#   'coverage',
#   'economic',
#   'losses',
#   'arising',
#   'unilateral',
#   'cancellation',
#   'contract',
#   'result',
#   'direct',
#   'indirect',
#   'actions',
#   'foreign',
#   'government',
#   'agents',
#   'circumstances',
#   'insured',
#   'breach',
#   'contract',
#   'coverage',
#   'usually',
#   'purchased',
#   'importers',
#   'exporters',
#   'contractors'],
#  ['insurance',
#   'indemnify',
#   'insured',
#   'loss',
#   'net',
#   'profit',
#   'chemical',
#   'analysis',
#   'recall',
#   'examination',
#   'transportation',
#   'destruction',
#   'extra',
#   'expenses',
#   'incurred',
#   'regain',
#   'market',
#   'share',
#   'following',
#   'malicious',
#   'product',
#   'tampering',
#   'incident'],
#  ['provision',
#   'found',
#   'reinsurance',
#   'agreements',
#   'provides',
#   'profit',
#   'sharing',
#   'parties',
#   'agree',
#   'formula',
#   'calculating',
#   'profit',
#   'allowance',
#   'reinsurer',
#   'expenses',
#   'cedent',
#   'share',
#   'profit',
#   'expenses'],
#  ['property',
#   'transfer',
#   'liability',
#   'insurance',
#   'covers',
#   'buyer',
#   'property',
#   'third-party',
#   'bodily',
#   'injury',
#   '(',
#   'bi',
#   ')',
#   'property',
#   'damage',
#   '(',
#   'pd',
#   ')',
#   'claims',
#   'cleanup',
#   'costs',
#   'arising',
#   'property',
#   'contamination',
#   'yet',
#   'detected',
#   'policy',
#   'inception',
#   'date',
#   'failure',
#   'disclose',
#   'known',
#   'contamination',
#   'voids',
#   'coverage',
#   'respect',
#   'particular',
#   'pollution',
#   'incident'],
#  ['first-party',
#   'insurance',
#   'indemnifies',
#   'owner',
#   'user',
#   'property',
#   'loss',
#   'loss',
#   'income-producing',
#   'ability',
#   'loss',
#   'damage',
#   'caused',
#   'covered',
#   'peril',
#   'fire',
#   'explosion',
#   'sense',
#   'property',
#   'insurance',
#   'encompasses',
#   'inland',
#   'marine',
#   'boiler',
#   'machinery',
#   '(',
#   'bm',
#   ')',
#   'crime',
#   'insurance',
#   'well',
#   'known',
#   'fire',
#   'insurance',
#   'simply',
#   'called',
#   'property',
#   'insurance',
#   'insurance',
#   'buildings',
#   'contents'],
#  ['defined',
#   'general',
#   'liability',
#   'policy',
#   'physical',
#   'injury',
#   'tangible',
#   'property',
#   'including',
#   'resulting',
#   'loss',
#   'use',
#   'loss',
#   'use',
#   'tangible',
#   'property',
#   'physically',
#   'injured',
#   'also',
#   'addressed',
#   'homeowners',
#   'personal',
#   'auto',
#   'policies'],
#  ['claims',
#   'law',
#   'specialist',
#   'designation',
#   'offered',
#   'american',
#   'educational',
#   'institute',
#   '(',
#   'aei',
#   ')',
#   'requires',
#   'successful',
#   'completion',
#   'aei',
#   'property',
#   'self-study',
#   'program'],
#  ['proportionately'],
#  ['premium',
#   'losses',
#   'calculated',
#   'pro',
#   'rata',
#   'basis',
#   'reinsurer',
#   'fixed',
#   'percentage',
#   'premium',
#   'percentage',
#   'losses'],
#  ['refers',
#   'arrangement',
#   'assignment',
#   'liability',
#   'member',
#   'group',
#   'held',
#   'responsible',
#   'financial',
#   'results',
#   'group',
#   'proportion',
#   'participation',
#   'compare'],
#  ['adjustment',
#   'policy',
#   'benefits',
#   'due',
#   'change',
#   'exposure',
#   'existence',
#   'insurance'],
#  ['method',
#   'used',
#   'arriving',
#   'insurance',
#   'reinsurance',
#   'rate',
#   'premium',
#   'policy',
#   'period',
#   'based',
#   'loss',
#   'experience',
#   'prior',
#   'period',
#   'schedule',
#   'credits',
#   'experience',
#   'modification',
#   'individual',
#   'risk',
#   'rating',
#   'modifications',
#   'factors',
#   'used',
#   'prospective',
#   'rating',
#   'whereas',
#   'losses',
#   'incurred',
#   'policy',
#   'period',
#   'effect',
#   'final',
#   'premium',
#   'guaranteed',
#   'cost',
#   'plans',
#   'without',
#   'dividend',
#   'examples',
#   'prospectively',
#   'rated',
#   'insurance',
#   'plans'],
#  ['spread',
#   'loss',
#   'program',
#   'giving',
#   'accident',
#   'year',
#   'reinsurance',
#   'long',
#   'tail',
#   'risks',
#   'premiums',
#   'paid',
#   'annually',
#   'expected',
#   'life',
#   'policy',
#   '(',
#   'adjustments',
#   'pricing',
#   'resulting',
#   'adverse',
#   'loss',
#   'development',
#   'occur',
#   'prospectively',
#   ')'],
#  ['notice',
#   'given',
#   'allow',
#   'option',
#   'withdrawing',
#   'reinsurance',
#   'treaty',
#   'renewal',
#   'terms',
#   'unacceptable',
#   'issued',
#   'continuous',
#   'contracts'],
#  ['property',
#   'insurance',
#   'endorsement',
#   'makes',
#   'condition',
#   'coverage',
#   'protective',
#   'safeguards',
#   'cited',
#   'endorsement',
#   '(',
#   'automatic',
#   'sprinkler',
#   'system',
#   'night',
#   'watch',
#   'guard',
#   ')',
#   'operation',
#   'times',
#   'except',
#   'insurer',
#   'notified',
#   'impairment',
#   'protection',
#   'failure',
#   'maintain',
#   'protective',
#   'safeguards',
#   'good',
#   'working',
#   'order',
#   'failure',
#   'notify',
#   'insurer',
#   'even',
#   'temporary',
#   'impairment',
#   'protection',
#   'suspends',
#   'coverage',
#   'protection',
#   'restored'],
#  ['provides',
#   'supplemental',
#   'coverage',
#   'professional',
#   'errors',
#   'omissions',
#   '(',
#   'e',
#   ')',
#   'claims',
#   'insured',
#   'design',
#   'professionals',
#   'policy',
#   'sits',
#   'atop',
#   'insured',
#   'design',
#   'professionals',
#   'practice',
#   'policies',
#   'form',
#   'excess',
#   'coverage',
#   'event',
#   'design',
#   'professional',
#   'policy',
#   'limit',
#   'exhausted',
#   'sufficient',
#   'pay',
#   'claim',
#   'insured',
#   '(',
#   'e',
#   'g',
#   'project',
#   'owner',
#   'design-build',
#   'contractor',
#   ')',
#   'must',
#   'prove',
#   'legal',
#   'claim',
#   'professional',
#   'negligence',
#   'design',
#   'professional',
#   'collect',
#   'policy'],
#  ['private-sector',
#   'non-profit',
#   'corporation',
#   'created',
#   'part',
#   'sarbanes-oxley',
#   'act',
#   '(',
#   'sox',
#   ')',
#   'pcaob',
#   'developed',
#   'response',
#   'auditing',
#   'failures',
#   'associated',
#   'several',
#   'high-profile',
#   'corporate',
#   'bankruptcies',
#   'early',
#   '2000s',
#   'purpose',
#   'oversee',
#   'accounting',
#   'firms',
#   'audit',
#   'public',
#   'corporations',
#   'effort',
#   'protect',
#   'interests',
#   'investing',
#   'public',
#   'pcaob',
#   'consists',
#   'five',
#   'members',
#   'including',
#   'chairman',
#   'securities',
#   'exchange',
#   'commission',
#   '(',
#   'sec',
#   ')',
#   'appoints',
#   'conducts',
#   'inspections',
#   'public',
#   'accounting',
#   'firms',
#   'develops',
#   'auditing',
#   'quality',
#   'control',
#   'standards',
#   'conducts',
#   'investigations',
#   'disciplinary',
#   'proceedings'],
#  ['authorized',
#   'liability',
#   'risk',
#   'retention',
#   'act',
#   '1986',
#   'group',
#   'formed',
#   'obtain',
#   'liability',
#   'coverage',
#   'members',
#   'must',
#   'similar',
#   'related',
#   'exposures',
#   'act',
#   'requires',
#   'purchasing',
#   'group',
#   'domiciled',
#   'specific',
#   'state',
#   'contrast',
#   'risk',
#   'retention',
#   'groups',
#   '(',
#   'rrgs',
#   ')',
#   'purchasing',
#   'groups',
#   'risk-bearing',
#   'entities'],
#  ['damages',
#   'excess',
#   'required',
#   'compensate',
#   'plaintiff',
#   'wrong',
#   'done',
#   'imposed',
#   'order',
#   'punish',
#   'defendant',
#   'particularly',
#   'wanton',
#   'willful',
#   'nature',
#   'wrongdoing',
#   'also',
#   'called',
#   'exemplary',
#   'damages',
#   'although',
#   'standard',
#   'commercial',
#   'general',
#   'liability',
#   '(',
#   'cgl',
#   ')',
#   'policy',
#   'business',
#   'auto',
#   'policy',
#   '(',
#   'bap',
#   ')',
#   'contain',
#   'punitive',
#   'damage',
#   'exclusion',
#   'many',
#   'umbrella',
#   'excess',
#   'liability',
#   'policies',
#   'contain',
#   'exclusion'],
#  ['term',
#   'used',
#   'describe',
#   'liability',
#   'exposures',
#   'encountered',
#   'communicating',
#   'conducting',
#   'business',
#   'online',
#   'potential',
#   'liabilities',
#   'include',
#   'internet',
#   'e-mail',
#   'online',
#   'communication',
#   'tools',
#   'could',
#   'result',
#   'claims',
#   'alleging',
#   'breaches',
#   'privacy',
#   'rights',
#   'infringement',
#   'misappropriation',
#   'intellectual',
#   'property',
#   'employment',
#   'discrimination',
#   'violations',
#   'obscenity',
#   'laws',
#   'spreading',
#   'computer',
#   'viruses',
#   'defamation',
#   'media',
#   'liability',
#   'policies',
#   'available',
#   'cover',
#   'exposures'],
#  ['coverage',
#   'extension',
#   'found',
#   'protection',
#   'indemnity',
#   'policy',
#   'pays',
#   'port',
#   'charges',
#   'incurred',
#   'well',
#   'net',
#   'loss',
#   'policyholder',
#   'vessel',
#   'must',
#   'deviate',
#   'specified',
#   'route',
#   'put',
#   'ashore',
#   'sick',
#   'injured',
#   'passenger',
#   'crew',
#   'member'],
#  ['bond',
#   'surety',
#   'guarantees',
#   'specified',
#   'public',
#   'official',
#   'faithfully',
#   'perform',
#   'official',
#   'duties',
#   'including',
#   'accounting',
#   'funds',
#   'entrusted',
#   'care'],
#  ['liability',
#   'exposure',
#   'faced',
#   'public',
#   'official',
#   'wrongful',
#   'acts',
#   'usually',
#   'defined',
#   'public',
#   'officials',
#   'liability',
#   'insurance',
#   'policies',
#   'actual',
#   'alleged',
#   'errors',
#   'omissions',
#   'misstatements',
#   'negligence',
#   'breach',
#   'duty',
#   'capacity',
#   'public',
#   'official',
#   'employee',
#   'public',
#   'entity'],
#  ['captive',
#   'insurance',
#   'company',
#   'one',
#   'corporate',
#   'owner',
#   'insuring',
#   'risks',
#   'parent',
#   'organization',
#   'subsidiaries',
#   'also',
#   'called',
#   'single-parent',
#   'captive'],
#  ['provides',
#   'liability',
#   'coverage',
#   'errors',
#   'omissions',
#   'public',
#   'officials',
#   'effect',
#   'policies',
#   'serve',
#   'function',
#   'elected',
#   'appointed',
#   'officials',
#   'state',
#   'local',
#   'government',
#   'directors',
#   'officers',
#   '(',
#   ')',
#   'insurance',
#   'serves',
#   'directors',
#   'officers',
#   'corporations',
#   'however',
#   'one',
#   'major',
#   'difference',
#   'public',
#   'officials',
#   'liability',
#   'forms',
#   'employees',
#   'public',
#   'entity',
#   'insureds',
#   'whereas',
#   'case',
#   'policies',
#   'exclusions',
#   'policy',
#   'include',
#   'losses',
#   'due',
#   'fraud',
#   'dishonesty',
#   'bodily',
#   'injury',
#   '(',
#   'bi',
#   ')',
#   'property',
#   'damage',
#   '(',
#   'pd',
#   ')',
#   'false',
#   'arrest',
#   'assault',
#   'battery',
#   'defamation',
#   'fiduciary',
#   'liability'],
#  ['corporation',
#   'whose',
#   'shares',
#   'stock',
#   'held',
#   'available',
#   'purchase',
#   'members',
#   'public',
#   'shares',
#   'public',
#   'corporations',
#   'bought',
#   'sold',
#   'one',
#   'major',
#   'stock',
#   'exchanges',
#   'new',
#   'york',
#   'stock',
#   'exchange',
#   '(',
#   'nyse',
#   ')',
#   'national',
#   'association',
#   'securities',
#   'dealers',
#   'automated',
#   'quotations',
#   '(',
#   'nasdaq',
#   ')',
#   'see',
#   'also'],
#  ['lawsuit',
#   'brought',
#   'one',
#   'named',
#   'plaintiffs',
#   'behalf',
#   'potential',
#   'group',
#   'similarly',
#   'situated',
#   'individuals',
#   '(',
#   'known',
#   'class',
#   ')',
#   'allegedly',
#   'suffered',
#   'common',
#   'claim',
#   'lawsuits',
#   'become',
#   'class',
#   'actions',
#   'actual',
#   'class',
#   'certified',
#   'court',
#   'therefore',
#   'putative',
#   'class',
#   'action',
#   'means',
#   'class',
#   'yet',
#   'certified',
#   'court',
#   'court',
#   'certifies',
#   'class',
#   'lawsuit',
#   'becomes',
#   'class',
#   'action',
#   'see',
#   'also'],
#  ['reinsurance',
#   'contract',
#   'endorsement',
#   'providing',
#   'event',
#   'cedent',
#   'insolvency',
#   'reinsurer',
#   'pay',
#   'loss',
#   'covered',
#   'reinsurance',
#   'contract',
#   'directly',
#   'insured',
#   'also',
#   'called',
#   'assumption',
#   'endorsement'],
#  ['type',
#   'insurance',
#   'designed',
#   'cover',
#   'consumers',
#   'technology',
#   'services',
#   'products',
#   'specifically',
#   'policies',
#   'intended',
#   'cover',
#   'variety',
#   'liability',
#   'property',
#   'losses',
#   'may',
#   'result',
#   'business',
#   'engages',
#   'various',
#   'electronic',
#   'activities',
#   'selling',
#   'internet',
#   'collecting',
#   'data',
#   'within',
#   'internal',
#   'electronic',
#   'network'],
#  ['type',
#   'online',
#   'crime',
#   'criminal',
#   'threatens',
#   'damage',
#   'shut',
#   'company',
#   'website',
#   'e-mail',
#   'server',
#   'computer',
#   'system',
#   'threatens',
#   'expose',
#   'electronic',
#   'data',
#   'information',
#   'belonging',
#   'company',
#   'unless',
#   'company',
#   'pays',
#   'criminal',
#   'specific',
#   'ransom',
#   'amount'],
#  ['insuring',
#   'agreement',
#   'contained',
#   'within',
#   'policies',
#   'written',
#   'cover',
#   'claims',
#   'associated',
#   'data',
#   'breaches',
#   'policies',
#   'often',
#   'termed',
#   'cyber',
#   'privacy',
#   'insurance',
#   'information',
#   'security',
#   'privacy',
#   'insurance',
#   'cybersecurity',
#   'insurance'],
#  ['bond',
#   'required',
#   'u',
#   'customs',
#   'service',
#   'guarantees',
#   'payment',
#   'duties',
#   'taxes',
#   'due',
#   'law',
#   'goods',
#   'directly',
#   'indirectly',
#   'imported',
#   'exported',
#   'united',
#   'states',
#   'well',
#   'reporting',
#   'statistical',
#   'data',
#   'relating',
#   'shipments',
#   'involved',
#   'bond',
#   'may',
#   'issued',
#   'either',
#   'single',
#   'continuous',
#   'form'],
#  ['used',
#   'retrocessions',
#   'primary',
#   'insurer',
#   'ability',
#   'receive',
#   'reinsurance',
#   'payments',
#   'directly',
#   'retrocessionaire',
#   'unable',
#   'recover',
#   'reinsurer'],
#  ['policy',
#   'term',
#   'defined',
#   'insurance',
#   'services',
#   'office',
#   'inc',
#   '(',
#   'iso',
#   ')',
#   'garage',
#   'policy',
#   'term',
#   'defined',
#   'include',
#   'autos',
#   'employees',
#   'members',
#   'households',
#   'left',
#   'insured',
#   'garage',
#   'service',
#   'repair',
#   'storage',
#   'safekeeping',
#   'individuals',
#   'pay',
#   'services',
#   'performed'],
#  ['termination',
#   'provision',
#   'reinsurance',
#   'contract',
#   'reinsurer',
#   'liable',
#   'losses',
#   'taking',
#   'place',
#   'date',
#   'termination',
#   'see',
#   'also'],
#  ['endowment',
#   'payable',
#   'end',
#   'policy',
#   'period',
#   'insured',
#   'alive',
#   'insured',
#   'died',
#   'nothing',
#   'paid',
#   'form',
#   'benefits'],
#  ['pay-as-you-go',
#   'technique',
#   'funding',
#   'pension',
#   'plan',
#   'used',
#   'today',
#   'social',
#   'security',
#   'known',
#   'costly',
#   'method',
#   'pension',
#   'funding'],
#  ['portion',
#   'insured',
#   'pension',
#   'benefit',
#   'accrued',
#   'due',
#   'credited',
#   'service',
#   'given',
#   'time',
#   'period'],
#  ['1984', 'california', 'court', 'appeals', 'decision'],
#  ['unique',
#   'feature',
#   'aircraft',
#   'insurance',
#   'policies',
#   'commonly',
#   'specify',
#   'declarations',
#   'intended',
#   'use',
#   'aircraft',
#   '(',
#   'e',
#   'g',
#   'business',
#   'pleasure',
#   'industrial',
#   'aid',
#   'crop',
#   'dusting',
#   ')',
#   'exclusion',
#   'may',
#   'invalidate',
#   'coverage',
#   'aircraft',
#   'used',
#   'purpose',
#   'one',
#   'stated',
#   'policy',
#   'exclusion',
#   'apply',
#   'aircraft',
#   'typically',
#   'must',
#   'used',
#   'unauthorized',
#   'purpose',
#   'knowledge',
#   'consent',
#   'named',
#   'insured',
#   'executive',
#   'officer',
#   'partner'],
#  ['type',
#   'workers',
#   'injury',
#   'arises',
#   'repetition',
#   'mentally',
#   'physically',
#   'traumatic',
#   'job',
#   'tasks',
#   'extended',
#   'length',
#   'time',
#   'examples',
#   'carpal',
#   'tunnel',
#   'syndrome',
#   'hearing',
#   'loss'],
#  ['reinsurance',
#   'contract',
#   'ceding',
#   'company',
#   'reduces',
#   'net',
#   'exposure',
#   'reinsured',
#   'share',
#   'agreement'],
#  ['reinsurance',
#   'agreement',
#   'ratio',
#   'reinsured',
#   'losses',
#   'ceding',
#   'company',
#   'earned',
#   'subject',
#   'premium',
#   'agreement',
#   'less',
#   'expense',
#   'loading',
#   'also',
#   'known',
#   'burning',
#   'cost'],
#  ['risk',
#   'involved',
#   'situations',
#   'present',
#   'opportunity',
#   'loss',
#   'opportunity',
#   'gain',
#   'pure',
#   'risks',
#   'generally',
#   'insurable',
#   'whereas',
#   'speculative',
#   'risks',
#   '(',
#   'also',
#   'present',
#   'opportunity',
#   'gain',
#   ')',
#   'generally',
#   'see',
#   'also'],
#  ['type',
#   'claims-made',
#   'policy',
#   'requiring',
#   'claim',
#   'must',
#   'made',
#   'insured',
#   'policy',
#   'period',
#   'coverage',
#   'apply',
#   'unlike',
#   'claims-made',
#   'reported',
#   'forms',
#   'pure',
#   'claims-made',
#   'policies',
#   'specify',
#   'claim',
#   'must',
#   'also',
#   'reported',
#   'insurer',
#   'policy',
#   'period',
#   'instead',
#   'indicate',
#   'claim',
#   'must',
#   'reported',
#   'insurer',
#   'immediately',
#   'soon',
#   'practicable',
#   'insureds',
#   'pure',
#   'claims-made',
#   'policies',
#   'preferable',
#   'claims-made',
#   'reported',
#   'policies',
#   'sometimes',
#   'difficult',
#   'report',
#   'claim',
#   'insurer',
#   'made',
#   'late',
#   'policy',
#   'period'],
#  ['common',
#   'law',
#   'remedy',
#   'employment-at-will',
#   'doctrine',
#   'created',
#   'judicial',
#   'system',
#   'courts',
#   'various',
#   'jurisdictions',
#   'recognized',
#   'employee',
#   'terminated',
#   'exercising',
#   'rights',
#   'laws',
#   'enacted',
#   'protect',
#   'employee',
#   'example',
#   'wrongful',
#   'termination',
#   'suit',
#   'allowed',
#   'involved',
#   'firing',
#   'employee',
#   'missing',
#   'week',
#   'work',
#   'serve',
#   'jury',
#   'duty'],
#  ['form',
#   'business',
#   'life',
#   'insurance',
#   'member',
#   'group',
#   'purchases',
#   'insurance',
#   'members',
#   'group',
#   'ensure',
#   'continuance',
#   'business',
#   'event',
#   'one',
#   'principals',
#   'becomes',
#   'disabled',
#   'dies'],
#  ['endorsement',
#   'alters',
#   'clarifies',
#   'application',
#   'liability',
#   'policy',
#   'cross-liability',
#   'claims',
#   'commonly',
#   'intended',
#   'mean',
#   'endorsement',
#   'provides',
#   'cross-liability',
#   'coverage',
#   'however',
#   'term',
#   'used',
#   'caution',
#   'original',
#   'cross-liability',
#   'endorsements',
#   'exclusions',
#   'deleted',
#   'coverage'],
#  ['party', 'named', 'defendant', 'cross-complaint'],
#  ['coverage',
#   'connection',
#   'suit',
#   'brought',
#   'insured',
#   'another',
#   'party',
#   'insured',
#   'status',
#   'policy',
#   'cross-liability',
#   'coverage',
#   'provided',
#   'intrinsic',
#   'feature',
#   'standard',
#   'commercial',
#   'general',
#   'liability',
#   '(',
#   'cgl',
#   ')',
#   'policy',
#   'means',
#   'separation',
#   'insureds',
#   'condition',
#   'umbrella',
#   'professional',
# ...
#   'building',
#   'ordinance',
#   '(',
#   ')',
#   'requiring',
#   'building',
#   'damaged',
#   'specified',
#   'extent',
#   '(',
#   'typically',
#   '50',
#   'percent',
#   ')',
#   'must',
#   'demolished',
#   'rebuilt',
#   'accordance',
#   'current',
#   'building',
#   'codes',
#   'rather',
#   'simply',
#   'repaired',
#   'unendorsed',
#   'standard',
#   'commercial',
#   'property',
#   'insurance',
#   'forms',
#   'cover',
#   'loss',
#   'undamaged',
#   'portion',
#   'building',
#   'cost',
#   'demolishing',
#   'undamaged',
#   'portion',
#   'building',
#   'increased',
#   'cost',
#   'rebuilding',
#   'entire',
#   'structure',
#   'accordance',
#   'current',
#   'building',
#   'codes',
#   'however',
#   'coverage',
#   'loss',
#   'exposures',
#   'widely',
#   'available',
#   'endorsement',
#   'standard',
#   'homeowners',
#   'policies',
#   'include',
#   'provision',
#   'granting',
#   'limited',
#   'amount',
#   '(',
#   'e',
#   'g',
#   '10',
#   'percent',
#   'dwelling',
#   'limit',
#   ')',
#   'building',
#   'ordinance',
#   'coverage',
#   'amount',
#   'increased',
#   'endorsement',
#   'see',
#   'also'],
#  ['right',
#   'subrogation',
#   'granted',
#   'common',
#   'law',
#   'one',
#   'party',
#   'made',
#   'payment',
#   'behalf',
#   'another',
#   'becomes',
#   'entitled',
#   'whatever',
#   'recovery',
#   'rights',
#   'party',
#   'responsible',
#   'third',
#   'party',
#   'see',
#   'also'],
#  ['judicial',
#   'doctrine',
#   'litigant',
#   'may',
#   'prevented',
#   'stopped',
#   'raising',
#   'argument',
#   'legal',
#   'defense',
#   'lawsuit',
#   'generally',
#   'elements',
#   'equitable',
#   'estoppel',
#   'act',
#   'omission',
#   'part',
#   'party',
#   'estopped',
#   'reliance',
#   'act',
#   'omission',
#   'party',
#   'circumstances',
#   'would',
#   'make',
#   'unfair',
#   'party',
#   'estopped',
#   'allowed',
#   'raise',
#   'argument',
#   'legal',
#   'defense',
#   'example',
#   'equitable',
#   'estoppel',
#   'may',
#   'applied',
#   'insurer',
#   'stalls',
#   'investigation',
#   'claim',
#   'indicates',
#   'insured',
#   'claim',
#   'paid',
#   'convinces',
#   'insured',
#   'sue',
#   'insurer',
#   'denies',
#   'claim',
#   'based',
#   '1-year',
#   'time-to-sue',
#   'limitation',
#   'policy',
#   'since',
#   'insurer',
#   'example',
#   'persuaded',
#   'insured',
#   'file',
#   'suit',
#   'timely',
#   'manner',
#   'insured',
#   'relied',
#   'insurer',
#   'overtures',
#   'would',
#   'unfair',
#   'allow',
#   'insurer',
#   'raise',
#   '1-year',
#   'time-to-sue',
#   'limitation',
#   'policy',
#   'fairness',
#   'insurer',
#   'may',
#   'equitably',
#   'estopped',
#   'raising',
#   'time-to-sue',
#   'limitation',
#   'defense',
#   'claim'],
#  ['environmental',
#   'monitoring',
#   'data',
#   'collected',
#   'auspices',
#   'emap',
#   'emap',
#   'data',
#   'share',
#   'common',
#   'attribute',
#   'known',
#   'quality',
#   'collected',
#   'context',
#   'explicit',
#   'data',
#   'quality',
#   'objectives',
#   '(',
#   'dqos',
#   ')',
#   'consistent',
#   'quality',
#   'assurance',
#   'program'],
#  ['reduces',
#   'risk',
#   'pollution',
#   'cleanup',
#   'cost',
#   'overruns',
#   'providing',
#   'insurance',
#   'coverage',
#   'excess',
#   'cleanup',
#   'costs',
#   'actual',
#   'cost',
#   'exceeds',
#   'original',
#   'estimate',
#   'established',
#   'percentage',
#   '130',
#   'percent',
#   'part',
#   'percentage',
#   'exceeds',
#   '100',
#   'percent',
#   'represents',
#   'built-in',
#   'buffer',
#   'coverage',
#   'triggered',
#   'policy',
#   'size',
#   'buffer',
#   'depend',
#   'underwriter',
#   'confidence',
#   'estimate'],
#  ['layer',
#   'insurance',
#   '(',
#   'risk',
#   'retention',
#   ')',
#   'resides',
#   'primary',
#   '(',
#   'burning',
#   ')',
#   'layer',
#   'excess',
#   'layers',
#   'example',
#   'primary',
#   'layer',
#   '100',
#   '000',
#   'excess',
#   'layer',
#   'attachment',
#   'point',
#   '500',
#   '000',
#   'buffer',
#   'layer',
#   '400',
#   '000',
#   'required'],
#  ['purposes',
#   'motor',
#   'carrier',
#   'liability',
#   'limits',
#   'requirements',
#   'motor',
#   'carriers',
#   'foreign',
#   'commerce',
#   'subject',
#   'requirements',
#   'carriers',
#   'interstate',
#   'commerce',
#   'defined',
#   'motor',
#   'carrier',
#   'act',
#   '(',
#   'mca',
#   ')',
#   '1980',
#   'term',
#   'means',
#   'commerce',
#   'place',
#   'foreign',
#   'country',
#   'united',
#   'states',
#   'territory',
#   'possession',
#   'united',
#   'states',
#   'insofar',
#   'transportation',
#   'takes',
#   'place',
#   'within',
#   'united',
#   'states',
#   'also',
#   'includes',
#   'commerce',
#   'places',
#   'foreign',
#   'country',
#   'countries',
#   '(',
#   'e',
#   'g',
#   'trade',
#   'canada',
#   'mexico',
#   ')',
#   'insofar',
#   'transportation',
#   'takes',
#   'place',
#   'within',
#   'united',
#   'states'],
#  ['law',
#   'imposing',
#   'criminal',
#   'liability',
#   'corporate',
#   'directors',
#   'officers',
#   'illegal',
#   'payments',
#   'made',
#   'foreign',
#   'officials',
#   'example',
#   'minister',
#   'trade',
#   'country',
#   'may',
#   'demand',
#   'annual',
#   '50',
#   '000',
#   'payment',
#   'corporation',
#   'x',
#   'return',
#   'allowing',
#   'corporation',
#   'ship',
#   'products',
#   'country',
#   'corporation',
#   'x',
#   'payment',
#   'monies',
#   'would',
#   'constitute',
#   'violation',
#   'fcpa',
#   'could',
#   'subject',
#   'corporation',
#   'x',
#   'directors',
#   'officers',
#   'liability',
#   'united',
#   'states'],
#  ['establishes',
#   'rules',
#   'reporting',
#   'foreign',
#   'financial',
#   'assets',
#   'held',
#   'u',
#   'taxpayers',
#   'foreign',
#   'financial',
#   'institution',
#   '(',
#   'ffi',
#   ')',
#   'nonfinancial',
#   'foreign',
#   'entity',
#   '(',
#   'nffe',
#   ')',
#   'fatca',
#   'imposes',
#   '30',
#   'percent',
#   'fatca',
#   'withholding',
#   'tax',
#   'withholdable',
#   'payments',
#   'made',
#   'ffi',
#   'nffe',
#   'unless',
#   'ffi',
#   'nffe',
#   'meets',
#   'certain',
#   'stipulated',
#   'conditions'],
#  ['federal',
#   'law',
#   'prohibiting',
#   'pay',
#   'discrimination',
#   'employees',
#   'gender',
#   'act',
#   'compels',
#   'businesses',
#   'pay',
#   'equal',
#   'wages',
#   'employees',
#   'performing',
#   'substantially',
#   'equal',
#   'work',
#   'regardless',
#   'sex',
#   'individual',
#   'employees',
#   'pay',
#   'differentials',
#   'may',
#   'based',
#   'merit',
#   'seniority',
#   'lawful',
#   'factor',
#   'sex',
#   'equal',
#   'pay',
#   'act',
#   'applies',
#   'businesses',
#   'regardless',
#   'number',
#   'employees',
#   'inequalities',
#   'pay',
#   'men',
#   'women',
#   'performance',
#   'substantially',
#   'equal',
#   'jobs',
#   'prohibited',
#   'unless',
#   'differences',
#   'due',
#   'factor',
#   'sex',
#   'seniority',
#   'system',
#   'merit',
#   'system',
#   'claims',
#   'alleging',
#   'violation',
#   'equal',
#   'pay',
#   'act',
#   'covered',
#   'employment',
#   'practices',
#   'liability',
#   'insurance',
#   '(',
#   'epli',
#   ')',
#   'policies'],
#  ['coverage',
#   'loss',
#   'due',
#   'mechanical',
#   'electrical',
#   'breakdown',
#   'nearly',
#   'type',
#   'equipment',
#   'including',
#   'photocopiers',
#   'computers',
#   'coverage',
#   'applies',
#   'cost',
#   'repair',
#   'replace',
#   'equipment',
#   'property',
#   'damaged',
#   'equipment',
#   'breakdown',
#   'resulting',
#   'business',
#   'income',
#   'extra',
#   'expense',
#   'loss',
#   'often',
#   'covered',
#   'well',
#   'equipment',
#   'breakdown',
#   'insurance',
#   'increasingly',
#   'replacing',
#   'traditional',
#   'boiler',
#   'machinery',
#   '(',
#   'bm',
#   ')',
#   'insurance',
#   'part',
#   'simply',
#   'title',
#   'descriptive',
#   'coverage',
#   'provided',
#   'also',
#   'today',
#   'equipment',
#   'breakdown',
#   'policies',
#   'typically',
#   'provide',
#   'slightly',
#   'broader',
#   'coverage',
#   'traditional',
#   'bm',
#   'policies',
#   'usually',
#   'use',
#   'specialized',
#   'terminology',
#   'found',
#   'traditional',
#   'bm',
#   'policies'],
#  ['insurance',
#   'must',
#   'purchased',
#   'comply',
#   'terms',
#   'contract',
#   'example',
#   'mortgagee',
#   'purchase',
#   'insurance',
#   'mortgaged',
#   'property',
#   'charge',
#   'premium',
#   'mortgagor'],
#  ['lawsuit',
#   'brought',
#   'foreign',
#   'investors',
#   'bought',
#   'shares',
#   'foreign-domiciled',
#   'companies',
#   'foreign',
#   'exchanges',
#   'violations',
#   'american',
#   'securities',
#   'laws',
#   'respect',
#   'securities'],
#  ['provides',
#   'coverage',
#   'financial',
#   'losses',
#   'arising',
#   'inability',
#   'bring',
#   'project',
#   'completion',
#   'coverage',
#   'encompasses',
#   'delays',
#   'well',
#   'total',
#   'termination',
#   'contract',
#   'resulting',
#   'events',
#   'totally',
#   'outside',
#   'control',
#   'contractor',
#   '(',
#   'e',
#   'fire',
#   'earthquake',
#   'war',
#   'revolution',
#   'flood',
#   'epidemics',
#   ')',
#   'types',
#   'losses',
#   'covered',
#   'policy',
#   'include',
#   'continued',
#   'debt',
#   'servicing',
#   'loss',
#   'income',
#   'ongoing',
#   'fixed',
#   'costs',
#   'spoilage',
#   'related',
#   'contingencies',
#   'coverage',
#   'limited',
#   'domestic',
#   'market',
#   'commonly',
#   'placed',
#   'political',
#   'risk',
#   'coverage',
#   'contractors',
#   'working',
#   'foreign',
#   'countries'],
#  ['property',
#   'insurance',
#   'covering',
#   'equipment',
#   'often',
#   'moved',
#   'place',
#   'place',
#   'form',
#   'inland',
#   'marine',
#   'insurance'],
#  ['french',
#   'superior',
#   'force',
#   'unexpected',
#   'uncontrollable',
#   'event',
#   'upsets',
#   'one',
#   'plans',
#   'releases',
#   'one',
#   'obligation'],
#  ['enforces',
#   'principal',
#   'federal',
#   'statutes',
#   'prohibiting',
#   'employment',
#   'discrimination',
#   'including',
#   'title',
#   'vii',
#   'civil',
#   'rights',
#   'act',
#   '1964',
#   'age',
#   'discrimination',
#   'employment',
#   'act',
#   '1967',
#   'equal',
#   'pay',
#   'act',
#   '1963',
#   'title',
#   'americans',
#   'disabilities',
#   'act',
#   '(',
#   'ada',
#   ')',
#   '1990',
#   'civil',
#   'rights',
#   'act',
#   '1991',
#   'section',
#   '501',
#   'rehabilitation',
#   'act',
#   '1973',
#   'eeoc',
#   'established',
#   'title',
#   'vii',
#   'civil',
#   'rights',
#   'act',
#   '1964',
#   'began',
#   'operating',
#   'july',
#   '2',
#   '1965',
#   'individuals',
#   'believe',
#   'discriminated',
#   'employment',
#   'file',
#   'administrative',
#   'charges',
#   'eeoc',
#   'investigates',
#   'attempts',
#   'reach',
#   'voluntary',
#   'resolution',
#   'charging',
#   'party',
#   'respondent',
#   'finds',
#   'discrimination',
#   'occurred',
#   'unable',
#   'eeoc',
#   'may',
#   'sue',
#   'federal',
#   'court',
#   'commission',
#   'also',
#   'issues',
#   'regulatory',
#   'forms',
#   'guidance',
#   'interpreting',
#   'laws',
#   'enforces'],
#  ['clause',
#   'reinsurance',
#   'contract',
#   'stating',
#   'reinsurer',
#   'duty',
#   'follow',
#   'fortunes',
#   'insured',
#   'reinsurer',
#   'party',
#   'original',
#   'insurance'],
#  ['also',
#   'known',
#   'specific',
#   'working',
#   'layer',
#   'underlying',
#   'excess',
#   'loss',
#   'reinsurance',
#   'method',
#   'insurer',
#   'may',
#   'recover',
#   'losses',
#   'individual',
#   'risk',
#   'excess',
#   'specific',
#   'per',
#   'risk',
#   'retention',
#   'property',
#   'casualty',
#   'applications'],
#  ['official',
#   'flood',
#   'insurance',
#   'map',
#   'community',
#   'federal',
#   'emergency',
#   'management',
#   'agency',
#   '(',
#   'fema',
#   ')',
#   'indicated',
#   'special',
#   'flood',
#   'hazard',
#   'areas',
#   'risk',
#   'premium',
#   'zones',
#   'designated',
#   'community',
#   'common',
#   'map',
#   'fema',
#   'produces',
#   'used',
#   'variety',
#   'parties',
#   'insurance',
#   'agents',
#   'insurers',
#   'use',
#   'firm',
#   'determine',
#   'extent',
#   'flood',
#   'risk',
#   'faced',
#   'properties',
#   'buildings',
#   'community',
#   'officials',
#   'use',
#   'firm',
#   'administer',
#   'floodplain',
#   'management',
#   'regulations',
#   'mitigate',
#   'loss',
#   'exposure',
#   'floods',
#   'lending',
#   'institutions',
#   'federal',
#   'government',
#   'entities',
#   'use',
#   'firm',
#   'locate',
#   'properties',
#   'buildings',
#   'relation',
#   'mapped',
#   'flood',
#   'hazards',
#   'ascertain',
#   'whether',
#   'flood',
#   'insurance',
#   'required',
#   'making',
#   'loans',
#   'providing',
#   'grants',
#   'rebuild',
#   'structures',
#   'following',
#   'disaster',
#   'see',
#   'also'],
#  ['umbrella',
#   'policy',
#   'provision',
#   'follows',
#   'underlying',
#   'policy',
#   'provision',
#   'applies',
#   'follow',
#   'form',
#   'also',
#   'identifies',
#   'excess',
#   'liability',
#   'policy',
#   'follows',
#   'underlying',
#   'policies',
#   'policy',
#   'provisions',
#   'policy',
#   'may',
#   'stand',
#   'alone',
#   'certain',
#   'exclusions',
#   'conditions',
#   'etc',
#   'relating',
#   'back',
#   'underlying',
#   'coverage',
#   'provisions',
#   'type',
#   'policy',
#   'form',
#   'typically',
#   'used',
#   'excess',
#   'scheduled',
#   'underlying',
#   'insurance',
#   'usually',
#   'contains',
#   'requirement',
#   'insured',
#   'maintain',
#   'scheduled',
#   'underlying',
#   'insurance',
#   'see',
#   'also'],
#  ['liability',
#   'insurance',
#   'maximum',
#   'amount',
#   'insurer',
#   'pay',
#   'one',
#   'person',
#   'injuries',
#   'two',
#   'people',
#   'injured',
#   'auto',
#   'accident',
#   'at-fault',
#   'driver',
#   'policy',
#   '50',
#   '000',
#   'per',
#   'person',
#   'limit',
#   'insurer',
#   'pay',
#   '50',
#   '000',
#   'person',
#   'injuries',
#   'one',
#   'person',
#   'injuries',
#   'worth',
#   '25',
#   '000',
#   'person',
#   'worth',
#   '75',
#   '000',
#   'first',
#   'claimant',
#   'receive',
#   '25',
#   '000',
#   'second',
#   'receive',
#   'per',
#   'person',
#   'maximum',
#   '50',
#   '000',
#   'insurer',
#   'see',
#   'also'],
#  ['provision',
#   'found',
#   'nearly',
#   'property',
#   'insurance',
#   'policies',
#   '(',
#   'even',
#   'risks',
#   'policies',
#   ')',
#   'eliminating',
#   'coverage',
#   'damage',
#   'flood',
#   'may',
#   'also',
#   'eliminate',
#   'coverage',
#   'types',
#   'water',
#   'damage',
#   'seepage',
#   'sewer',
#   'backup',
#   'flood',
#   'coverage',
#   'sometimes',
#   'provided',
#   'endorsement',
#   'separate',
#   'flood',
#   'insurance',
#   'policy',
#   'may',
#   'available',
#   'national',
#   'flood',
#   'insurance',
#   'program',
#   '(',
#   'nfip',
#   ')'],
#  ['nonstandard',
#   'commercial',
#   'property',
#   'insurance',
#   'provision',
#   'essentially',
#   'converts',
#   'blanket',
#   'limits',
#   'specific',
#   'per',
#   'location',
#   'limits',
#   'provision',
#   'establishes',
#   'insured',
#   'collect',
#   'commercial',
#   'property',
#   'loss',
#   'given',
#   'location',
#   'amount',
#   'reported',
#   'location',
#   'insured',
#   'statement',
#   'values',
#   'sometimes',
#   'used',
#   'combination',
#   'another',
#   'nonstandard',
#   'commercial',
#   'property',
#   'insurance',
#   'provision',
#   'margin',
#   'clause',
#   'margin',
#   'clause',
#   'softens',
#   'negative',
#   'impact',
#   'per',
#   'occurrence',
#   'limitation',
#   'liability',
#   'provision',
#   'stipulating',
#   'insured',
#   'collect',
#   'loss',
#   'given',
#   'location',
#   'specified',
#   'percentage',
#   'greater',
#   '100',
#   'percent',
#   '(',
#   '110',
#   '125',
#   'percent',
#   ')',
#   'values',
#   'reported',
#   'location'],
#  ['liability',
#   'insurance',
#   'maximum',
#   'amount',
#   'insurer',
#   'pay',
#   'claims',
#   'resulting',
#   'single',
#   'occurrence',
#   'matter',
#   'many',
#   'people',
#   'injured',
#   'much',
#   'property',
#   'damaged',
#   'many',
#   'different',
#   'claimants',
#   'may',
#   'make',
#   'claims',
#   'see',
#   'also'],
#  ['life',
#   'insurance',
#   'expiration',
#   'date',
#   'provides',
#   'payment',
#   'face',
#   'value',
#   'upon',
#   'death',
#   'insured',
#   'regardless',
#   'may',
#   'occur',
#   'contrasts',
#   'term',
#   'insurance',
#   'pays',
#   'benefits',
#   'death',
#   'takes',
#   'place',
#   'limited',
#   'term',
#   '(',
#   'e',
#   'g',
#   '1',
#   '3',
#   '5',
#   '10',
#   'years',
#   ')',
#   'policy',
#   'permanent',
#   'life',
#   'insurance',
#   'policies',
#   'insured',
#   'pays',
#   'level',
#   'premium',
#   'rate',
#   'life',
#   'approach',
#   'results',
#   'overpayment',
#   'premiums',
#   'early',
#   'years',
#   'policy',
#   'underpayment',
#   'latter',
#   'years',
#   'intended',
#   'average',
#   'life',
#   'insured',
#   'types',
#   'permanent',
#   'life',
#   'insurance',
#   '(',
#   'e',
#   'g',
#   'whole',
#   'life',
#   'universal',
#   'life',
#   'variable',
#   'life',
#   'insurance',
#   ')',
#   'accumulate',
#   'cash',
#   'value',
#   'insured',
#   'may',
#   'borrow',
#   'otherwise',
#   'use'],
#  ['class',
#   'workers',
#   'compensation',
#   'disability',
#   'injured',
#   'employee',
#   'incapable',
#   'ever',
#   'working',
#   'employment',
#   'statutes',
#   'employee',
#   'receive',
#   'weekly',
#   'wages',
#   'life'],
#  ['workers',
#   'compensation',
#   'disability',
#   'level',
#   'injured',
#   'employee',
#   'still',
#   'able',
#   'work',
#   'skill',
#   'efficiency',
#   'demonstrated',
#   'prior',
#   'injury',
#   'result',
#   'earning',
#   'capability',
#   'worker',
#   'affected',
#   'workers',
#   'compensation',
#   'statutes',
#   'provide',
#   'scheduled',
#   'benefits',
#   'based',
#   'percentage',
#   'disability'],
#  ...]

# %%
# docs[0]

vocab = [word for words in docs for word in words]
vocab
# Out:
# ['optional',
#  'provision',
#  'life',
#  'insurance',
#  'authorizes',
#  'insurer',
#  'pay',
#  'cash',
#  'value',
#  'premium',
#  'due',
#  'end',
#  'grace',
#  'period',
#  'provision',
#  'useful',
#  'preventing',
#  'inadvertent',
#  'lapse',
#  'policy',
#  'provided',
#  'nonjudicial',
#  'dispute',
#  'settlement',
#  'program',
#  'carriage',
#  'household',
#  'goods',
#  'class',
#  'organic',
#  'compounds',
#  'composed',
#  'carbon',
#  'hydrogen',
#  'common',
#  'hydrocarbons',
#  'include',
#  'natural',
#  'gas',
#  'crude',
#  'oil',
#  'coal',
#  'hydrocarbons',
#  'primary',
#  'source',
#  'world',
#  'electric',
#  'energy',
#  'heat',
#  'sources',
#  'due',
#  'power',
#  'created',
#  'burned',
#  'process',
#  'fractures',
#  'hard-to-reach',
#  'shale',
#  'rock',
#  'formations',
#  'earth',
#  'surface',
#  'opened',
#  'widened',
#  'injecting',
#  'water',
#  'chemicals',
#  'sand',
#  'high',
#  'pressure',
#  'extract',
#  'natural',
#  'gas',
#  'oil',
#  'trapped',
#  'shale',
#  'rocks',
#  'enables',
#  'wells',
#  'would',
#  'flow',
#  'low',
#  'rates',
#  'produce',
#  'oil',
#  'gas',
#  'commercially',
#  'viable',
#  'volumes',
#  'risk',
#  'financing',
#  'techniques',
#  'combination',
#  'retention',
#  'transfer',
#  'hybrid',
#  'plans',
#  'designed',
#  'transfer',
#  'part',
#  'risk',
#  'loss',
#  'insurer',
#  'organization',
#  'retains',
#  'balance',
#  'exposure',
#  'also',
#  'called',
#  'blended',
#  'plans',
#  'alternative',
#  'market',
#  'plans',
#  'combination',
#  'standard',
#  'group',
#  'captive',
#  'structured',
#  'reinsurance',
#  'designed',
#  'create',
#  'significant',
#  'limits',
#  'insurance',
#  'risks',
#  'one',
#  'reason',
#  'another',
#  'covered',
#  'commercial',
#  'insurance',
#  'markets',
#  'major',
#  'difference',
#  'hybrid',
#  'captive',
#  'standard',
#  'group',
#  'captive',
#  'limits',
#  'liability',
#  'structured',
#  'internal',
#  'rate',
#  'return',
#  'established',
#  'organization',
#  'necessary',
#  'justify',
#  'investment',
#  'operation',
#  'based',
#  'usually',
#  'short-term',
#  'cost',
#  'borrowing',
#  'often',
#  'used',
#  'discount',
#  'rate',
#  'net',
#  'present',
#  'value',
#  'cost',
#  'analysis',
#  'type',
#  'risk',
#  'financing',
#  'plan',
#  'makes',
#  'use',
#  'internal',
#  'external',
#  'funds',
#  'pay',
#  'losses',
#  'thus',
#  'falls',
#  'pure',
#  'transfer',
#  'approach',
#  'pure',
#  'retention',
#  'approach',
#  'risk',
#  'costs',
#  'hybrid',
#  'techniques',
#  'tend',
#  'less',
#  'experience-responsive',
#  'compared',
#  'pure',
#  'retention',
#  'experience-responsive',
#  'compared',
#  'pure',
#  'transfer',
#  'techniques',
#  'examples',
#  'hybrid',
#  'techniques',
#  'include',
#  'pooling',
#  'arrangements',
#  'high-deductible',
#  'plans',
#  'multiple-parent',
#  'captives',
#  'retrospectively',
#  'rated',
#  'insurance',
#  'policies',
#  'involves',
#  'detailed',
#  'analysis',
#  'steps',
#  'integral',
#  'particular',
#  'task',
#  'process',
#  'includes',
#  'listing',
#  'categorizing',
#  'hazards',
#  'persons',
#  'property',
#  'might',
#  'impact',
#  'step',
#  'detailing',
#  'reasonable',
#  'mechanical',
#  'procedural',
#  'managerial',
#  'safeguards',
#  'hazard',
#  'main',
#  'goal',
#  'make',
#  'task',
#  'overall',
#  'process',
#  'subject',
#  'appropriate',
#  'risk',
#  'control',
#  'techniques',
#  'leading',
#  'greater',
#  'workplace',
#  'safety',
#  'permanent',
#  'additions',
#  'changes',
#  'made',
#  'building',
#  'lessee',
#  'expense',
#  'may',
#  'legally',
#  'removed',
#  'property',
#  'policies',
#  'vary',
#  'whether',
#  'tenants',
#  'improvements',
#  'betterments',
#  'covered',
#  'building',
#  'category',
#  'contents',
#  'category',
#  'care',
#  'must',
#  'taken',
#  'assign',
#  'values',
#  'proper',
#  'category',
#  'covered',
#  'property',
#  'point',
#  'law',
#  'understanding',
#  'particular',
#  'product',
#  'safe',
#  'suitable',
#  'particular',
#  'use',
#  'vendor',
#  'knows',
#  'time',
#  'sale',
#  'use',
#  'product',
#  'intended',
#  'actions',
#  'agent',
#  'may',
#  'extend',
#  'beyond',
#  'rights',
#  'powers',
#  'explicitly',
#  'provided',
#  'agency',
#  'contract',
#  'actions',
#  'result',
#  'response',
#  'insurer',
#  'authority',
#  'extended',
#  'fall',
#  'within',
#  'agency',
#  'contract',
#  'sue',
#  'prosecute',
#  'bring',
#  'new',
#  'party',
#  'action',
#  'situation',
#  'surplus',
#  'account',
#  'stock',
#  'insurer',
#  'threatened',
#  'exhaustion',
#  'insurer',
#  'invades',
#  'capital',
#  'account',
#  'meet',
#  'liabilities',
#  'jurisdictions',
#  'allow',
#  'legal',
#  'principle',
#  'holds',
#  'incorporation',
#  'defective',
#  'product',
#  'real',
#  'property',
#  'constitutes',
#  'property',
#  'damage',
#  '(',
#  'pd',
#  ')',
#  'defined',
#  'commercial',
#  'general',
#  'liability',
#  '(',
#  'cgl',
#  ')',
#  'policy',
#  'doctrine',
#  'argued',
#  'mostly',
#  'unsuccessfully',
#  'pursuit',
#  'liability',
#  'coverage',
#  'construction',
#  'defects',
#  'produced',
#  'actual',
#  'physical',
#  'damage',
#  'clause',
#  'life',
#  'health',
#  'insurance',
#  'policy',
#  'stipulates',
#  'given',
#  'length',
#  'time',
#  '(',
#  'usually',
#  '2',
#  'years',
#  ')',
#  'insurer',
#  'may',
#  'contest',
#  'claims',
#  'expiration',
#  'time',
#  'claims',
#  'contested',
#  'reason',
#  'nonpayment',
#  'premium',
#  'provision',
#  'liability',
#  'insurance',
#  'policy',
#  'requires',
#  'allows',
#  'insured',
#  'report',
#  'incidents',
#  'accidents',
#  'occurrences',
#  'may',
#  'lead',
#  'claims',
#  'also',
#  'called',
#  'awareness',
#  'provision',
#  'notice',
#  'potential',
#  'claim',
#  'provision',
#  'consulting',
#  'services',
#  'provided',
#  'accounting',
#  'firms',
#  'bulk',
#  'involve',
#  'computer',
#  'software',
#  'hardware',
#  'areas',
#  'falling',
#  'heading',
#  'management',
#  'advisory',
#  'services',
#  'include',
#  'business',
#  'asset',
#  'valuation',
#  'mergers',
#  'acquisitions',
#  'investments',
#  'capital',
#  'budgeting',
#  'business',
#  'strategy',
#  'marketing',
#  'organizational',
#  'structure',
#  'business',
#  'operations',
#  'real',
#  'estate',
#  'litigation',
#  'support',
#  'one',
#  'severe',
#  'exposures',
#  'covered',
#  'accountants',
#  'professional',
#  'liability',
#  'policies',
#  'healthcare',
#  'provider',
#  'whose',
#  'goal',
#  'provide',
#  'appropriate',
#  'cost-effective',
#  'medical',
#  'treatment',
#  'two',
#  'types',
#  'providers',
#  'health',
#  'maintenance',
#  'organization',
#  '(',
#  'hmo',
#  ')',
#  'preferred',
#  'provider',
#  'organization',
#  '(',
#  'ppo',
#  ')',
#  'coverage',
#  'event',
#  'late',
#  'delivery',
#  'product',
#  'agreed',
#  'amount',
#  'based',
#  'contract',
#  'insured',
#  'manufacturer',
#  'purchaser',
#  'designed',
#  'manufacturers',
#  'compelled',
#  'enter',
#  'contracts',
#  'assume',
#  'responsibility',
#  'delay',
#  'completion',
#  'product',
#  'policy',
#  'generally',
#  'covers',
#  '90',
#  'percent',
#  'penalty',
#  'loss',
#  'sustained',
#  'extend',
#  'strikes',
#  'labor',
#  'disputes',
#  'form',
#  'liability',
#  'coverage',
#  'written',
#  'cover',
#  'organizations',
#  'engaged',
#  'delivering',
#  'medical',
#  'services',
#  'managed-care',
#  'basis',
#  'health',
#  'maintenance',
#  'organizations',
#  '(',
#  'hmos',
#  ')',
#  'representative',
#  'types',
#  'claims',
#  'covered',
#  'policies',
#  'include',
#  'allegations',
#  'negligent',
#  'provider',
#  'selection',
#  'direct',
#  'professional',
#  'liability',
#  'wrongful',
#  'denial',
#  'treatment',
#  'endorsement',
#  'fiduciary',
#  'liability',
#  'policy',
#  'providing',
#  'coverage',
#  'bodily',
#  'injury',
#  '(',
#  'bi',
#  ')',
#  'property',
#  'damage',
#  '(',
#  'pd',
#  ')',
#  'personal',
#  'injury',
#  '(',
#  'pi',
#  ')',
#  'result',
#  'administering',
#  'managed',
#  'care',
#  'health',
#  'plans',
#  'endorsement',
#  'necessary',
#  'fiduciary',
#  'liability',
#  'policies',
#  'usually',
#  'exclude',
#  'coverage',
#  'perils',
#  'however',
#  'managed',
#  'care',
#  'plans',
#  'subject',
#  'employee',
#  'retirement',
#  'income',
#  'security',
#  'act',
#  '(',
#  'erisa',
#  ')',
#  'coverage',
#  'necessary',
#  'two',
#  'common',
#  'claims',
#  'involving',
#  'managed',
#  'care',
#  'plans',
#  'allege',
#  '(',
#  '1',
#  ')',
#  'employer-sponsor',
#  'managed',
#  'healthcare',
#  'plan',
#  'negligently',
#  'selected',
#  'managed',
#  'healthcare',
#  'plan',
#  'provider',
#  '(',
#  '2',
#  ')',
#  'employer-sponsor',
#  'managed',
#  'healthcare',
#  'plan',
#  'wrongly',
#  'denied',
#  'delayed',
#  'medical',
#  'benefits',
#  'provided',
#  'plan',
#  'process',
#  'delivery',
#  'health',
#  'care',
#  'structured',
#  'monitored',
#  'goal',
#  'providing',
#  'medical',
#  'services',
#  'appropriate',
#  'economically',
#  'reasonable',
#  'software',
#  'designed',
#  'infiltrate',
#  'damage',
#  'computer',
#  'system',
#  'without',
#  'computer',
#  'owner',
#  'knowledge',
#  'consent',
#  'term',
#  'shortened',
#  'combination',
#  'words',
#  'malicious',
#  'software',
#  'generic',
#  'term',
#  'used',
#  'refer',
#  'variety',
#  'forms',
#  'hostile',
#  'intrusive',
#  'software',
#  'computer',
#  'viruses',
#  'worms',
#  'trojan',
#  'horses',
#  'spyware',
#  'see',
#  'also',
#  'broad',
#  'risks',
#  'policy',
#  'provides',
#  'combination',
#  'commercial',
#  'property',
#  'commercial',
#  'inland',
#  'marine',
#  'coverages',
#  'manufacturers',
#  'many',
#  'businesses',
#  'need',
#  'mops',
#  'developed',
#  'mid-1950s',
#  'method',
#  'insuring',
#  'single',
#  'policy',
#  'stock',
#  'manufacturing',
#  'process',
#  'transit',
#  'mop',
#  'combination',
#  'commercial',
#  'property',
#  'commercial',
#  'marine',
#  'coverages',
#  'met',
#  'needs',
#  'many',
#  'different',
#  'types',
#  'organizations',
#  'mop',
#  'eligibility',
#  'also',
#  'expanded',
#  'time',
#  'include',
#  'many',
#  'industrial',
#  'processing',
#  'commercial',
#  'operations',
#  'recent',
#  'years',
#  'term',
#  'commercial',
#  'output',
#  'policy',
#  'cop',
#  'acronym',
#  'begun',
#  'replace',
#  'term',
#  'manufacturers',
#  'output',
#  'policy',
#  'mop',
#  'acronym',
#  'commercial',
#  'insurance',
#  'arena',
#  'since',
#  'accurately',
#  'reflect',
#  'wide',
#  'range',
#  'organizations',
#  'insured',
#  'type',
#  'policy',
#  'american',
#  'association',
#  'insurance',
#  'services',
#  '(',
#  'aais',
#  ')',
#  'offers',
#  'standard',
#  'cop',
#  'forms',
#  'rules',
#  'use',
#  'member',
#  'insurers',
#  'addition',
#  'many',
#  'insurers',
#  'developed',
#  'cop',
#  'forms',
#  'rules',
#  'cop',
#  'premiums',
#  'typically',
#  'developed',
#  'using',
#  'distinctive',
#  'rating',
#  'system',
#  '(',
#  'referred',
#  'deficiency',
#  'point',
#  'rating',
#  'system',
#  ')',
#  'allows',
#  'many',
#  'insurers',
#  'competitive',
#  'using',
#  'cop',
#  'could',
#  'using',
#  'standard',
#  'commercial',
#  'property',
#  'policy',
#  'property',
#  'insurance',
#  'endorsement',
#  'provision',
#  'establishing',
#  'market',
#  'value',
#  '(',
#  'rather',
#  'actual',
#  'cash',
#  'value',
#  '(',
#  'acv',
#  ')',
#  'replacement',
#  'cost',
#  '(',
#  'rc',
#  ')',
#  'value',
#  ')',
#  'valuation',
#  'basis',
#  'covered',
#  'property',
#  'usually',
#  'used',
#  'connection',
#  'agricultural',
#  'products',
#  'commodities',
#  'whose',
#  'value',
#  'fluctuates',
#  'accordance',
#  'commodities',
#  'exchange',
#  'also',
#  'occasionally',
#  'used',
#  'valuation',
#  'basis',
#  'building',
#  'refers',
#  'deductible',
#  'arrangement',
#  'policy',
#  'deductible',
#  'equals',
#  'policy',
#  'limit',
#  'contract',
#  'used',
#  'oil',
#  'gas',
#  'companies',
#  'enter',
#  'agreement',
#  'advance',
#  'contractors',
#  'specifies',
#  'terms',
#  'conditions',
#  'govern',
#  'contractors',
#  'work',
#  'agreement',
#  'typically',
#  'used',
#  'on-site',
#  'services',
#  'performed',
#  'oilfield',
#  'service',
#  'contractors',
#  'repetitive',
#  'basis',
#  'equipment',
#  'maintenance',
#  'well',
#  'services',
#  'cementing',
#  'services',
#  'goal',
#  'speed',
#  'simplify',
#  'future',
#  'contracts',
#  'long-term',
#  'client',
#  'vendor',
#  'relationships',
#  'property',
#  'liability',
#  'coverage',
#  'combining',
#  'several',
#  'locations',
#  'operations',
#  'single',
#  'policy',
#  'insured',
#  'insureds',
#  'term',
#  'may',
#  'also',
#  'used',
#  'case',
#  'construction',
#  'wrap-ups',
#  'either',
#  'case',
#  'underlying',
#  'policies',
#  'certificates',
#  'insurance',
#  'issued',
#  'insureds',
#  'policy',
#  'evidence',
#  'coverage',
#  'master',
#  'policy',
#  'one',
#  'six',
#  'building',
#  'construction',
#  'categories',
#  'established',
#  'insurance',
#  'services',
#  'office',
#  'inc',
#  '(',
#  'iso',
#  ')',
#  'coverage',
#  'acts',
#  'errors',
#  'omissions',
#  'physicians',
#  'surgeons',
#  'encompassing',
#  'physicians',
#  'professional',
#  'liability',
#  'insurance',
#  'hospital',
#  'professional',
#  'liability',
#  '(',
#  'hpl',
#  ')',
#  'insurance',
#  'allied',
#  'healthcare',
#  '(',
#  'e',
#  'g',
#  'nurses',
#  ')',
#  'professional',
#  'liability',
#  'insurance',
#  'although',
#  'majority',
#  'policies',
#  'written',
#  'claims-made',
#  'coverage',
#  'trigger',
#  'coverage',
#  'sometimes',
#  'available',
#  'occurrence',
#  'basis',
#  'typical',
#  'exclusions',
#  'intentional',
#  ...]

# %%
from nltk.stem.wordnet import WordNetLemmatizer
wordnet = WordNetLemmatizer()
vocab = [wordnet.lemmatize(word) for word in vocab]
vocab
# Out:
# ['optional',
#  'provision',
#  'life',
#  'insurance',
#  'authorizes',
#  'insurer',
#  'pay',
#  'cash',
#  'value',
#  'premium',
#  'due',
#  'end',
#  'grace',
#  'period',
#  'provision',
#  'useful',
#  'preventing',
#  'inadvertent',
#  'lapse',
#  'policy',
#  'provided',
#  'nonjudicial',
#  'dispute',
#  'settlement',
#  'program',
#  'carriage',
#  'household',
#  'good',
#  'class',
#  'organic',
#  'compound',
#  'composed',
#  'carbon',
#  'hydrogen',
#  'common',
#  'hydrocarbon',
#  'include',
#  'natural',
#  'gas',
#  'crude',
#  'oil',
#  'coal',
#  'hydrocarbon',
#  'primary',
#  'source',
#  'world',
#  'electric',
#  'energy',
#  'heat',
#  'source',
#  'due',
#  'power',
#  'created',
#  'burned',
#  'process',
#  'fracture',
#  'hard-to-reach',
#  'shale',
#  'rock',
#  'formation',
#  'earth',
#  'surface',
#  'opened',
#  'widened',
#  'injecting',
#  'water',
#  'chemical',
#  'sand',
#  'high',
#  'pressure',
#  'extract',
#  'natural',
#  'gas',
#  'oil',
#  'trapped',
#  'shale',
#  'rock',
#  'enables',
#  'well',
#  'would',
#  'flow',
#  'low',
#  'rate',
#  'produce',
#  'oil',
#  'gas',
#  'commercially',
#  'viable',
#  'volume',
#  'risk',
#  'financing',
#  'technique',
#  'combination',
#  'retention',
#  'transfer',
#  'hybrid',
#  'plan',
#  'designed',
#  'transfer',
#  'part',
#  'risk',
#  'loss',
#  'insurer',
#  'organization',
#  'retains',
#  'balance',
#  'exposure',
#  'also',
#  'called',
#  'blended',
#  'plan',
#  'alternative',
#  'market',
#  'plan',
#  'combination',
#  'standard',
#  'group',
#  'captive',
#  'structured',
#  'reinsurance',
#  'designed',
#  'create',
#  'significant',
#  'limit',
#  'insurance',
#  'risk',
#  'one',
#  'reason',
#  'another',
#  'covered',
#  'commercial',
#  'insurance',
#  'market',
#  'major',
#  'difference',
#  'hybrid',
#  'captive',
#  'standard',
#  'group',
#  'captive',
#  'limit',
#  'liability',
#  'structured',
#  'internal',
#  'rate',
#  'return',
#  'established',
#  'organization',
#  'necessary',
#  'justify',
#  'investment',
#  'operation',
#  'based',
#  'usually',
#  'short-term',
#  'cost',
#  'borrowing',
#  'often',
#  'used',
#  'discount',
#  'rate',
#  'net',
#  'present',
#  'value',
#  'cost',
#  'analysis',
#  'type',
#  'risk',
#  'financing',
#  'plan',
#  'make',
#  'use',
#  'internal',
#  'external',
#  'fund',
#  'pay',
#  'loss',
#  'thus',
#  'fall',
#  'pure',
#  'transfer',
#  'approach',
#  'pure',
#  'retention',
#  'approach',
#  'risk',
#  'cost',
#  'hybrid',
#  'technique',
#  'tend',
#  'le',
#  'experience-responsive',
#  'compared',
#  'pure',
#  'retention',
#  'experience-responsive',
#  'compared',
#  'pure',
#  'transfer',
#  'technique',
#  'example',
#  'hybrid',
#  'technique',
#  'include',
#  'pooling',
#  'arrangement',
#  'high-deductible',
#  'plan',
#  'multiple-parent',
#  'captive',
#  'retrospectively',
#  'rated',
#  'insurance',
#  'policy',
#  'involves',
#  'detailed',
#  'analysis',
#  'step',
#  'integral',
#  'particular',
#  'task',
#  'process',
#  'includes',
#  'listing',
#  'categorizing',
#  'hazard',
#  'person',
#  'property',
#  'might',
#  'impact',
#  'step',
#  'detailing',
#  'reasonable',
#  'mechanical',
#  'procedural',
#  'managerial',
#  'safeguard',
#  'hazard',
#  'main',
#  'goal',
#  'make',
#  'task',
#  'overall',
#  'process',
#  'subject',
#  'appropriate',
#  'risk',
#  'control',
#  'technique',
#  'leading',
#  'greater',
#  'workplace',
#  'safety',
#  'permanent',
#  'addition',
#  'change',
#  'made',
#  'building',
#  'lessee',
#  'expense',
#  'may',
#  'legally',
#  'removed',
#  'property',
#  'policy',
#  'vary',
#  'whether',
#  'tenant',
#  'improvement',
#  'betterment',
#  'covered',
#  'building',
#  'category',
#  'content',
#  'category',
#  'care',
#  'must',
#  'taken',
#  'assign',
#  'value',
#  'proper',
#  'category',
#  'covered',
#  'property',
#  'point',
#  'law',
#  'understanding',
#  'particular',
#  'product',
#  'safe',
#  'suitable',
#  'particular',
#  'use',
#  'vendor',
#  'know',
#  'time',
#  'sale',
#  'use',
#  'product',
#  'intended',
#  'action',
#  'agent',
#  'may',
#  'extend',
#  'beyond',
#  'right',
#  'power',
#  'explicitly',
#  'provided',
#  'agency',
#  'contract',
#  'action',
#  'result',
#  'response',
#  'insurer',
#  'authority',
#  'extended',
#  'fall',
#  'within',
#  'agency',
#  'contract',
#  'sue',
#  'prosecute',
#  'bring',
#  'new',
#  'party',
#  'action',
#  'situation',
#  'surplus',
#  'account',
#  'stock',
#  'insurer',
#  'threatened',
#  'exhaustion',
#  'insurer',
#  'invades',
#  'capital',
#  'account',
#  'meet',
#  'liability',
#  'jurisdiction',
#  'allow',
#  'legal',
#  'principle',
#  'hold',
#  'incorporation',
#  'defective',
#  'product',
#  'real',
#  'property',
#  'constitutes',
#  'property',
#  'damage',
#  '(',
#  'pd',
#  ')',
#  'defined',
#  'commercial',
#  'general',
#  'liability',
#  '(',
#  'cgl',
#  ')',
#  'policy',
#  'doctrine',
#  'argued',
#  'mostly',
#  'unsuccessfully',
#  'pursuit',
#  'liability',
#  'coverage',
#  'construction',
#  'defect',
#  'produced',
#  'actual',
#  'physical',
#  'damage',
#  'clause',
#  'life',
#  'health',
#  'insurance',
#  'policy',
#  'stipulates',
#  'given',
#  'length',
#  'time',
#  '(',
#  'usually',
#  '2',
#  'year',
#  ')',
#  'insurer',
#  'may',
#  'contest',
#  'claim',
#  'expiration',
#  'time',
#  'claim',
#  'contested',
#  'reason',
#  'nonpayment',
#  'premium',
#  'provision',
#  'liability',
#  'insurance',
#  'policy',
#  'requires',
#  'allows',
#  'insured',
#  'report',
#  'incident',
#  'accident',
#  'occurrence',
#  'may',
#  'lead',
#  'claim',
#  'also',
#  'called',
#  'awareness',
#  'provision',
#  'notice',
#  'potential',
#  'claim',
#  'provision',
#  'consulting',
#  'service',
#  'provided',
#  'accounting',
#  'firm',
#  'bulk',
#  'involve',
#  'computer',
#  'software',
#  'hardware',
#  'area',
#  'falling',
#  'heading',
#  'management',
#  'advisory',
#  'service',
#  'include',
#  'business',
#  'asset',
#  'valuation',
#  'merger',
#  'acquisition',
#  'investment',
#  'capital',
#  'budgeting',
#  'business',
#  'strategy',
#  'marketing',
#  'organizational',
#  'structure',
#  'business',
#  'operation',
#  'real',
#  'estate',
#  'litigation',
#  'support',
#  'one',
#  'severe',
#  'exposure',
#  'covered',
#  'accountant',
#  'professional',
#  'liability',
#  'policy',
#  'healthcare',
#  'provider',
#  'whose',
#  'goal',
#  'provide',
#  'appropriate',
#  'cost-effective',
#  'medical',
#  'treatment',
#  'two',
#  'type',
#  'provider',
#  'health',
#  'maintenance',
#  'organization',
#  '(',
#  'hmo',
#  ')',
#  'preferred',
#  'provider',
#  'organization',
#  '(',
#  'ppo',
#  ')',
#  'coverage',
#  'event',
#  'late',
#  'delivery',
#  'product',
#  'agreed',
#  'amount',
#  'based',
#  'contract',
#  'insured',
#  'manufacturer',
#  'purchaser',
#  'designed',
#  'manufacturer',
#  'compelled',
#  'enter',
#  'contract',
#  'assume',
#  'responsibility',
#  'delay',
#  'completion',
#  'product',
#  'policy',
#  'generally',
#  'cover',
#  '90',
#  'percent',
#  'penalty',
#  'loss',
#  'sustained',
#  'extend',
#  'strike',
#  'labor',
#  'dispute',
#  'form',
#  'liability',
#  'coverage',
#  'written',
#  'cover',
#  'organization',
#  'engaged',
#  'delivering',
#  'medical',
#  'service',
#  'managed-care',
#  'basis',
#  'health',
#  'maintenance',
#  'organization',
#  '(',
#  'hmo',
#  ')',
#  'representative',
#  'type',
#  'claim',
#  'covered',
#  'policy',
#  'include',
#  'allegation',
#  'negligent',
#  'provider',
#  'selection',
#  'direct',
#  'professional',
#  'liability',
#  'wrongful',
#  'denial',
#  'treatment',
#  'endorsement',
#  'fiduciary',
#  'liability',
#  'policy',
#  'providing',
#  'coverage',
#  'bodily',
#  'injury',
#  '(',
#  'bi',
#  ')',
#  'property',
#  'damage',
#  '(',
#  'pd',
#  ')',
#  'personal',
#  'injury',
#  '(',
#  'pi',
#  ')',
#  'result',
#  'administering',
#  'managed',
#  'care',
#  'health',
#  'plan',
#  'endorsement',
#  'necessary',
#  'fiduciary',
#  'liability',
#  'policy',
#  'usually',
#  'exclude',
#  'coverage',
#  'peril',
#  'however',
#  'managed',
#  'care',
#  'plan',
#  'subject',
#  'employee',
#  'retirement',
#  'income',
#  'security',
#  'act',
#  '(',
#  'erisa',
#  ')',
#  'coverage',
#  'necessary',
#  'two',
#  'common',
#  'claim',
#  'involving',
#  'managed',
#  'care',
#  'plan',
#  'allege',
#  '(',
#  '1',
#  ')',
#  'employer-sponsor',
#  'managed',
#  'healthcare',
#  'plan',
#  'negligently',
#  'selected',
#  'managed',
#  'healthcare',
#  'plan',
#  'provider',
#  '(',
#  '2',
#  ')',
#  'employer-sponsor',
#  'managed',
#  'healthcare',
#  'plan',
#  'wrongly',
#  'denied',
#  'delayed',
#  'medical',
#  'benefit',
#  'provided',
#  'plan',
#  'process',
#  'delivery',
#  'health',
#  'care',
#  'structured',
#  'monitored',
#  'goal',
#  'providing',
#  'medical',
#  'service',
#  'appropriate',
#  'economically',
#  'reasonable',
#  'software',
#  'designed',
#  'infiltrate',
#  'damage',
#  'computer',
#  'system',
#  'without',
#  'computer',
#  'owner',
#  'knowledge',
#  'consent',
#  'term',
#  'shortened',
#  'combination',
#  'word',
#  'malicious',
#  'software',
#  'generic',
#  'term',
#  'used',
#  'refer',
#  'variety',
#  'form',
#  'hostile',
#  'intrusive',
#  'software',
#  'computer',
#  'virus',
#  'worm',
#  'trojan',
#  'horse',
#  'spyware',
#  'see',
#  'also',
#  'broad',
#  'risk',
#  'policy',
#  'provides',
#  'combination',
#  'commercial',
#  'property',
#  'commercial',
#  'inland',
#  'marine',
#  'coverage',
#  'manufacturer',
#  'many',
#  'business',
#  'need',
#  'mop',
#  'developed',
#  'mid-1950s',
#  'method',
#  'insuring',
#  'single',
#  'policy',
#  'stock',
#  'manufacturing',
#  'process',
#  'transit',
#  'mop',
#  'combination',
#  'commercial',
#  'property',
#  'commercial',
#  'marine',
#  'coverage',
#  'met',
#  'need',
#  'many',
#  'different',
#  'type',
#  'organization',
#  'mop',
#  'eligibility',
#  'also',
#  'expanded',
#  'time',
#  'include',
#  'many',
#  'industrial',
#  'processing',
#  'commercial',
#  'operation',
#  'recent',
#  'year',
#  'term',
#  'commercial',
#  'output',
#  'policy',
#  'cop',
#  'acronym',
#  'begun',
#  'replace',
#  'term',
#  'manufacturer',
#  'output',
#  'policy',
#  'mop',
#  'acronym',
#  'commercial',
#  'insurance',
#  'arena',
#  'since',
#  'accurately',
#  'reflect',
#  'wide',
#  'range',
#  'organization',
#  'insured',
#  'type',
#  'policy',
#  'american',
#  'association',
#  'insurance',
#  'service',
#  '(',
#  'aais',
#  ')',
#  'offer',
#  'standard',
#  'cop',
#  'form',
#  'rule',
#  'use',
#  'member',
#  'insurer',
#  'addition',
#  'many',
#  'insurer',
#  'developed',
#  'cop',
#  'form',
#  'rule',
#  'cop',
#  'premium',
#  'typically',
#  'developed',
#  'using',
#  'distinctive',
#  'rating',
#  'system',
#  '(',
#  'referred',
#  'deficiency',
#  'point',
#  'rating',
#  'system',
#  ')',
#  'allows',
#  'many',
#  'insurer',
#  'competitive',
#  'using',
#  'cop',
#  'could',
#  'using',
#  'standard',
#  'commercial',
#  'property',
#  'policy',
#  'property',
#  'insurance',
#  'endorsement',
#  'provision',
#  'establishing',
#  'market',
#  'value',
#  '(',
#  'rather',
#  'actual',
#  'cash',
#  'value',
#  '(',
#  'acv',
#  ')',
#  'replacement',
#  'cost',
#  '(',
#  'rc',
#  ')',
#  'value',
#  ')',
#  'valuation',
#  'basis',
#  'covered',
#  'property',
#  'usually',
#  'used',
#  'connection',
#  'agricultural',
#  'product',
#  'commodity',
#  'whose',
#  'value',
#  'fluctuates',
#  'accordance',
#  'commodity',
#  'exchange',
#  'also',
#  'occasionally',
#  'used',
#  'valuation',
#  'basis',
#  'building',
#  'refers',
#  'deductible',
#  'arrangement',
#  'policy',
#  'deductible',
#  'equal',
#  'policy',
#  'limit',
#  'contract',
#  'used',
#  'oil',
#  'gas',
#  'company',
#  'enter',
#  'agreement',
#  'advance',
#  'contractor',
#  'specifies',
#  'term',
#  'condition',
#  'govern',
#  'contractor',
#  'work',
#  'agreement',
#  'typically',
#  'used',
#  'on-site',
#  'service',
#  'performed',
#  'oilfield',
#  'service',
#  'contractor',
#  'repetitive',
#  'basis',
#  'equipment',
#  'maintenance',
#  'well',
#  'service',
#  'cementing',
#  'service',
#  'goal',
#  'speed',
#  'simplify',
#  'future',
#  'contract',
#  'long-term',
#  'client',
#  'vendor',
#  'relationship',
#  'property',
#  'liability',
#  'coverage',
#  'combining',
#  'several',
#  'location',
#  'operation',
#  'single',
#  'policy',
#  'insured',
#  'insured',
#  'term',
#  'may',
#  'also',
#  'used',
#  'case',
#  'construction',
#  'wrap-ups',
#  'either',
#  'case',
#  'underlying',
#  'policy',
#  'certificate',
#  'insurance',
#  'issued',
#  'insured',
#  'policy',
#  'evidence',
#  'coverage',
#  'master',
#  'policy',
#  'one',
#  'six',
#  'building',
#  'construction',
#  'category',
#  'established',
#  'insurance',
#  'service',
#  'office',
#  'inc',
#  '(',
#  'iso',
#  ')',
#  'coverage',
#  'act',
#  'error',
#  'omission',
#  'physician',
#  'surgeon',
#  'encompassing',
#  'physician',
#  'professional',
#  'liability',
#  'insurance',
#  'hospital',
#  'professional',
#  'liability',
#  '(',
#  'hpl',
#  ')',
#  'insurance',
#  'allied',
#  'healthcare',
#  '(',
#  'e',
#  'g',
#  'nurse',
#  ')',
#  'professional',
#  'liability',
#  'insurance',
#  'although',
#  'majority',
#  'policy',
#  'written',
#  'claims-made',
#  'coverage',
#  'trigger',
#  'coverage',
#  'sometimes',
#  'available',
#  'occurrence',
#  'basis',
#  'typical',
#  'exclusion',
#  'intentional',
#  ...]

# %%
print(len(vocab))

vocab = set(vocab)
print(len(vocab))
# Out:
# 107304
# 8067

# %% [markdown]
# There are 8067 unique words in document.

# %% [markdown]
# Wrap above into function

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

def get_vocabulary(docs):
    tokenized = [word_tokenize(text.lower()) for text in docs]
    stop = set(stopwords.words('english'))
    docs = [[word for word in words if word not in stop] for words in tokenized]
    vocab = [word for words in docs for word in words]

    wordnet = WordNetLemmatizer()
    vocab = [wordnet.lemmatize(word) for word in vocab]
    vocab = set(vocab)
    return vocab

# %%
terms = []
texts = []

for index, row in df_insurance_terms_2.iterrows():
#     print(index, row[0], row[1])
    terms.append(row[0])
    texts.append(row[1])
    
vocab_terms = get_vocabulary(terms)
vocab_texts = get_vocabulary(texts)

# %%
print(len(vocab_terms), len(vocab_texts))
# Out:
# 2873 8067

# %% [markdown]
# So there are 2873 unique words in terms and 8067 unique words in texts.
# Let me set vocabulary for terms and texts to be (1/3)*size in the analysis.

# %%
max_size_terms = 2873//3
max_size_texts = 8067//3
print(max_size_terms, max_size_texts)
# Out:
# 957 2689

# %%
X = documents.values
y = labels.values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# %%
y_train
# Out:
# array(['property damage (PD)', 'impaired risk', 'common carrier',
#        'employees as insureds endorsement', 'graduated drivers licenses',
#        'rectification coverage', 'risk sharing', 'maturity date',
#        'delayed completion coverage',
#        'fire department service charge coverage',
#        'series business unit (SBU)',
#        'alternative dispute resolution (ADR)', 'expiration',
#        'increased limits table', 'contingent commission',
#        'additional medical', 'zone rating', 'index-based contracts',
#        'Pension Protection Act of 2006', 'setoff',
#        'best demonstrated available technology (BDAT)', 'actuary',
#        'risk concentration', 'net loss reserves',
#        'continuation of coverage in bankruptcy provision',
#        'legal action against insurer', 'tortfeasor', 'damages',
#        'homeowners modified form 8 (HO 8)',
#        'Quality Indicator Profile (QIP)', 'betterment clause',
#        'contribution by equal shares', 'water quality-based limitations',
#        'cash surrender value', 'examination under oath (EUO)',
#        'personal lines',
#        'Associate in Insurance Accounting and Finance (AIAF)',
#        'earned surplus', 'criteria pollutant', 'defense within limits',
#        'known loss rule', 'National Safety Council',
#        'contingent beneficiary', 'commutation', 'factory firms',
#        'white hat hackers', 'full preliminary term reserve valuation',
#        'joint underwriting association (JUA)', 'cumulative injury',
#        'mortgage impairment insurance', 'cooperation clause',
#        'noon clause', 'running down clause',
#        'Write-Your-Own (WYO) Program',
#        'Employee Retirement Income Security Act liability',
#        'related product liability exclusion', 'trend factor',
#        'negligent referral', 'waiting period deductible',
#        'Interjurisdictional Agreement on Workers Compensation (IJA)',
#        'proof of loss', 'negative basis', 'loan-backs', 'beauty contest',
#        'group annuity', 'public policy exception', 'policy conditions',
#        'electrical damage or injury exclusion',
#        'hydraulic fracturing (fracking)', 'profit commission',
#        'Department of Transportation (DOT)', 'motor home policy',
#        'hybrid captive', 'mediation incentive deductible',
#        'noninsurance risk transfer', 'products guarantee legal liability',
#        'litigation hold', 'controlled unrelated business',
#        'testing coverage', 'Insurance Information Institute (III)',
#        'third country national (TCN)', 'designated insured endorsement',
#        'margin clause',
#        'Uniformed Services Employment and Reemployment Rights Act (USERRA) of 1994',
#        'sales', 'swap', 'Terrorism Risk Insurance Act (TRIA) of 2002',
#        'deductible', 'summary judgment', 'animal mortality insurance',
#        'cat bond lite', 'green upgrades coverage',
#        'employers liability coverage', 'employee hired autos endorsement',
#        'loss reduction', 'wrongful termination',
#        'Information Practices Act (SB 1386) of 1977', 'Cumis counsel',
#        'attachment point', 'act-as-one provision', 'liquidity risk',
#        'tolling a statute of limitations',
#        'professional services exclusion', 'probability of ruin',
#        'residual market load (RML)', 'general average losses',
#        'joint defense', 'low speed vehicle (LSV)', 'publishers liability',
#        'facultative obligatory treaty',
#        'insurance agents errors and omissions', 'third-party risk',
#        'catastrophic loss', 'risk volatility', 'system safety approach',
#        'basis risk', 'due diligence', 'elimination period', 'rebate',
#        'action levels', 'storekeepers broad form',
#        'blanket medical expense', 'nonledger assets', 'boatowners policy',
#        'collateralization of cash flow programs', 'override',
#        'estimated premium', 'new for old', 'affiliated companies',
#        'construction management (CM)', 'bad faith',
#        'master service agreement (MSA)', 'motion', 'pollutant',
#        'nontransferability provisions', 'multiple protection insurance',
#        'frequency', 'continuous contract', 'return-to-work program',
#        'limitation of liability clause', 'Spearin Doctrine',
#        'loss rating', 'dealers driveaway collision', 'direct procurement',
#        'insured', 'premium notice', 'mix of services', 'cutoff',
#        'air toxins', 'brother-sister relationship', 'assume',
#        'automatic insureds', 'outplacement', 'strategic risk',
#        'assumed premiums', 'independent adjuster', 'law of large numbers',
#        'floating excess policy', 'ceded premiums',
#        'unnamed pilot exclusion',
#        'comprehensive boiler and machinery coverage',
#        'assumption of risk', 'employees as additional insureds',
#        'return of remuneration exclusion', 'monetary threshold',
#        'informed consent', 'supplementary payments',
#        'extracontractual obligations (ECO)', 'Side C coverage',
#        'loss of consortium suits', 'putting in expenses',
#        'intrafamily immunity', 'certified act of terrorism',
#        'contract certainty', 'manual premium', 'prejudgment interest',
#        'personal property', 'bifurcation', 'declarations',
#        'with average 3 percent (WA 3 )', 'intermediary', 'capital sum',
#        'work hardening', 'model', 'cancel and rewrite',
#        'prohibited transaction exemption (PTE)',
#        'Class Action Fairness Act of 2005', 'family exclusion',
#        'privileged communication',
#        'Federal Savings and Loan Insurance Corporation (FSLIC)',
#        'subbroker', 'hedging transaction', 'public easement',
#        'buyers  market', 'Jumpstart Our Business Startups (JOBS) Act',
#        'back-to-back deductible', 'intermodal', 'drop down provision',
#        'overtime surcharge', 'specific rating', 'court reporter',
#        'product', 'passive loss',
#        'earth movement or earthquake exclusion',
#        'motor vehicle registration law', 'accident year experience',
#        'optimum level of risk retention',
#        'care  custody  or control (CCC)',
#        'New Source Performance Standards (NSPS)', 'unbundling',
#        'garagekeepers coverage garagekeepers legal liability',
#        'conditional binding receipt', 'bank', 'policy expense allowance',
#        'trip permit', 'reputational risk', ' add-on  no-fault laws',
#        'laptop exclusion', 'loss development', 'consequential damages',
#        'product liability exclusion', 'reversionary',
#        'in camera proceedings', 'contractor s limitation endorsement',
#        'dominant cause', 'capital adequacy', 'concealment',
#        'loss of income coverage', 'procuring cause',
#        'Humana v  Commissioner', 'National Response Center',
#        'Carmack Amendment', 'basic extended reporting period (BERP)',
#        'vicarious liability', 'wrongful discipline', 'rescission',
#        'dynamic risk', 'operational risk', 'normal loss',
#        'underwriting cash flow', 'retrospective aggregates',
#        'identity theft coverage', 'indemnification', 'risk pool',
#        'liquidated damages', 'proration', 'trailer interchange insurance',
#        'negligent evaluation', 'central tendency', 'quid pro quo',
#        'general supervision',
#        'compulsory insurance requirements (international insurance)',
#        'pollution exclusion', 'experience', 'predecessor firm coverage',
#        'statutory coverages',
#        'Captive Insurance Companies Association (CICA)', 'gross weight',
#        'remedial action (RA)', 'excess', 'other insurance clause',
#        'extremely hazardous substances',
#        'intellectual property defense cost reimbursement insurance',
#        'Side B coverage', 'verbal threshold', 'inspection fees',
#        'professional reinsurer',
#        'Joint Commission on Accreditation of Healthcare Organizations (JCAHO)',
#        'expiration notice', 'indemnity payments',
#        'specified causes of loss coverage', 'venue',
#        'special mobile equipment', 'slabbed',
#        'improvements and betterments', ' say-on-pay  provision',
#        'Best s Capital Adequacy Ratio (BCAR)', 'large deductible plan',
#        'platooning', 'product liability', 'depreciation',
#        'consequential bodily injury suits',
#        'National Independent Statistical Service (NISS)',
#        'commercial auto insurance coverage forms',
#        'waiver of subrogation', 'casualty insurance', 'storm surge',
#        'payment account', 'surplus line', 'effective date',
#        'ministerial exception', 'insurance policy',
#        'docket control system', 'loss trending', 'third party',
#        'mature claims-made', 'collar', 'collateral source rule',
#        'expiration file', 'intrapolicy stacking',
#        'premises burglary coverage', 'builders risk policy',
#        'ordinance or law coverage', 'membership accounting',
#        'motion practice', 'license',
#        'Workers  Compensation Claim Law Associate (WCLA)',
#        'emergency medical technician (EMT) and paramedics professional liability',
#        'MCS-90 endorsement', 'false arrest', 'financial consolidation',
#        'special litigation committee (SLC)', 'client company',
#        'offset (setoff)',
#        'mean variance covariance (MVC) risk modeling method',
#        'Uniform Task Based Management System (UTBMS)', 'pro rata',
#        'line sheet', 'physical-mental injuries', 'graded commission',
#        'home office', 'special employer', 'case management',
#        'Public Law 15 (McCarran Act)', 'nonassignable',
#        'mercantile robbery', 'merger and acquisition litigation',
#        'nonsubscription', 'group property and liability insurance',
#        'payout profile', 'funded covers', 'recurring clause',
#        'agreed value coverage option or provision', 'debit system',
#        'admitted company', 'ecological risk assessment',
#        'innkeepers legal liability', 'formularies', 'nonprofit insurers',
#        'rating methodology', 'syndicate',
#        'paid loss retrospective rating plan', 'write',
#        'rip and tear coverage', 'risk manager', 'commutation clause',
#        'course of employment', 'insurance requirements', 'segregation',
#        'notice of circumstances during extended reporting period provision',
#        'punitive damages', 'vacancy permit endorsement',
#        'fixed-cost insurance', 'time series analysis',
#        'unrelated business income tax (UBIT)', 'Kotecki waiver',
#        'insurance-linked securities (ILS)',
#        'fire legal liability coverage', 'COPE',
#        'functional capacity evaluation (FCE)', 'pain and suffering',
#        'exculpatory clause', 'underwriting guidelines',
#        'good student discount', 'initial public offering (IPO)',
#        'design-build professional liability insurance',
#        'alienated premises', 'weapon of mass destruction (WMD)',
#        'basket aggregate', 'employee benefit programs',
#        'first dollar defense coverage', 'guaranteed replacement cost',
#        'homeowners policy comprehensive form 5 (HO 5)', 'response action',
#        'qualified plan', 'enforceable requirements',
#        'employee dishonesty coverage', 'swaption', 'dismemberment',
#        'trade disruption insurance', 'Million Dollar Round Table (MDRT)',
#        'product liability insurance', 'commission', 'rate', 'coinsurer',
#        'writ', 'adhesion contract', 'first named insured',
#        'litigation management', 'capitated fee',
#        'livestock coverage form', 'stock captive',
#        'liquor law liability (dramshop)', 'inflation guard provision',
#        'timing risk', 'essential functions', 'credit wrap',
#        'Regulation 114 Trust', 'interest rate risk',
#        'North American Industry Classification System (NAICS)',
#        'underwriting', 'zone system', 'contributing excess',
#        'property transfer liability insurance', 'safe burglary insurance',
#        'consent to settlement clause', 'terrorism', 'historical cost',
#        'underwriting period', 'experience refund', 'class rating',
#        'stacking', 'incurred loss ratio', 'Montrose doctrine',
#        'general aggregate limit', 'endangerment assessment',
#        'maintenance wrap-up', 'dividend addition',
#        'reinstatement premium', 'appraisers errors and omissions',
#        'Financial Institutions Reform  Recovery  and Enforcement Act (FIRREA)',
#        'medical fee schedule', 'risk index', 'facultative automatic',
#        'risk-adjusted return on risk-adjusted capital (RARORAC)',
#        'buffer layer', 'National Response Team (NRT)', 'penal sum',
#        'hazardous ranking system (HRS)', 'Z-list',
#        'certificate of compliance', 'common law',
#        'Committee of Sponsoring Organizations (COSO)',
#        'preauthorized check plan', 'designated contractor', 'blue plan',
#        'nonsubject premium', 'intrastate experience rating',
#        'pure loss cost', 'condominium association coverage form (ISO)',
#        'group contract', 'total pollution exclusion',
#        'Securities Act of 1933', 'purchasing group',
#        'Basel Committee on Banking Supervision',
#        'international reverse business', 'supervision coverage',
#        'ground up loss', 'implied authority', 'adjusted earnings',
#        'contract attorney', 'litigation', 'direct writer',
#        'financial risk management', 'remedial response',
#        'remediation cost cap policy', 'risk control',
#        'single premium insurance', 'parallel proceedings',
#        'adverse selection', 'risk management process',
#        'wrap-up exclusion endorsement',
#        'National Highway Traffic Safety Administration (NHTSA)',
#        'intellectual property infringement abatement insurance',
#        'hospital professional liability (HPL) insurance',
#        'foreign title equivalent coverage provision', 'exclusive remedy',
#        'Associate in Information Technology (AIT)',
#        'fellow employee exclusion', 'extended coverage (EC) endorsement',
#        'Ponzi scheme', 'passive retention', 'owner-operator',
#        'voyage clause', 'York Antwerp Rules',
#        'fellow employee suits coverage', 'subjective symptoms', 'fees',
#        'general duty clause', 'premises-operations',
#        'related party insurance income (RPII)', 'first dollar coverage',
#        'dependent properties time element coverage', 'loss triangle',
#        'alien insurer', 'accident', 'weighted average loss forecasting',
#        'auto coverage symbols', 'no further remedial action planned',
#        'sliding scale commission', 'disintermediation risk',
#        'electronic data liability', 'carrier', 'noneconomic damages',
#        'brownfield', 'wharfinger legal liability coverage',
#        'spousal coverage extension', 'per occurrence limit',
#        'pair or set clause', 'psychological rehabilitation',
#        'Unified Carrier Registration Agreement (UCRA)',
#        'composite rating', 'classification limitation',
#        'police professional liability insurance',
#        'first dollar defense  umbrella', 'foreign insurer',
#        'ex parte hearings', 'full-timers coverage',
#        'nonadmitted reinsurance',
#        'Pension Benefit Guaranty Corporation (PBGC)', 'portfolio',
#        'excess interest', 'specifications', 'fiduciary liability',
#        'owners protective errors and omissions insurance coverage',
#        'glass insurance', 'coemployment', 'Yellow Book',
#        'pure claims-made policy', 'minimum premium', 'reporting policy',
#        'causes of loss forms (ISO)', 'Brownian motion',
#        'Chartered Property Casualty Underwriter (CPCU)',
#        'nonrescission provision', 'cross-liability endorsement',
#        'community rating', 'residence employee  homeowners policy',
#        'tail value at risk (Tail VaR) or tail conditional expectation (TCE)',
#        'ultimate loss', 'excess insurance',
#        'export and or import embargo indemnity',
#        'contractors professional liability insurance',
#        'Risk Retention Act (RRA) of 1986', 'mobile equipment',
#        'flood insurance rate map (FIRM)', 'business income worksheet',
#        'loss costs',
#        'payment card industry fines and assessments insuring agreement',
#        'noncontributory insurance', 'hybrid plans',
#        'marina operators legal liability coverage', 'associate',
#        'vendors endorsement',
#        'Racketeer Influenced and Corrupt Organizations (RICO) Act of 1970',
#        'discontinuance', 'commercial insurer or reinsurer',
#        'downsizing exclusion',
#        'Children s Online Privacy Protection Act (COPPA) of 1998',
#        'analytic risk modeling method', 'stochastic dominance',
#        'A M  Best rating', 'jewelers block insurance',
#        'collapse additional coverage', 'policyholder',
#        'mutual additional insured status', 'intellectual property',
#        'ceding company', 'risk-adjustment investment (capital)',
#        'independent agency system',
#        'commercial property conditions form (ISO)', 'perfect hedge',
#        'liquidity ratio', 'stand-alone excess policy',
#        'incurred but not reported (IBNR) losses', 'equity stripping',
#        'risk retention group (RRG)', 'experience modifier', 'subsidence',
#        'alternative risk financing mechanism',
#        'manufacturers penalty insurance', 'double excess coverage',
#        'Medical Injury Compensation Reform Act (MICRA) of 1975',
#        'severance pay exception wording',
#        'Comprehensive Environmental Response  Compensation  and Liability Act (CERCLA) of 1980',
#        'acute exposure', 'noninsurance', 'demand surge', 'obligor',
#        'morale hazard', 'specialty risks', 'claims administrator',
#        'ultimate net loss', 'production contracts',
#        'businessowners policy (BOP)', 'guardian ad litem',
#        'surplus reinsurance', 'cradle-to-grave or manifest system',
#        'National Flood Insurance Program (NFIP)',
#        'loss portfolio transfer (LPT)', 'risk gap', 'self rating',
#        'ordinary payroll limitation or exclusion endorsement',
#        'policy owner', 'uberrimae fidei', 'gross earnings coverage',
#        'malpractice insurance', 'death benefit',
#        'public or livery conveyance use', 'salesmen s samples coverage',
#        'bench trial', 'Foreign Account Tax Compliance Act (FATCA)',
#        'salvage', 'cost and freight (C and F)', 'nonassessable',
#        'follow form',
#        'free of particular average (American conditions) (FPAAC)',
#        'irrevocable beneficiary', 'counterparty', 'principal',
#        'supplementary employee retirement plan (SERP)', 'shortfall risk',
#        'Lloyd s broker', 'voluntary compensation endorsement',
#        'self-insurer s bond', 'submission', 'discovery rule',
#        'systems performance insurance', 'hostile fire',
#        'clinical patterns', 'incident reporting provision',
#        'Saffir-Simpson scale', 'excess point', 'communicable disease',
#        'restoration of limits provision', 'residential wrap-up',
#        'letter of credit (LOC)', 'locality standard', 'appeal', 'event',
#        'Cooke ratio', 'general counsel', 'occurrence basis',
#        'abandonment', 'scheduled limits', 'assurance',
#        'bare walls coverage', 'named nonowner policy or endorsement',
#        'wrap-around risk financing program',
#        'medical payments  general liability',
#        'Motor Carrier Act (MCA) of 1980', 'burden of proof',
#        'saline substances contamination endorsement',
#        'risk identification', 'friable asbestos',
#        'sexual abuse exclusion', 'payor benefit',
#        'coincidental excess coverage',
#        'difference-in-limits (DIL) policy', 'refund annuity',
#        'designated employees', 'security holder exclusion',
#        'employment practices liability insurance (EPLI)',
#        'vessel in navigation',
#        'workers compensation and employers liability policy',
#        'index bureau', 'cover note', 'claims cooperation clause',
#        'disparagement of goods', 'Tax Reform Act (TRA) of 1984',
#        'valued coverage', 'business income coverage', 'defense clause',
#        'cession', 'hull coverage', 'putative class action',
#        'settlement lag', 'substitute physician coverage endorsement',
#        'probationary period', 'custom bond',
#        'party-in-interest transactions', 'financial responsibility',
#        'board committees', 'competitive bidding', 'drilling fluid',
#        'on-demand bonds  bank guarantees', 'base premium',
#        'hull (physical damage) coverages  aircraft', 'experience account',
#        'coded excess', 'average basis', 'spamming', 'paid up',
#        'data processing coverage', 'underlying interest', 'motor vehicle',
#        'Associate in Management (AIM)', 'patient compensation funds',
#        'single interest insurance', 'debit agent',
#        'business auto policy (BAP)', 'valuation date',
#        'loss ratio coverage', 'airport premises liability  aircraft',
#        'waiver of premium', 'fee disputes exclusion',
#        'contra proferentem rule', 'gross vehicle weight (GVW)',
#        'borderline risk', 'jettison', 'ceding commission',
#        'stand-alone terrorism coverage', 'occupational disease',
#        'freight forwarder', 'rating organization', 'aleatory contract',
#        'trip transit insurance', 'severance pay',
#        'Federal Motor Carrier Safety Administration (FMCSA)',
#        'Warsaw Convention', 'ex-medical coverage', 'lapse',
#        'lead umbrella', 'slander', 'credit report',
#        'group credit insurance', 'deemer period', 'maturity',
#        'admiralty law', 'regulatory agency exclusion', 'reporting lag',
#        'special perils', 'common policy conditions', 'off-duty coverage',
#        'welfare and pension plan bond coverage',
#        'cost  insurance  and freight (CIF)', 'overlapping insurance',
#        'investment risk',
#        'Cable Communications Policy Act (CPPA) of 1984',
#        'specific loss limit', 'glovebag', 'promisor', 'tacit renewal',
#        'apportionment', 'private carrier', 'loss conversion factor (LCF)',
#        'connected vehicle', 'cross-indemnity agreement',
#        'prohibition of voluntary payments provision',
#        'commercial output policy (COP)',
#        'Associate in Risk Management (ARM)',
#        'Financial Stability Board (FSB)', 'lean construction',
#        'named insured',
#        'Section 501(c) of the U S  Internal Revenue Code',
#        'claims leakage (CL)', 'value-added services', 'codefendant',
#        'filed forms', 'admitted insurer',
#        'gross combination weight (GCW)', 'integrated risk',
#        'claims-made coverage trigger', 'auto', 'freight broker',
#        'Household Goods Transportation Act of 1980', 'gap financing',
#        'franchise insurance', 'representations and warranties insurance',
#        'gross receipts or mileage  auto', 'break point',
#        'reinsurance facility', 'abatement', 'derivative contract',
#        'governing classification', 'outstanding loss reserves (OSLR)',
#        'reinsurance premium', 'ground coverage',
#        'geographical (coverage territory) limitations',
#        'common law defenses', 'double indemnity', 'insurable interest',
#        'contingent liability',
#        'nuclear  biological  chemical (NBC) weapons',
#        'employee pension benefit plans', 'claims reserve',
#        'free of capture and seizure (FC S) warranty', 'direct premiums',
#        'blanket group boiler and machinery coverage',
#        'building ordinance coverage', 'risk tolerance',
#        'State Emergency Response Commission (SERC)',
#        'employee welfare benefit plans', 'libel', 'guest statutes  auto',
#        'hazardous waste', 'Liability Risk Retention Act of 1996',
#        'Casualty Claim Law Associate (CCLA)', 'group self-insurance',
#        'fiduciary liability  follow-on  claims', 'option backdating',
#        'security requirements', 'regression analysis',
#        'bodily injury by disease  each employee (workers compensation)',
#        'insurance risk scoring', 'event risk',
#        'threshold limit value (TLV)', 'year 2000 (Y2K) exclusion',
#        'manuscript form or policy', 'trend analysis', 'thermal pollution',
#        'transit coverage', 'malicious code',
#        'managing general underwriter (MGU)', 'direct writing carrier',
#        'subcontractor exception', 'Lloyd s managing agent',
#        'Driver s Privacy Protection Act (DPPA) of 1994', 'panel counsel',
#        'ride sharing', 'unauthorized insurer', 'survival action',
#        'gross domestic product (GDP)', 'defendant', 'pure captive',
#        'overriding commission', 'full prior acts coverage',
#        'written premium',
#        'Longshore and Harbor Workers  Compensation Act (LHWCA) of 1927',
#        'market risk', 'water quality standards', 'object', 'med-mal',
#        'progressive injury or damage', 'mutual fund',
#        'return on risk-adjusted capital (RORAC)', 'dividend options',
#        'consent judgment', 'terminal coverage', 'self-insurance',
#        'collateral documents', 'time element loss', 'market cycles',
#        'root cause analysis (RCA)', 'building rate', 'paralegal',
#        'risk appetite', 'indemnity',
#        'risk management information system (RMIS)',
#        'captive value added (CVA)', 'forward', 'demand trigger coverage',
#        'additional insured', 'funded retention', 'separate account',
#        'viatical settlement', 'war risk insurance', 'buyback deductible',
#        'Black Lung Benefits Act of 1973', 'pro hoc vice',
#        'judgment rates', 'reinsurance treaty', 'FAS 5',
#        'severability of exclusions',
#        'as their interests may appear (ATIMA)', 'ocean marine coverage',
#        'preexisting condition',
#        'architects and engineers (A E) liability coverage',
#        'conditionally renewable', 'offshore captive',
#        'mutual law enforcement agreements', 'statutory insurance',
#        'guaranteed insurability',
#        'Insurance Institute for Highway Safety (IIHS)', 'underinsurance',
#        'industrial insured captive insurance company',
#        'third-party-over action', 'federal crop insurance', 'coemployer',
#        'option instruments', 'subject business', ' extrinsic facts  test',
#        'general liability insurance', 'dirty bomb',
#        'vertical exhaustion rule', 'executor', 'consolidation',
#        'healthcare reimbursement plan', 'loss damage waiver (LDW)',
#        'automatic additional insured endorsement', 'evidence',
#        'disclosure dollar loss (DDL)', 'business continuity plan (BCP)',
#        'premium discount', 'terminal operator', 'annuity due',
#        'owners and contractors protective (OCP) liability coverage',
#        'insurability', 'motor vehicle insurance law',
#        'physical impairment', 'asset share value',
#        'per occurrence limitation of liability provision',
#        'catastrophe reinsurance',
#        'project management protective liability (PMPL) insurance',
#        'credibility', 'operational capital',
#        'Risk and Insurance Management Society  Inc  (RIMS)',
#        'add-on control device', 'frame construction (ISO)',
#        'liability for guests  property  premises coverage form L',
#        'nonconcurrency of coverage triggers', 'triple excess coverage',
#        'collision insurance', 'servicing carrier', 'open perils',
#        'economic capital', 'reinsurance assumed', 'average severity',
#        'Migrant and Seasonal Agricultural Worker Protection Act (MSAWPA) of 1983',
#        'domestic insurer', ' sudden and accidental ',
#        'operational risk management (ORM)', 'reproduction cost',
#        'inherent defects insurance (IDI)',
#        'Carriage of Goods by Sea Act (COGSA) of 1936',
#        'Clean Air Act (CAA) of 1970',
#        'single-entry multiple company interface (SEMCI)',
#        'triple trigger theory', 'rider', 'impaired property',
#        'controlling', ' damages reduction  provision',
#        'amendment of  insured contract  definition endorsement',
#        'money and securities broad form policy',
#        'admitted authorized reinsurance', 'employment risk',
#        'homeowners policy contents broad form 4 (HO 4)',
#        'retired directors liability policies', 'general exclusions',
#        'policy', 'valuable papers and records coverage',
#        'guaranteed cost', 'retroactive insurance',
#        'installment settlement', 'indemnitee', 'excess liability policy',
#        'redomiciling', 'risk distribution', 'reportable quantity (RQ)',
#        'Property Claim Law Associate (PCLA)', 'offer',
#        'Environmental Monitoring and Assessment Program (EMAP) data',
#        'sponsored captive', 'immediate annuity', 'substandard',
#        'brokerage market', 'motorcycle insurance', 'window plan',
#        'interrogatory', 'Associate in Personal Insurance (API)',
#        'managed care coverage endorsement', 'futures contract',
#        'direct threat', 'approval', 'bumbershoot', 'payroll audit',
#        'admitted insurance', 'without prejudice',
#        'designated construction project general aggregate limit endorsement',
#        'aircraft insurance policies', 'interrelated claims provisions',
#        'paid losses', 'cross-complainant', 'tail',
#        'securities deposited with others coverage form J',
#        'failure to insure exclusion', 'clash cover',
#        'extended discovery provision', 'ostensible agency liability',
#        'computer software design errors and omissions', 'capacity',
#        'gross profits insurance', 'release', 'entire contract clause',
#        'noncombustible construction (ISO)', 'breach of contract', 'loss',
#        'securities class action claims'], dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer_X = TfidfVectorizer(stop_words='english', max_features=max_size_texts)
vec_X_trained = vectorizer_X.fit_transform(X_train)

vectorizer_y = TfidfVectorizer(stop_words='english', max_features=max_size_terms)
vec_y_trained = vectorizer_y.fit_transform(y_train)

# %%
vocab_X = vectorizer_X.get_feature_names()
vocab_X
# Out:
# ['00',
#  '000',
#  '05',
#  '10',
#  '100',
#  '110',
#  '12',
#  '125',
#  '15',
#  '17',
#  '18',
#  '1980s',
#  '1986',
#  '1989',
#  '1990',
#  '1998',
#  '20',
#  '2000',
#  '2008',
#  '2012',
#  '2014',
#  '21',
#  '24',
#  '25',
#  '250',
#  '30',
#  '32',
#  '401',
#  '41',
#  '50',
#  '500',
#  '501',
#  '54',
#  '55',
#  '60',
#  '65',
#  '72',
#  '90',
#  '99',
#  'a201',
#  'aais',
#  'abandoned',
#  'abc',
#  'ability',
#  'able',
#  'absence',
#  'absolute',
#  'abuse',
#  'abuses',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'accepts',
#  'access',
#  'accessible',
#  'accessing',
#  'accident',
#  'accidental',
#  'accordance',
#  'according',
#  'accordingly',
#  'account',
#  'accountants',
#  'accounting',
#  'accounts',
#  'accrued',
#  'accurate',
#  'acquired',
#  'acquiring',
#  'acquisition',
#  'act',
#  'action',
#  'actions',
#  'active',
#  'activities',
#  'activity',
#  'acts',
#  'actual',
#  'actually',
#  'actuarial',
#  'acute',
#  'acv',
#  'ada',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'adequate',
#  'adjust',
#  'adjusted',
#  'adjustment',
#  'administered',
#  'administration',
#  'administrative',
#  'administrator',
#  'admitted',
#  'adopted',
#  'advance',
#  'advanced',
#  'advantage',
#  'advantages',
#  'adverse',
#  'advice',
#  'advisory',
#  'aei',
#  'affect',
#  'affected',
#  'affecting',
#  'affiliated',
#  'afforded',
#  'affords',
#  'age',
#  'agencies',
#  'agency',
#  'agent',
#  'agents',
#  'aggregate',
#  'agree',
#  'agreed',
#  'agreement',
#  'agreements',
#  'agrees',
#  'air',
#  'aircraft',
#  'airlines',
#  'airplane',
#  'airport',
#  'alaes',
#  'alkalis',
#  'allegations',
#  'allege',
#  'alleged',
#  'allegedly',
#  'alleging',
#  'allocated',
#  'allow',
#  'allowable',
#  'allowance',
#  'allowed',
#  'allowing',
#  'allows',
#  'alternative',
#  'alters',
#  'ambient',
#  'ambiguities',
#  'ambiguity',
#  'amend',
#  'amendment',
#  'amendments',
#  'america',
#  'american',
#  'americans',
#  'amounting',
#  'amounts',
#  'analysis',
#  'annual',
#  'annuitant',
#  'annuity',
#  'answers',
#  'anticipated',
#  'anticipates',
#  'appeal',
#  'appliances',
#  'applicability',
#  'applicable',
#  'applicant',
#  'application',
#  'applications',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appoint',
#  'appointed',
#  'apportioned',
#  'appraisal',
#  'appraiser',
#  'approach',
#  'approaches',
#  'appropriate',
#  'appropriately',
#  'approval',
#  'approve',
#  'approved',
#  'arbitration',
#  'arbitrator',
#  'arbitrators',
#  'architects',
#  'area',
#  'areas',
#  'arise',
#  'arisen',
#  'arises',
#  'arising',
#  'arranged',
#  'arrangement',
#  'arrangements',
#  'arrest',
#  'asbestos',
#  'ascertain',
#  'aside',
#  'aspect',
#  'aspects',
#  'assert',
#  'asserted',
#  'assess',
#  'assessed',
#  'assessment',
#  'asset',
#  'assets',
#  'assigned',
#  'assignment',
#  'assist',
#  'assistance',
#  'associated',
#  'association',
#  'associations',
#  'assume',
#  'assumed',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'atima',
#  'attached',
#  'attachment',
#  'attack',
#  'attempt',
#  'attempts',
#  'attention',
#  'attorney',
#  'attorneys',
#  'audit',
#  'audits',
#  'authorities',
#  'authority',
#  'authorized',
#  'authorizes',
#  'auto',
#  'automatic',
#  'automatically',
#  'automobile',
#  'automobiles',
#  'autos',
#  'availability',
#  'available',
#  'average',
#  'aviation',
#  'avoid',
#  'avoiding',
#  'award',
#  'awarded',
#  'awards',
#  'awareness',
#  'away',
#  'backdating',
#  'bad',
#  'balance',
#  'balances',
#  'bank',
#  'banking',
#  'bankruptcy',
#  'banks',
#  'bap',
#  'bar',
#  'bare',
#  'bargaining',
#  'barring',
#  'base',
#  'based',
#  'basel',
#  'basic',
#  'basis',
#  'bearing',
#  'begin',
#  'beginning',
#  'begins',
#  'begun',
#  'behalf',
#  'believe',
#  'belonging',
#  'beneficiary',
#  'benefit',
#  'benefits',
#  'bermuda',
#  'berps',
#  'berth',
#  'best',
#  'better',
#  'betterments',
#  'bi',
#  'bicycles',
#  'billing',
#  'bills',
#  'binder',
#  'biological',
#  'blanket',
#  'blue',
#  'bm',
#  'board',
#  'bodies',
#  'bodily',
#  'body',
#  'boiler',
#  'bomb',
#  'bond',
#  'bonding',
#  'bonds',
#  'book',
#  'books',
#  'bop',
#  'borne',
#  'borrowed',
#  'borrower',
#  'borrowers',
#  'bound',
#  'breach',
#  'breached',
#  'breaches',
#  'break',
#  'breakage',
#  'breakdown',
#  'brief',
#  'bring',
#  'bringing',
#  'brings',
#  'broad',
#  'broaden',
#  'broadened',
#  'broadens',
#  'broader',
#  'broker',
#  'brokers',
#  'brought',
#  'buffer',
#  'build',
#  'builders',
#  'building',
#  'buildings',
#  'built',
#  'burglary',
#  'burning',
#  'business',
#  'businesses',
#  'buy',
#  'buyer',
#  'buyers',
#  'buying',
#  'buyout',
#  'bylaws',
#  'ca',
#  'cable',
#  'calculated',
#  'calculating',
#  'calculation',
#  'calendar',
#  'california',
#  'called',
#  'canada',
#  'cancel',
#  'cancellation',
#  'cancels',
#  'cap',
#  'capacity',
#  'capital',
#  'capped',
#  'captive',
#  'captives',
#  'carbon',
#  'card',
#  'care',
#  'cargo',
#  'carrier',
#  'carriers',
#  'carries',
#  'carry',
#  'case',
#  'cases',
#  'cash',
#  'casualty',
#  'catastrophe',
#  'catastrophic',
#  'categories',
#  'category',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'caveat',
#  'ccc',
#  'cede',
#  'ceded',
#  'cedent',
#  'ceding',
#  'center',
#  'central',
#  'cercla',
#  'certain',
#  'certainty',
#  'certified',
#  'cg',
#  'cgl',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'characteristics',
#  'charge',
#  'charged',
#  'charges',
#  'chartered',
#  'chemical',
#  'chemicals',
#  'child',
#  'children',
#  'choose',
#  'chosen',
#  'chronic',
#  'church',
#  'cica',
#  'circumstances',
#  'civil',
#  'civilian',
#  'claim',
#  'claimant',
#  'claimants',
#  'claims',
#  'clarify',
#  'class',
#  'classes',
#  'classification',
#  'classified',
#  'clause',
#  'clauses',
#  'clean',
#  'cleanup',
#  'clearly',
#  'client',
#  'clients',
#  'clinical',
#  'closed',
#  'closely',
#  'cm',
#  'coast',
#  'code',
#  'codes',
#  'coemployers',
#  'coincidental',
#  'coinsurance',
#  'collapse',
#  'collateral',
#  'collateralize',
#  'collateralized',
#  'collect',
#  'collected',
#  'collecting',
#  'collection',
#  'collectively',
#  'collision',
#  'combination',
#  'combined',
#  'combines',
#  'commerce',
#  'commercial',
#  'commission',
#  'commissions',
#  'committed',
#  'committee',
#  'committees',
#  'commodities',
#  'commodity',
#  'common',
#  'commonly',
#  'communication',
#  'communications',
#  'communities',
#  'community',
#  'companies',
#  'company',
#  'comparable',
#  'compared',
#  'compensation',
#  'complete',
#  'completed',
#  'completion',
#  'complex',
#  'compliance',
#  'complicated',
#  'complied',
#  'comply',
#  'component',
#  'components',
#  'composed',
#  'comprehensive',
#  'comprise',
#  'compulsory',
#  'computer',
#  'computerized',
#  'computers',
#  'concealment',
#  'concentration',
#  'concept',
#  'concern',
#  'concerned',
#  'concrete',
#  'condition',
#  'conditioning',
#  'conditions',
#  'condominium',
#  'conduct',
#  'conducts',
#  'confers',
#  'conflict',
#  'confronted',
#  'conjunction',
#  'connection',
#  'consecutive',
#  'consent',
#  'consequences',
#  'consequential',
#  'consider',
#  'considerable',
#  'consideration',
#  'considered',
#  'consist',
#  'consistent',
#  'constitute',
#  'constraint',
#  'construction',
#  'consumer',
#  'consumers',
#  'consuming',
#  'contact',
#  'contain',
#  'contained',
#  'containing',
#  'contains',
#  'contaminant',
#  'contaminants',
#  'contamination',
#  'contemporary',
#  'contents',
#  'context',
#  'contingency',
#  'contingent',
#  'continue',
#  'continuous',
#  'contract',
#  'contracting',
#  'contractor',
#  'contractors',
#  'contracts',
#  'contractual',
#  'contrast',
#  'contrasted',
#  'contrasts',
#  'contribute',
#  'contributed',
#  'contributing',
#  'contribution',
#  'contributions',
#  'control',
#  'controlled',
#  'controlling',
#  'conventional',
#  'convert',
#  'converted',
#  'coordinate',
#  'cop',
#  'copyright',
#  'corporate',
#  'corporation',
#  'corporations',
#  'correct',
#  'correlation',
#  'corresponding',
#  'cosmetic',
#  'cost',
#  'costs',
#  'council',
#  'counsel',
#  'counterparties',
#  'counterparts',
#  'counterparty',
#  'countries',
#  'country',
#  'course',
#  'court',
#  'courts',
#  'cover',
#  'coverage',
#  'coverages',
#  'covered',
#  'covering',
#  'covers',
#  'cp',
#  'cpcu',
#  'cr',
#  'cranes',
#  'crashes',
#  'create',
#  'created',
#  'creates',
#  'credible',
#  'credit',
#  'credits',
#  'crew',
#  'crime',
#  'criminal',
#  'crises',
#  'criteria',
#  'critical',
#  'crop',
#  'crops',
#  'cross',
#  'cumbersome',
#  'currency',
#  'current',
#  'currently',
#  'custody',
#  'custom',
#  'customary',
#  'customer',
#  'customers',
#  'cyber',
#  'cycle',
#  'damage',
#  'damaged',
#  'damages',
#  'damaging',
#  'data',
#  'date',
#  'day',
#  'days',
#  'deadlines',
#  'deal',
#  'dealers',
#  'dealership',
#  'dealing',
#  'deals',
#  'death',
#  'debit',
#  'debt',
#  'debts',
#  'dec',
#  'december',
#  'decide',
#  'decision',
#  'decisions',
#  'declaration',
#  'declarations',
#  'decline',
#  'decrease',
#  'decreases',
#  'deduct',
#  'deductibility',
#  'deductible',
#  'deductibles',
#  'deemed',
#  'defamatory',
#  'default',
#  'defect',
#  'defective',
#  'defects',
#  'defend',
#  'defendant',
#  'defendants',
#  'defending',
#  'defense',
#  'defenses',
#  'deferral',
#  'deficiencies',
#  'deficiency',
#  'define',
#  'defined',
#  'defining',
#  'definition',
#  'definitions',
#  'degree',
#  'delaware',
#  'delay',
#  'delayed',
#  'delete',
#  'deleted',
#  'delivering',
#  'delivery',
#  'demand',
#  'demolished',
#  'demolishing',
#  'denominator',
#  'department',
#  'departments',
#  'dependent',
#  'depending',
#  'depends',
#  'deposited',
#  'deposits',
#  'depreciation',
#  'derivative',
#  'derivatives',
#  'derived',
#  'described',
#  'describes',
#  'describing',
#  'design',
#  'designate',
#  'designated',
#  'designation',
#  'designed',
#  'designer',
#  'desirable',
#  'desire',
#  'despite',
#  'destination',
#  'destroyed',
#  'destruction',
#  'detailed',
#  'details',
#  'determination',
#  'determinations',
#  'determine',
#  'determined',
#  'determines',
#  'determining',
#  'develop',
#  'developed',
#  'developers',
#  'developing',
#  'development',
#  'deviation',
#  'deviations',
#  'device',
#  'devices',
#  'dic',
#  'did',
#  'dies',
#  'difference',
#  'different',
#  'differentiated',
#  'differs',
#  'difficult',
#  'difficulties',
#  'difficulty',
#  'diminishing',
#  'dioxide',
#  'direct',
#  'directed',
#  'directly',
#  'director',
#  'directors',
#  'directorship',
#  'dirty',
#  'disabilities',
#  'disability',
#  'disabled',
#  'disappearance',
#  'disapprove',
#  'disaster',
#  'discharge',
#  'discipline',
#  'disclose',
#  'disclosing',
#  'disclosure',
#  'discount',
#  'discounts',
#  'discovered',
#  'discovery',
#  'discrimination',
#  'discriminatory',
#  'disease',
#  'diseases',
#  'dishonest',
#  'dishonesty',
#  'dismemberment',
#  'dismissal',
#  'disorder',
#  'disorders',
#  'disperse',
#  'disposal',
#  'disposed',
#  'dispute',
#  'disputes',
#  'disruption',
#  'distance',
#  'distinction',
#  'distinguishable',
#  'distinguished',
#  'distributed',
#  'distribution',
#  'distributions',
#  'divided',
#  'dividend',
#  'dividends',
#  'divides',
#  'dividing',
#  'division',
#  'doctrine',
#  'document',
#  'documents',
#  'does',
#  'doing',
#  'dollar',
#  'dollars',
#  'domestic',
#  'domicile',
#  'domiciled',
#  'domiciles',
#  'dominance',
#  'dot',
#  'double',
#  'downsizing',
#  'drafted',
#  'drilling',
#  'driven',
#  'driver',
#  'drivers',
#  'driving',
#  'drop',
#  'drug',
#  'duration',
#  'duties',
#  'duty',
#  'dwelling',
#  'early',
#  'earned',
#  'earnings',
#  'earth',
#  'earthquake',
#  'easement',
#  'economic',
#  'ecor',
#  'edition',
#  'editions',
#  'edp',
#  'educational',
#  'effect',
#  'effected',
#  'effective',
#  'effectively',
#  'effects',
#  'efficiency',
#  'efficient',
#  'effluent',
#  'effort',
#  'elect',
#  'electrical',
#  'electronic',
#  'electronically',
#  'element',
#  'elements',
#  'eligible',
#  'eliminated',
#  'eliminates',
#  'eliminating',
#  'elimination',
#  'emap',
#  'embargo',
#  'emergency',
#  'emission',
#  'employ',
#  'employee',
#  'employees',
#  'employer',
#  'employers',
#  'employment',
#  'enable',
#  'enables',
#  'enacted',
#  'encompasses',
#  'end',
#  'ended',
#  'endorsed',
#  'endorsement',
#  'endorsements',
#  'energy',
#  'enforcement',
#  'enforces',
#  'enforcing',
#  'engaged',
#  'engineer',
#  'engineering',
#  'engineers',
#  'enrollment',
#  'enron',
#  'ensuing',
#  'ensure',
#  'ensuring',
#  'entail',
#  'enter',
#  'entered',
#  'enterprise',
#  'entire',
#  'entities',
#  'entitled',
#  'entity',
#  'entries',
#  'entry',
#  'environment',
#  'environmental',
#  'epa',
#  'epl',
#  'epli',
#  'equal',
#  'equally',
#  'equals',
#  'equipment',
#  'equity',
#  'erisa',
#  'erm',
#  'error',
#  'errors',
#  'especially',
#  'essential',
#  'essentially',
#  'establish',
#  'established',
#  'establishes',
#  'establishing',
#  'estate',
#  'esteem',
#  'estimate',
#  'estimated',
#  'estimates',
#  'evaluating',
#  'evaluation',
#  'event',
#  'events',
#  'evidence',
#  'exactly',
#  'examination',
#  'examinations',
#  'example',
#  'examples',
#  'exams',
#  'exceed',
#  'exceeds',
#  'exception',
#  'exceptions',
#  'excess',
#  'excessive',
#  'exchange',
#  'exclude',
#  'excluded',
#  'excludes',
#  'excluding',
#  'exclusion',
#  'exclusions',
#  'exclusive',
#  'executive',
#  'exempt',
#  'exercise',
#  'exhausted',
#  'existence',
#  'existing',
#  'exists',
#  'expected',
#  'expense',
#  'expenses',
#  'expensive',
#  'experience',
#  'expertise',
#  'expiration',
#  'explosion',
#  'export',
#  'exposed',
#  'exposure',
#  'exposures',
#  'expressed',
#  'expression',
#  'extend',
#  'extended',
#  'extent',
#  'external',
#  'extra',
#  'extrinsic',
#  'face',
#  'faced',
#  'facilitate',
#  'facilities',
#  'facility',
#  'fact',
#  'factor',
#  'factors',
#  'facts',
#  'failing',
#  'fails',
#  'failure',
#  'faith',
#  'fall',
#  'falls',
#  'false',
#  'family',
#  'farm',
#  'farmer',
#  ...]

# %%
vocab_y = vectorizer_y.get_feature_names()
vocab_y
# Out:
# ['114',
#  '1386',
#  '15',
#  '1927',
#  '1933',
#  '1936',
#  '1970',
#  '1973',
#  '1975',
#  '1977',
#  '1980',
#  '1983',
#  '1984',
#  '1986',
#  '1994',
#  '1996',
#  '1998',
#  '2000',
#  '2002',
#  '2005',
#  'abatement',
#  'accident',
#  'account',
#  'accounting',
#  'act',
#  'action',
#  'add',
#  'added',
#  'additional',
#  'adequacy',
#  'adjusted',
#  'adjustment',
#  'administration',
#  'administrator',
#  'admiralty',
#  'admitted',
#  'adr',
#  'adverse',
#  'affiliated',
#  'agency',
#  'agent',
#  'agents',
#  'aggregate',
#  'aggregates',
#  'agreed',
#  'agreement',
#  'agreements',
#  'agricultural',
#  'aiaf',
#  'aim',
#  'air',
#  'aircraft',
#  'airport',
#  'ait',
#  'aleatory',
#  'alien',
#  'alienated',
#  'allowance',
#  'alternative',
#  'amendment',
#  'american',
#  'analysis',
#  'analytic',
#  'animal',
#  'annuity',
#  'antwerp',
#  'api',
#  'appeal',
#  'appear',
#  'appetite',
#  'apportionment',
#  'appraisers',
#  'approach',
#  'approval',
#  'architects',
#  'arm',
#  'arrest',
#  'asbestos',
#  'assessment',
#  'assessments',
#  'associate',
#  'association',
#  'assumed',
#  'auto',
#  'automatic',
#  'average',
#  'bank',
#  'based',
#  'basis',
#  'beneficiary',
#  'benefit',
#  'best',
#  'blanket',
#  'board',
#  'bodily',
#  'boiler',
#  'bond',
#  'broad',
#  'broker',
#  'building',
#  'burglary',
#  'business',
#  'capacity',
#  'capital',
#  'captive',
#  'capture',
#  'care',
#  'carmack',
#  'carriage',
#  'carrier',
#  'case',
#  'cash',
#  'casualty',
#  'cat',
#  'catastrophe',
#  'catastrophic',
#  'cause',
#  'causes',
#  'ccc',
#  'ccla',
#  'ceded',
#  'ceding',
#  'center',
#  'central',
#  'cercla',
#  'certainty',
#  'certificate',
#  'certified',
#  'cession',
#  'charge',
#  'chartered',
#  'check',
#  'chemical',
#  'children',
#  'cica',
#  'cif',
#  'circumstances',
#  'cl',
#  'claim',
#  'claims',
#  'clash',
#  'class',
#  'classification',
#  'clause',
#  'clean',
#  'client',
#  'clinical',
#  'cm',
#  'code',
#  'coded',
#  'codefendant',
#  'coemployer',
#  'coemployment',
#  'cogsa',
#  'coincidental',
#  'coinsurer',
#  'collapse',
#  'collar',
#  'collateral',
#  'collateralization',
#  'collision',
#  'combination',
#  'commercial',
#  'commission',
#  'commissioner',
#  'committee',
#  'committees',
#  'common',
#  'communicable',
#  'communication',
#  'communications',
#  'community',
#  'commutation',
#  'companies',
#  'company',
#  'compensation',
#  'competitive',
#  'complainant',
#  'completion',
#  'compliance',
#  'composite',
#  'comprehensive',
#  'compulsory',
#  'computer',
#  'concealment',
#  'concentration',
#  'condition',
#  'conditional',
#  'conditionally',
#  'conditions',
#  'condominium',
#  'connected',
#  'consent',
#  'consequential',
#  'consolidation',
#  'consortium',
#  'construction',
#  'contamination',
#  'contents',
#  'contest',
#  'contingent',
#  'continuation',
#  'continuity',
#  'continuous',
#  'contra',
#  'contract',
#  'contractor',
#  'contractors',
#  'contracts',
#  'contributing',
#  'contribution',
#  'control',
#  'controlled',
#  'controlling',
#  'convention',
#  'conversion',
#  'conveyance',
#  'cooke',
#  'cooperation',
#  'cop',
#  'cope',
#  'coppa',
#  'corporation',
#  'corrupt',
#  'coso',
#  'cost',
#  'costs',
#  'council',
#  'counsel',
#  'counterparty',
#  'country',
#  'course',
#  'court',
#  'covariance',
#  'cover',
#  'coverage',
#  'coverages',
#  'covers',
#  'cpcu',
#  'cppa',
#  'cradle',
#  'credibility',
#  'credit',
#  'criteria',
#  'crop',
#  'cross',
#  'cumis',
#  'cumulative',
#  'custody',
#  'custom',
#  'cutoff',
#  'cva',
#  'cycles',
#  'damage',
#  'damages',
#  'data',
#  'date',
#  'ddl',
#  'dealers',
#  'death',
#  'debit',
#  'declarations',
#  'deductible',
#  'deemer',
#  'defects',
#  'defendant',
#  'defense',
#  'defenses',
#  'definition',
#  'delayed',
#  'demand',
#  'demonstrated',
#  'department',
#  'dependent',
#  'deposited',
#  'depreciation',
#  'derivative',
#  'design',
#  'designated',
#  'destruction',
#  'development',
#  'device',
#  'difference',
#  'dil',
#  'diligence',
#  'direct',
#  'directors',
#  'dirty',
#  'discipline',
#  'disclosure',
#  'discontinuance',
#  'discount',
#  'discovery',
#  'disease',
#  'dishonesty',
#  'disintermediation',
#  'dismemberment',
#  'disparagement',
#  'dispute',
#  'disputes',
#  'disruption',
#  'distribution',
#  'dividend',
#  'doctrine',
#  'dollar',
#  'domestic',
#  'double',
#  'duty',
#  'earnings',
#  'element',
#  'emergency',
#  'employee',
#  'employees',
#  'employers',
#  'employment',
#  'endorsement',
#  'enforcement',
#  'environmental',
#  'equipment',
#  'errors',
#  'evaluation',
#  'event',
#  'ex',
#  'exception',
#  'excess',
#  'exclusion',
#  'exclusions',
#  'expense',
#  'experience',
#  'expiration',
#  'extended',
#  'factor',
#  'facultative',
#  'federal',
#  'fee',
#  'fees',
#  'fellow',
#  'fiduciary',
#  'financial',
#  'financing',
#  'firm',
#  'flood',
#  'flow',
#  'follow',
#  'foreign',
#  'form',
#  'forms',
#  'free',
#  'freight',
#  'funded',
#  'gap',
#  'garagekeepers',
#  'general',
#  'goods',
#  'gross',
#  'ground',
#  'group',
#  'guaranteed',
#  'hazardous',
#  'healthcare',
#  'highway',
#  'ho',
#  'home',
#  'homeowners',
#  'hull',
#  'hybrid',
#  'impaired',
#  'impairment',
#  'income',
#  'incurred',
#  'indemnity',
#  'independent',
#  'index',
#  'industry',
#  'information',
#  'injury',
#  'institute',
#  'insurability',
#  'insurance',
#  'insured',
#  'insureds',
#  'insurer',
#  'intellectual',
#  'international',
#  'investment',
#  'iso',
#  'joint',
#  'judgment',
#  'lag',
#  'large',
#  'law',
#  'legal',
#  'liability',
#  'limit',
#  'limitation',
#  'limitations',
#  'limits',
#  'line',
#  'liquidity',
#  'litigation',
#  'lloyd',
#  'loan',
#  'loss',
#  'losses',
#  'machinery',
#  'management',
#  'managing',
#  'market',
#  'maturity',
#  'medical',
#  'method',
#  'mobile',
#  'modeling',
#  'modifier',
#  'money',
#  'monitoring',
#  'montrose',
#  'morale',
#  'mortality',
#  'mortgage',
#  'motion',
#  'motor',
#  'motorcycle',
#  'movement',
#  'msa',
#  'msawpa',
#  'multiple',
#  'mutual',
#  'mvc',
#  'naics',
#  'named',
#  'national',
#  'navigation',
#  'nbc',
#  'negative',
#  'negligent',
#  'net',
#  'new',
#  'nfip',
#  'nhtsa',
#  'niss',
#  'nonadmitted',
#  'nonassessable',
#  'nonassignable',
#  'noncombustible',
#  'nonconcurrency',
#  'noncontributory',
#  'noneconomic',
#  'noninsurance',
#  'nonledger',
#  'nonowner',
#  'nonprofit',
#  'nonrescission',
#  'nonsubject',
#  'nonsubscription',
#  'nontransferability',
#  'noon',
#  'normal',
#  'north',
#  'note',
#  'notice',
#  'nrt',
#  'nsps',
#  'nuclear',
#  'numbers',
#  'oath',
#  'object',
#  'obligations',
#  'obligatory',
#  'obligor',
#  'occupational',
#  'occurrence',
#  'ocean',
#  'ocp',
#  'offer',
#  'offering',
#  'office',
#  'offset',
#  'offshore',
#  'old',
#  'omissions',
#  'online',
#  'open',
#  'operational',
#  'operations',
#  'operator',
#  'operators',
#  'optimum',
#  'option',
#  'options',
#  'ordinance',
#  'ordinary',
#  'organization',
#  'organizations',
#  'orm',
#  'oslr',
#  'ostensible',
#  'outplacement',
#  'output',
#  'outstanding',
#  'overlapping',
#  'override',
#  'overriding',
#  'overtime',
#  'owner',
#  'owners',
#  'paid',
#  'pain',
#  'pair',
#  'panel',
#  'papers',
#  'paralegal',
#  'parallel',
#  'paramedics',
#  'parte',
#  'particular',
#  'party',
#  'passive',
#  'patient',
#  'patterns',
#  'pay',
#  'payment',
#  'payments',
#  'payor',
#  'payout',
#  'payroll',
#  'pbgc',
#  'pcla',
#  'pd',
#  'penal',
#  'penalty',
#  'pension',
#  'percent',
#  'perfect',
#  'performance',
#  'perils',
#  'period',
#  'permit',
#  'personal',
#  'physical',
#  'physician',
#  'pilot',
#  'plan',
#  'planned',
#  'plans',
#  'platooning',
#  'pmpl',
#  'point',
#  'police',
#  'policies',
#  'policy',
#  'policyholder',
#  'pollutant',
#  'pollution',
#  'ponzi',
#  'pool',
#  'portfolio',
#  'practice',
#  'practices',
#  'preauthorized',
#  'predecessor',
#  'preexisting',
#  'prejudgment',
#  'prejudice',
#  'preliminary',
#  'premises',
#  'premium',
#  'premiums',
#  'principal',
#  'prior',
#  'privacy',
#  'private',
#  'privileged',
#  'pro',
#  'probability',
#  'probationary',
#  'proceedings',
#  'process',
#  'processing',
#  'procurement',
#  'procuring',
#  'product',
#  'production',
#  'products',
#  'proferentem',
#  'professional',
#  'profile',
#  'profit',
#  'profits',
#  'program',
#  'programs',
#  'progressive',
#  'prohibited',
#  'prohibition',
#  'project',
#  'promisor',
#  'proof',
#  'properties',
#  'property',
#  'proration',
#  'protection',
#  'protective',
#  'provision',
#  'provisions',
#  'psychological',
#  'pte',
#  'public',
#  'publishers',
#  'punitive',
#  'purchasing',
#  'pure',
#  'putative',
#  'putting',
#  'qip',
#  'qualified',
#  'quality',
#  'quantity',
#  'quid',
#  'quo',
#  'ra',
#  'racketeer',
#  'ranking',
#  'rarorac',
#  'rata',
#  'rate',
#  'rates',
#  'rating',
#  'ratio',
#  'rca',
#  'rebate',
#  'receipt',
#  'receipts',
#  'records',
#  'recovery',
#  'rectification',
#  'recurring',
#  'redomiciling',
#  'reduction',
#  'reemployment',
#  'referral',
#  'reform',
#  'refund',
#  'registration',
#  'regression',
#  'regulation',
#  'regulatory',
#  'rehabilitation',
#  'reimbursement',
#  'reinstatement',
#  'reinsurance',
#  'reinsurer',
#  'related',
#  'relationship',
#  'release',
#  'remedial',
#  'remediation',
#  'remedy',
#  'remuneration',
#  'renewable',
#  'renewal',
#  'replacement',
#  'report',
#  'reportable',
#  'reported',
#  'reporter',
#  'reporting',
#  'representations',
#  'reproduction',
#  'reputational',
#  'requirements',
#  'rescission',
#  'reserve',
#  'reserves',
#  'residence',
#  'residential',
#  'residual',
#  'resolution',
#  'response',
#  'responsibility',
#  'restoration',
#  'retention',
#  'retired',
#  'retirement',
#  'retroactive',
#  'retrospective',
#  'return',
#  'revenue',
#  'reverse',
#  'reversionary',
#  'rewrite',
#  'rico',
#  'ride',
#  'rider',
#  'rights',
#  'rims',
#  'rip',
#  'risk',
#  'risks',
#  'rmis',
#  'rml',
#  'robbery',
#  'root',
#  'rorac',
#  'round',
#  'rpii',
#  'rq',
#  'rra',
#  'rrg',
#  'ruin',
#  'rule',
#  'rules',
#  'running',
#  'safe',
#  'safety',
#  'saffir',
#  'sales',
#  'salesmen',
#  'saline',
#  'salvage',
#  'samples',
#  'savings',
#  'say',
#  'sb',
#  'sbu',
#  'scale',
#  'schedule',
#  'scheduled',
#  'scheme',
#  'scoring',
#  'sea',
#  'seasonal',
#  'section',
#  'securities',
#  'security',
#  'segregation',
#  'seizure',
#  'selection',
#  'self',
#  'semci',
#  'separate',
#  'serc',
#  'series',
#  'serp',
#  'service',
#  'services',
#  'servicing',
#  'set',
#  'setoff',
#  'settlement',
#  'severability',
#  'severance',
#  'severity',
#  'sexual',
#  'share',
#  'shares',
#  'sharing',
#  'sheet',
#  'shortfall',
#  'simpson',
#  'single',
#  'sister',
#  'slabbed',
#  'slander',
#  'slc',
#  'sliding',
#  'society',
#  'software',
#  'source',
#  'spamming',
#  'spearin',
#  'special',
#  'specialty',
#  'specific',
#  'specifications',
#  'specified',
#  'speed',
#  'sponsored',
#  'sponsoring',
#  'spousal',
#  'stability',
#  'stacking',
#  'stand',
#  'standard',
#  'standards',
#  'startups',
#  'state',
#  'statistical',
#  'status',
#  'statute',
#  'statutes',
#  'statutory',
#  'stochastic',
#  'stock',
#  'storekeepers',
#  'storm',
#  'strategic',
#  'stripping',
#  'student',
#  'subbroker',
#  'subcontractor',
#  'subject',
#  'subjective',
#  'submission',
#  'subrogation',
#  'subsidence',
#  'substances',
#  'substandard',
#  'substitute',
#  'sudden',
#  'suffering',
#  'suits',
#  'sum',
#  'summary',
#  'supervision',
#  'supplementary',
#  'surcharge',
#  'surge',
#  'surplus',
#  'surrender',
#  'survival',
#  'swap',
#  'swaption',
#  'symbols',
#  'symptoms',
#  'syndicate',
#  'systems',
#  'table',
#  'tacit',
#  'tail',
#  'task',
#  'tax',
#  'tce',
#  'tcn',
#  'team',
#  'tear',
#  'technician',
#  'technology',
#  'tendency',
#  'term',
#  'terminal',
#  'termination',
#  'territory',
#  'terrorism',
#  'test',
#  'testing',
#  'theft',
#  'theory',
#  'thermal',
#  'threat',
#  'threshold',
#  'time',
#  'timers',
#  'timing',
#  'title',
#  'tlv',
#  'tolerance',
#  'tolling',
#  'tortfeasor',
#  'total',
#  'toxins',
#  'tra',
#  'trade',
#  'traffic',
#  'trailer',
#  'transaction',
#  'transactions',
#  'transfer',
#  'transit',
#  'transportation',
#  'treaty',
#  'trend',
#  'trending',
#  'tria',
#  'trial',
#  'triangle',
#  'trigger',
#  'triggers',
#  'trip',
#  'triple',
#  'trust',
#  'uberrimae',
#  'ubit',
#  'ucra',
#  'ultimate',
#  'umbrella',
#  'unauthorized',
#  'unbundling',
#  'underinsurance',
#  'underlying',
#  'underwriter',
#  'underwriting',
#  'unified',
#  'uniform',
#  'uniformed',
#  'unit',
#  'unnamed',
#  'unrelated',
#  'upgrades',
#  'use',
#  'userra',
#  'utbms',
#  'vacancy',
#  'valuable',
#  'valuation',
#  'value',
#  'valued',
#  'var',
#  'variance',
#  'vehicle',
#  'vendors',
#  'venue',
#  'verbal',
#  'vertical',
#  'vessel',
#  'viatical',
#  'vicarious',
#  'vice',
#  'volatility',
#  'voluntary',
#  'voyage',
#  'wa',
#  'waiting',
#  'waiver',
#  'walls',
#  'war',
#  'warranties',
#  'warranty',
#  'warsaw',
#  'waste',
#  'water',
#  'wcla',
#  'weapon',
#  'weapons',
#  'weight',
#  'weighted',
#  'welfare',
#  'wharfinger',
#  'white',
#  'window',
#  'wmd',
#  'wording',
#  'work',
#  'worker',
#  'workers',
#  'worksheet',
#  'wrap',
#  'writ',
#  'write',
#  'writer',
#  'writing',
#  'written',
#  'wrongful',
#  'wyo',
#  'y2k',
#  'year',
#  'yellow',
#  'zone']

# %% [markdown]
# Use grid search to find the optimized k for KMeans.

# %%
vec_labels = vectorizer_y.transform(labels)

from sklearn.cluster import KMeans
n=8
kmeans = KMeans(n_clusters=n).fit(vec_trained)
print(kmeans.labels_.size)
kmeans.labels_
# Out:
# 978
# array([2, 7, 4, 3, 6, 5, 7, 4, 2, 2, 6, 6, 4, 6, 0, 1, 6, 7, 6, 0, 6, 0,
#        2, 7, 2, 5, 6, 1, 2, 6, 2, 0, 6, 4, 6, 2, 1, 7, 6, 5, 2, 6, 4, 4,
#        6, 6, 4, 2, 6, 2, 5, 2, 2, 2, 5, 5, 0, 5, 6, 1, 5, 7, 7, 6, 1, 1,
#        2, 2, 6, 0, 6, 3, 7, 5, 7, 2, 6, 7, 2, 2, 1, 3, 2, 1, 5, 6, 2, 2,
#        6, 4, 7, 2, 1, 3, 6, 5, 6, 6, 0, 6, 6, 6, 5, 7, 0, 6, 6, 3, 5, 0,
#        5, 7, 2, 0, 6, 7, 7, 6, 6, 6, 2, 2, 6, 2, 7, 0, 4, 2, 6, 6, 5, 6,
#        6, 2, 5, 4, 6, 4, 1, 4, 6, 0, 3, 2, 4, 0, 1, 4, 6, 6, 7, 5, 1, 6,
#        0, 5, 6, 5, 0, 5, 2, 6, 5, 5, 6, 6, 5, 0, 5, 1, 6, 6, 2, 4, 0, 6,
#        2, 6, 5, 2, 0, 6, 1, 6, 6, 6, 6, 5, 6, 6, 0, 7, 6, 6, 6, 6, 3, 5,
#        1, 2, 6, 2, 2, 2, 3, 6, 7, 2, 6, 7, 3, 4, 0, 0, 6, 6, 2, 5, 6, 6,
#        5, 4, 6, 5, 6, 7, 2, 2, 6, 0, 6, 3, 5, 5, 1, 5, 7, 7, 2, 0, 7, 5,
#        5, 7, 6, 2, 3, 5, 6, 1, 5, 2, 2, 2, 5, 1, 7, 3, 6, 0, 2, 6, 5, 5,
#        6, 0, 0, 6, 5, 2, 2, 6, 3, 6, 2, 1, 7, 0, 6, 2, 2, 1, 6, 3, 2, 2,
#        2, 7, 6, 4, 6, 2, 6, 6, 5, 5, 6, 1, 6, 2, 2, 2, 2, 7, 6, 6, 1, 5,
#        3, 2, 7, 6, 1, 4, 7, 6, 6, 6, 6, 0, 6, 1, 1, 6, 2, 2, 6, 1, 2, 0,
#        7, 6, 2, 4, 6, 6, 2, 1, 6, 0, 2, 0, 2, 5, 7, 0, 1, 4, 6, 5, 5, 2,
#        0, 6, 0, 1, 7, 5, 2, 1, 6, 4, 6, 6, 6, 5, 5, 6, 2, 4, 5, 2, 2, 6,
#        6, 6, 2, 6, 2, 7, 4, 2, 0, 0, 2, 6, 4, 0, 6, 0, 2, 6, 5, 6, 6, 6,
#        7, 7, 7, 6, 7, 6, 0, 2, 2, 5, 6, 2, 6, 0, 2, 3, 0, 6, 2, 6, 1, 0,
#        0, 2, 6, 1, 7, 0, 7, 0, 6, 4, 6, 6, 6, 1, 7, 0, 5, 6, 0, 0, 0, 2,
#        4, 2, 6, 7, 7, 7, 5, 0, 4, 0, 1, 6, 6, 7, 6, 5, 6, 4, 6, 6, 7, 5,
#        3, 5, 5, 5, 1, 7, 5, 2, 6, 7, 3, 2, 6, 5, 6, 0, 1, 5, 0, 2, 2, 7,
#        6, 6, 6, 3, 6, 0, 6, 2, 0, 6, 6, 2, 5, 2, 2, 1, 3, 0, 5, 5, 5, 6,
#        6, 3, 0, 6, 0, 5, 2, 1, 5, 2, 1, 6, 5, 0, 0, 2, 6, 7, 5, 5, 6, 1,
#        6, 0, 2, 4, 5, 7, 3, 7, 6, 0, 6, 0, 7, 6, 1, 5, 5, 6, 6, 5, 6, 7,
#        6, 6, 2, 2, 2, 5, 6, 0, 7, 6, 2, 7, 6, 5, 6, 6, 7, 0, 6, 7, 2, 5,
#        6, 5, 6, 6, 7, 2, 6, 2, 6, 6, 5, 7, 2, 6, 0, 6, 2, 0, 0, 0, 5, 2,
#        6, 6, 5, 4, 3, 2, 6, 6, 2, 0, 0, 5, 2, 4, 7, 6, 6, 7, 6, 1, 1, 6,
#        6, 2, 6, 6, 5, 6, 0, 6, 2, 2, 7, 6, 6, 6, 7, 6, 5, 2, 2, 2, 2, 3,
#        7, 5, 6, 1, 2, 7, 6, 5, 0, 5, 5, 0, 1, 5, 5, 1, 1, 6, 2, 0, 2, 6,
#        2, 2, 2, 0, 2, 6, 6, 5, 6, 6, 6, 2, 1, 0, 6, 4, 0, 2, 7, 0, 7, 6,
#        4, 2, 6, 3, 1, 0, 2, 4, 3, 0, 0, 2, 0, 5, 4, 3, 2, 6, 0, 2, 1, 3,
#        6, 0, 2, 1, 3, 6, 1, 0, 5, 2, 6, 4, 6, 6, 2, 5, 6, 2, 2, 5, 6, 0,
#        5, 0, 6, 7, 6, 4, 4, 1, 3, 0, 3, 6, 5, 2, 7, 7, 6, 5, 6, 6, 2, 6,
#        7, 6, 3, 7, 5, 3, 6, 6, 7, 2, 6, 6, 7, 0, 6, 4, 1, 0, 0, 2, 2, 6,
#        4, 2, 5, 6, 6, 6, 2, 0, 2, 2, 7, 6, 6, 2, 6, 6, 7, 1, 6, 6, 6, 7,
#        1, 5, 6, 7, 6, 2, 2, 7, 6, 2, 6, 4, 6, 5, 6, 3, 5, 6, 6, 6, 6, 6,
#        7, 0, 5, 0, 1, 6, 6, 2, 6, 2, 6, 7, 4, 6, 2, 7, 6, 2, 0, 7, 2, 6,
#        7, 6, 7, 7, 6, 6, 5, 7, 6, 4, 2, 0, 1, 6, 6, 6, 6, 5, 2, 2, 2, 5,
#        4, 6, 5, 4, 4, 3, 2, 6, 1, 2, 1, 4, 6, 5, 5, 6, 5, 6, 7, 6, 6, 4,
#        6, 6, 6, 0, 6, 6, 5, 6, 3, 6, 6, 2, 0, 4, 6, 6, 7, 6, 2, 2, 5, 5,
#        3, 6, 2, 7, 0, 6, 3, 6, 6, 7, 6, 2, 6, 6, 6, 6, 2, 2, 6, 2, 5, 2,
#        0, 1, 2, 5, 1, 4, 2, 0, 2, 6, 4, 5, 6, 7, 6, 1, 4, 6, 7, 0, 2, 6,
#        6, 1, 6, 6, 5, 6, 6, 7, 5, 0, 6, 6, 2, 5, 5, 0, 6, 5, 2, 5, 0, 5,
#        6, 5, 0, 6, 6, 4, 2, 4, 7, 5], dtype=int32)

# %%
from sklearn.model_selection import GridSearchCV
