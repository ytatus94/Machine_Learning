# %% [markdown]
# # Titanic

# %%
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

train = pd.read_csv('titanic/train.csv')
test = pd.read_csv('titanic/test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# # 把 train 和 test 結合起來

# %%
data = train.append(test, sort=True)
#data.head()
data.iloc[885:895]
# Out:
#       Age Cabin Embarked     Fare                                      Name  \
# 885  39.0   NaN        Q  29.1250      Rice, Mrs. William (Margaret Norton)
# 886  27.0   NaN        S  13.0000                     Montvila, Rev. Juozas
# 887  19.0   B42        S  30.0000              Graham, Miss. Margaret Edith
# 888   NaN   NaN        S  23.4500  Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0  C148        C  30.0000                     Behr, Mr. Karl Howell
# 890  32.0   NaN        Q   7.7500                       Dooley, Mr. Patrick
# 0    34.5   NaN        Q   7.8292                          Kelly, Mr. James
# 1    47.0   NaN        S   7.0000          Wilkes, Mrs. James (Ellen Needs)
# 2    62.0   NaN        Q   9.6875                 Myles, Mr. Thomas Francis
# 3    27.0   NaN        S   8.6625                          Wirz, Mr. Albert
#
#      Parch  PassengerId  Pclass     Sex  SibSp  Survived      Ticket
# ...

# %% [markdown]
# # 把 index 重複的問題解決

# %%
data.reset_index(inplace=True, drop=True)
data.iloc[885:895]
# Out:
#       Age Cabin Embarked     Fare                                      Name  \
# 885  39.0   NaN        Q  29.1250      Rice, Mrs. William (Margaret Norton)
# 886  27.0   NaN        S  13.0000                     Montvila, Rev. Juozas
# 887  19.0   B42        S  30.0000              Graham, Miss. Margaret Edith
# 888   NaN   NaN        S  23.4500  Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0  C148        C  30.0000                     Behr, Mr. Karl Howell
# 890  32.0   NaN        Q   7.7500                       Dooley, Mr. Patrick
# 891  34.5   NaN        Q   7.8292                          Kelly, Mr. James
# 892  47.0   NaN        S   7.0000          Wilkes, Mrs. James (Ellen Needs)
# 893  62.0   NaN        Q   9.6875                 Myles, Mr. Thomas Francis
# 894  27.0   NaN        S   8.6625                          Wirz, Mr. Albert
#
#      Parch  PassengerId  Pclass     Sex  SibSp  Survived      Ticket
# ...

# %% [markdown]
# 開始分析

# %%
plt.style.use('seaborn')
sns.countplot(data['Survived'])
plt.show()

# %%
sns.countplot(data['Pclass'], hue=data['Survived'])
plt.show()

# %%
sns.countplot(data['Sex'], hue=data['Survived'])
plt.show()

# %%
sns.countplot(data['Embarked'], hue=data['Survived'])
plt.show()

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Age', kde=False)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Fare', kde=False)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Parch', kde=False)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'SibSp', kde=False)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
data['Family_size'] = data['Parch'] + data['SibSp']

g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Family_size', kde=False)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # 特徵工程
# 提取出稱謂

# %%
data['Name'].str.split(', ', expand=True).head()
# Out:
#            0                                           1
# 0     Braund                             Mr. Owen Harris
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                 Miss. Laina
# 3   Futrelle          Mrs. Jacques Heath (Lily May Peel)
# 4      Allen                           Mr. William Henry

# %%
data['Title1'] = data['Name'].str.split(', ', expand=True)[1]
data['Title1'].head()
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# 3            Mrs. Jacques Heath (Lily May Peel)
# 4                             Mr. William Henry
# Name: Title1, dtype: object

# %%
data['Title1'] = data['Title1'].str.split('.', expand=True)[0]
data['Title1'].head()
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4      Mr
# Name: Title1, dtype: object

# %%
data['Title1'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %% [markdown]
# 將稱謂對性別，生存率，和年齡做分析

# %%
pd.crosstab(data['Title1'], data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col0 {
#             background-color:  #ffff66;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col1 {
#             background-color:  #ffff66;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col2 {
#             background-color:  #ffff66;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col3 {
#             background-color:  #008066;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col4 {
#             background-color:  #ffff66;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col5 {
#             background-color:  #ffff66;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col6 {
#             background-color:  #008066;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col7 {
#             background-color:  #ffff66;
#         }    #T_e55e0b3e_8ec2_11e8_8cee_32000d20ee01row0_col8 {
#             background-color:  #ffff66;
# ...

# %%
pd.crosstab(data['Title1'], data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col0 {
#             background-color:  #008066;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col1 {
#             background-color:  #ffff66;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col2 {
#             background-color:  #008066;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col3 {
#             background-color:  #008066;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col4 {
#             background-color:  #008066;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col5 {
#             background-color:  #ffff66;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col6 {
#             background-color:  #ffff66;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col7 {
#             background-color:  #ffff66;
#         }    #T_e569bbb4_8ec2_11e8_b7ff_32000d20ee01row0_col8 {
#             background-color:  #ffff66;
# ...

# %%
data.groupby(['Title1'])['Age'].mean()
# Out:
# Title1
# Capt            70.000000
# Col             54.000000
# Don             40.000000
# Dona            39.000000
# Dr              43.571429
# Jonkheer        38.000000
# Lady            48.000000
# Major           48.500000
# Master           5.482642
# Miss            21.774238
# Mlle            24.000000
# Mme             24.000000
# Mr              32.252151
# Mrs             36.994118
# Ms              28.000000
# Rev             41.250000
# Sir             49.000000
# the Countess    33.000000
# Name: Age, dtype: float64

# %%
data.groupby(['Title1', 'Pclass'])['Age'].mean()
# Out:
# Title1        Pclass
# Capt          1         70.000000
# Col           1         54.000000
# Don           1         40.000000
# Dona          1         39.000000
# Dr            1         45.600000
#               2         38.500000
# Jonkheer      1         38.000000
# Lady          1         48.000000
# Major         1         48.500000
# Master        1          6.984000
#               2          2.757273
#               3          6.090000
# Miss          1         30.338983
#               2         20.717083
#               3         17.360874
# Mlle          1         24.000000
# Mme           1         24.000000
# Mr            1         41.450758
#               2         32.346715
#               3         28.318910
# Mrs           1         43.208955
#               2         33.518519
#               3         32.326531
# Ms            2         28.000000
#               3               NaN
# Rev           2         41.250000
# Sir           1         49.000000
# ...

# %% [markdown]
# 取代少數稱謂

# %%
data['Title2'] = data['Title1'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','the Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],
                                        ['Miss','Mrs','Miss','Mr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mr','Mr','Mrs'])

data['Title2'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
data.groupby(['Title2'])['Age'].mean()
# Out:
# Title2
# Master     5.482642
# Miss      21.824366
# Mr        32.811056
# Mrs       36.971264
# Name: Age, dtype: float64

# %%
data.groupby(['Title2', 'Pclass'])['Age'].mean()
# Out:
# Title2  Pclass
# Master  1          6.984000
#         2          2.757273
#         3          6.090000
# Miss    1         30.131148
#         2         20.865714
#         3         17.360874
# Mr      1         42.241497
#         2         32.914966
#         3         28.318910
# Mrs     1         42.802817
#         2         33.518519
#         3         32.326531
# Name: Age, dtype: float64

# %%
pd.crosstab(data['Title2'], data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row0_col0 {
#             background-color:  #ffff66;
#         }    #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row0_col1 {
#             background-color:  #008066;
#         }    #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row0_col2 {
#             background-color:  #ffff66;
#         }    #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row0_col3 {
#             background-color:  #008066;
#         }    #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row1_col0 {
#             background-color:  #008066;
#         }    #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row1_col1 {
#             background-color:  #ffff66;
#         }    #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row1_col2 {
#             background-color:  #008066;
#         }    #T_e579ba34_8ec2_11e8_8aaa_32000d20ee01row1_col3 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_e579ba34_8ec2_11e8_8aaa_32000d20ee01" >
# <thead>    <tr>
# ...

# %%
pd.crosstab(data['Title2'], data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row0_col0 {
#             background-color:  #ffff66;
#         }    #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row0_col1 {
#             background-color:  #ffff66;
#         }    #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row0_col2 {
#             background-color:  #008066;
#         }    #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row0_col3 {
#             background-color:  #ffff66;
#         }    #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row1_col0 {
#             background-color:  #008066;
#         }    #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row1_col1 {
#             background-color:  #008066;
#         }    #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row1_col2 {
#             background-color:  #ffff66;
#         }    #T_e57e489a_8ec2_11e8_adcf_32000d20ee01row1_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_e57e489a_8ec2_11e8_adcf_32000d20ee01" >
# <thead>    <tr>
# ...

# %%
list( data.groupby(['Title2','Pclass'])['Age'].mean().iteritems() )[:3]
# Out:
# [(('Master', 1), 6.984),
#  (('Master', 2), 2.7572727272727273),
#  (('Master', 3), 6.090000000000001)]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# Family_size    1309 non-null int64
# Title1         1309 non-null object
# Title2         1309 non-null object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 153.5+ KB

# %% [markdown]
# 取出票號不是數字的部分

# %%
data['Ticket_info'] = data['Ticket'].apply(lambda x: x.replace('.', '').replace('/','').strip().split(' ')[0] if not x.isdigit() else 'X')
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket  Family_size Title1  \
# 0       3    male      1       0.0         A/5 21171            1     Mr
# 1       1  female      1       1.0          PC 17599            1    Mrs
# 2       3  female      0       1.0  STON/O2. 3101282            0   Miss
# ...

# %%
data['Ticket_info'].unique()
# Out:
# array(['A5', 'PC', 'STONO2', 'X', 'PP', 'CA', 'SCParis', 'SCA4', 'A4',
#        'SP', 'SOC', 'WC', 'SOTONOQ', 'WEP', 'STONO', 'C', 'SCPARIS',
#        'SOP', 'Fa', 'LINE', 'FCC', 'SWPP', 'SCOW', 'PPP', 'SC', 'SCAH',
#        'AS', 'SOPP', 'FC', 'SOTONO2', 'CASOTON', 'SCA3', 'STONOQ', 'AQ4',
#        'A', 'LP', 'AQ3'], dtype=object)

# %%
sns.countplot(data['Ticket_info'], hue=data['Survived'])
plt.show()

# %% [markdown]
# 填補空缺值

# %%
data[data['Embarked'].isna()]
# Out:
#       Age Cabin Embarked  Fare                                       Name  \
# 61   38.0   B28      NaN  80.0                        Icard, Miss. Amelie
# 829  62.0   B28      NaN  80.0  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Parch  PassengerId  Pclass     Sex  SibSp  Survived  Ticket  Family_size  \
# 61       0           62       1  female      0       1.0  113572            0
# 829      0          830       1  female      0       1.0  113572            0
#
#     Title1 Title2 Ticket_info
# 61    Miss   Miss           X
# 829    Mrs    Mrs           X

# %%
data['Embarked'].mode()
# Out:
# 0    S
# dtype: object

# %%
data['Embarked'] = data['Embarked'].fillna('S')

# %%
data[data['Fare'].isna()]
# Out:
#        Age Cabin Embarked  Fare                Name  Parch  PassengerId  \
# 1043  60.5   NaN        S   NaN  Storey, Mr. Thomas      0         1044
#
#       Pclass   Sex  SibSp  Survived Ticket  Family_size Title1 Title2  \
# 1043       3  male      0       NaN   3701            0     Mr     Mr
#
#      Ticket_info
# 1043           X

# %%
data['Fare'].mean()
# Out:
# 33.2954792813456

# %%
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())

# %% [markdown]
# 把 Cabin=NaN 改成 NoCabin

# %%
data['Cabin'] = data['Cabin'].apply(lambda x: str(x)[0] if not pd.isnull(x) else 'NoCabin')
data['Cabin'].unique()
# Out:
# array(['NoCabin', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
data.head()
# Out:
#     Age    Cabin Embarked     Fare  \
# 0  22.0  NoCabin        S   7.2500
# 1  38.0        C        C  71.2833
# 2  26.0  NoCabin        S   7.9250
# 3  35.0        C        S  53.1000
# 4  35.0  NoCabin        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket  Family_size Title1  \
# 0       3    male      1       0.0         A/5 21171            1     Mr
# 1       1  female      1       1.0          PC 17599            1    Mrs
# 2       3  female      0       1.0  STON/O2. 3101282            0   Miss
# ...

# %%
sns.countplot(data['Cabin'], hue=data['Survived'])
plt.show()

# %% [markdown]
# 將資料換成整數，才能餵給 sklearn

# %%
#for i in ['Sex', 'Embarked', 'Pclass', 'Title1', 'Title2', 'Cabin', 'Ticket_info']:
    #data[i] = data[i].astype('category').cat.codes
data['Sex'] = data['Sex'].astype('category').cat.codes
data['Embarked'] = data['Embarked'].astype('category').cat.codes
data['Pclass'] = data['Pclass'].astype('category').cat.codes
data['Title1'] = data['Title1'].astype('category').cat.codes
data['Title2'] = data['Title2'].astype('category').cat.codes
data['Cabin'] = data['Cabin'].astype('category').cat.codes
data['Ticket_info'] = data['Ticket_info'].astype('category').cat.codes

data.head()
# Out:
#     Age  Cabin  Embarked     Fare  \
# 0  22.0      7         2   7.2500
# 1  38.0      2         0  71.2833
# 2  26.0      7         2   7.9250
# 3  35.0      2         2  53.1000
# 4  35.0      7         2   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass  Sex  SibSp  Survived            Ticket  Family_size  Title1  \
# 0       2    1      1       0.0         A/5 21171            1      12
# 1       0    0      1       1.0          PC 17599            1      13
# 2       2    0      0       1.0  STON/O2. 3101282            0       9
# ...

# %% [markdown]
# # 用隨機森林推算年齡

# %%
#data_age_isnull = data[data['Age'].isnull()]
#data_age_notnull = data[data['Age'].notnull()]
##data_age_isnull.head()
##data_age_notnull.head()

# %% [markdown]
# 把比平均值大四倍標準差的當成 outlier

# %%
#fare_outlier = np.abs(data_age_notnull['Fare'] - data_age_notnull['Fare'].mean()) > 4 * data_age_notnull['Fare'].std()
#familiar_size_outlier = np.abs(data_age_notnull['Family_size'] - data_age_notnull['Family_size'].mean()) > 4 * data_age_notnull['Family_size'].std()
##fare_outlier
##familiar_size_outlier

# %%
#outlier = data_age_notnull[fare_outlier | familiar_size_outlier]
#outlier

# %%
#not_outlier = data_age_notnull[~(fare_outlier | familiar_size_outlier)]
#not_outlier.head()

# %%
#rf_age = RandomForestRegressor(n_estimators=2000, random_state=42)
#X_train_age = not_outlier[['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_size', 'Title1', 'Title2','Cabin','Ticket_info']]
#y_train_age = not_outlier['Age']
#rf_age.fit(X_train_age, y_train_age)

# %%
#X_test_age = data_age_isnull[['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_size', 'Title1', 'Title2','Cabin','Ticket_info']]
#y_pred_age = rf_age.predict(X_test_age)
##y_pred_age
#data_age_isnull.loc[:, 'Age'] = y_pred_age
#data_age_isnull.head()

# %%
#data_age_filled = data_age_notnull.append(data_age_isnull)
#data_age_filled.info()

# %%
#data_age_filled.sort_values(by='PassengerId')
#data_age_filled.reset_index(inplace=True, drop=True)

# %%
#X_train_all = data_age_filled[data_age_filled['Survived'].notnull()]
#X_train = X_train_all[['Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_size', 'Title2','Ticket_info','Cabin']]
#y_train = X_train_all['Survived']
#X_test_all = data_age_filled[data_age_filled['Survived'].isnull()]
#X_test = X_test_all[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_size', 'Title2','Ticket_info','Cabin']]

# %%
#rf = RandomForestClassifier(criterion='entropy', n_estimators=1000, random_state=42, n_jobs=-1)
#rf.fit(X_train, y_train)

# %%
#y_pred = rf.predict(X_test)
#y_pred

# %%
#submit = pd.DataFrame({'PassengerId':X_test_all['PassengerId'], 'Survived':y_pred})
#submit_sorted = submit.sort_values(by='PassengerId')
#submit_sorted.to_csv('unit_4_1.csv', index=False)

# %% [markdown]
# # 用 Yeh James 的方法

# %%
dataAgeNull = data[data["Age"].isnull()]
dataAgeNotNull = data[data["Age"].notnull()]
remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
                      (np.abs(dataAgeNotNull["Family_size"]-dataAgeNotNull["Family_size"].mean())>(4*dataAgeNotNull["Family_size"].std()))                     
                     ]
rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_size', 'Title1', 'Title2','Cabin','Ticket_info']
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])

ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])
dataAgeNull.loc[:,"Age"] = ageNullValues
data = dataAgeNull.append(dataAgeNotNull)
data.reset_index(inplace=True, drop=True)
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
dataTrain = data[pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])
dataTest = data[~pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])

# %%
dataTrain.columns
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Family_size', 'Title1',
#        'Title2', 'Ticket_info'],
#       dtype='object')

# %%
dataTrain = dataTrain[['Survived', 'Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_size', 'Title2','Ticket_info','Cabin']]
dataTest = dataTest[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_size', 'Title2','Ticket_info','Cabin']]

# %%
dataTrain.head()
# Out:
#      Survived   Age  Embarked     Fare  Pclass  Sex  Family_size  Title2  \
# 263       0.0  22.0         2   7.2500       2    1            1       2
# 264       1.0  38.0         0  71.2833       0    0            1       3
# 265       1.0  26.0         2   7.9250       2    0            0       1
# 266       1.0  35.0         2  53.1000       0    0            1       3
# 267       0.0  35.0         2   8.0500       2    1            0       2
#
#      Ticket_info  Cabin
# 263            2      7
# 264           14      2
# 265           31      7
# 266           36      2
# 267           36      7

# %%
rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=1000,
                             min_samples_split=12,
                             min_samples_leaf=1,
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1) 

rf.fit(dataTrain.iloc[:, 1:], dataTrain.iloc[:, 0])
print("%.4f" % rf.oob_score_)
# Out:
# 0.8294

# %%
pd.concat((pd.DataFrame(dataTrain.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
# Out:
#       variable  importance
# 4          Sex    0.264997
# 2         Fare    0.163890
# 6       Title2    0.152698
# 0          Age    0.131891
# 3       Pclass    0.091048
# 5  Family_size    0.070839
# 8        Cabin    0.067029
# 7  Ticket_info    0.031735
# 1     Embarked    0.025873

# %%
rf_res =  rf.predict(dataTest)
#submit_james['Survived'] = rf_res
submit_james = pd.DataFrame({'PassengerId':test['PassengerId'], 'Survived':rf_res})
submit_james['Survived'] = submit_james['Survived'].astype(int)
submit_james
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         1
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
submit_james.to_csv('submit_james.csv', index= False)
